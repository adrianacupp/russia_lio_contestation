# %% [markdown]
# ## Import Dataset and EDA

# %%
#Modules
import pandas as pd
import numpy as np
import pickle
import re

# %% [markdown]
# compare your dataset with Kremlin to see what url actually overlap. they cannot overlap cause url from kremlin are all from http://kremlin.ru/events/president/news

# %% [markdown]
# ## data clean

# %% [markdown]
# ### messages to the federal assembly

# %%
#messages to the federal assembly (mtfa)
mtfa = pd.read_pickle('data/corpus_adriana/corpus_president_of_russia/messages_to_federal_assembly.pkl')
mtfa.info()

# %%
#detect the fist part before the actual speech
for i in range(14):
    text = mtfa['text'][i]
    match = re.search(r': Уважаем|: Добрый', text)
    if match:
        text_before = text[:match.start()]
        print(f"Row {i}: {text_before}")
        print(f"Number of characters: {len(text_before)}")
        print(f"--------------------------")
    else:
        print(f"Row {i}: No match found.")

# %%
#detect the last part after the actual speech
for i in range(len(mtfa)):
    text = mtfa['text'][i]
    match = re.search(r'Опубликован.*$', text)
    if match:
        text_after = match.group(0)
        print(f"Row {i}: {text_after}")
        print(f"Number of characters: {len(text_after)}")
        print(f"--------------------------")
    else:
        print(f"Row {i}: No match found.")

# %%
# alternative way to detect the last words
for i in range(14):
    text = mtfa['text'][i]
    last_33_words = ' '.join(text.split()[-33:])
    print(f"Row {i}: {last_33_words}")

# %%
def clean(text):
    # replace actual newline characters \n with a space
    text = re.sub(r'\n', ' ', text)
    #replace last part with a space
    match = re.search(r'Опубликован.*$', text)
    if match:
        text_after = match.group(0)
        text = text.replace(text_after, ' ')
    #replace initial part with a white space
    match = re.search(r'Уважаем|Добрый', text)
    if match:
        text = ' ' + text[match.start():]
    
    return text.strip()

# %%
mtfa['text_clean'] = mtfa['text'].map(clean)
mtfa['text_clean']

# %%
# after applying the transformation
for i in range(14):
    text = mtfa['text_clean'][i]
    last_33_words = ' '.join(text.split()[-33:])
    print(f"Row {i}: {last_33_words}")

# %%
# Before cleaning
for i in range(len(mtfa)):
    text = mtfa['text'][i]
    num_words = len(text.split())
    print(f"Row {i}: Number of words before cleaning: {num_words}")
print('-----------------------')
# After cleaning
for i in range(len(mtfa)):
    text = mtfa['text_clean'][i]
    num_words = len(text.split())
    print(f"Row {i}: Number of words after cleaning: {num_words}")

# %% [markdown]
# identify and remove noise with regex

# %%
mtfa['text_clean'].iloc[0]

# %%
#Identify Noise with Regular Expression
import re 
RE_SUSPICIOUS = re.compile(r'[xa0#<>{}\[\]\\]')

def impurity(text, min_len=10): 
    """returns the share of suspicious characters in a text""" 
    if text == None or len(text) < min_len: 
        return 0 
    else: 
        return len(RE_SUSPICIOUS.findall(text))/len(text)

# %%
mtfa['impurity'] = mtfa['text_clean'].apply(impurity)

# %%
mtfa['impurity'].sort_values(ascending=False).value_counts()

# %%
# get the top 3 records 
#critical part is just []...I will leave as it is for the moment
mtfa[['text_clean', 'impurity']].sort_values(by='impurity', ascending=False).head(3)

# %%
def clean_2(text):
    # replace everything non-alphanumeric with a space
    text = re.sub(r'\W+', ' ', text)
    # replace two or more dots with one
    text = re.sub(r'\.{2,}', ' ', text)
    # replace sequences of white spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    # convert text to lowercase
    text = text.lower()
    # replace \xa0 with a white space
    text = re.sub(r'\xa0', ' ', text)
    return text.strip()

# %%
mtfa['text_clean'] = mtfa['text_clean'].map(clean_2)
mtfa['text_clean']

# %%
mtfa['text_clean'].iloc[0]

# %%
mtfa.drop(columns=['impurity'], inplace=True)

# %%
mtfa['speaker'] = mtfa['speaker'].replace({'* * *, В.Путин:': 'В.Путин:', 'Д.Медведев:, * * *': 'Д.Медведев:'})

# %%
#save the dataset (overwrite the previous one)
mtfa.to_pickle('data/corpus_adriana/corpus_president_of_russia/messages_to_federal_assembly.pkl')

# %%
mtfa = pd.read_pickle('data/corpus_adriana/corpus_president_of_russia/messages_to_federal_assembly.pkl')
mtfa
# Out:
#           date                                                URL  \
# 0   2020-01-15  http://kremlin.ru/events/president/transcripts...
# 1   2015-12-03  http://kremlin.ru/events/president/transcripts...
# 2   2013-12-12  http://kremlin.ru/events/president/transcripts...
# 3   2012-12-12  http://kremlin.ru/events/president/transcripts...
# 4   2016-12-01  http://kremlin.ru/events/president/transcripts...
# 5   2018-03-01  http://kremlin.ru/events/president/transcripts...
# 6   2009-11-12  http://kremlin.ru/events/president/transcripts...
# 7   2021-04-21  http://kremlin.ru/events/president/transcripts...
# 8   2014-12-04  http://kremlin.ru/events/president/transcripts...
# 9   2019-02-20  http://kremlin.ru/events/president/transcripts...
# 10  2008-11-05  http://kremlin.ru/events/president/transcripts...
# 11  2023-02-21  http://kremlin.ru/events/president/transcripts...
# 12  2011-12-22  http://kremlin.ru/events/president/transcripts...
# 13  2010-11-30  http://kremlin.ru/events/president/transcripts...
#
#                                                 title       speaker  \
# 0           Послание Президента Федеральному Собранию      В.Путин:
# 1           Послание Президента Федеральному Собранию      В.Путин:
# 2           Послание Президента Федеральному Собранию      В.Путин:
# 3           Послание Президента Федеральному Собранию      В.Путин:
# 4           Послание Президента Федеральному Собранию      В.Путин:
# 5           Послание Президента Федеральному Собранию      В.Путин:
# 6   Послание Федеральному Собранию Российской Феде...   Д.Медведев:
# 7           Послание Президента Федеральному Собранию     В.Путин:
# 8           Послание Президента Федеральному Собранию      В.Путин:
# 9           Послание Президента Федеральному Собранию      В.Путин:
# 10  Послание Федеральному Собранию Российской Феде...   Д.Медведев:
# 11          Послание Президента Федеральному Собранию      В.Путин:
# 12          Послание Президента Федеральному Собранию   Д.Медведев:
# 13          Послание Президента Федеральному Собранию  Д.Медведев:
#
#                                                  text  \
# 0   Все материалы сайта доступны по лицензии: Crea...
# 1   Все материалы сайта доступны по лицензии: Crea...
# 2   Все материалы сайта доступны по лицензии: Crea...
# 3   Все материалы сайта доступны по лицензии: Crea...
# 4   Все материалы сайта доступны по лицензии: Crea...
# 5   Все материалы сайта доступны по лицензии: Crea...
# 6   Все материалы сайта доступны по лицензии: Crea...
# 7   Все материалы сайта доступны по лицензии: Crea...
# 8   Все материалы сайта доступны по лицензии: Crea...
# 9   Все материалы сайта доступны по лицензии: Crea...
# 10  Все материалы сайта доступны по лицензии: Crea...
# 11  Все материалы сайта доступны по лицензии: Crea...
# 12  Все материалы сайта доступны по лицензии: Crea...
# 13  Все материалы сайта доступны по лицензии: Crea...
#
#                                            text_clean
# 0   уважаемые члены совета федерации и депутаты го...
# 1   уважаемые члены совета федерации уважаемые деп...
# 2   уважаемые граждане россии уважаемые члены сове...
# 3   уважаемые граждане россии уважаемые члены сове...
# 4   добрый день уважаемые коллеги уважаемые члены ...
# 5   уважаемые граждане россии уважаемые члены сове...
# 6   уважаемые граждане россии уважаемые депутаты и...
# 7   уважаемые члены совета федерации депутаты госу...
# 8   уважаемые члены совета федерации депутаты госу...
# 9   уважаемые члены совета федерации уважаемые деп...
# 10  уважаемые депутаты и члены совета федерации на...
# 11  добрый день уважаемые депутаты федерального со...
# 12  уважаемые граждане россии уважаемые депутаты и...
# 13  уважаемые граждане россии уважаемые депутаты и...

# %%
for i in range(len(mtfa)):
    text = mtfa['text_clean'][i]
    num_words = len(text.split())
    print(f"Row {i}: Number of words after cleaning: {num_words}")
# Out:
# Row 0: Number of words after cleaning: 7575
# Row 1: Number of words after cleaning: 6577
# Row 2: Number of words after cleaning: 7959
# Row 3: Number of words after cleaning: 9726
# Row 4: Number of words after cleaning: 7766
# Row 5: Number of words after cleaning: 12812
# Row 6: Number of words after cleaning: 9891
# Row 7: Number of words after cleaning: 7949
# Row 8: Number of words after cleaning: 7074
# Row 9: Number of words after cleaning: 9876
# Row 10: Number of words after cleaning: 8493
# Row 11: Number of words after cleaning: 10609
# Row 12: Number of words after cleaning: 6720
# Row 13: Number of words after cleaning: 7320

# %% [markdown]
# ### statements on major issues

# %%
# statements on major issues (somi)
somi = pd.read_pickle('data/corpus_adriana/corpus_president_of_russia/statements_on_major_issues.pkl')
somi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67656 entries, 0 to 67655
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     67656 non-null  object
#  1   url      67656 non-null  object
#  2   title    67656 non-null  object
#  3   speaker  61807 non-null  object
#  4   text     67656 non-null  object
# dtypes: object(5)
# memory usage: 2.6+ MB

# %%
somi['speaker'] = somi['speaker'].replace({'В.Путин': 'В.Путин:', 'Putin:':'В.Путин:', 'Д.Медведев': 'Д.Медведев:'})

# %%
#speakers 
somi.speaker.value_counts()
# Out:
# В.Путин:                                            24971
# Д.Медведев:                                          9511
# Вопрос:                                               914
# Д.Песков:                                             364
# Ф.Лукьянов:                                           341
#                                                     ...
# А.Чачава:                                               1
# Х.-В.Штейнфельд:                                        1
# Из зала:                                                1
# В.Мельниченко                                           1
# Стенографический\nотчёт о заседании РОК «Победа»        1
# Name: speaker, Length: 1756, dtype: int64

# %%
somi.speaker.isna().value_counts()
# Out:
# False    61807
# True      5849
# Name: speaker, dtype: int64

# %%
somi.loc[(somi['speaker'].isna()) & (somi['text'].str.contains('Д.Медведев:')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['text'].str.contains('В.Путин')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['text'].str.contains('Вопрос:')), 'speaker'] = 'Вопрос:'

# %%
#for url with only one speaker medvedev
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/1')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/2088')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/976')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/8596')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/787')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/7685')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/634')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/633')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/5989')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/591')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/5566')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/5552')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/2283')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/859')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/2445')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/2592')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/3257')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/3387')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/3805')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/3921')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/4186')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/4336')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/4358')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/5209')), 'speaker'] = 'Д.Медведев:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/5269')), 'speaker'] = 'Д.Медведев:'

# %%
#for url with only one speaker putin
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/2$')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22147')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22197')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22204')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22237')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22279')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22281')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22338')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22384')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22394')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22395')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22401')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22442')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/63527')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22403')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22545')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22546')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22549')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22714')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22777')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22838')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22949')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22979')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23009')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23066')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23619')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/63888')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23547')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23656')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23791')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23820')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23857')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/2393')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/24642')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/24809')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/24864')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22619')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23407')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23437')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23503')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/23512')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/49957')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/54467')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/63560')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/64270')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/67551')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/68366')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/47045')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/69299')), 'speaker'] = 'В.Путин:'
somi.loc[(somi['speaker'].isna()) & (somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/67044')), 'speaker'] = 'В.Путин:'

# %%
somi.speaker.isna().value_counts()
# Out:
# False    65401
# True      2255
# Name: speaker, dtype: int64

# %%
condition_1 = somi[somi['speaker'].isna()]['text'].str.contains('Все материалы')
condition_2 = somi[somi['speaker'].isna()]['text'].str.contains('\* \* \*')
condition_3 = somi[somi['speaker'].isna()]['text'].str.strip().str.len() == 0
condition_4 = somi[somi['speaker'].isna()]['text'].str.contains('Глава государства|Глава|Президент России|Президент')
condition_5 = somi[somi['speaker'].isna()]['text'].str.contains('http://')
condition_6 = somi[somi['speaker'].isna()]['text'].str.contains('Дата публикации')
condition_7 = somi[somi['speaker'].isna()]['text'].str.contains('Ссылка на материал:')
condition_8 = somi[somi['speaker'].isna()]['text'].str.contains('Опубликован в разделе|Опубликован в разделах|Официальный сайт')
condition_9 = somi[somi['speaker'].isna()]['text'].str.contains('Владимир Путин|Дмитрий Медведев')
condition_10 = somi[somi['speaker'].isna()]['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/6769|http://kremlin.ru/events/president/transcripts/statements/6074')

filtered_somi = somi[~(somi['speaker'].isna() & 
                       (condition_1 | condition_2 | condition_3| condition_4| condition_5| condition_6| condition_7|condition_8|condition_9|condition_10))]

# %%
filtered_somi.speaker.isna().value_counts()
# Out:
# False    65401
# True       665
# Name: speaker, dtype: int64

# %%
url_pattern = 'http://kremlin.ru/events/president/transcripts/statements/2134'
filtered_somi.loc[(filtered_somi['speaker'].isna()) & (filtered_somi['url'].str.contains(url_pattern))]
# Out:
#              date                                                url  \
# 47372  2008-11-20  http://kremlin.ru/events/president/transcripts...
# 47373  2008-11-20  http://kremlin.ru/events/president/transcripts...
# 47375  2008-11-20  http://kremlin.ru/events/president/transcripts...
# 47376  2008-11-20  http://kremlin.ru/events/president/transcripts...
# 47377  2008-11-20  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 47539  2008-11-20  http://kremlin.ru/events/president/transcripts...
# 47540  2008-11-20  http://kremlin.ru/events/president/transcripts...
# 47541  2008-11-20  http://kremlin.ru/events/president/transcripts...
# 47542  2008-11-20  http://kremlin.ru/events/president/transcripts...
# 47548  2008-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                 title speaker  \
# 47372  Х съезд партии «Единая Россия»    None
# 47373  Х съезд партии «Единая Россия»    None
# 47375  Х съезд партии «Единая Россия»    None
# 47376  Х съезд партии «Единая Россия»    None
# 47377  Х съезд партии «Единая Россия»    None
# ...                               ...     ...
# 47539  Х съезд партии «Единая Россия»    None
# 47540  Х съезд партии «Единая Россия»    None
# 47541  Х съезд партии «Единая Россия»    None
# 47542  Х съезд партии «Единая Россия»    None
# 47548  Х съезд партии «Единая Россия»    None
#
#                                                     text
# 47372  Главная тема съезда – долгосрочная стратегия р...
# 47373  На форуме собрались более шестисот делегатов и...
# 47375  Рад приветствовать делегатов и гостей съезда. ...
# 47376  Прежде всего мне бы хотелось поблагодарить вас...
# 47377  Благодаря парламентскому влиянию вашей партии ...
# ...                                                  ...
# 47539  Партия «Единая Россия» отстаивала и будет отст...
# 47540              Мы с вами будем это делать и сделаем.
# 47541                             Благодарю за внимание.
# 47542                         Опубликован в разделах:  ,
# 47548                     Х съезд партии «Единая Россия»
#
# [167 rows x 5 columns]

# %%
#the breakpoint
break_point = filtered_somi.loc[(filtered_somi['speaker'].isna()) & (filtered_somi['url'].str.contains(url_pattern)) & (filtered_somi['text'].str.contains('<…>'))]

# %%
# loop over the rows that match the filter criteria
for idx, row in filtered_somi.loc[(filtered_somi['speaker'].isna()) & (filtered_somi['url'].str.contains(url_pattern))].iterrows():
    if str(idx) < str(break_point):
        filtered_somi.at[idx, 'speaker'] = 'Medvedev:'
    else:
        filtered_somi.at[idx, 'speaker'] = 'Putin:'

# %%
filtered_somi.speaker.isna().value_counts()
# Out:
# False    65568
# True       498
# Name: speaker, dtype: int64

# %%
filtered_somi.loc[(filtered_somi['speaker'].isna()) & (filtered_somi['text'].str.contains('Г.Шрёдер:')), 'speaker'] = 'Г.Шрёдер:'
# Out:
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_4286/3325061389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_somi.loc[(filtered_somi['speaker'].isna()) & (filtered_somi['text'].str.contains('Г.Шрёдер:')), 'speaker'] = 'Г.Шрёдер:'

# %%
row_to_fill = filtered_somi.loc[filtered_somi['url'].str.contains('http://kremlin.ru/events/president/transcripts/statements/22950')].copy()
row_to_fill['speaker'].fillna(method='ffill', inplace=True)
filtered_somi.loc[row_to_fill.index] = row_to_fill
# Out:
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_4286/1007969576.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_somi.loc[row_to_fill.index] = row_to_fill

# %%
filtered_somi.speaker.isna().value_counts()
# Out:
# False    65623
# True       443
# Name: speaker, dtype: int64

# %%
filtered_somi.drop(filtered_somi.loc[filtered_somi['speaker'].isna() & (filtered_somi['date'] < '2014-01-01')].index, inplace=True)
# Out:
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_4286/84537534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_somi.drop(filtered_somi.loc[filtered_somi['speaker'].isna() & (filtered_somi['date'] < '2014-01-01')].index, inplace=True)

# %%
filtered_somi.speaker.isna().value_counts()
# Out:
# False    65623
# True       271
# Name: speaker, dtype: int64

# %%
filtered_somi.drop(filtered_somi.loc[filtered_somi['speaker'].isna()].index, inplace=True)
# Out:
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_4286/2892791293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_somi.drop(filtered_somi.loc[filtered_somi['speaker'].isna()].index, inplace=True)

# %%
filtered_somi.reset_index(drop=True)
# Out:
#              date                                                url  \
# 0      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 1      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 2      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 3      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 4      2010-03-29  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 65618  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 65619  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 65620  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 65621  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 65622  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                        title       speaker  \
# 0      Совещание в связи с терактами в метро   Д.Медведев:
# 1      Совещание в связи с терактами в метро   Д.Медведев:
# 2      Совещание в связи с терактами в метро  А.Бортников:
# 3      Совещание в связи с терактами в метро  А.Бортников:
# 4      Совещание в связи с терактами в метро  А.Бортников:
# ...                                      ...           ...
# 65618   Инвестиционный форум «Россия зовёт!»      В.Путин:
# 65619   Инвестиционный форум «Россия зовёт!»      В.Путин:
# 65620   Инвестиционный форум «Россия зовёт!»      В.Путин:
# 65621   Инвестиционный форум «Россия зовёт!»      В.Путин:
# 65622   Инвестиционный форум «Россия зовёт!»      В.Путин:
#
#                                                     text
# 0      : Сегодня в московском метро произошли террори...
# 1      Теперь по сути происшедшего. Первый – Александ...
# 2      Дмитрий Анатольевич, сегодня в 7.57 произошел ...
# 3      По предварительной взрывотехнической экспертиз...
# 4      По нашей предварительной версии, эти террорист...
# ...                                                  ...
# 65618
# 65619                Официальный сайт президента России:
# 65620               Инвестиционный форум «Россия зовёт!»
# 65621  http://kremlin.ru/events/president/transcripts...
# 65622           Администрация Президента России 2023 год
#
# [65623 rows x 5 columns]

# %%
speaker_counts = filtered_somi.speaker.value_counts()

# %%
# Filter the speaker counts to keep only those with a count of 200 or greater, excluding 'Вопрос:' and '* * *'
filtered_speaker_counts = speaker_counts[(speaker_counts >= 200) & (speaker_counts.index != 'Вопрос:') & (speaker_counts.index != '* * *')]
# Create a list of the speakers to keep
speakers_to_keep = list(filtered_speaker_counts.index)
# Filter the original DataFrame to keep only rows with the desired speakers. assign a new df
somi_filtered_speaker = filtered_somi[filtered_somi['speaker'].isin(speakers_to_keep)]

# %%
somi_filtered_speaker.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41023 entries, 8 to 67655
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     41023 non-null  object
#  1   url      41023 non-null  object
#  2   title    41023 non-null  object
#  3   speaker  41023 non-null  object
#  4   text     41023 non-null  object
# dtypes: object(5)
# memory usage: 1.9+ MB

# %%
somi_filtered_speaker
# Out:
#              date                                                url  \
# 8      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 9      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 14     2010-03-29  http://kremlin.ru/events/president/transcripts...
# 15     2010-03-29  http://kremlin.ru/events/president/transcripts...
# 16     2010-03-29  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 67651  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 67652  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 67653  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 67654  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 67655  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                        title      speaker  \
# 8      Совещание в связи с терактами в метро  Д.Медведев:
# 9      Совещание в связи с терактами в метро  Д.Медведев:
# 14     Совещание в связи с терактами в метро  Д.Медведев:
# 15     Совещание в связи с терактами в метро     С.Шойгу:
# 16     Совещание в связи с терактами в метро     С.Шойгу:
# ...                                      ...          ...
# 67651   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 67652   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 67653   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 67654   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 67655   Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                                     text
# 8      : Сегодня в московском метро произошли террори...
# 9      Теперь по сути происшедшего. Первый – Александ...
# 14     , что сделали спасатели, какова сейчас ситуаци...
# 15     Дмитрий Анатольевич, все системы сработали дос...
# 16     Задействованы были все необходимые силы: по ли...
# ...                                                  ...
# 67651
# 67652                Официальный сайт президента России:
# 67653               Инвестиционный форум «Россия зовёт!»
# 67654  http://kremlin.ru/events/president/transcripts...
# 67655           Администрация Президента России 2023 год
#
# [41023 rows x 5 columns]

# %%
#assign this df before continuing the cleaning
somi_filtered_speaker.to_pickle('data/corpus_adriana/corpus_president_of_russia/statements_on_major_issues.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #assign this df before continuing the cleaning
# ----> 2 somi_filtered_speaker.to_pickle('data/corpus_adriana/corpus_president_of_russia/statements_on_major_issues.pkl')
#
# NameError: name 'somi_filtered_speaker' is not defined

# %% [markdown]
# ##### continue the data cleaning of somi corpus

# %%
#read the df
somi = pd.read_pickle('data/corpus_adriana/corpus_president_of_russia/statements_on_major_issues.pkl')
somi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41023 entries, 8 to 67655
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     41023 non-null  object
#  1   url      41023 non-null  object
#  2   title    41023 non-null  object
#  3   speaker  41023 non-null  object
#  4   text     41023 non-null  object
# dtypes: object(5)
# memory usage: 1.9+ MB

# %%
somi.reset_index(drop=True, inplace=True)

# %%
somi
# Out:
#              date                                                url  \
# 0      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 1      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 2      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 3      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 4      2010-03-29  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 41018  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 41019  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 41020  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 41021  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 41022  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                        title      speaker  \
# 0      Совещание в связи с терактами в метро  Д.Медведев:
# 1      Совещание в связи с терактами в метро  Д.Медведев:
# 2      Совещание в связи с терактами в метро  Д.Медведев:
# 3      Совещание в связи с терактами в метро     С.Шойгу:
# 4      Совещание в связи с терактами в метро     С.Шойгу:
# ...                                      ...          ...
# 41018   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 41019   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 41020   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 41021   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 41022   Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                                     text
# 0      : Сегодня в московском метро произошли террори...
# 1      Теперь по сути происшедшего. Первый – Александ...
# 2      , что сделали спасатели, какова сейчас ситуаци...
# 3      Дмитрий Анатольевич, все системы сработали дос...
# 4      Задействованы были все необходимые силы: по ли...
# ...                                                  ...
# 41018
# 41019                Официальный сайт президента России:
# 41020               Инвестиционный форум «Россия зовёт!»
# 41021  http://kremlin.ru/events/president/transcripts...
# 41022           Администрация Президента России 2023 год
#
# [41023 rows x 5 columns]

# %%
somi['text'].str.contains('Путин:|:Медведев').value_counts()
# Out:
# False    40944
# True        79
# Name: text, dtype: int64

# %%
filtered_text = somi[somi['text'].str.contains('Ссылка на материал:')]
word_counts = filtered_text['text'].str.split().str.len()
word_counts
# Out:
# 26       3
# 131      3
# 166      3
# 195      3
# 722      3
#         ..
# 40675    3
# 40770    3
# 40794    3
# 40842    3
# 41016    3
# Name: text, Length: 469, dtype: int64

# %%
somi[somi['text'].str.contains('Официальный сайт')]
# Out:
#              date                                                url  \
# 29     2010-03-29  http://kremlin.ru/events/president/transcripts...
# 134    2016-01-12  http://kremlin.ru/events/president/transcripts...
# 169    2009-06-06  http://kremlin.ru/events/president/transcripts...
# 198    2008-09-11  http://kremlin.ru/events/president/transcripts...
# 725    2004-01-27  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 40678  2010-03-29  http://kremlin.ru/events/president/transcripts...
# 40773  2003-12-03  http://kremlin.ru/events/president/transcripts...
# 40797  2016-10-05  http://kremlin.ru/events/president/transcripts...
# 40845  2014-03-21  http://kremlin.ru/events/president/transcripts...
# 41019  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                                    title      speaker  \
# 29                 Совещание в связи с терактами в метро  Д.Медведев:
# 134             Интервью немецкому изданию Bild. Часть 2     Реплика:
# 169    Выступление на заседании Всемирного зернового ...  Д.Медведев:
# 198    Вступительное слово на совещании по вопросам с...  Д.Медведев:
# 725    Выступление на заседании президиума Государств...     В.Путин:
# ...                                                  ...          ...
# 40678  Дмитрий Медведев почтил память жертв взрывов в...  Д.Медведев:
# 40773  Вступительное слово на заседании Совета Безопа...     В.Путин:
# 40797     Встреча с сотрудниками Службы внешней разведки     В.Путин:
# 40845                 Расширенное заседание коллегии МВД     В.Путин:
# 41019               Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                       text
# 29     Официальный сайт президента России:
# 134    Официальный сайт президента России:
# 169    Официальный сайт президента России:
# 198    Официальный сайт президента России:
# 725    Официальный сайт президента России:
# ...                                    ...
# 40678  Официальный сайт президента России:
# 40773  Официальный сайт президента России:
# 40797  Официальный сайт президента России:
# 40845  Официальный сайт президента России:
# 41019  Официальный сайт президента России:
#
# [469 rows x 5 columns]

# %%
condition_1 = somi['text'].str.contains('Все материалы')
condition_2 = somi['text'].str.strip().str.len() == 0
condition_3 = somi['text'].str.contains('\* \* \*')
condition_4 = somi['text'].str.contains('http://')
condition_5 = somi['text'].str.contains('Дата публикации')
condition_6 = somi['text'].str.contains('Ссылка на материал:')
condition_7 = somi['text'].str.contains('Официальный сайт')
filtered_somi = somi[~((condition_1 | condition_2 | condition_3| condition_4| condition_5| condition_6| condition_7))]

# %%
filtered_somi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37589 entries, 0 to 41022
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     37589 non-null  object
#  1   url      37589 non-null  object
#  2   title    37589 non-null  object
#  3   speaker  37589 non-null  object
#  4   text     37589 non-null  object
# dtypes: object(5)
# memory usage: 1.7+ MB

# %%
filtered_somi.reset_index(drop=True, inplace=True)

# %%
filtered_somi
# Out:
#              date                                                url  \
# 0      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 1      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 2      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 3      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 4      2010-03-29  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 37584  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37585  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37586  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37587  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37588  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                        title      speaker  \
# 0      Совещание в связи с терактами в метро  Д.Медведев:
# 1      Совещание в связи с терактами в метро  Д.Медведев:
# 2      Совещание в связи с терактами в метро  Д.Медведев:
# 3      Совещание в связи с терактами в метро     С.Шойгу:
# 4      Совещание в связи с терактами в метро     С.Шойгу:
# ...                                      ...          ...
# 37584   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37585   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37586   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37587   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37588   Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                                     text
# 0      : Сегодня в московском метро произошли террори...
# 1      Теперь по сути происшедшего. Первый – Александ...
# 2      , что сделали спасатели, какова сейчас ситуаци...
# 3      Дмитрий Анатольевич, все системы сработали дос...
# 4      Задействованы были все необходимые силы: по ли...
# ...                                                  ...
# 37584                              Спасибо\nВам большое.
# 37585                               Спасибо вам большое.
# 37586                         Опубликован в разделах:  ,
# 37587               Инвестиционный форум «Россия зовёт!»
# 37588           Администрация Президента России 2023 год
#
# [37589 rows x 5 columns]

# %%
def clean(text):
    # replace actual newline characters \n with a space
    text = re.sub(r'\n', ' ', text)
    # replace everything non-alphanumeric with a space
    text = re.sub(r'\W+', ' ', text)
    # replace two or more dots with one
    text = re.sub(r'\.{2,}', ' ', text)
    # replace sequences of white spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    # convert text to lowercase
    text = text.lower()
    # replace \xa0 with a white space
    text = re.sub(r'\xa0', ' ', text)
    #replace Д.Медведев:|В.Путин: with a white space
    text = re.sub(r'(Д\.Медведев:|В\.Путин:)', ' ', text)
    return text.strip()

# %%
filtered_somi_copy = filtered_somi.copy()
filtered_somi_copy.loc[:, 'text_clean'] = filtered_somi['text'].map(clean)

# %%
filtered_somi_copy
# Out:
#              date                                                url  \
# 0      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 1      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 2      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 3      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 4      2010-03-29  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 37582  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37583  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37584  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37585  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37587  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                        title      speaker  \
# 0      Совещание в связи с терактами в метро  Д.Медведев:
# 1      Совещание в связи с терактами в метро  Д.Медведев:
# 2      Совещание в связи с терактами в метро  Д.Медведев:
# 3      Совещание в связи с терактами в метро     С.Шойгу:
# 4      Совещание в связи с терактами в метро     С.Шойгу:
# ...                                      ...          ...
# 37582   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37583   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37584   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37585   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37587   Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                                     text  \
# 0      : Сегодня в московском метро произошли террори...
# 1      Теперь по сути происшедшего. Первый – Александ...
# 2      , что сделали спасатели, какова сейчас ситуаци...
# 3      Дмитрий Анатольевич, все системы сработали дос...
# 4      Задействованы были все необходимые силы: по ли...
# ...                                                  ...
# 37582  В отношении инфраструктуры, Вы знаете, у нас е...
# 37583  А Вам\nя желаю всего самого доброго – и в Ваше...
# 37584                              Спасибо\nВам большое.
# 37585                               Спасибо вам большое.
# 37587               Инвестиционный форум «Россия зовёт!»
#
#                                               text_clean
# 0      сегодня в московском метро произошли террорист...
# 1      теперь по сути происшедшего первый александр в...
# 2      что сделали спасатели какова сейчас ситуация э...
# 3      дмитрий анатольевич все системы сработали дост...
# 4      задействованы были все необходимые силы по лин...
# ...                                                  ...
# 37582  в отношении инфраструктуры вы знаете у нас ест...
# 37583  а вам я желаю всего самого доброго и в вашей п...
# 37584                                спасибо вам большое
# 37585                                спасибо вам большое
# 37587                  инвестиционный форум россия зовёт
#
# [36766 rows x 6 columns]

# %%
filtered_somi_copy[filtered_somi_copy['text_clean'].str.contains('администрация президента россии')]
# Out:
#              date                                                url  \
# 25     2010-03-29  http://kremlin.ru/events/president/transcripts...
# 122    2016-01-12  http://kremlin.ru/events/president/transcripts...
# 149    2009-06-06  http://kremlin.ru/events/president/transcripts...
# 170    2008-09-11  http://kremlin.ru/events/president/transcripts...
# 689    2004-01-27  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 37273  2010-03-29  http://kremlin.ru/events/president/transcripts...
# 37360  2003-12-03  http://kremlin.ru/events/president/transcripts...
# 37378  2016-10-05  http://kremlin.ru/events/president/transcripts...
# 37420  2014-03-21  http://kremlin.ru/events/president/transcripts...
# 37588  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                                    title      speaker  \
# 25                 Совещание в связи с терактами в метро  Д.Медведев:
# 122             Интервью немецкому изданию Bild. Часть 2     Реплика:
# 149    Выступление на заседании Всемирного зернового ...  Д.Медведев:
# 170    Вступительное слово на совещании по вопросам с...  Д.Медведев:
# 689    Выступление на заседании президиума Государств...     В.Путин:
# ...                                                  ...          ...
# 37273  Дмитрий Медведев почтил память жертв взрывов в...  Д.Медведев:
# 37360  Вступительное слово на заседании Совета Безопа...     В.Путин:
# 37378     Встреча с сотрудниками Службы внешней разведки     В.Путин:
# 37420                 Расширенное заседание коллегии МВД     В.Путин:
# 37588               Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                            text  \
# 25     Администрация Президента России 2023 год
# 122    Администрация Президента России 2023 год
# 149    Администрация Президента России 2023 год
# 170    Администрация Президента России 2023 год
# 689    Администрация Президента России 2023 год
# ...                                         ...
# 37273  Администрация Президента России 2023 год
# 37360  Администрация Президента России 2023 год
# 37378  Администрация Президента России 2023 год
# 37420  Администрация Президента России 2023 год
# 37588  Администрация Президента России 2023 год
#
#                                      text_clean
# 25     администрация президента россии 2023 год
# 122    администрация президента россии 2023 год
# 149    администрация президента россии 2023 год
# 170    администрация президента россии 2023 год
# 689    администрация президента россии 2023 год
# ...                                         ...
# 37273  администрация президента россии 2023 год
# 37360  администрация президента россии 2023 год
# 37378  администрация президента россии 2023 год
# 37420  администрация президента россии 2023 год
# 37588  администрация президента россии 2023 год
#
# [469 rows x 6 columns]

# %%
filtered_somi_copy[filtered_somi_copy['text_clean'].str.contains('опубликован в разделах')]
# Out:
#              date                                                url  \
# 23     2010-03-29  http://kremlin.ru/events/president/transcripts...
# 120    2016-01-12  http://kremlin.ru/events/president/transcripts...
# 732    2019-07-09  http://kremlin.ru/events/president/transcripts...
# 830    2011-11-21  http://kremlin.ru/events/president/transcripts...
# 915    2018-07-19  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 37259  2022-09-21  http://kremlin.ru/events/president/transcripts...
# 37271  2010-03-29  http://kremlin.ru/events/president/transcripts...
# 37376  2016-10-05  http://kremlin.ru/events/president/transcripts...
# 37418  2014-03-21  http://kremlin.ru/events/president/transcripts...
# 37586  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                                    title      speaker  \
# 23                 Совещание в связи с терактами в метро  Д.Медведев:
# 120             Интервью немецкому изданию Bild. Часть 2     Реплика:
# 732    II Глобальный саммит по производству и индустр...     В.Путин:
# 830           Встреча с офицерами Южного военного округа  Д.Медведев:
# 915    Совещание послов и постоянных представителей Р...     В.Путин:
# ...                                                  ...          ...
# 37259          Обращение Президента Российской Федерации     В.Путин:
# 37271  Дмитрий Медведев почтил память жертв взрывов в...  Д.Медведев:
# 37376     Встреча с сотрудниками Службы внешней разведки     В.Путин:
# 37418                 Расширенное заседание коллегии МВД     В.Путин:
# 37586               Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                    text              text_clean
# 23     Опубликован в разделах:  ,  ,  ,  опубликован в разделах
# 120          Опубликован в разделах:  ,  опубликован в разделах
# 732          Опубликован в разделах:  ,  опубликован в разделах
# 830          Опубликован в разделах:  ,  опубликован в разделах
# 915          Опубликован в разделах:  ,  опубликован в разделах
# ...                                 ...                     ...
# 37259        Опубликован в разделах:  ,  опубликован в разделах
# 37271        Опубликован в разделах:  ,  опубликован в разделах
# 37376        Опубликован в разделах:  ,  опубликован в разделах
# 37418        Опубликован в разделах:  ,  опубликован в разделах
# 37586        Опубликован в разделах:  ,  опубликован в разделах
#
# [354 rows x 6 columns]

# %%
condition_1 = filtered_somi_copy['text_clean'].str.contains('опубликован в разделах')
condition_2 = filtered_somi_copy['text_clean'].str.contains('администрация президента россии')
filtered_somi = filtered_somi_copy[~((condition_1 | condition_2))]

# %%
filtered_somi
# Out:
#              date                                                url  \
# 0      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 1      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 2      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 3      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 4      2010-03-29  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 37582  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37583  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37584  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37585  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37587  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                        title      speaker  \
# 0      Совещание в связи с терактами в метро  Д.Медведев:
# 1      Совещание в связи с терактами в метро  Д.Медведев:
# 2      Совещание в связи с терактами в метро  Д.Медведев:
# 3      Совещание в связи с терактами в метро     С.Шойгу:
# 4      Совещание в связи с терактами в метро     С.Шойгу:
# ...                                      ...          ...
# 37582   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37583   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37584   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37585   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37587   Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                                     text  \
# 0      : Сегодня в московском метро произошли террори...
# 1      Теперь по сути происшедшего. Первый – Александ...
# 2      , что сделали спасатели, какова сейчас ситуаци...
# 3      Дмитрий Анатольевич, все системы сработали дос...
# 4      Задействованы были все необходимые силы: по ли...
# ...                                                  ...
# 37582  В отношении инфраструктуры, Вы знаете, у нас е...
# 37583  А Вам\nя желаю всего самого доброго – и в Ваше...
# 37584                              Спасибо\nВам большое.
# 37585                               Спасибо вам большое.
# 37587               Инвестиционный форум «Россия зовёт!»
#
#                                               text_clean
# 0      сегодня в московском метро произошли террорист...
# 1      теперь по сути происшедшего первый александр в...
# 2      что сделали спасатели какова сейчас ситуация э...
# 3      дмитрий анатольевич все системы сработали дост...
# 4      задействованы были все необходимые силы по лин...
# ...                                                  ...
# 37582  в отношении инфраструктуры вы знаете у нас ест...
# 37583  а вам я желаю всего самого доброго и в вашей п...
# 37584                                спасибо вам большое
# 37585                                спасибо вам большое
# 37587                  инвестиционный форум россия зовёт
#
# [36766 rows x 6 columns]

# %%
somi = pd.read_pickle('data/corpus_adriana/corpus_president_of_russia/statements_on_major_issues.pkl')
somi
# Out:
#              date                                                url  \
# 0      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 1      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 2      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 3      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 4      2010-03-29  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 37582  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37583  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37584  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37585  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37587  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                        title      speaker  \
# 0      Совещание в связи с терактами в метро  Д.Медведев:
# 1      Совещание в связи с терактами в метро  Д.Медведев:
# 2      Совещание в связи с терактами в метро  Д.Медведев:
# 3      Совещание в связи с терактами в метро     С.Шойгу:
# 4      Совещание в связи с терактами в метро     С.Шойгу:
# ...                                      ...          ...
# 37582   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37583   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37584   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37585   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37587   Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                                     text  \
# 0      : Сегодня в московском метро произошли террори...
# 1      Теперь по сути происшедшего. Первый – Александ...
# 2      , что сделали спасатели, какова сейчас ситуаци...
# 3      Дмитрий Анатольевич, все системы сработали дос...
# 4      Задействованы были все необходимые силы: по ли...
# ...                                                  ...
# 37582  В отношении инфраструктуры, Вы знаете, у нас е...
# 37583  А Вам\nя желаю всего самого доброго – и в Ваше...
# 37584                              Спасибо\nВам большое.
# 37585                               Спасибо вам большое.
# 37587               Инвестиционный форум «Россия зовёт!»
#
#                                               text_clean
# 0      сегодня в московском метро произошли террорист...
# 1      теперь по сути происшедшего первый александр в...
# 2      что сделали спасатели какова сейчас ситуация э...
# 3      дмитрий анатольевич все системы сработали дост...
# 4      задействованы были все необходимые силы по лин...
# ...                                                  ...
# 37582  в отношении инфраструктуры вы знаете у нас ест...
# 37583  а вам я желаю всего самого доброго и в вашей п...
# 37584                                спасибо вам большое
# 37585                                спасибо вам большое
# 37587                  инвестиционный форум россия зовёт
#
# [36766 rows x 6 columns]

# %%
def clean(text):
    #replace Д.Медведев:|В.Путин: with a white space
    text = re.sub(r'(Д\.Медведев:|В\.Путин:)', ' ', text)
    # replace actual newline characters \n with a space
    text = re.sub(r'\n', ' ', text)
    # replace everything non-alphanumeric with a space
    text = re.sub(r'\W+', ' ', text)
    # replace two or more dots with one
    text = re.sub(r'\.{2,}', ' ', text)
    # replace sequences of white spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    # convert text to lowercase
    text = text.lower()
    # replace \xa0 with a white space
    text = re.sub(r'\xa0', ' ', text)
    return text.strip()

# %%
somi_copy = somi.copy()
somi_copy.loc[:, 'text_clean'] = somi['text'].map(clean)

# %%
somi_copy
# Out:
#              date                                                url  \
# 0      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 1      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 2      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 3      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 4      2010-03-29  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 37582  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37583  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37584  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37585  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37587  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                        title      speaker  \
# 0      Совещание в связи с терактами в метро  Д.Медведев:
# 1      Совещание в связи с терактами в метро  Д.Медведев:
# 2      Совещание в связи с терактами в метро  Д.Медведев:
# 3      Совещание в связи с терактами в метро     С.Шойгу:
# 4      Совещание в связи с терактами в метро     С.Шойгу:
# ...                                      ...          ...
# 37582   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37583   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37584   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37585   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37587   Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                                     text  \
# 0      : Сегодня в московском метро произошли террори...
# 1      Теперь по сути происшедшего. Первый – Александ...
# 2      , что сделали спасатели, какова сейчас ситуаци...
# 3      Дмитрий Анатольевич, все системы сработали дос...
# 4      Задействованы были все необходимые силы: по ли...
# ...                                                  ...
# 37582  В отношении инфраструктуры, Вы знаете, у нас е...
# 37583  А Вам\nя желаю всего самого доброго – и в Ваше...
# 37584                              Спасибо\nВам большое.
# 37585                               Спасибо вам большое.
# 37587               Инвестиционный форум «Россия зовёт!»
#
#                                               text_clean
# 0      сегодня в московском метро произошли террорист...
# 1      теперь по сути происшедшего первый александр в...
# 2      что сделали спасатели какова сейчас ситуация э...
# 3      дмитрий анатольевич все системы сработали дост...
# 4      задействованы были все необходимые силы по лин...
# ...                                                  ...
# 37582  в отношении инфраструктуры вы знаете у нас ест...
# 37583  а вам я желаю всего самого доброго и в вашей п...
# 37584                                спасибо вам большое
# 37585                                спасибо вам большое
# 37587                  инвестиционный форум россия зовёт
#
# [36766 rows x 6 columns]

# %%
word_counts = somi_copy['text'].str.split().str.len()
word_counts
# Out:
# 0        14
# 1        20
# 2        14
# 3        54
# 4        71
#          ..
# 37582    56
# 37583    17
# 37584     3
# 37585     3
# 37587     4
# Name: text, Length: 36766, dtype: int64

# %%
somi_copy[somi_copy['text_clean'].str.contains('медведев|путин')]
# Out:
#              date                                                url  \
# 26     2012-03-23  http://kremlin.ru/events/president/transcripts...
# 28     2012-03-23  http://kremlin.ru/events/president/transcripts...
# 173    2019-06-20  http://kremlin.ru/events/president/transcripts...
# 735    2011-11-21  http://kremlin.ru/events/president/transcripts...
# 921    2020-05-09  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 36934  2011-08-05  http://kremlin.ru/events/president/transcripts...
# 36937  2011-08-05  http://kremlin.ru/events/president/transcripts...
# 36938  2011-08-05  http://kremlin.ru/events/president/transcripts...
# 36986  2011-08-05  http://kremlin.ru/events/president/transcripts...
# 37272  2010-03-29  http://kremlin.ru/events/president/transcripts...
#
#                                                    title      speaker  \
# 26     Конференция Российского совета по международны...  Д.Медведев:
# 28     Конференция Российского совета по международны...  Д.Медведев:
# 173                    Прямая линия с Владимиром Путиным  Т.Ремезова:
# 735           Встреча с офицерами Южного военного округа  Д.Медведев:
# 921                                      75-летие Победы  Д.Медведев:
# ...                                                  ...          ...
# 36934                         Интервью Дмитрия Медведева  Д.Медведев:
# 36937                         Интервью Дмитрия Медведева  Д.Медведев:
# 36938                         Интервью Дмитрия Медведева  Д.Медведев:
# 36986                         Интервью Дмитрия Медведева  Д.Медведев:
# 37272  Дмитрий Медведев почтил память жертв взрывов в...  Д.Медведев:
#
#                                                     text  \
# 26     Дмитрий Медведев принял участие в научно-практ...
# 28     На полях конференции Дмитрий Медведев встретил...
# 173    Почти\n400 тысяч СМС- и ММС-сообщений. Но в эт...
# 735    В ходе поездки в Северную Осетию – Аланию Дмит...
# 921    По окончании церемонии с Ивановской площади Кр...
# ...                                                  ...
# 36934  Саркози сделал очень добрую вещь, он позвонил ...
# 36937  Что касается плана Медведева – Саркози. Он воо...
# 36938  Уважаемые друзья, могу вам сказать одну вещь. ...
# 36986                         Интервью Дмитрия Медведева
# 37272  Дмитрий Медведев почтил память жертв взрывов в...
#
#                                               text_clean
# 26     дмитрий медведев принял участие в научно практ...
# 28     на полях конференции дмитрий медведев встретил...
# 173    почти 400 тысяч смс и ммс сообщений но в этом ...
# 735    в ходе поездки в северную осетию аланию дмитри...
# 921    по окончании церемонии с ивановской площади кр...
# ...                                                  ...
# 36934  саркози сделал очень добрую вещь он позвонил м...
# 36937  что касается плана медведева саркози он вообще...
# 36938  уважаемые друзья могу вам сказать одну вещь ес...
# 36986                         интервью дмитрия медведева
# 37272  дмитрий медведев почтил память жертв взрывов в...
#
# [280 rows x 6 columns]

# %%
description = somi_copy[somi_copy['text_clean'].str.contains('дмитрий медведев|владимир путин|пресидент') & 
                        ~somi_copy['text_clean'].str.contains('уважаем|добр|дорог')]

# %%
description.reset_index(inplace=True, drop=True)

# %%
word_counts = description['text'].str.split().str.len()
word_counts
# Out:
# 0      18
# 1      12
# 2      26
# 3      17
# 4      10
#        ..
# 103    28
# 104     7
# 105    10
# 106    14
# 107     9
# Name: text, Length: 108, dtype: int64

# %%
somi_copy.drop(somi_copy[somi_copy['text_clean'].str.contains('дмитрий медведев|владимир путин|пресидент') & 
                          ~somi_copy['text_clean'].str.contains('уважаем|добр|дорог')].index, inplace=True)

# %%
somi_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36658 entries, 0 to 37587
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        36658 non-null  object
#  1   url         36658 non-null  object
#  2   title       36658 non-null  object
#  3   speaker     36658 non-null  object
#  4   text        36658 non-null  object
#  5   text_clean  36658 non-null  object
# dtypes: object(6)
# memory usage: 2.0+ MB

# %%
somi_copy.to_pickle('data/corpus_adriana/corpus_president_of_russia/statements_on_major_issues.pkl')

# %% [markdown]
# #### somi concatenated

# %%
somi = pd.read_pickle('data/corpus_adriana/corpus_president_of_russia/statements_on_major_issues.pkl')
somi
# Out:
#              date                                                url  \
# 0      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 1      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 2      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 3      2010-03-29  http://kremlin.ru/events/president/transcripts...
# 4      2010-03-29  http://kremlin.ru/events/president/transcripts...
# ...           ...                                                ...
# 37582  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37583  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37584  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37585  2019-11-20  http://kremlin.ru/events/president/transcripts...
# 37587  2019-11-20  http://kremlin.ru/events/president/transcripts...
#
#                                        title      speaker  \
# 0      Совещание в связи с терактами в метро  Д.Медведев:
# 1      Совещание в связи с терактами в метро  Д.Медведев:
# 2      Совещание в связи с терактами в метро  Д.Медведев:
# 3      Совещание в связи с терактами в метро     С.Шойгу:
# 4      Совещание в связи с терактами в метро     С.Шойгу:
# ...                                      ...          ...
# 37582   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37583   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37584   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37585   Инвестиционный форум «Россия зовёт!»     В.Путин:
# 37587   Инвестиционный форум «Россия зовёт!»     В.Путин:
#
#                                                     text  \
# 0      : Сегодня в московском метро произошли террори...
# 1      Теперь по сути происшедшего. Первый – Александ...
# 2      , что сделали спасатели, какова сейчас ситуаци...
# 3      Дмитрий Анатольевич, все системы сработали дос...
# 4      Задействованы были все необходимые силы: по ли...
# ...                                                  ...
# 37582  В отношении инфраструктуры, Вы знаете, у нас е...
# 37583  А Вам\nя желаю всего самого доброго – и в Ваше...
# 37584                              Спасибо\nВам большое.
# 37585                               Спасибо вам большое.
# 37587               Инвестиционный форум «Россия зовёт!»
#
#                                               text_clean
# 0      сегодня в московском метро произошли террорист...
# 1      теперь по сути происшедшего первый александр в...
# 2      что сделали спасатели какова сейчас ситуация э...
# 3      дмитрий анатольевич все системы сработали дост...
# 4      задействованы были все необходимые силы по лин...
# ...                                                  ...
# 37582  в отношении инфраструктуры вы знаете у нас ест...
# 37583  а вам я желаю всего самого доброго и в вашей п...
# 37584                                спасибо вам большое
# 37585                                спасибо вам большое
# 37587                  инвестиционный форум россия зовёт
#
# [36658 rows x 6 columns]

# %%
def concat_strings(x):
    return ' '.join(x)

# %%
somi_concatenated = somi.groupby(['date', 'url', 'title', 'speaker'], as_index=False).agg({'text': concat_strings})

# %%
somi_concatenated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     691 non-null    object
#  1   url      691 non-null    object
#  2   title    691 non-null    object
#  3   speaker  691 non-null    object
#  4   text     691 non-null    object
# dtypes: object(5)
# memory usage: 27.1+ KB

# %%
somi_concatenated.text.iloc[0]
# Out:
# 'В.Путин: Добрый день, уважаемые коллеги! Сегодня я подписал закон о\xa0местном самоуправлении, над которым и\xa0Администрация, и\xa0Правительство, и\xa0депутаты Государственной Думы очень долго работали. Этот документ\xa0– одна из\xa0важнейших составляющих полномасштабной административной реформы, о\xa0которой мы много говорим. Я знаю, что на\xa0этой неделе на\xa0Правительстве рассматриваются вопросы в\xa0этом контексте. Два слова об\xa0этом законе. Местное самоуправление, мы хорошо знаем, это дополнительные гарантии прав граждан в\xa0управлении делами государства. Это приближение власти непосредственно к\xa0людям. Повышение социальной активности граждан. Это также предотвращение чрезмерной концентрации власти в\xa0центре. Дополнительные гарантии устойчивости политической системы. Закон вступает в\xa0силу с\xa01\xa0января 2006\xa0года. Мы предусмотрели очень длительный переходный период для того, чтобы как следует подготовиться к\xa0его реализации. Сделано это не\xa0случайно. Сам закон содержит подробный план действий федеральных и\xa0региональных властей на\xa0переходный период. Я прошу Правительство строго следовать этому плану. Это план, который вырабатывался, по\xa0сути, с\xa0вашим прямым участием. Необходимо заблаговременно внести в\xa0парламент поправки во\xa0многие федеральные законы с\xa0целью приведения их в\xa0соответствие с\xa0обновленной моделью местного самоуправления и\xa0федеративных отношений. Необходимо освободить региональные и\xa0местные власти от\xa0навязанных им с\xa0федерального уровня не\xa0обоснованных ни\xa0с\xa0финансовой точки зрения, ни\xa0с\xa0точки зрения реальных потребностей государства и\xa0общества функций. Мы должны приложить все усилия, чтобы реализовать предусмотренные законом принципы межбюджетных отношений в\xa0налоговой и\xa0бюджетной сфере. Это позволит обеспечить рациональное расходование средств налогоплательщиков и\xa0повышение эффективности и\xa0ответственности региональных и\xa0местных властей. Что крайне важно, особенно сейчас,\xa0– мы входим с\xa0вами в\xa0зимний период. Знаем, с\xa0какими сложностями сталкивались на\xa0этом уровне органы муниципального самоуправления постоянно на\xa0протяжении последних лет. Правительство не\xa0должно расслаблять то\xa0обстоятельство, что срок введения отложен на\xa0достаточно длительное время. Работу необходимо начинать сегодня, во\xa0взаимодействии с\xa0соответствующей комиссией по\xa0разграничению полномочий, учитывая мнения и\xa0предложения регионов Российской Федерации, самих муниципалитетов. Соответствующие поручения и\xa0Правительству, и\xa0комиссии будут сформулированы, хотя я абсолютно уверен в\xa0том, что вы и\xa0так знаете, что нужно делать. У\xa0нас прошли выборы в\xa0двух регионах Российской Федерации\xa0– в\xa0Чеченской Республике и\xa0в\xa0Санкт-Петербурге. До\xa0конца года должны состояться выборы еще в\xa0десяти субъектах Российской Федерации. Причем в\xa0крупных субъектах. Это будет существенным образом отражаться на\xa0внутриполитической ситуации в\xa0России. Необходимо сделать все, что от\xa0вас зависит, для нормального течения этих выборных процессов в\xa0России. Хочу обратить внимание на\xa0высокую явку избирателей в\xa0Чеченской Республике. По\xa0предварительным данным\xa0– 86,8 процента. Я думаю, что не\xa0требует комментариев то, что сейчас происходит в\xa0Чечне. Сам факт, я уже не\xa0говорю о\xa0результате, конечно, вполне приятен. Даже не\xa0в\xa0этом дело. Сам факт такой высокой явки говорит о\xa0том, что люди надеются на\xa0лучшую жизнь, надеются на\xa0объективные изменения в\xa0республике, в\xa0жизни своих семей, надеются на\xa0решение прежде всего социальных вопросов, вопросов обеспечения их безопасности. Но\xa0если проблема безопасности\xa0– это отдельная тема, которой мы занимались и\xa0будем заниматься больше и\xa0больше\xa0– и\xa0больше ответственности будет возлагаться на\xa0республиканские власти, то\xa0социальные и\xa0экономические вопросы в\xa0Чечне без поддержки Правительства Российской Федерации не\xa0ре ...

# %%
def clean(text):
    # replace actual newline characters \n with a space
    text = re.sub(r'\n', ' ', text)
    #replace Д.Медведев:|В.Путин: with a white space
    text = re.sub(r'(Д\.Медведев:|В\.Путин:)', ' ', text)
    # replace everything non-alphanumeric with a space
    text = re.sub(r'\W+', ' ', text)
    # replace two or more dots with one
    text = re.sub(r'\.{2,}', ' ', text)
    # replace sequences of white spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    # convert text to lowercase
    text = text.lower()
    # replace \xa0 with a white space
    text = re.sub(r'\xa0', ' ', text)
    return text.strip()

# %%
somi_concatenated['text_clean'] = somi_concatenated['text'].map(clean)

# %%
somi_concatenated.to_pickle('data/corpus_adriana/corpus_president_of_russia/somi_concatenated.pkl')

# %% [markdown]
# ### interviews

# %%
#interviews
interviews = pd.read_pickle('data/corpus_adriana/corpus_president_of_russia/interviews.pkl')
interviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9642 entries, 0 to 9641
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     9642 non-null   object
#  1   url      9642 non-null   object
#  2   title    9642 non-null   object
#  3   speaker  9642 non-null   object
#  4   text     9642 non-null   object
# dtypes: object(5)
# memory usage: 376.8+ KB

# %%
interviews['speaker'] = interviews['speaker'].replace({'В.Путин': 'В.Путин:', 'Д.Медведев': 'Д.Медведев:'})

# %%
interviews.speaker.value_counts()
# Out:
# В.Путин:             4829
# Д.Медведев:          1724
# Вопрос:               458
# А.Ванденко:           333
# М.Келли:              156
#                      ...
# Э.Хула                  1
# Л.Фонтана               1
# Дж.Стефанопулос         1
# Дж.Миклетвейт           1
# Газета «Политика»       1
# Name: speaker, Length: 118, dtype: int64

# %%
filtered_speakers = interviews['speaker'].str.contains('В.Путин:|Д.Медведев')

# %%
filtered_interviews = interviews[(filtered_speakers)]

# %%
filtered_interviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6554 entries, 1 to 9641
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     6554 non-null   object
#  1   url      6554 non-null   object
#  2   title    6554 non-null   object
#  3   speaker  6554 non-null   object
#  4   text     6554 non-null   object
# dtypes: object(5)
# memory usage: 307.2+ KB

# %%
filtered_interviews.speaker.value_counts()
# Out:
# В.Путин:       4829
# Д.Медведев:    1724
# В.Путин: «        1
# Name: speaker, dtype: int64

# %%
condition_1 = filtered_interviews['text'].str.contains('Опубликован в разделах:')
condition_2 = filtered_interviews['text'].str.contains('Дата публикации:')
condition_3 = filtered_interviews['text'].str.contains('Ссылка на материал:')
condition_4 = filtered_interviews['text'].str.strip().str.len() == 0
condition_5 = filtered_interviews['text'].str.contains('Официальный сайт президента России:')
condition_6 = filtered_interviews['text'].str.contains('http://')
condition_7 = filtered_interviews['text'].str.contains('<…>|\* \* \*')
condition_8 = filtered_interviews['text'].str.contains('Администрация Президента России')


filtered_interviews = filtered_interviews[~(condition_1 | condition_2 | condition_3| condition_4| condition_5| condition_6|condition_7|condition_8)]

# %%
def clean(text):
    # replace actual newline characters \n with a space
    text = re.sub(r'\n', ' ', text)
    #replace Д.Медведев:|В.Путин: with a white space
    text = re.sub(r'(Д\.Медведев:|В\.Путин:)', ' ', text)
    # replace everything non-alphanumeric with a space
    text = re.sub(r'\W+', ' ', text)
    # replace two or more dots with one
    text = re.sub(r'\.{2,}', ' ', text)
    # replace sequences of white spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    # convert text to lowercase
    text = text.lower()
    # replace \xa0 with a white space
    text = re.sub(r'\xa0', ' ', text)
    return text.strip()

# %%
interviews['text_clean'] = interviews['text'].map(clean)

# %%
interviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9642 entries, 0 to 9641
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        9642 non-null   object
#  1   url         9642 non-null   object
#  2   title       9642 non-null   object
#  3   speaker     9642 non-null   object
#  4   text        9642 non-null   object
#  5   text_clean  9642 non-null   object
# dtypes: object(6)
# memory usage: 452.1+ KB

# %%
interviews.to_pickle('data/corpus_adriana/corpus_president_of_russia/interviews.pkl')

# %%
def concat_strings(x):
    return ' '.join(x)

# %%
interviews_concatenated = filtered_interviews.groupby(['date', 'url', 'title', 'speaker'], as_index=False).agg({'text': concat_strings})

# %%
interviews_concatenated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     114 non-null    object
#  1   url      114 non-null    object
#  2   title    114 non-null    object
#  3   speaker  114 non-null    object
#  4   text     114 non-null    object
# dtypes: object(5)
# memory usage: 4.6+ KB

# %%
interviews_concatenated.text.iloc[0]
# Out:
# 'Я не\xa0думаю, что открою для Вас какую‑то особую истину, если скажу, что работа у\xa0Президента очень интересная, но\xa0довольно сложная. И\xa0не\xa0важно, сколько тебе лет, 44\xa0года или 88,\xa0– это требует определённой мобилизации. Мы с\xa0Вами приблизительно одного возраста, поэтому Вы можете себе представить, какие эмоции в\xa0этом случае испытываешь. Хотя, конечно, с\xa0другой стороны, для того чтобы всё это понять и\xa0прочувствовать, нужно немножко посидеть в\xa0этом кресле. Это так, это правда. Что касается моей работы, то\xa0я могу сказать, что, наверное, те испытания, которые для меня являются значимыми, они сегодня очевидны. Это экономический кризис, который, к\xa0сожалению, случился в\xa0прошлом году. Я ещё только несколько месяцев был Президентом, когда в\xa0воздухе появился «аромат» кризиса, и\xa0все мы почувствовали, что это довольно серьёзно, что это рассчитано на\xa0значительное время. Другой очень большой, серьёзной проблемой были, конечно, те испытания, с\xa0которыми мы столкнулись в\xa0результате грузинского инцидента, когда нам пришлось защищать народ Южной Осетии. Я не\xa0хотел, чтобы события развивались по\xa0такому сценарию, но\xa0мне пришлось принять такое решение. Вот, наверное, два наиболее серьёзных испытания, с\xa0которыми мне пришлось столкнуться в\xa0самом начале работы. У\xa0нас существуют свои достаточно развитые отношения с\xa0Ираном, поэтому я могу судить о\xa0намерениях Ирана не\xa0понаслышке, не\xa0из\xa0справок спецслужб других стран, а\xa0исходя из\xa0реальной картины. Я, безусловно, полагаю, что Иран нуждается в\xa0системе мотивации к\xa0правильному поведению по\xa0вопросам своей ядерной программы. В\xa0этом никаких сомнений. Во‑вторых, Иран должен сотрудничать с\xa0МАГАТЭ, он должен сотрудничать с\xa0Международным агентством, потому что это его обязанность. В‑третьих, мы должны создавать для Ирана систему позитивных мотивов для того, чтобы он хотел этого сотрудничества. 9\xa0сентября Иран передал свои предложения, посвящённые этим наиболее сложным вопросам, и\xa0сейчас они анализируются. Уже прозвучали голоса о\xa0том, что это слишком мало, это слишком общие предложения. Вы знаете, я считаю, что наша обязанность, всех государств, которые работают над этой проблемой,\xa0– эти предложения как минимум изучить. Сначала Иран долго изучал тот пакет стимулов, который ему передавался при посредничестве Соланы. Сейчас нужно изучить этот пакет. Что\xa0же касается санкций\xa0– мне только что на\xa0эту тему довелось рассуждать во\xa0время общения с\xa0политологами, которые приехали на\xa0конференцию [конференция «Современное государство и\xa0глобальная безопасность» в\xa0Ярославле]. Я им сказал простую вещь: как правило, санкции ни\xa0к\xa0чему не\xa0приводят, хотя иногда они бывают необходимы. Но, прежде чем говорить о\xa0применении каких‑то дополнительных санкций, мы должны выбрать весь свободный ход, весь воздух, который существует. Вот это будет ответственным поведением со\xa0стороны мирового сообщества. Да, мы должны стимулировать Иран, но\xa0мы должны чётко быть уверены, что у\xa0нас не\xa0остаётся никаких других вариантов и\xa0что наши иранские коллеги нас по\xa0каким‑то причинам не\xa0слышат. Вот это, по‑моему, самая простая и\xa0прагматическая позиция. И, кстати сказать, я её озвучивал во\xa0время консультаций по\xa0этому поводу, которые состоялись на\xa0«восьмёрке» в\xa0Италии, когда мы обсуждали этот вопрос, когда это обсуждали все лидеры восьми государств. Иран должен кооперироваться с\xa0МАГАТЭ, это абсолютно очевидная вещь, если он хочет развивать свою программу по\xa0ядерной составляющей, по\xa0ядерной энергетике. Это его обязанность, а\xa0не\xa0его выбор. Потому что в\xa0противном случае действительно будет всё время возникать вопрос: а\xa0что он делает? Вот это очевидно. Конечно. У\xa0нас действительно есть военная составляющая в\xa0отношениях с\xa0Ираном, и\xa0мы думаем о\xa0том, что это должна быть такая работа, которая полностью соответствует международным обязательствам как ...

# %%
def clean(text):
    # replace actual newline characters \n with a space
    text = re.sub(r'\n', ' ', text)
    #replace Д.Медведев:|В.Путин: with a white space
    text = re.sub(r'(Д\.Медведев:|В\.Путин:)', ' ', text)
    # replace everything non-alphanumeric with a space
    text = re.sub(r'\W+', ' ', text)
    # replace two or more dots with one
    text = re.sub(r'\.{2,}', ' ', text)
    # replace sequences of white spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    # convert text to lowercase
    text = text.lower()
    # replace \xa0 with a white space
    text = re.sub(r'\xa0', ' ', text)
    return text.strip()

# %%
interviews_concatenated['text_clean'] = interviews_concatenated['text'].map(clean)

# %%
interviews_concatenated
# Out:
#            date                                                url  \
# 0    2009-09-20  http://kremlin.ru/events/president/transcripts...
# 1    2009-11-07  http://kremlin.ru/events/president/transcripts...
# 2    2010-02-25  http://kremlin.ru/events/president/transcripts...
# 3    2010-04-12  http://kremlin.ru/events/president/transcripts...
# 4    2010-04-14  http://kremlin.ru/events/president/transcripts...
# ..          ...                                                ...
# 109  2021-10-14  http://kremlin.ru/events/president/transcripts...
# 110  2021-11-13  http://kremlin.ru/events/president/transcripts...
# 111  2022-02-03  http://kremlin.ru/events/president/transcripts...
# 112  2022-06-03  http://kremlin.ru/events/president/transcripts...
# 113  2023-01-13  http://kremlin.ru/events/president/transcripts...
#
#                                                  title      speaker  \
# 0    Интервью телекомпании «Си-Эн-Эн» • Президент Р...  Д.Медведев:
# 1    Интервью немецкому журналу «Шпигель» • Президе...  Д.Медведев:
# 2    Интервью французскому журналу «Пари-матч» • Пр...  Д.Медведев:
# 3    Интервью Дмитрия Медведева американскому телек...  Д.Медведев:
# 4    Интервью журналисту «Известий» Мэлору Стуруа •...  Д.Медведев:
# ..                                                 ...          ...
# 109        Интервью телеканалу CNBC • Президент России     В.Путин:
# 110    Интервью телеканалу «Россия» • Президент России     В.Путин:
# 111  Интервью Медиакорпорации Китая • Президент России     В.Путин:
# 112    Интервью телеканалу «Россия» • Президент России     В.Путин:
# 113  Комментарий телеканалу «Россия» • Президент Ро...     В.Путин:
#
#                                                   text  \
# 0    Я не думаю, что открою для Вас какую‑то особую...
# 1    Время бежит очень быстро. Спустя 20 лет всё, ч...
# 2    : Прежде всего хотел бы сказать, что мне очень...
# 3    То, что Россия – это нормальная современная ст...
# 4    : Вы знаете, его легко оценивать. Это самый бе...
# ..                                                 ...
# 109  Хочу вернуть вам эту шайбу в ответ. Нет, я на ...
# 110  Во-первых, это вопрос не ко мне,\nпочему они н...
# 111  : Мы давно знакомы\nс Председателем Си Цзиньпи...
# 112  Да, конечно, мы сейчас видим попытки переложит...
# 113  Где\nВы родились? Я\nкатался с удовольствием, ...
#
#                                             text_clean
# 0    я не думаю что открою для вас какую то особую ...
# 1    время бежит очень быстро спустя 20 лет всё что...
# 2    прежде всего хотел бы сказать что мне очень пр...
# 3    то что россия это нормальная современная стран...
# 4    вы знаете его легко оценивать это самый бесспо...
# ..                                                 ...
# 109  хочу вернуть вам эту шайбу в ответ нет я на та...
# 110  во первых это вопрос не ко мне почему они не р...
# 111  мы давно знакомы с председателем си цзиньпином...
# 112  да конечно мы сейчас видим попытки переложить ...
# 113  где вы родились я катался с удовольствием с уд...
#
# [114 rows x 6 columns]

# %%
interviews_concatenated.to_pickle('data/corpus_adriana/corpus_president_of_russia/interviews_concatenated.pkl')

# %% [markdown]
# ### news

# %%
news = pd.read_excel('data/putin_corpus.xlsx')
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33189 entries, 0 to 33188
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          33189 non-null  object
#  1   URL           33189 non-null  object
#  2   description   30316 non-null  object
#  3   introduction  30316 non-null  object
#  4   id            33189 non-null  int64
#  5   speaker       33189 non-null  object
#  6   p             33189 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ MB

# %%
news.speaker.value_counts()
# Out:
# В.Путин                  20444
# К.-Ж.Токаев                335
# С.Абэ                      314
# С.Брилёв                   271
# А.Костин                   223
#                          ...
# П.Тайченачев                 1
# А.Марзуки                    1
# С.Хасан                      1
# Т.Николич (по-русски)        1
# Йон Фредерик Баксаас         1
# Name: speaker, Length: 944, dtype: int64

# %%
news.drop(['introduction','id'], axis=1, inplace=True)

# %%
news.rename(columns={'p':'text'},inplace=True)

# %%
filtered_speakers = news['speaker'].str.contains('В.Путин|Д.Медведев')

# %%
filtered_news = news[(filtered_speakers)]

# %%
filtered_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20585 entries, 0 to 33188
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         20585 non-null  object
#  1   URL          20585 non-null  object
#  2   description  18490 non-null  object
#  3   speaker      20585 non-null  object
#  4   text         20585 non-null  object
# dtypes: object(5)
# memory usage: 964.9+ KB

# %%
def concat_strings(x):
    return ' '.join(x)

# %%
news_concatenated = filtered_news.groupby(['date', 'URL', 'description', 'speaker'], as_index=False).agg({'text': concat_strings})

# %%
news_concatenated.text.iloc[0]
# Out:
# 'Клянусь при осуществлении полномочий Президента Российской Федерации уважать и охранять права и свободы человека и гражданина, соблюдать и защищать Конституцию Российской Федерации, защищать суверенитет и независимость, безопасность и целостность государства, верно служить народу. Уважаемые граждане России! Дорогие друзья! Вступая в должность Президента Российской Федерации, понимаю всю свою ответственность перед Родиной. Её интересы, безопасность, благополучие граждан страны всегда были и всегда останутся для меня превыше всего. Сделаю всё, чтобы оправдать доверие миллионов наших граждан. Считаю смыслом всей своей жизни и своим долгом служение Отечеству, служение нашему народу, поддержка которого вдохновляет и помогает решать самые сложные и трудные задачи. Мы вместе прошли большой и сложный путь, поверили в себя, в свои силы, укрепили страну, вернули себе достоинство великой нации, мир увидел возрождённую Россию, и это результат усилий нашего народа, общей напряжённой работы, в которой есть личный вклад каждого. Сегодня у нас есть всё для движения вперёд, для созидания: дееспособное и развивающееся государство, прочная экономическая и социальная база, активное и ответственное гражданское общество. Я вижу в этом большую заслугу Дмитрия Анатольевича Медведева. Его президентство обеспечило преемственность и устойчивость развития страны, придало дополнительный импульс модернизации всех сторон нашей жизни. Впереди у него сложные и очень ответственные задачи. Я желаю ему успехов. Сегодня мы вступаем в новый этап национального развития, нам потребуется решать задачи принципиально иного уровня, иного качества и масштаба. Ближайшие годы будут определяющими для судьбы России на десятилетия вперёд. И мы все должны понимать, что жизнь будущих поколений, историческая перспектива государства и нашей нации зависят сегодня именно от нас, от реальных успехов в создании новой экономики и современных стандартов жизни, от наших усилий по сбережению народа и поддержке российских семей, от нашей настойчивости в обустройстве огромных российских пространств от Балтики до Тихого океана, от нашей способности стать лидерами и центром притяжения всей Евразии. Мы добьёмся наших целей, если будем единым, сплочённым народом, если будем дорожить нашим Отечеством, укреплять российскую демократию, конституционные права и свободы, расширять участие граждан в управлении страной, в формировании национальной повестки дня, чтобы стремление каждого к лучшей жизни было воплощено в совместной работе для процветания всей страны. Мы обязательно добьёмся успеха, если будем опираться на прочный фундамент культурных и духовных традиций нашего многонационального народа, на нашу тысячелетнюю историю, на те ценности, которые всегда составляли нравственную основу нашей жизни, если каждый из нас будет жить по совести, с верой и любовью к Родине, к своим близким, заботиться о счастье своих детей и благополучии своих родителей. Мы хотим и будем жить в демократической стране, где у каждого есть свобода и простор для приложения таланта и труда, своих сил. Мы хотим и будем жить в успешной России, которую уважают в мире как надёжного, открытого, честного и предсказуемого партнёра. Я верю в силу наших общих целей и идеалов, в силу нашей решимости преобразить страну, в силу объединённых действий граждан, в наше общее стремление к свободе, к правде, к справедливости. Мы готовы к грядущим испытаниям и грядущим свершениям. У России великая история и не менее великое будущее. И мы будем работать с верой в душе, с искренними и чистыми помыслами. Спасибо!'

# %%
news_concatenated
# Out:
#            date                                            URL  \
# 0    2012-05-07  http://kremlin.ru/events/president/news/15224
# 1    2012-05-07  http://kremlin.ru/events/president/news/15224
# 2    2012-05-07  http://kremlin.ru/events/president/news/15260
# 3    2012-05-09  http://kremlin.ru/events/president/news/15271
# 4    2012-05-09  http://kremlin.ru/events/president/news/15272
# ..          ...                                            ...
# 749  2022-06-30  http://kremlin.ru/events/president/news/68790
# 750  2022-07-25  http://kremlin.ru/events/president/news/69059
# 751  2022-07-31  http://kremlin.ru/events/president/news/69082
# 752  2022-08-07  http://kremlin.ru/events/president/news/69123
# 753  2022-08-09  http://kremlin.ru/events/president/news/69134
#
#                                            description     speaker  \
# 0    В Большом Кремлёвском дворце состоялась торжес...     В.Путин
# 1    В Большом Кремлёвском дворце состоялась торжес...  Д.Медведев
# 2    Глава государства приехал во Дворец спорта «Ме...     В.Путин
# 3    Владимир Путин присутствовал на военном параде...     В.Путин
# 4    В Кремле состоялся торжественный приём в ознам...     В.Путин
# ..                                                 ...         ...
# 749  Глава государства возложил цветы к подножию мо...     В.Путин
# 750  Владимир Путин поздравил сотрудников органов с...     В.Путин
# 751  В День Военно-Морского Флота Верховный Главнок...     В.Путин
# 752  Владимир Путин поздравил работников и ветерано...     В.Путин
# 753  Президент обратился к участникам и гостям конц...     В.Путин
#
#                                                   text
# 0    Клянусь при осуществлении полномочий Президент...
# 1    Уважаемые граждане России! Дорогие друзья! Вст...
# 2    Дорогие друзья, уважаемые любители спорта и хо...
# 3    Уважаемые граждане России! Дорогие ветераны! Т...
# 4    Дорогие наши ветераны! Уважаемые коллеги, друз...
# ..                                                 ...
# 749  Уважаемые товарищи! Дорогие ветераны! Мы собра...
# 750  Уважаемые товарищи! Поздравляю вас с профессио...
# 751  Товарищи матросы и старшины, мичманы и офицеры...
# 752  Уважаемые друзья! Сегодня мы отмечаем День жел...
# 753  Дорогие друзья! Рад приветствовать участников ...
#
# [754 rows x 5 columns]

# %%
def clean(text):
    # replace actual newline characters \n with a space
    text = re.sub(r'\n', ' ', text)
    #replace Д.Медведев:|В.Путин: with a white space
    text = re.sub(r'(Д\.Медведев:|В\.Путин:)', ' ', text)
    # replace everything non-alphanumeric with a space
    text = re.sub(r'\W+', ' ', text)
    # replace two or more dots with one
    text = re.sub(r'\.{2,}', ' ', text)
    # replace sequences of white spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    # convert text to lowercase
    text = text.lower()
    # replace \xa0 with a white space
    text = re.sub(r'\xa0', ' ', text)
    return text.strip()

# %%
news_concatenated['text_clean'] = news_concatenated['text'].map(clean)

# %%
news_concatenated
# Out:
#            date                                            URL  \
# 0    2012-05-07  http://kremlin.ru/events/president/news/15224
# 1    2012-05-07  http://kremlin.ru/events/president/news/15224
# 2    2012-05-07  http://kremlin.ru/events/president/news/15260
# 3    2012-05-09  http://kremlin.ru/events/president/news/15271
# 4    2012-05-09  http://kremlin.ru/events/president/news/15272
# ..          ...                                            ...
# 749  2022-06-30  http://kremlin.ru/events/president/news/68790
# 750  2022-07-25  http://kremlin.ru/events/president/news/69059
# 751  2022-07-31  http://kremlin.ru/events/president/news/69082
# 752  2022-08-07  http://kremlin.ru/events/president/news/69123
# 753  2022-08-09  http://kremlin.ru/events/president/news/69134
#
#                                            description     speaker  \
# 0    В Большом Кремлёвском дворце состоялась торжес...     В.Путин
# 1    В Большом Кремлёвском дворце состоялась торжес...  Д.Медведев
# 2    Глава государства приехал во Дворец спорта «Ме...     В.Путин
# 3    Владимир Путин присутствовал на военном параде...     В.Путин
# 4    В Кремле состоялся торжественный приём в ознам...     В.Путин
# ..                                                 ...         ...
# 749  Глава государства возложил цветы к подножию мо...     В.Путин
# 750  Владимир Путин поздравил сотрудников органов с...     В.Путин
# 751  В День Военно-Морского Флота Верховный Главнок...     В.Путин
# 752  Владимир Путин поздравил работников и ветерано...     В.Путин
# 753  Президент обратился к участникам и гостям конц...     В.Путин
#
#                                                   text  \
# 0    Клянусь при осуществлении полномочий Президент...
# 1    Уважаемые граждане России! Дорогие друзья! Вст...
# 2    Дорогие друзья, уважаемые любители спорта и хо...
# 3    Уважаемые граждане России! Дорогие ветераны! Т...
# 4    Дорогие наши ветераны! Уважаемые коллеги, друз...
# ..                                                 ...
# 749  Уважаемые товарищи! Дорогие ветераны! Мы собра...
# 750  Уважаемые товарищи! Поздравляю вас с профессио...
# 751  Товарищи матросы и старшины, мичманы и офицеры...
# 752  Уважаемые друзья! Сегодня мы отмечаем День жел...
# 753  Дорогие друзья! Рад приветствовать участников ...
#
#                                             text_clean
# 0    клянусь при осуществлении полномочий президент...
# 1    уважаемые граждане россии дорогие друзья вступ...
# 2    дорогие друзья уважаемые любители спорта и хок...
# 3    уважаемые граждане россии дорогие ветераны тов...
# 4    дорогие наши ветераны уважаемые коллеги друзья...
# ..                                                 ...
# 749  уважаемые товарищи дорогие ветераны мы собрали...
# 750  уважаемые товарищи поздравляю вас с профессион...
# 751  товарищи матросы и старшины мичманы и офицеры ...
# 752  уважаемые друзья сегодня мы отмечаем день желе...
# 753  дорогие друзья рад приветствовать участников и...
#
# [754 rows x 6 columns]

# %%
news_concatenated.to_pickle('data/corpus_adriana/corpus_president_of_russia/news_concatenated.pkl')
