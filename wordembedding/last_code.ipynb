# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import os
import pickle
import csv
import math
from sklearn.utils import resample
import random
import time

random.seed(3919)

# %%
import pandas as pd
import re
from collections import Counter

# %%
from pprint import pprint
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import gensim.test.utils 
import itertools
from sklearn.utils import resample
from multiprocessing import Pool

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# #### load word2vec model on entire corpus

# %%
# from office
model_path = '/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/wordembedding/models/model2.bin'
model = KeyedVectors.load_word2vec_format(model_path, binary=True)

# %%
# from mac
model_path = '/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/wordembedding/models/model2.bin'
model = KeyedVectors.load_word2vec_format(model_path, binary=True)

# %%
model.most_similar(positive = ['миропорядок'],topn=20)
# check for synonyms
# Out:
# [('полицентричный', 0.8527029156684875),
#  ('формирование_полицентричного', 0.820906400680542),
#  ('демократический_справедливый', 0.8150774240493774),
#  ('справедливый_демократический', 0.8125821352005005),
#  ('международный_система', 0.8066527843475342),
#  ('многополярный', 0.805690586566925),
#  ('демократический_полицентричного', 0.7952263951301575),
#  ('демократический_система', 0.791087806224823),
#  ('формирование_многополярный', 0.7885502576828003),
#  ('объективный_процесс', 0.7861343622207642),
#  ('многообразие_современный', 0.7795619964599609),
#  ('отражать_культурно', 0.7786999344825745),
#  ('объективно_формироваться', 0.7784688472747803),
#  ('новый_мироустройство', 0.7783229351043701),
#  ('однополярная', 0.7770311832427979),
#  ('пятисотлетнее', 0.774179220199585),
#  ('справедливый_демократичный', 0.7732346057891846),
#  ('ооноцентричной', 0.7725827693939209),
#  ('новый_миропорядок', 0.7700087428092957),
#  ('тенденция_формирование', 0.7696325182914734)]

# %% [markdown]
# ### import dataset

# %%
#read df phrased lemma with preprocessed text (from office PC)
df = pd.read_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/df_lemma_preprocessing.pkl')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6779 entries, 0 to 4311
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           6779 non-null   object
#  1   url            6779 non-null   object
#  2   title          6779 non-null   object
#  3   speaker        6779 non-null   object
#  4   text           6779 non-null   object
#  5   text_clean     6779 non-null   object
#  6   word_count     6779 non-null   int64
#  7   lemma          6779 non-null   object
#  8   phrased_lemma  6779 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 529.6+ KB

# %%
df.speaker.value_counts()
# Out:
# speaker
# С.Лавров                                                 5207
# В.Путин                                                   745
# В.Путин:                                                  429
# Д.Медведев:                                               256
# Реплика:                                                   54
# С.Шойгу:                                                   14
# Т.Голикова:                                                13
# Д.Песков:                                                   9
# Т.Ремезова:                                                 8
# С.Шойгу     Шойгу Сергей КужугетовичМинистр обороны :       7
# В.Матвиенко:                                                7
# С.Брилёв:                                                   7
# Д.Медведев                                                  5
# Ф.Лукьянов:                                                 4
# К.Клеймёнов:                                                4
# М.Ситтель:                                                  3
# Д.Медведев:                                                 1
# В.Путин (по-немецки)                                        1
# В.Путин (по-английски)                                      1
# В.Путин:                                                    1
# В.Путин: «                                                  1
# В.Путин (по-японски)                                        1
# В.Путин (по-немецки, как переведено)                        1
# Name: count, dtype: int64

# %%
df['speaker'] = df['speaker'].str.replace('.*В\.Путин.*', 'В.Путин', regex=True)
df['speaker'] = df['speaker'].str.replace('.*Д\.Медведев.*', 'Д.Медведев', regex=True)
df.speaker.value_counts()
# Out:
# speaker
# С.Лавров                                                 5207
# В.Путин                                                  1180
# Д.Медведев                                                262
# Реплика:                                                   54
# С.Шойгу:                                                   14
# Т.Голикова:                                                13
# Д.Песков:                                                   9
# Т.Ремезова:                                                 8
# С.Шойгу     Шойгу Сергей КужугетовичМинистр обороны :       7
# В.Матвиенко:                                                7
# С.Брилёв:                                                   7
# К.Клеймёнов:                                                4
# Ф.Лукьянов:                                                 4
# М.Ситтель:                                                  3
# Name: count, dtype: int64

# %%
value_counts = df['speaker'].value_counts()
valid_speakers = value_counts[value_counts >= 262].index
df = df[df['speaker'].isin(valid_speakers)]

# %%
df = df.reset_index(drop=True)

# %%
df['speaker'].value_counts()
# Out:
# speaker
# С.Лавров      5207
# В.Путин       1180
# Д.Медведев     262
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6649 entries, 0 to 6648
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           6649 non-null   object
#  1   url            6649 non-null   object
#  2   title          6649 non-null   object
#  3   speaker        6649 non-null   object
#  4   text           6649 non-null   object
#  5   text_clean     6649 non-null   object
#  6   word_count     6649 non-null   int64
#  7   lemma          6649 non-null   object
#  8   phrased_lemma  6649 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 467.6+ KB

# %%
# frpm MAC
df = pd.read_pickle('/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/corpus_president_of_russia/df_lemma_preprocessing.pkl')

# %%
#total words count
total_words=0
for sentence in df.phrased_lemma:
    total_words += len(sentence)

print("total number of words", total_words)
# Out:
# total number of words 3637525

# %% [markdown]
# ## filter data according to speaker

# %%
df_president = df[df['speaker'].isin(['В.Путин', 'Д.Медведев'])]
df_lavrov = df[df['speaker'] == 'С.Лавров']
print(df_president.info())
print(df_lavrov.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1442 entries, 0 to 5154
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1442 non-null   object
#  1   url            1442 non-null   object
#  2   title          1442 non-null   object
#  3   speaker        1442 non-null   object
#  4   text           1442 non-null   object
#  5   text_clean     1442 non-null   object
#  6   word_count     1442 non-null   int64
#  7   lemma          1442 non-null   object
#  8   phrased_lemma  1442 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 112.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 5207 entries, 46 to 6648
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           5207 non-null   object
#  1   url            5207 non-null   object
#  2   title          5207 non-null   object
#  3   speaker        5207 non-null   object
#  4   text           5207 non-null   object
#  5   text_clean     5207 non-null   object
#  6   word_count     5207 non-null   int64
#  7   lemma          5207 non-null   object
#  8   phrased_lemma  5207 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 406.8+ KB
# None

# %% [markdown]
# ### codebook

# %%
eurasianism = ['евразия',
               'русский_мир', 
               'цивилизация', 
               'доминирование_запад', 
               'правило_запад',
               'запад', 
               'гегемония',
               'исторический_ревизионизм']

westphalianism = [ 'оон',
                  'великодержавность',
                  'статус',
                  'принцип_суверенный',
                  'международное_право',
                  'демократический_справедливый',
                  'международное_право_норма', 
                  'ооноцентричной',
                  'суверенность']

# %%
security_concerns = [ 'национальная_безопасность',
                     'противовес',
                     'дестабилизация',
                     'нато',
                     'угроза',
                     'подменить_международное_право',
                     'порядок_основать', 
                     'однополярная',
                     'новый_мироустройство', 
                     'расширяться_восток',
                     'однополярный_модель', 
                     'однополярный', 
                     'военный_инфраструктура',
                     'стабильность']

multipolarism = ['многополярный', 
                 'партнёрство', 
                 'сотрудничество', 
                 'полицентричный',
                 'формирование_многополярный', 
                 'формирование_полицентричного', 
                 'демократический_полицентричного']

# %% [markdown]
# ### model training on df_president

# %%
# model: sg
# vector_size: 100
# n_neighbours: 30

# %%
sents = df_president['phrased_lemma']

model = Word2Vec(
    sents,
    vector_size=100, 
    min_count=0, 
    sg=1, 
    hs=0, 
    negative=5, 
    window=30, 
    workers=4,
    epochs = 100
)

# %%
model.wv.most_similar(positive = ['миропорядок'],topn=20)
# Out:
# [('основа_послевоенный', 0.5780996680259705),
#  ('суверенность', 0.576310396194458),
#  ('барыш', 0.5760592818260193),
#  ('оставаться_приоритетный', 0.5754704475402832),
#  ('создание_оон', 0.5754444003105164),
#  ('ялты', 0.5730659365653992),
#  ('модель_развитие', 0.572852611541748),
#  ('пытаться_действовать', 0.5717422366142273),
#  ('демократический_справедливый', 0.5681470632553101),
#  ('иметься_разногласие', 0.5679141879081726),
#  ('эгоизм', 0.5646154284477234),
#  ('судьба_мир', 0.5606570243835449),
#  ('исторический_ревизионизм', 0.5589326024055481),
#  ('стабильность_контроль', 0.558393120765686),
#  ('пересмотреть_решение', 0.5513536930084229),
#  ('оон', 0.5512755513191223),
#  ('происходить_ирак', 0.5486944317817688),
#  ('мировой_война', 0.5473155975341797),
#  ('основа_признание', 0.5448662042617798),
#  ('потсдам', 0.54439777135849)]

# %%
#save the model (from office)
model.wv.save_word2vec_format('models/model_president.bin', binary=True)

# %%
#read the model (from Mac)
model = KeyedVectors.load_word2vec_format('models/model_president.bin', binary=True)

# %% [markdown]
# #### compare similarity of миропорядок and concepts

# %%
#eurasianism
target_word = 'миропорядок'

for word in eurasianism:
    if word in model.wv.key_to_index:
        similarity_score = model.wv.similarity(target_word, word)
        print(f"Similarity between '{target_word}' and '{word}': {similarity_score}")
    else:
        print(f"Word '{word}' not found in the model vocabulary.")
# Out:
# Similarity between 'миропорядок' and 'евразия': 0.24765656888484955
# Similarity between 'миропорядок' and 'русский_мир': 0.10029808431863785
# Similarity between 'миропорядок' and 'цивилизация': 0.2897200584411621
# Similarity between 'миропорядок' and 'доминирование_запад': 0.31616562604904175
# Word 'правило_запад' not found in the model vocabulary.
# Similarity between 'миропорядок' and 'запад': 0.3861308693885803
# Similarity between 'миропорядок' and 'гегемония': 0.3281331956386566
# Similarity between 'миропорядок' and 'исторический_ревизионизм': 0.5589325428009033

# %%
#westphalianism
target_word = 'миропорядок'

for word in westphalianism:
    if word in model.wv.key_to_index:
        similarity_score = model.wv.similarity(target_word, word)
        print(f"Similarity between '{target_word}' and '{word}': {similarity_score}")
    else:
        print(f"Word '{word}' not found in the model vocabulary.")
# Out:
# Similarity between 'миропорядок' and 'оон': 0.5512754917144775
# Similarity between 'миропорядок' and 'великодержавность': 0.312639057636261
# Similarity between 'миропорядок' and 'статус': 0.11950218677520752
# Similarity between 'миропорядок' and 'принцип_суверенный': 0.5035377144813538
# Similarity between 'миропорядок' and 'международное_право': 0.47772637009620667
# Similarity between 'миропорядок' and 'демократический_справедливый': 0.5681471228599548
# Similarity between 'миропорядок' and 'международное_право_норма': 0.2981109619140625
# Word 'ооноцентричной' not found in the model vocabulary.
# Similarity between 'миропорядок' and 'суверенность': 0.5763103365898132

# %%
#security_concerns
target_word = 'миропорядок'

for word in security_concerns:
    if word in model.wv.key_to_index:
        similarity_score = model.wv.similarity(target_word, word)
        print(f"Similarity between '{target_word}' and '{word}': {similarity_score}")
    else:
        print(f"Word '{word}' not found in the model vocabulary.")
# Out:
# Similarity between 'миропорядок' and 'национальная_безопасность': 0.2768123149871826
# Similarity between 'миропорядок' and 'противовес': 0.1606745421886444
# Similarity between 'миропорядок' and 'дестабилизация': 0.2797945439815521
# Similarity between 'миропорядок' and 'нато': 0.327647864818573
# Similarity between 'миропорядок' and 'угроза': 0.4285593628883362
# Word 'подменить_международное_право' not found in the model vocabulary.
# Similarity between 'миропорядок' and 'порядок_основать': 0.31800001859664917
# Similarity between 'миропорядок' and 'однополярная': 0.47891393303871155
# Word 'новый_мироустройство' not found in the model vocabulary.
# Word 'расширяться_восток' not found in the model vocabulary.
# Similarity between 'миропорядок' and 'однополярный_модель': 0.5220150351524353
# Similarity between 'миропорядок' and 'однополярный': 0.4034838080406189
# Similarity between 'миропорядок' and 'военный_инфраструктура': 0.2322080135345459
# Similarity between 'миропорядок' and 'стабильность': 0.38676029443740845

# %%
#multipolarism
target_word = 'миропорядок'

for word in multipolarism:
    if word in model.wv.key_to_index:
        similarity_score = model.wv.similarity(target_word, word)
        print(f"Similarity between '{target_word}' and '{word}': {similarity_score}")
    else:
        print(f"Word '{word}' not found in the model vocabulary.")
# Out:
# Similarity between 'миропорядок' and 'многополярный': 0.5393487215042114
# Similarity between 'миропорядок' and 'партнёрство': 0.38272297382354736
# Similarity between 'миропорядок' and 'сотрудничество': 0.36457592248916626
# Similarity between 'миропорядок' and 'полицентричный': 0.43081212043762207
# Similarity between 'миропорядок' and 'формирование_многополярный': 0.43045470118522644
# Word 'формирование_полицентричного' not found in the model vocabulary.
# Word 'демократический_полицентричного' not found in the model vocabulary.

# %%
target_word = 'миропорядок'
concept_lists = {'eurasianism': eurasianism, 'westphalianism': westphalianism, 'security_concerns': security_concerns, 'multipolarism': multipolarism}
similarity_scores = {}

for concept, concept_list in concept_lists.items():
    concept_similarity_scores = {}
    for word in concept_list:
        if word in model.key_to_index and target_word in model.key_to_index:
            similarity_score = model.similarity(word, target_word)
            concept_similarity_scores[word] = similarity_score
    similarity_scores[concept] = concept_similarity_scores

print(similarity_scores)
# Out:
# {'eurasianism': {'евразия': 0.24765657, 'русский_мир': 0.100298084, 'цивилизация': 0.28972006, 'доминирование_запад': 0.31616563, 'запад': 0.38613087, 'гегемония': 0.3281332, 'исторический_ревизионизм': 0.55893254}, 'westphalianism': {'оон': 0.5512755, 'великодержавность': 0.31263906, 'статус': 0.11950219, 'принцип_суверенный': 0.5035377, 'международное_право': 0.47772637, 'демократический_справедливый': 0.5681471, 'международное_право_норма': 0.29811096, 'суверенность': 0.57631034}, 'security_concerns': {'национальная_безопасность': 0.27681231, 'противовес': 0.16067454, 'дестабилизация': 0.27979454, 'нато': 0.32764786, 'угроза': 0.42855936, 'порядок_основать': 0.31800002, 'однополярная': 0.47891393, 'однополярный_модель': 0.52201504, 'однополярный': 0.4034838, 'военный_инфраструктура': 0.23220801, 'стабильность': 0.3867603}, 'multipolarism': {'многополярный': 0.5393487, 'партнёрство': 0.38272297, 'сотрудничество': 0.36457592, 'полицентричный': 0.43081212, 'формирование_многополярный': 0.4304547}}

# %%
#### Mean of sim_scores
mean_similarity_scores = {}

for concept, similarity_scores in similarity_scores.items():
    scores = [score for score in similarity_scores.values() if score is not None]
    if scores:
        mean_similarity = sum(scores) / len(scores)
        mean_similarity_scores[concept] = mean_similarity

print(mean_similarity_scores)
# Out:
# {'eurasianism': 0.31814813507454737, 'westphalianism': 0.42590615525841713, 'security_concerns': 0.3468063392422416, 'multipolarism': 0.42958288788795473}

# %% [markdown]
# #### plot the cos_sim

# %%
# Create the "figures" directory if it doesn't exist
os.makedirs("figures", exist_ok=True)

# %%
concepts = list(mean_similarity_scores.keys())
scores = list(mean_similarity_scores.values())

plt.bar(concepts, scores, color=['red', 'blue', 'green', 'orange'])
plt.xlabel('Concepts')
plt.ylabel('Similarity Score')
plt.title('President of Russia (2004-2023)')
plt.ylim(0.0, 1.0)

plt.savefig("figures/similarity_scores_president.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### model training on df_lavrov - ministry of foreign affairs

# %%
# model: sg
# vector_size: 100
# n_neighbours: 30

# %%
sents = df_lavrov['phrased_lemma']

model = Word2Vec(
    sents,
    vector_size=100, 
    min_count=0, 
    sg=1, 
    hs=0, 
    negative=5, 
    window=30, 
    workers=4,
    epochs = 100
)

# %%
model.wv.most_similar(positive = ['миропорядок'],topn=20)
# Out:
# [('полицентричный', 0.8717437982559204),
#  ('справедливый_демократический', 0.8196866512298584),
#  ('многополярный', 0.8070980310440063),
#  ('международный_система', 0.7871850728988647),
#  ('объективный_процесс', 0.7828384041786194),
#  ('международный_отношение', 0.7809760570526123),
#  ('мировой_дело', 0.7777078151702881),
#  ('формирование_полицентричного', 0.7568362355232239),
#  ('формирование_справедливый', 0.7482756972312927),
#  ('справедливый_демократичный', 0.7255140542984009),
#  ('демократический_справедливый', 0.7183964252471924),
#  ('современный_мир', 0.7137557864189148),
#  ('мировой_политика', 0.7124815583229065),
#  ('отражать_культурно', 0.7113863825798035),
#  ('система_международный', 0.7037854194641113),
#  ('объективный_тенденция', 0.7025946974754333),
#  ('устав_оон', 0.7015862464904785),
#  ('модель_развитие', 0.6963783502578735),
#  ('демократичный', 0.6946595311164856),
#  ('объективно_формироваться', 0.6938616037368774)]

# %%
#save the model (from office)
model.wv.save_word2vec_format('models/model_lavrov.bin', binary=True)

# %%
#load model (from max)
model = KeyedVectors.load_word2vec_format('models/model_lavrov.bin', binary=True)

# %% [markdown]
# ##### compare target word and concepts

# %%
#eurasianism
target_word = 'миропорядок'

for word in eurasianism:
    if word in model.wv.key_to_index:
        similarity_score = model.wv.similarity(target_word, word)
        print(f"Similarity between '{target_word}' and '{word}': {similarity_score}")
    else:
        print(f"Word '{word}' not found in the model vocabulary.")
# Out:
# Similarity between 'миропорядок' and 'евразия': 0.3910239338874817
# Similarity between 'миропорядок' and 'русский_мир': 0.26330146193504333
# Similarity between 'миропорядок' and 'цивилизация': 0.5965651869773865
# Similarity between 'миропорядок' and 'доминирование_запад': 0.5792051553726196
# Similarity between 'миропорядок' and 'правило_запад': 0.579656720161438
# Similarity between 'миропорядок' and 'запад': 0.4629846513271332
# Similarity between 'миропорядок' and 'гегемония': 0.6030754446983337
# Similarity between 'миропорядок' and 'исторический_ревизионизм': 0.23695485293865204

# %%
#westphalianism
target_word = 'миропорядок'

for word in westphalianism:
    if word in model.wv.key_to_index:
        similarity_score = model.wv.similarity(target_word, word)
        print(f"Similarity between '{target_word}' and '{word}': {similarity_score}")
    else:
        print(f"Word '{word}' not found in the model vocabulary.")
# Out:
# Similarity between 'миропорядок' and 'оон': 0.4939163327217102
# Similarity between 'миропорядок' and 'великодержавность': 0.3066272437572479
# Similarity between 'миропорядок' and 'статус': 0.1836901605129242
# Similarity between 'миропорядок' and 'принцип_суверенный': 0.5152139067649841
# Similarity between 'миропорядок' and 'международное_право': 0.6902965307235718
# Similarity between 'миропорядок' and 'демократический_справедливый': 0.7183963656425476
# Similarity between 'миропорядок' and 'международное_право_норма': 0.49549055099487305
# Similarity between 'миропорядок' and 'ооноцентричной': 0.5608055591583252
# Similarity between 'миропорядок' and 'суверенность': 0.5548860430717468

# %%
#security_concerns
target_word = 'миропорядок'

for word in security_concerns:
    if word in model.wv.key_to_index:
        similarity_score = model.wv.similarity(target_word, word)
        print(f"Similarity between '{target_word}' and '{word}': {similarity_score}")
    else:
        print(f"Word '{word}' not found in the model vocabulary.")
# Out:
# Similarity between 'миропорядок' and 'национальная_безопасность': 0.17626459896564484
# Similarity between 'миропорядок' and 'противовес': 0.4809919595718384
# Similarity between 'миропорядок' and 'дестабилизация': 0.30706802010536194
# Similarity between 'миропорядок' and 'нато': 0.17297029495239258
# Similarity between 'миропорядок' and 'угроза': 0.37211960554122925
# Similarity between 'миропорядок' and 'подменить_международное_право': 0.5779725909233093
# Similarity between 'миропорядок' and 'порядок_основать': 0.6909120678901672
# Similarity between 'миропорядок' and 'однополярная': 0.5067741870880127
# Similarity between 'миропорядок' and 'новый_мироустройство': 0.6214396357536316
# Similarity between 'миропорядок' and 'расширяться_восток': 0.1606040745973587
# Similarity between 'миропорядок' and 'однополярный_модель': 0.636550784111023
# Similarity between 'миропорядок' and 'однополярный': 0.6485018134117126
# Similarity between 'миропорядок' and 'военный_инфраструктура': 0.09632354974746704
# Similarity between 'миропорядок' and 'стабильность': 0.36636775732040405

# %%
#multipolarism
target_word = 'миропорядок'

for word in multipolarism:
    if word in model.wv.key_to_index:
        similarity_score = model.wv.similarity(target_word, word)
        print(f"Similarity between '{target_word}' and '{word}': {similarity_score}")
    else:
        print(f"Word '{word}' not found in the model vocabulary.")
# Out:
# Similarity between 'миропорядок' and 'многополярный': 0.8070979714393616
# Similarity between 'миропорядок' and 'партнёрство': 0.37531188130378723
# Similarity between 'миропорядок' and 'сотрудничество': 0.3251774311065674
# Similarity between 'миропорядок' and 'полицентричный': 0.8717436790466309
# Similarity between 'миропорядок' and 'формирование_многополярный': 0.6345558166503906
# Similarity between 'миропорядок' and 'формирование_полицентричного': 0.7568362355232239
# Similarity between 'миропорядок' and 'демократический_полицентричного': 0.6646922826766968

# %%
target_word = 'миропорядок'
concept_lists = {'eurasianism': eurasianism, 'westphalianism': westphalianism, 'security_concerns': security_concerns, 'multipolarism': multipolarism}
similarity_scores = {}

for concept, concept_list in concept_lists.items():
    concept_similarity_scores = {}
    for word in concept_list:
        if word in model.key_to_index and target_word in model.key_to_index:
            similarity_score = model.similarity(word, target_word)
            concept_similarity_scores[word] = similarity_score
    similarity_scores[concept] = concept_similarity_scores

print(similarity_scores)
# Out:
# {'eurasianism': {'евразия': 0.39102393, 'русский_мир': 0.26330146, 'цивилизация': 0.5965652, 'доминирование_запад': 0.57920516, 'правило_запад': 0.5796567, 'запад': 0.46298465, 'гегемония': 0.60307544, 'исторический_ревизионизм': 0.23695485}, 'westphalianism': {'оон': 0.49391633, 'великодержавность': 0.30662724, 'статус': 0.18369016, 'принцип_суверенный': 0.5152139, 'международное_право': 0.69029653, 'демократический_справедливый': 0.71839637, 'международное_право_норма': 0.49549055, 'ооноцентричной': 0.56080556, 'суверенность': 0.55488604}, 'security_concerns': {'национальная_безопасность': 0.1762646, 'противовес': 0.48099196, 'дестабилизация': 0.30706802, 'нато': 0.1729703, 'угроза': 0.3721196, 'подменить_международное_право': 0.5779726, 'порядок_основать': 0.69091207, 'однополярная': 0.5067742, 'новый_мироустройство': 0.62143964, 'расширяться_восток': 0.16060407, 'однополярный_модель': 0.6365508, 'однополярный': 0.6485018, 'военный_инфраструктура': 0.09632355, 'стабильность': 0.36636776}, 'multipolarism': {'многополярный': 0.807098, 'партнёрство': 0.37531188, 'сотрудничество': 0.32517743, 'полицентричный': 0.8717437, 'формирование_многополярный': 0.6345558, 'формирование_полицентричного': 0.75683624, 'демократический_полицентричного': 0.6646923}}

# %%
#### Mean of sim_scores
mean_similarity_scores = {}

for concept, similarity_scores in similarity_scores.items():
    scores = [score for score in similarity_scores.values() if score is not None]
    if scores:
        mean_similarity = sum(scores) / len(scores)
        mean_similarity_scores[concept] = mean_similarity

print(mean_similarity_scores)
# Out:
# {'eurasianism': 0.464095925912261, 'westphalianism': 0.5021469659275479, 'security_concerns': 0.4153472099985395, 'multipolarism': 0.6336307568209512}

# %% [markdown]
# ##### plot the cos_sim

# %%
concepts = list(mean_similarity_scores.keys())
scores = list(mean_similarity_scores.values())

plt.bar(concepts, scores, color=['red', 'blue', 'green', 'orange'])
plt.xlabel('Concepts')
plt.ylabel('Similarity Score')
plt.title('Lavrov (2003-2023)')
plt.ylim(0.0, 1.0)

plt.savefig("figures/similarity_scores_lavrov.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## filter data according to time

# %%
#trasnform date into datetime
df['date'] = pd.to_datetime(df.date)
df['date'] = df['date'].dt.strftime('%Y-%m-%d')
df['date'].sort_values()
# Out:
# 0       2003-10-06
# 1       2003-11-11
# 2       2003-11-13
# 3       2003-12-03
# 4       2004-01-12
#            ...
# 4786    2022-12-15
# 4787    2022-12-21
# 4832    2023-01-13
# 4792    2023-02-21
# 4788    2023-02-21
# Name: date, Length: 6649, dtype: object

# %%
# create boolean masks for each date range
mask1 = (df['date'] >= '2003-01-01') & (df['date'] <= '2008-03-02')
mask2 = (df['date'] >= '2008-03-03') & (df['date'] <= '2012-03-04')
mask3 = (df['date'] >= '2012-03-05') & (df['date'] <= '2018-03-18')
mask4 = (df['date'] >= '2018-03-19') & (df['date'] <= '2023-12-31')

# %%
# create smaller dataframes using boolean indexing
t1 = df.loc[mask1] # second Putin's mandate (plus_ a couple of doc from 2003 in Lavrov's):2004-2008
t2 = df.loc[mask2] # Medvedev: 2008-2012
t3 = df.loc[mask3] # third Putin's mandate: 2012-2018
t4 = df.loc[mask4] # fourth Putin's mandate: 2018 - till present (2023)

# %%
# Save the four dataframes in separate pickle files (from office)
t1.to_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t1.pkl')
t2.to_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t2.pkl')
t3.to_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t3.pkl')
t4.to_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t4.pkl')

# %%
# read each era from office
t1 = pd.read_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t1.pkl')
t2 = pd.read_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t2.pkl')
t3 = pd.read_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t3.pkl')
t4 = pd.read_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t4.pkl')

# %%
# read each era from MAC
t1 = pd.read_pickle('/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/corpus_president_of_russia/t1.pkl')
t2 = pd.read_pickle('/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/corpus_president_of_russia/t2.pkl')
t3 = pd.read_pickle('/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/corpus_president_of_russia/t3.pkl')
t4 = pd.read_pickle('/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/corpus_president_of_russia/t4.pkl')

# %%
print(t1.info())
print(t2.info())
print(t3.info())
print(t4.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 0 to 1037
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1038 non-null   object
#  1   url            1038 non-null   object
#  2   title          1038 non-null   object
#  3   speaker        1038 non-null   object
#  4   text           1038 non-null   object
#  5   text_clean     1038 non-null   object
#  6   word_count     1038 non-null   int64
#  7   lemma          1038 non-null   object
#  8   phrased_lemma  1038 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 81.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1133 entries, 1038 to 2170
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1133 non-null   object
#  1   url            1133 non-null   object
#  2   title          1133 non-null   object
#  3   speaker        1133 non-null   object
#  4   text           1133 non-null   object
#  5   text_clean     1133 non-null   object
#  6   word_count     1133 non-null   int64
#  7   lemma          1133 non-null   object
#  8   phrased_lemma  1133 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 88.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2482 entries, 2171 to 4652
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           2482 non-null   object
#  1   url            2482 non-null   object
#  2   title          2482 non-null   object
#  3   speaker        2482 non-null   object
#  4   text           2482 non-null   object
#  5   text_clean     2482 non-null   object
#  6   word_count     2482 non-null   int64
#  7   lemma          2482 non-null   object
#  8   phrased_lemma  2482 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 193.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1996 entries, 4653 to 6648
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1996 non-null   object
#  1   url            1996 non-null   object
#  2   title          1996 non-null   object
#  3   speaker        1996 non-null   object
#  4   text           1996 non-null   object
#  5   text_clean     1996 non-null   object
#  6   word_count     1996 non-null   int64
#  7   lemma          1996 non-null   object
#  8   phrased_lemma  1996 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 155.9+ KB
# None

# %% [markdown]
# ### Codebook

# %%
eurasianism = ['евразия',
               'русский_мир', 
               'цивилизация', 
               'доминирование_запад', 
               'правило_запад',
               'запад', 
               'гегемония',
               'исторический_ревизионизм']

westphalianism = [ 'оон',
                  'великодержавность',
                  'статус',
                  'принцип_суверенный',
                  'международное_право',
                  'демократический_справедливый',
                  'международное_право_норма', 
                  'ооноцентричной',
                  'суверенность']

# %%
security_concerns = [ 'национальная_безопасность',
                     'противовес',
                     'дестабилизация',
                     'нато',
                     'угроза',
                     'подменить_международное_право',
                     'порядок_основать', 
                     'однополярная',
                     'новый_мироустройство', 
                     'расширяться_восток',
                     'однополярный_модель', 
                     'однополярный', 
                     'военный_инфраструктура']

multipolarism = ['многополярный', 
                 'партнёрство', 
                 'сотрудничество', 
                 'полицентричный',
                 'формирование_многополярный', 
                 'формирование_полицентричного', 
                 'демократический_полицентричного']

# %%
concept_lists = [eurasianism, westphalianism, security_concerns, multipolarism]

# %% [markdown]
# ### transform data in list of lists

# %%
#transform each timeframe df in a list
era1 = t1['phrased_lemma'].tolist()
era2 = t2['phrased_lemma'].tolist()
era3 = t3['phrased_lemma'].tolist()
era4 = t4['phrased_lemma'].tolist()

# %%
print(len(era1))
print(len(era2))
print(len(era3))
print(len(era4))
# Out:
# 1038
# 1133
# 2482
# 1996

# %%
#create a list of eras

list_of_lists = []
list_of_lists.append(era1)
list_of_lists.append(era2)
list_of_lists.append(era3)
list_of_lists.append(era4)

# %%
len(list_of_lists)
# Out:
# 4

# %%
# Save the object to a file
with open("list_of_lists.pkl", 'wb') as file:
    pickle.dump(list_of_lists, file)

# %%
#load the object
file_path = "list_of_lists.pkl"

# Load the object from the file
with open(file_path, 'rb') as file:
    list_of_lists = pickle.load(file)

# %%
word_freqs =  [Counter(sent) for sent in list_of_lists[0]]
# print the top 10 most common words in the first document
print(word_freqs[0].most_common(10))
# Out:
# [('власть', 7), ('федерация', 4), ('самоуправление', 3), ('правительство', 3), ('чечня', 3), ('закон_местный', 2), ('работать', 2), ('знать', 2), ('дополнительный_гарантия', 2), ('закон', 2)]

# %% [markdown]
# #### count target_word

# %%
word_count = 0
for doc in t4['phrased_lemma']:
    if 'миропорядок' in doc:
        word_count += doc.count('миропорядок')

print(f"'миропорядок' appears {word_count} times in the 'phrased_lemma' column of the DataFrame.")
# Out:
# 'миропорядок' appears 273 times in the 'phrased_lemma' column of the DataFrame.

# %%
t1['phrased_lemma'].head()
# Out:
# 0    [добрый_день, уважаемый_коллега, сегодня_подпи...
# 1    [добрый_день, уважаемый_друг, коллега, позволи...
# 2    [добрый_день, уважаемый_коллега, повестка_день...
# 3    [добрый_день, уважаемый_коллега, сегодняшний_п...
# 4    [добрый_день, уважаемый_коллега, сегодня_прово...
# Name: phrased_lemma, dtype: object

# %% [markdown]
# ### Iterating over lists of sentences by era to do era-by-era word2vec modeling

# %% [markdown]
# #### Bootstrap 1

# %%
n_bootstraps = 1
target_word = 'миропорядок'
vector_size=100 
min_count=2 
sg=1 
hs=0 
negative=5 
window=30 
workers=4 
epochs=100

# %%
#print the progress for each run
def word_embedding(list_of_lists, target_word, eurasianism, westphalianism, security_concerns, multipolarism, 
                   n_bootstraps=n_bootstraps, vector_size=vector_size, min_count=min_count, sg=sg, 
                   hs=hs, negative=negative, window=window, workers=workers, epochs=epochs):
    
    scores = {}
    
    for j in range(len(list_of_lists)):
        era_scores = {}
        start_time = time.time()
        for k in range(n_bootstraps):
            sentence_samples = resample(list_of_lists[j])
            model = Word2Vec(
                sentence_samples,
                vector_size=vector_size, 
                min_count=min_count, 
                sg=sg, 
                hs=hs, 
                negative=negative, 
                window=window, 
                workers=workers,
                epochs=epochs
            )

            eurasianism_scores = []
            westphalianism_scores = []
            security_concerns_scores = []
            multipolarism_scores = []

            for word in eurasianism:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    eurasianism_scores.append(similarity_score)
                else:
                    eurasianism_scores.append('NA')

            for word in westphalianism:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    westphalianism_scores.append(similarity_score)
                else:
                    westphalianism_scores.append('NA')

            for word in security_concerns:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    security_concerns_scores.append(similarity_score)
                else:
                    security_concerns_scores.append('NA')

            for word in multipolarism:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    multipolarism_scores.append(similarity_score)
                else:
                    multipolarism_scores.append('NA')

            era_scores[k] = {
                'eurasianism': eurasianism_scores,
                'westphalianism': westphalianism_scores,
                'security_concerns': security_concerns_scores,
                'multipolarism': multipolarism_scores
            }
            
            # Print progress for each run
            print("Finished with run %d out of %d for era %d" % (k+1, n_bootstraps, j+1))
            
        scores[j] = era_scores
        
        end_time = time.time()
        era = j+1
        print("Finished with era %d in %.2f seconds." % (era, end_time-start_time))
        
    print("*******Finished with all eras.*******")
    
    return scores

# %%
scores = word_embedding(list_of_lists, target_word, eurasianism, westphalianism, security_concerns, multipolarism, 
               n_bootstraps = n_bootstraps, vector_size=vector_size, min_count=min_count, sg=sg, hs=hs, negative=negative, 
               window=window, workers=workers, epochs=epochs)

# %%
scores
# Out:
# {0: {0: {'eurasianism': [0.24020499,
#     0.04616564,
#     0.4281209,
#     'NA',
#     'NA',
#     0.31814328,
#     'NA'],
#    'westphalianism': [0.34797907,
#     'NA',
#     0.049718715,
#     0.34105372,
#     0.3788538,
#     0.540496,
#     'NA',
#     'NA'],
#    'security_concerns': [0.21594404,
#     0.17258343,
#     0.18759382,
#     0.0892711,
#     0.3124377,
#     'NA',
#     'NA',
#     'NA',
#     0.485964,
#     'NA',
#     'NA',
#     0.38715616,
#     0.20799051],
#    'multipolarism': [0.4912367,
#     0.035349432,
#     0.19190118,
#     'NA',
#     'NA',
#     'NA',
#     'NA']}},
#  1: {0: {'eurasianism': [0.21877506,
#     0.27081355,
#     0.33106706,
#     0.36956027,
#     'NA',
#     0.22912292,
#     0.15011434],
#    'westphalianism': [0.3404446,
#     'NA',
#     -0.053720046,
#     'NA',
#     0.32228217,
#     0.27334717,
#     'NA',
#     'NA'],
#    'security_concerns': [0.10136472,
#     0.32170203,
#     0.22874717,
#     0.15813214,
#     0.33350313,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.35080466,
#     0.20446427],
#    'multipolarism': [0.44506273,
#     0.31017554,
#     0.31856322,
#     0.5845984,
#     0.3791715,
#     0.71591043,
#     0.4468908]}},
#  2: {0: {'eurasianism': [0.2689929,
#     0.18699314,
#     0.49616635,
#     0.40325454,
#     'NA',
#     0.2940561,
#     0.4370848],
#    'westphalianism': [0.3442626,
#     'NA',
#     0.20489432,
#     0.21451098,
#     0.41539338,
#     0.70602953,
#     0.3553678,
#     'NA'],
#    'security_concerns': [0.096868455,
#     0.30371228,
#     0.26154664,
#     0.1019153,
#     0.3472059,
#     'NA',
#     'NA',
#     'NA',
#     0.520681,
#     'NA',
#     0.6409021,
#     0.48227823,
#     0.09280784],
#    'multipolarism': [0.67245317,
#     0.3622719,
#     0.32376066,
#     0.79580194,
#     0.5283363,
#     0.6696334,
#     0.5168099]}},
#  3: {0: {'eurasianism': [0.23016088,
#     0.16438672,
#     0.3101435,
#     0.45900676,
#     0.5831936,
#     0.51667833,
#     0.4993385],
#    'westphalianism': [0.47722602,
#     0.16316606,
#     0.15573063,
#     0.4942312,
#     0.6249817,
#     0.41627362,
#     0.3415958,
#     0.5352251],
#    'security_concerns': [0.030732535,
#     0.45698333,
#     0.181207,
#     0.24441804,
#     0.28963837,
#     0.5525778,
#     0.7147499,
#     0.46794823,
#     0.36498114,
#     0.25967255,
#     0.4502059,
#     0.49226236,
#     0.10607727],
#    'multipolarism': [0.6209686,
#     0.3570177,
#     0.27113426,
#     0.6216254,
#     0.52554727,
#     0.4968855,
#     0.44965228]}}}

# %%
# initialize empty dictionary to store the scores
stat_types = {}

# loop through each target word and its scores
for target_word, target_scores in scores.items():

    # initialize empty dictionary to store the scores for this target word
    target_stat_types = {}

    # loop through each era and its scores for this target word
    for era, era_scores in target_scores.items():

        # initialize empty dictionary to store the scores for this era
        era_stat_types = {}

        # loop through each statistical type and its score for this era
        for stat_type, score in era_scores.items():
            era_stat_types[stat_type] = score

        # add the scores for this era to the scores for this target word
        target_stat_types[era] = era_stat_types

    # add the scores for this target word to the overall dictionary of scores
    stat_types[target_word] = target_stat_types

# %%
stat_types
# Out:
# {0: {0: {'eurasianism': [0.24020499,
#     0.04616564,
#     0.4281209,
#     'NA',
#     'NA',
#     0.31814328,
#     'NA'],
#    'westphalianism': [0.34797907,
#     'NA',
#     0.049718715,
#     0.34105372,
#     0.3788538,
#     0.540496,
#     'NA',
#     'NA'],
#    'security_concerns': [0.21594404,
#     0.17258343,
#     0.18759382,
#     0.0892711,
#     0.3124377,
#     'NA',
#     'NA',
#     'NA',
#     0.485964,
#     'NA',
#     'NA',
#     0.38715616,
#     0.20799051],
#    'multipolarism': [0.4912367,
#     0.035349432,
#     0.19190118,
#     'NA',
#     'NA',
#     'NA',
#     'NA']}},
#  1: {0: {'eurasianism': [0.21877506,
#     0.27081355,
#     0.33106706,
#     0.36956027,
#     'NA',
#     0.22912292,
#     0.15011434],
#    'westphalianism': [0.3404446,
#     'NA',
#     -0.053720046,
#     'NA',
#     0.32228217,
#     0.27334717,
#     'NA',
#     'NA'],
#    'security_concerns': [0.10136472,
#     0.32170203,
#     0.22874717,
#     0.15813214,
#     0.33350313,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.35080466,
#     0.20446427],
#    'multipolarism': [0.44506273,
#     0.31017554,
#     0.31856322,
#     0.5845984,
#     0.3791715,
#     0.71591043,
#     0.4468908]}},
#  2: {0: {'eurasianism': [0.2689929,
#     0.18699314,
#     0.49616635,
#     0.40325454,
#     'NA',
#     0.2940561,
#     0.4370848],
#    'westphalianism': [0.3442626,
#     'NA',
#     0.20489432,
#     0.21451098,
#     0.41539338,
#     0.70602953,
#     0.3553678,
#     'NA'],
#    'security_concerns': [0.096868455,
#     0.30371228,
#     0.26154664,
#     0.1019153,
#     0.3472059,
#     'NA',
#     'NA',
#     'NA',
#     0.520681,
#     'NA',
#     0.6409021,
#     0.48227823,
#     0.09280784],
#    'multipolarism': [0.67245317,
#     0.3622719,
#     0.32376066,
#     0.79580194,
#     0.5283363,
#     0.6696334,
#     0.5168099]}},
#  3: {0: {'eurasianism': [0.23016088,
#     0.16438672,
#     0.3101435,
#     0.45900676,
#     0.5831936,
#     0.51667833,
#     0.4993385],
#    'westphalianism': [0.47722602,
#     0.16316606,
#     0.15573063,
#     0.4942312,
#     0.6249817,
#     0.41627362,
#     0.3415958,
#     0.5352251],
#    'security_concerns': [0.030732535,
#     0.45698333,
#     0.181207,
#     0.24441804,
#     0.28963837,
#     0.5525778,
#     0.7147499,
#     0.46794823,
#     0.36498114,
#     0.25967255,
#     0.4502059,
#     0.49226236,
#     0.10607727],
#    'multipolarism': [0.6209686,
#     0.3570177,
#     0.27113426,
#     0.6216254,
#     0.52554727,
#     0.4968855,
#     0.44965228]}}}

# %%
### Saving the model
with open('models/naive_model_entire_corpus_one_bootstrap.pkl', 'wb') as f:
    pickle.dump(stat_types, f)

# %%
### Saving the model
with open('models/naive_model_entire_corpus_one_bootstrap.pkl', 'wb') as f:
    pickle.dump(stat_types, f)

# %%
### Loading the model
with open('models/naive_model_entire_corpus_one_bootstrap.pkl', 'rb') as f:
    stat_types = pickle.load(f)

# %%
stat_types
# Out:
# {0: {0: {'eurasianism': [0.24020499,
#     0.04616564,
#     0.4281209,
#     'NA',
#     'NA',
#     0.31814328,
#     'NA'],
#    'westphalianism': [0.34797907,
#     'NA',
#     0.049718715,
#     0.34105372,
#     0.3788538,
#     0.540496,
#     'NA',
#     'NA'],
#    'security_concerns': [0.21594404,
#     0.17258343,
#     0.18759382,
#     0.0892711,
#     0.3124377,
#     'NA',
#     'NA',
#     'NA',
#     0.485964,
#     'NA',
#     'NA',
#     0.38715616,
#     0.20799051],
#    'multipolarism': [0.4912367,
#     0.035349432,
#     0.19190118,
#     'NA',
#     'NA',
#     'NA',
#     'NA']}},
#  1: {0: {'eurasianism': [0.21877506,
#     0.27081355,
#     0.33106706,
#     0.36956027,
#     'NA',
#     0.22912292,
#     0.15011434],
#    'westphalianism': [0.3404446,
#     'NA',
#     -0.053720046,
#     'NA',
#     0.32228217,
#     0.27334717,
#     'NA',
#     'NA'],
#    'security_concerns': [0.10136472,
#     0.32170203,
#     0.22874717,
#     0.15813214,
#     0.33350313,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.35080466,
#     0.20446427],
#    'multipolarism': [0.44506273,
#     0.31017554,
#     0.31856322,
#     0.5845984,
#     0.3791715,
#     0.71591043,
#     0.4468908]}},
#  2: {0: {'eurasianism': [0.2689929,
#     0.18699314,
#     0.49616635,
#     0.40325454,
#     'NA',
#     0.2940561,
#     0.4370848],
#    'westphalianism': [0.3442626,
#     'NA',
#     0.20489432,
#     0.21451098,
#     0.41539338,
#     0.70602953,
#     0.3553678,
#     'NA'],
#    'security_concerns': [0.096868455,
#     0.30371228,
#     0.26154664,
#     0.1019153,
#     0.3472059,
#     'NA',
#     'NA',
#     'NA',
#     0.520681,
#     'NA',
#     0.6409021,
#     0.48227823,
#     0.09280784],
#    'multipolarism': [0.67245317,
#     0.3622719,
#     0.32376066,
#     0.79580194,
#     0.5283363,
#     0.6696334,
#     0.5168099]}},
#  3: {0: {'eurasianism': [0.23016088,
#     0.16438672,
#     0.3101435,
#     0.45900676,
#     0.5831936,
#     0.51667833,
#     0.4993385],
#    'westphalianism': [0.47722602,
#     0.16316606,
#     0.15573063,
#     0.4942312,
#     0.6249817,
#     0.41627362,
#     0.3415958,
#     0.5352251],
#    'security_concerns': [0.030732535,
#     0.45698333,
#     0.181207,
#     0.24441804,
#     0.28963837,
#     0.5525778,
#     0.7147499,
#     0.46794823,
#     0.36498114,
#     0.25967255,
#     0.4502059,
#     0.49226236,
#     0.10607727],
#    'multipolarism': [0.6209686,
#     0.3570177,
#     0.27113426,
#     0.6216254,
#     0.52554727,
#     0.4968855,
#     0.44965228]}}}

# %%
#how the dict is structured
for key in stat_types.keys():
    print(key)
    for subkey in stat_types[key].keys():
       print(subkey)
       for subsubkey in stat_types[key][subkey].keys():
            print(subsubkey)
# Out:
# 0
# 0
# eurasianism
# westphalianism
# security_concerns
# multipolarism
# 1
# 0
# eurasianism
# westphalianism
# security_concerns
# multipolarism
# 2
# 0
# eurasianism
# westphalianism
# security_concerns
# multipolarism
# 3
# 0
# eurasianism
# westphalianism
# security_concerns
# multipolarism

# %%
for era in stat_types:
   for boostrap in stat_types[era]:
      print(f"Boostrap: {boostrap}, Era: {era}")
      for topic in stat_types[era][boostrap]:
        scores = stat_types[era][boostrap][topic]
        print(f"Topic: {topic}, Scores: {scores}")
# Out:
# Boostrap: 0, Era: 0
# Topic: eurasianism, Scores: [0.24020499, 0.04616564, 0.4281209, 'NA', 'NA', 0.31814328, 'NA']
# Topic: westphalianism, Scores: [0.34797907, 'NA', 0.049718715, 0.34105372, 0.3788538, 0.540496, 'NA', 'NA']
# Topic: security_concerns, Scores: [0.21594404, 0.17258343, 0.18759382, 0.0892711, 0.3124377, 'NA', 'NA', 'NA', 0.485964, 'NA', 'NA', 0.38715616, 0.20799051]
# Topic: multipolarism, Scores: [0.4912367, 0.035349432, 0.19190118, 'NA', 'NA', 'NA', 'NA']
# Boostrap: 0, Era: 1
# Topic: eurasianism, Scores: [0.21877506, 0.27081355, 0.33106706, 0.36956027, 'NA', 0.22912292, 0.15011434]
# Topic: westphalianism, Scores: [0.3404446, 'NA', -0.053720046, 'NA', 0.32228217, 0.27334717, 'NA', 'NA']
# Topic: security_concerns, Scores: [0.10136472, 0.32170203, 0.22874717, 0.15813214, 0.33350313, 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 0.35080466, 0.20446427]
# Topic: multipolarism, Scores: [0.44506273, 0.31017554, 0.31856322, 0.5845984, 0.3791715, 0.71591043, 0.4468908]
# Boostrap: 0, Era: 2
# Topic: eurasianism, Scores: [0.2689929, 0.18699314, 0.49616635, 0.40325454, 'NA', 0.2940561, 0.4370848]
# Topic: westphalianism, Scores: [0.3442626, 'NA', 0.20489432, 0.21451098, 0.41539338, 0.70602953, 0.3553678, 'NA']
# Topic: security_concerns, Scores: [0.096868455, 0.30371228, 0.26154664, 0.1019153, 0.3472059, 'NA', 'NA', 'NA', 0.520681, 'NA', 0.6409021, 0.48227823, 0.09280784]
# Topic: multipolarism, Scores: [0.67245317, 0.3622719, 0.32376066, 0.79580194, 0.5283363, 0.6696334, 0.5168099]
# Boostrap: 0, Era: 3
# Topic: eurasianism, Scores: [0.23016088, 0.16438672, 0.3101435, 0.45900676, 0.5831936, 0.51667833, 0.4993385]
# Topic: westphalianism, Scores: [0.47722602, 0.16316606, 0.15573063, 0.4942312, 0.6249817, 0.41627362, 0.3415958, 0.5352251]
# Topic: security_concerns, Scores: [0.030732535, 0.45698333, 0.181207, 0.24441804, 0.28963837, 0.5525778, 0.7147499, 0.46794823, 0.36498114, 0.25967255, 0.4502059, 0.49226236, 0.10607727]
# Topic: multipolarism, Scores: [0.6209686, 0.3570177, 0.27113426, 0.6216254, 0.52554727, 0.4968855, 0.44965228]

# %%
# check which words have been included and which not
# warning! it can overwrite scores and alter results in means and CI

concept_lists = [eurasianism, westphalianism, security_concerns, multipolarism]
topic_names = ['eurasianism', 'westphalianism', 'security_concerns', 'multipolarism']

for era in stat_types:
    for boostrapd in stat_types[era]:
        print(f"boostrap: {boostrap}, Era: {era}")
        for topic_idx, topic in enumerate(stat_types[era][boostrap]):
            scores = stat_types[era][boostrap][topic]
            concept_list = concept_lists[topic_idx]  # Get the corresponding concept list
            topic_name = topic_names[topic_idx]  # Get the corresponding topic name
            for i, score in enumerate(scores):
                if score != 'NA':
                    word = concept_list[i]  # Get the corresponding word from the concept list
                    print(f"Topic: {topic_name}, Word: {word}, Score: {score}")
                else:
                    word = concept_list[i]  # Get the corresponding word from the concept list
                    print(f"Topic: {topic_name}, Word: {word}, Score: NA")
        print()
# Out:
# boostrap: 0, Era: 0
# Topic: eurasianism, Word: евразия, Score: 0.24020498991012573
# Topic: eurasianism, Word: русский_мир, Score: 0.04616564139723778
# Topic: eurasianism, Word: цивилизация, Score: 0.4281209111213684
# Topic: eurasianism, Word: доминирование_запад, Score: NA
# Topic: eurasianism, Word: правило_запад, Score: NA
# Topic: eurasianism, Word: запад, Score: 0.3181432783603668
# Topic: eurasianism, Word: гегемония, Score: NA
# Topic: westphalianism, Word: оон, Score: 0.3479790687561035
# Topic: westphalianism, Word: великодержавность, Score: NA
# Topic: westphalianism, Word: статус, Score: 0.049718715250492096
# Topic: westphalianism, Word: принцип_суверенный, Score: 0.34105372428894043
# Topic: westphalianism, Word: международное_право, Score: 0.37885379791259766
# Topic: westphalianism, Word: демократический_справедливый, Score: 0.5404959917068481
# Topic: westphalianism, Word: международное_право_норма, Score: NA
# Topic: westphalianism, Word: ооноцентричной, Score: NA
# Topic: security_concerns, Word: национальная_безопасность, Score: 0.21594403684139252
# Topic: security_concerns, Word: противовес, Score: 0.1725834310054779
# Topic: security_concerns, Word: дестабилизация, Score: 0.18759381771087646
# Topic: security_concerns, Word: нато, Score: 0.08927109837532043
# Topic: security_concerns, Word: угроза, Score: 0.3124377131462097
# Topic: security_concerns, Word: подменить_международное_право, Score: NA
# Topic: security_concerns, Word: порядок_основать, Score: NA
# Topic: security_concerns, Word: однополярная, Score: NA
# Topic: security_concerns, Word: новый_мироустройство, Score: 0.48596400022506714
# Topic: security_concerns, Word: расширяться_восток, Score: NA
# Topic: security_concerns, Word: однополярный_модель, Score: NA
# Topic: security_concerns, Word: однополярный, Score: 0.3871561586856842
# Topic: security_concerns, Word: военный_инфраструктура, Score: 0
# Topic: westphalianism, Word: принцип_суверенный, Score: 0.4942311942577362
# Topic: westphalianism, Word: международное_право, Score: 0.624981701374054
# Topic: westphalianism, Word: демократический_справедливый, Score: 0.4162736237049103
# Topic: westphalianism, Word: международное_право_норма, Score: 0.3415957987308502
# Topic: westphalianism, Word: ооноцентричной, Score: 0.5352250933647156
# Topic: security_concerns, Word: национальная_безопасность, Score: 0.03073253482580185
# Topic: security_concerns, Word: противовес, Score: 0.4569833278656006
# Topic: security_concerns, Word: дестабилизация, Score: 0.18120700120925903
# Topic: security_concerns, Word: нато, Score: 0.24441803991794586
# Topic: security_concerns, Word: угроза, Score: 0.28963837027549744
# Topic: security_concerns, Word: подменить_международное_право, Score: 0.552577793598175
# Topic: security_concerns, Word: порядок_основать, Score: 0.7147498726844788
# Topic: security_concerns, Word: однополярная, Score: 0.46794822812080383
# Topic: security_concerns, Word: новый_мироустройство, Score: 0.36498114466667175
# Topic: security_concerns, Word: расширяться_восток, Score: 0.2596725523471832
# Topic: security_concerns, Word: однополярный_модель, Score: 0.45020589232444763
# Topic: security_concerns, Word: однополярный, Score: 0.4922623634338379
# Topic: security_concerns, Word: военный_инфраструктура, Score: 0.10607726871967316
# Topic: multipolarism, Word: многополярный, Score: 0.6209685802459717
# Topic: multipolarism, Word: партнёрство, Score: 0.3570176959037781
# Topic: multipolarism, Word: сотрудничество, Score: 0.27113425731658936
# Topic: multipolarism, Word: полицентричный, Score: 0.6216254234313965
# Topic: multipolarism, Word: формирование_многополярный, Score: 0.5255472660064697
# Topic: multipolarism, Word: формирование_полицентричного, Score: 0.4968855082988739
# Topic: multipolarism, Word: демократический_полицентричного, Score: 0.4496522843837738

# %% [markdown]
# ##### calculate the mean and the CI

# %%
means_wCI = []

# %%
## calculate means for nonNA vectors and CI
for era in stat_types:
    stats = []
    for boostrap in stat_types[era]:
        for topic in stat_types[era][boostrap]:
            scores = stat_types[era][boostrap][topic]
            non_na_scores = [score for score in scores if score != 'NA' and score is not None] # filter out None values
            test = np.asarray(non_na_scores)
            if len(test) > 0: # check if there are any non-NA values
                test_mean = test.mean()
                test_error = 1.95 * (test.std() / math.sqrt(len(non_na_scores)))
                test_ci = (test_mean - test_error, test_mean + test_error)
                test_stats = test_mean, test_ci
                stats.append(test_stats)
    means_wCI.append(stats)

# %%
means_wCI 
#The output of the code would be a list of statistics 
#The mean value 0.2581587 is the average of the non-'NA' scores for that particular target word and topic. 
#It is calculated by summing up all the non-'NA' scores and dividing the sum by the total count of non-'NA' scores
# Out:
# [[(0.2581587, (0.12222688421607017, 0.3940905429422855)),
#   (0.33162028, (0.19335707247677705, 0.46988347947177034)),
#   (0.2573676, (0.17413446928324944, 0.34060075257954353)),
#   (0.23949575, (0.026562985795988425, 0.4524285226878983))],
#  [(0.26157552, (0.2035434361318665, 0.31960760394534293)),
#   (0.22058848, (0.0643329493701458, 0.3768440015614033)),
#   (0.24267402, (0.17736866778358884, 0.3079793780423694)),
#   (0.4571961, (0.3566245378668493, 0.5577676354234035))],
#  [(0.34775797, (0.2629975169679969, 0.4325184136846215)),
#   (0.37340978, (0.24050905241898118, 0.5063105033404487)),
#   (0.3164353, (0.19332400783896447, 0.43954660668969153)),
#   (0.5527239, (0.4353032822733123, 0.6701444868917268))],
#  [(0.3947012, (0.28582279933162585, 0.5035796259575283)),
#   (0.4010538, (0.2911847662355842, 0.5109228063199578)),
#   (0.35472727, (0.2549437286080008, 0.4545108078299875)),
#   (0.47754726, (0.3886144462608239, 0.5664800700164894))]]

# %%
# define the file path
file_path = "models/means_wCI_entire_corpus_one_bootstrap.pkl"

# save the object to file
with open(file_path, 'wb') as f:
    pickle.dump(means_wCI, f)

# %% [markdown]
# ##### plot each concept cos sim evolution over time

# %%
# load the object from file
with open("models/means_wCI_entire_corpus_one_bootstrap.pkl", 'rb') as f:
    means_wCI = pickle.load(f)

# %% [markdown]
# ##### eurasianism

# %%
eurasianism_means = [era[0][0] for era in means_wCI]

# %%
eurasianism_means
# Out:
# [0.2581587, 0.26157552, 0.34775797, 0.3947012]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(eurasianism_means, marker="o", markersize=10, linewidth=2)
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'eurasianism' - 'word order' Cosine similarity")
plt.ylim(0.0, 1.0)
plt.savefig("figures/similarity_scores_eurasianism.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### westphalianism

# %%
westphalianism_means = [era[1][0] for era in means_wCI]

# %%
westphalianism_means
# Out:
# [0.33162028, 0.22058848, 0.37340978, 0.4010538]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(westphalianism_means, marker="o", markersize=10, linewidth=2,color='purple')
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'westphalianism' - 'word order' Cosine similarity")
plt.ylim(0.0, 1.0)
plt.savefig("figures/similarity_scores_westphalianism.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### security_concerns

# %%
sec_con_means = [era[2][0] for era in means_wCI]

# %%
sec_con_means
# Out:
# [0.2573676, 0.24267402, 0.3164353, 0.35472727]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(sec_con_means, marker="o", markersize=10, linewidth=2,color='green')
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'security concerns' - 'word order' Cosine similarity")
plt.ylim(0.0, 1.0)
plt.savefig("figures/similarity_scores_security_concerns.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### multipolarism

# %%
multipolarism_means = [era[3][0] for era in means_wCI]

# %%
multipolarism_means
# Out:
# [0.23949575, 0.4571961, 0.5527239, 0.47754726]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(multipolarism_means, marker="o", markersize=10, linewidth=2,color='red')
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'multipolarism' - 'word order' Cosine similarity")
plt.ylim(0.0, 1.0)
plt.savefig("figures/similarity_scores_multipolarism.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 50 Bootstraps

# %%
n_bootstraps = 50
target_word = 'миропорядок'
vector_size=100 
min_count=2 
sg=1 
hs=0 
negative=5 
window=30 
workers=5 
epochs=100

# %%
#print the progress for each run
def word_embedding(list_of_lists, target_word, eurasianism, westphalianism, security_concerns, multipolarism, 
                   n_bootstraps=n_bootstraps, vector_size=vector_size, min_count=min_count, sg=sg, 
                   hs=hs, negative=negative, window=window, workers=workers, epochs=epochs):
    
    scores = {}
    
    for j in range(len(list_of_lists)):
        era_scores = {}
        start_time = time.time()
        for k in range(n_bootstraps):
            sentence_samples = resample(list_of_lists[j])
            model = Word2Vec(
                sentence_samples,
                vector_size=vector_size, 
                min_count=min_count, 
                sg=sg, 
                hs=hs, 
                negative=negative, 
                window=window, 
                workers=workers,
                epochs=epochs
            )

            eurasianism_scores = []
            westphalianism_scores = []
            security_concerns_scores = []
            multipolarism_scores = []

            for word in eurasianism:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    eurasianism_scores.append(similarity_score)
                else:
                    eurasianism_scores.append('NA')

            for word in westphalianism:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    westphalianism_scores.append(similarity_score)
                else:
                    westphalianism_scores.append('NA')

            for word in security_concerns:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    security_concerns_scores.append(similarity_score)
                else:
                    security_concerns_scores.append('NA')

            for word in multipolarism:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    multipolarism_scores.append(similarity_score)
                else:
                    multipolarism_scores.append('NA')

            era_scores[k] = {
                'eurasianism': eurasianism_scores,
                'westphalianism': westphalianism_scores,
                'security_concerns': security_concerns_scores,
                'multipolarism': multipolarism_scores
            }
            
            # Print progress for each run
            print("Finished with run %d out of %d for era %d" % (k+1, n_bootstraps, j+1))
            
        scores[j] = era_scores
        
        end_time = time.time()
        era = j+1
        print("Finished with era %d in %.2f seconds." % (era, end_time-start_time))
        
    print("*******Finished with all eras.*******")
    
    return scores

# %%
scores = word_embedding(list_of_lists, target_word, eurasianism, westphalianism, security_concerns, multipolarism, 
               n_bootstraps = n_bootstraps, vector_size=vector_size, min_count=min_count, sg=sg, hs=hs, negative=negative, 
               window=window, workers=workers, epochs=epochs)
# Out:
# Finished with run 1 out of 50 for era 1
# Finished with run 2 out of 50 for era 1
# Finished with run 3 out of 50 for era 1
# Finished with run 4 out of 50 for era 1
# Finished with run 5 out of 50 for era 1
# Finished with run 6 out of 50 for era 1
# Finished with run 7 out of 50 for era 1
# Finished with run 8 out of 50 for era 1
# Finished with run 9 out of 50 for era 1
# Finished with run 10 out of 50 for era 1
# Finished with run 11 out of 50 for era 1
# Finished with run 12 out of 50 for era 1
# Finished with run 13 out of 50 for era 1
# Finished with run 14 out of 50 for era 1
# Finished with run 15 out of 50 for era 1
# Finished with run 16 out of 50 for era 1
# Finished with run 17 out of 50 for era 1
# Finished with run 18 out of 50 for era 1
# Finished with run 19 out of 50 for era 1
# Finished with run 20 out of 50 for era 1
# Finished with run 21 out of 50 for era 1
# Finished with run 22 out of 50 for era 1
# Finished with run 23 out of 50 for era 1
# Finished with run 24 out of 50 for era 1
# Finished with run 25 out of 50 for era 1
# Finished with run 26 out of 50 for era 1
# Finished with run 27 out of 50 for era 1
# Finished with run 28 out of 50 for era 1
# Finished with run 29 out of 50 for era 1
# Finished with run 30 out of 50 for era 1
# Finished with run 31 out of 50 for era 1
# Finished with run 32 out of 50 for era 1
# Finished with run 33 out of 50 for era 1
# Finished with run 34 out of 50 for era 1
# Finished with run 35 out of 50 for era 1
# Finished with run 36 out of 50 for era 1
# Finished with run 37 out of 50 for era 1
# Finished with run 38 out of 50 for era 1
# Finished with run 39 out of 50 for era 1
# Finished with run 40 out of 50 for era 1
# Finished with run 41 out of 50 for era 1
# Finished with run 42 out of 50 for era 1
# Finished with run 43 out of 50 for era 1
# Finished with run 44 out of 50 for era 1
# Finished with run 45 out of 50 for era 1
# Finished with run 46 out of 50 for era 1
# Finished with run 47 out of 50 for era 1
# Finished with run 48 out of 50 for era 1
# Finished with run 49 out of 50 for era 1
# Finished with run 50 out of 50 for era 1
# Finished with era 1 in 11441.93 seconds.
# Finished with run 1 out of 50 for era 2
# Finished with run 2 out of 50 for era 2
# Finished with run 3 out of 50 for era 2
# Finished with run 4 out of 50 for era 2
# Finished with run 5 out of 50 for era 2
# Finished with run 6 out of 50 for era 2
# Finished with run 7 out of 50 for era 2
# Finished with run 8 out of 50 for era 2
# Finished with run 9 out of 50 for era 2
# Finished with run 10 out of 50 for era 2
# Finished with run 11 out of 50 for era 2
# Finished with run 12 out of 50 for era 2
# Finished with run 13 out of 50 for era 2
# Finished with run 14 out of 50 for era 2
# Finished with run 15 out of 50 for era 2
# Finished with run 16 out of 50 for era 2
# Finished with run 17 out of 50 for era 2
# Finished with run 18 out of 50 for era 2
# Finished with run 19 out of 50 for era 2
# Finished with run 20 out of 50 for era 2
# Finished with run 21 out of 50 for era 2
# Finished with run 22 out of 50 for era 2
# Finished with run 23 out of 50 for era 2
# Finished with run 24 out of 50 for era 2
# Finished with run 25 out of 50 for era 2
# Finished with run 26 out of 50 for era 2
# Finished with run 27 out of 50 for era 2
# Finished with run 28 out of 50 for era 2
# Finished with run 29 out of 50 for era 2
# Finished with run 30 out of 50 for era 2
# Finished with run 31 out of 50 for era 2
# Finished with run 32 out of 50 for era 2
# Finished with run 33 out of 50 for era 2
# Finished with run 34 out of 50 for era 2
# Finished with run 35 out of 50 for era 2
# Finished with run 36 out of 50 for era 2
# Finished with run 37 out of 50 for era 2
# Finished with run 38 out of 50 for era 2
# Finished with run 39 out of 50 for era 2
# Finished with run 40 out of 50 for era 2
# Finished with run 41 out of 50 for era 2
# Finished with run 42 out of 50 for era 2
# Finished with run 43 out of 50 for era 2
# Finished with run 44 out of 50 for era 2
# Finished with run 45 out of 50 for era 2
# Finished with run 46 out of 50 for era 2
# Finished with run 47 out of 50 for era 2
# Finished with run 48 out of 50 for era 2
# Finished with run 49 out of 50 for era 2
# Finished with run 50 out of 50 for era 2
# Finished with era 2 in 20225.33 seconds.
# Finished with run 1 out of 50 for era 3
# Finished with run 2 out of 50 for era 3
# Finished with run 3 out of 50 for era 3
# Finished with run 4 out of 50 for era 3
# Finished with run 5 out of 50 for era 3
# Finished with run 6 out of 50 for era 3
# Finished with run 7 out of 50 for era 3
# Finished with run 8 out of 50 for era 3
# Finished with run 9 out of 50 for era 3
# Finished with run 10 out of 50 for era 3
# Finished with run 11 out of 50 for era 3
# Finished with run 12 out of 50 for era 3
# Finished with run 13 out of 50 for era 3
# Finished with run 14 out of 50 for era 3
# Finished with run 15 out of 50 for era 3
# Finished with run 16 out of 50 for era 3
# Finished with run 17 out of 50 for era 3
# Finished with run 18 out of 50 for era 3
# Finished with run 19 out of 50 for era 3
# Finished with run 20 out of 50 for era 3
# Finished with run 21 out of 50 for era 3
# Finished with run 22 out of 50 for era 3
# Finished with run 23 out of 50 for era 3
# Finished with run 24 out of 50 for era 3
# Finished with run 25 out of 50 for era 3
# Finished with run 26 out of 50 for era 3
# Finished with run 27 out of 50 for era 3
# Finished with run 28 out of 50 for era 3
# Finished with run 29 out of 50 for era 3
# Finished with run 30 out of 50 for era 3
# Finished with run 31 out of 50 for era 3
# Finished with run 32 out of 50 for era 3
# Finished with run 33 out of 50 for era 3
# Finished with run 34 out of 50 for era 3
# Finished with run 35 out of 50 for era 3
# Finished with run 36 out of 50 for era 3
# Finished with run 37 out of 50 for era 3
# Finished with run 38 out of 50 for era 3
# Finished with run 39 out of 50 for era 3
# Finished with run 40 out of 50 for era 3
# Finished with run 41 out of 50 for era 3
# Finished with run 42 out of 50 for era 3
# Finished with run 43 out of 50 for era 3
# Finished with run 44 out of 50 for era 3
# Finished with run 45 out of 50 for era 3
# Finished with run 46 out of 50 for era 3
# Finished with run 47 out of 50 for era 3
# Finished with run 48 out of 50 for era 3
# Finished with run 49 out of 50 for era 3
# Finished with run 50 out of 50 for era 3
# Finished with era 3 in 162256.03 seconds.
# Finished with run 1 out of 50 for era 4
# Finished with run 2 out of 50 for era 4
# Finished with run 3 out of 50 for era 4
# Finished with run 4 out of 50 for era 4
# Finished with run 5 out of 50 for era 4
# Finished with run 6 out of 50 for era 4
# Finished with run 7 out of 50 for era 4
# Finished with run 8 out of 50 for era 4
# Finished with run 9 out of 50 for era 4
# Finished with run 10 out of 50 for era 4
# Finished with run 11 out of 50 for era 4
# Finished with run 12 out of 50 for era 4
# Finished with run 13 out of 50 for era 4
# Finished with run 14 out of 50 for era 4
# Finished with run 15 out of 50 for era 4
# Finished with run 16 out of 50 for era 4
# Finished with run 17 out of 50 for era 4
# Finished with run 18 out of 50 for era 4
# Finished with run 19 out of 50 for era 4
# Finished with run 20 out of 50 for era 4
# Finished with run 21 out of 50 for era 4
# Finished with run 22 out of 50 for era 4
# Finished with run 23 out of 50 for era 4
# Finished with run 24 out of 50 for era 4
# Finished with run 25 out of 50 for era 4
# Finished with run 26 out of 50 for era 4
# Finished with run 27 out of 50 for era 4
# Finished with run 28 out of 50 for era 4
# Finished with run 29 out of 50 for era 4
# Finished with run 30 out of 50 for era 4
# Finished with run 31 out of 50 for era 4
# Finished with run 32 out of 50 for era 4
# Finished with run 33 out of 50 for era 4
# Finished with run 34 out of 50 for era 4
# Finished with run 35 out of 50 for era 4
# Finished with run 36 out of 50 for era 4
# Finished with run 37 out of 50 for era 4
# Finished with run 38 out of 50 for era 4
# Finished with run 39 out of 50 for era 4
# Finished with run 40 out of 50 for era 4
# Finished with run 41 out of 50 for era 4
# Finished with run 42 out of 50 for era 4
# Finished with run 43 out of 50 for era 4
# Finished with run 44 out of 50 for era 4
# Finished with run 45 out of 50 for era 4
# Finished with run 46 out of 50 for era 4
# Finished with run 47 out of 50 for era 4
# Finished with run 48 out of 50 for era 4
# Finished with run 49 out of 50 for era 4
# Finished with run 50 out of 50 for era 4
# Finished with era 4 in 87167.40 seconds.
# *******Finished with all eras.*******

# %%
scores
# Out:
# {0: {0: {'eurasianism': [0.26861662,
#     'NA',
#     0.4224597,
#     'NA',
#     'NA',
#     0.2951925,
#     'NA',
#     'NA'],
#    'westphalianism': [0.29417616,
#     'NA',
#     0.25111505,
#     0.10528102,
#     0.2954621,
#     0.5699735,
#     'NA',
#     'NA',
#     0.16846916],
#    'security_concerns': [0.10204306,
#     0.24536033,
#     0.19386089,
#     0.091113396,
#     0.26081195,
#     'NA',
#     'NA',
#     'NA',
#     0.48149937,
#     'NA',
#     'NA',
#     0.40881145,
#     0.046445318],
#    'multipolarism': [0.57526577,
#     0.23169893,
#     0.12056039,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   1: {'eurasianism': [0.21695624,
#     'NA',
#     0.43688533,
#     'NA',
#     'NA',
#     0.19233967,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3550019,
#     'NA',
#     0.1806682,
#     'NA',
#     0.35201317,
#     0.47790655,
#     'NA',
#     'NA',
#     0.29062065],
#    'security_concerns': [0.20916042,
#     0.1831182,
#     0.19599551,
#     0.100096494,
#     0.30253834,
#     'NA',
#     'NA',
#     'NA',
#     0.45114887,
#     'NA',
#     'NA',
#     'NA',
#     0.105179146],
#    'multipolarism': [0.43348157,
#     0.1253265,
#     0.2654461,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   2: {'eurasianism': [0.25282165,
#     0.08222587,
#     0.36149317,
#     'NA',
#     'NA',
#     0.20772223,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34803668,
#     0.46474037,
#     0.16731372,
#     'NA',
#     0.2859975,
#     'NA',
#     'NA',
#     'NA',
#     0.3004911],
#    'security_concerns': [0.17583856,
#     'NA',
#     0.15043114,
#     0.13739817,
#     0.26804477,
#     'NA',
#     'NA',
#     'NA',
#     0.37575597,
#     'NA',
#     'NA',
#     'NA',
#     -0.018795704],
#    'multipolarism': [0.38016504,
#     0.14395188,
#     0.15772629,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   3: {'eurasianism': [0.3162461,
#     0.015170151,
#     0.46097958,
#     'NA',
#     'NA',
#     0.3101261,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34937388,
#     0.40171447,
#     0.14890173,
#     0.13020103,
#     0.36965787,
#     0.47188637,
#     'NA',
#     'NA',
#     0.22727679],
#    'security_concerns': [0.1843154,
#     'NA',
#     0.114042096,
#     0.12603408,
#     0.24709393,
#     'NA',
#     'NA',
#     'NA',
#     0.41641283,
#     'NA',
#     'NA',
#     0.44330034,
#     0.24771978],
#    'multipolarism': [0.4588015,
#     0.048028123,
#     0.14778097,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   4: {'eurasianism': [0.19929491,
#     0.25271234,
#     0.43201032,
#     'NA',
#     'NA',
#     0.19304809,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3803378,
#     'NA',
#     0.1881384,
#     0.08745855,
#     0.29732528,
#     'NA',
#     'NA',
#     'NA',
#     0.28486234],
#    'security_concerns': [0.22881718,
#     0.13401555,
#     0.19261216,
#     0.087729625,
#     0.24883673,
#     'NA',
#     'NA',
#     'NA',
#     0.47696397,
#     'NA',
#     'NA',
#     'NA',
#     0.117491014],
#    'multipolarism': [0.4484873,
#     0.18722843,
#     0.19784798,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   5: {'eurasianism': [0.28447425,
#     0.07322036,
#     0.37434113,
#     'NA',
#     'NA',
#     0.14216082,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2441625,
#     0.38750297,
#     0.26327834,
#     0.2691071,
#     0.35761243,
#     0.3782691,
#     'NA',
#     'NA',
#     0.16060969],
#    'security_concerns': [0.15281534,
#     0.17980528,
#     0.13272482,
#     0.12708138,
#     0.2725994,
#     'NA',
#     'NA',
#     'NA',
#     0.4658937,
#     'NA',
#     'NA',
#     0.39683393,
#     0.1383805],
#    'multipolarism': [0.55482405,
#     0.16270395,
#     0.16827212,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   6: {'eurasianism': [0.22751963,
#     0.08876127,
#     0.41063502,
#     'NA',
#     'NA',
#     0.2726134,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30307546,
#     'NA',
#     0.11839778,
#     'NA',
#     0.34660468,
#     0.50763804,
#     'NA',
#     'NA',
#     0.29923767],
#    'security_concerns': [0.16882834,
#     0.22807789,
#     0.08303809,
#     0.11298816,
#     0.16838941,
#     'NA',
#     'NA',
#     'NA',
#     0.4332915,
#     'NA',
#     'NA',
#     'NA',
#     0.12395973],
#    'multipolarism': [0.4999324,
#     0.028371051,
#     0.20997028,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   7: {'eurasianism': [0.28725094,
#     'NA',
#     0.5118409,
#     'NA',
#     'NA',
#     0.24186808,
#     'NA',
#     'NA'],
#    'westphalianism': [0.29825684,
#     'NA',
#     0.14600042,
#     0.37441292,
#     0.35926738,
#     0.61034876,
#     'NA',
#     'NA',
#     0.27345556],
#    'security_concerns': [0.23573366,
#     'NA',
#     0.19786513,
#     0.18560009,
#     0.30058104,
#     'NA',
#     'NA',
#     'NA',
#     0.49209112,
#     'NA',
#     'NA',
#     'NA',
#     0.101475835],
#    'multipolarism': [0.39856246,
#     0.13194224,
#     0.17801489,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   8: {'eurasianism': [0.24421494,
#     0.07500764,
#     0.31099695,
#     'NA',
#     'NA',
#     0.1968447,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34827563,
#     0.47115576,
#     0.06438446,
#     'NA',
#     0.3586724,
#     0.6407889,
#     'NA',
#     'NA',
#     0.18654805],
#    'security_concerns': [0.24869655,
#     0.16108602,
#     0.1141353,
#     0.15245837,
#     0.26930904,
#     'NA',
#     'NA',
#     'NA',
#     0.43396655,
#     'NA',
#     'NA',
#     0.48294276,
#     0.21883999],
#    'multipolarism': [0.4134007,
#     0.20390211,
#     0.15061308,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   9: {'eurasianism': [0.1667035,
#     0.10164343,
#     0.4119568,
#     'NA',
#     'NA',
#     0.27888024,
#     'NA',
#     'NA'],
#    'westphalianism': [0.26120153,
#     'NA',
#     0.22594589,
#     'NA',
#     0.44212803,
#     0.5808045,
#     'NA',
#     'NA',
#     0.29419369],
#    'security_concerns': [0.2880953,
#     0.15303445,
#     0.13540658,
#     0.19073053,
#     0.27348405,
#     'NA',
#     'NA',
#     'NA',
#     0.22761537,
#     'NA',
#     'NA',
#     0.39071307,
#     0.25312522],
#    'multipolarism': [0.42203453,
#     0.07410641,
#     0.17548722,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   10: {'eurasianism': [0.279803,
#     'NA',
#     0.40516555,
#     'NA',
#     'NA',
#     0.1913603,
#     'NA',
#     'NA'],
#    'westphalianism': [0.31256753,
#     0.44722575,
#     0.19528164,
#     0.29625905,
#     0.40974125,
#     0.588949,
#     'NA',
#     'NA',
#     0.21527578],
#    'security_concerns': [0.06135087,
#     0.25792164,
#     0.2938076,
#     0.11495888,
#     0.27772027,
#     'NA',
#     'NA',
#     'NA',
#     0.49139193,
#     'NA',
#     'NA',
#     0.40406597,
#     0.13877037],
#    'multipolarism': [0.4608935,
#     0.16047798,
#     0.13596636,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   11: {'eurasianism': [0.26912564,
#     'NA',
#     0.3735627,
#     'NA',
#     'NA',
#     0.22677162,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3751029,
#     0.3552267,
#     0.17123114,
#     0.26970297,
#     0.45811078,
#     0.57969415,
#     'NA',
#     'NA',
#     0.29588875],
#    'security_concerns': [0.14560458,
#     0.1756094,
#     0.06730684,
#     0.052810047,
#     0.28996745,
#     'NA',
#     'NA',
#     'NA',
#     0.28409168,
#     'NA',
#     'NA',
#     0.4465115,
#     0.1493033],
#    'multipolarism': [0.5132751,
#     0.05679848,
#     0.096193835,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   12: {'eurasianism': [0.32554418,
#     0.24003199,
#     0.47870234,
#     'NA',
#     'NA',
#     0.25148264,
#     'NA',
#     'NA'],
#    'westphalianism': [0.27416226,
#     'NA',
#     0.16666433,
#     0.08349878,
#     0.38312224,
#     0.5164976,
#     'NA',
#     'NA',
#     0.39097786],
#    'security_concerns': [0.17485155,
#     'NA',
#     0.25297278,
#     0.17556699,
#     0.21736738,
#     'NA',
#     'NA',
#     'NA',
#     0.26022613,
#     'NA',
#     'NA',
#     0.40132844,
#     0.2536745],
#    'multipolarism': [0.38165992,
#     0.1510047,
#     0.16587391,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   13: {'eurasianism': [0.24570304,
#     0.06965464,
#     0.4076691,
#     'NA',
#     'NA',
#     0.23064518,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32997873,
#     'NA',
#     0.08774391,
#     0.18536222,
#     0.5076438,
#     0.5794456,
#     'NA',
#     'NA',
#     0.23867549],
#    'security_concerns': [0.15463158,
#     0.0983432,
#     0.073679626,
#     0.17197478,
#     0.29608995,
#     'NA',
#     'NA',
#     'NA',
#     0.4042678,
#     'NA',
#     'NA',
#     'NA',
#     0.16017096],
#    'multipolarism': [0.44413275,
#     0.15654345,
#     0.18959503,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   14: {'eurasianism': [0.30178708,
#     'NA',
#     0.39418626,
#     'NA',
#     'NA',
#     0.3432112,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32334438,
#     'NA',
#     0.19293262,
#     0.21982998,
#     0.35659367,
#     0.49706173,
#     'NA',
#     'NA',
#     0.24586363],
#    'security_concerns': [0.19167727,
#     0.23084566,
#     0.2520652,
#     0.16652493,
#     0.29357418,
#     'NA',
#     'NA',
#     'NA',
#     0.42578945,
#     'NA',
#     'NA',
#     'NA',
#     0.1086287],
#    'multipolarism': [0.43914613,
#     0.13515034,
#     0.18924251,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   15: {'eurasianism': [0.11635627,
#     0.067033045,
#     0.3072613,
#     'NA',
#     'NA',
#     0.22661924,
#     'NA',
#     'NA'],
#    'westphalianism': [0.37634823,
#     0.27286884,
#     0.1921258,
#     'NA',
#     0.293535,
#     0.46486115,
#     'NA',
#     'NA',
#     0.24689257],
#    'security_concerns': [0.16420162,
#     0.24044724,
#     0.07356139,
#     0.1627961,
#     0.29733205,
#     'NA',
#     'NA',
#     'NA',
#     0.40708798,
#     'NA',
#     'NA',
#     0.35918206,
#     0.14431319],
#    'multipolarism': [0.46622977,
#     0.12594599,
#     0.18901809,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   16: {'eurasianism': [0.3186611,
#     0.057644133,
#     0.3984292,
#     'NA',
#     'NA',
#     0.25728056,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34960535,
#     0.4327447,
#     0.19052096,
#     'NA',
#     0.32428253,
#     0.4202772,
#     'NA',
#     'NA',
#     0.30281538],
#    'security_concerns': [0.13392095,
#     0.17780983,
#     0.17782618,
#     0.21083386,
#     0.271169,
#     'NA',
#     'NA',
#     'NA',
#     0.49846414,
#     'NA',
#     'NA',
#     0.41865772,
#     0.12227538],
#    'multipolarism': [0.4437698,
#     0.14086466,
#     0.24604866,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   17: {'eurasianism': [0.1221354,
#     0.19082202,
#     0.35256976,
#     'NA',
#     'NA',
#     0.220179,
#     'NA',
#     'NA'],
#    'westphalianism': [0.33054632,
#     0.42868277,
#     0.18446286,
#     'NA',
#     0.3010165,
#     0.39187858,
#     'NA',
#     'NA',
#     0.26778612],
#    'security_concerns': [0.16962771,
#     0.14298283,
#     0.21153022,
#     0.19517687,
#     0.26515862,
#     'NA',
#     'NA',
#     'NA',
#     0.43552098,
#     'NA',
#     'NA',
#     0.34518194,
#     0.17639887],
#    'multipolarism': [0.460087,
#     0.20048758,
#     0.15231411,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   18: {'eurasianism': [0.21465006,
#     'NA',
#     0.34219053,
#     'NA',
#     'NA',
#     0.22095971,
#     'NA',
#     'NA'],
#    'westphalianism': [0.22324897,
#     0.35851565,
#     0.058601666,
#     'NA',
#     0.3724276,
#     0.5537837,
#     'NA',
#     'NA',
#     0.1538156],
#    'security_concerns': [0.053416733,
#     'NA',
#     0.25648066,
#     0.038446918,
#     0.2828356,
#     'NA',
#     'NA',
#     'NA',
#     0.37806797,
#     'NA',
#     'NA',
#     0.37659702,
#     0.0582142],
#    'multipolarism': [0.44806686,
#     0.14664319,
#     0.15896975,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   19: {'eurasianism': [0.27931225,
#     'NA',
#     0.40296823,
#     'NA',
#     'NA',
#     0.15260786,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30142277,
#     'NA',
#     0.2921376,
#     0.21013953,
#     0.37651223,
#     'NA',
#     'NA',
#     'NA',
#     0.22705652],
#    'security_concerns': [0.14767736,
#     0.16459472,
#     0.21796168,
#     0.120540865,
#     0.30913457,
#     'NA',
#     'NA',
#     'NA',
#     0.4050815,
#     'NA',
#     'NA',
#     0.2644157,
#     0.17310467],
#    'multipolarism': [0.4629557,
#     0.14197119,
#     0.2090818,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   20: {'eurasianism': [0.24261425,
#     0.23849295,
#     0.23532677,
#     'NA',
#     'NA',
#     0.11017794,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30710596,
#     0.3949141,
#     0.35777533,
#     0.12183706,
#     0.44328713,
#     0.33584854,
#     'NA',
#     'NA',
#     0.16893499],
#    'security_concerns': [0.19770858,
#     0.28366295,
#     0.12146483,
#     0.08742693,
#     0.16360322,
#     'NA',
#     'NA',
#     'NA',
#     0.23439705,
#     'NA',
#     'NA',
#     0.36425126,
#     0.14115648],
#    'multipolarism': [0.45918995,
#     0.08467303,
#     0.08570797,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   21: {'eurasianism': [0.2779709,
#     0.10924718,
#     0.31753924,
#     'NA',
#     'NA',
#     0.3686228,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30137494,
#     0.40493062,
#     0.13582699,
#     0.25549755,
#     0.3737063,
#     0.35687715,
#     'NA',
#     'NA',
#     0.26551405],
#    'security_concerns': [0.29881176,
#     0.15743418,
#     0.2186606,
#     0.28436306,
#     0.28674415,
#     'NA',
#     'NA',
#     'NA',
#     0.46429127,
#     'NA',
#     'NA',
#     0.37681416,
#     0.19704992],
#    'multipolarism': [0.45789978,
#     0.21439168,
#     0.21749206,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   22: {'eurasianism': [0.31416273,
#     'NA',
#     0.37826014,
#     'NA',
#     'NA',
#     0.266577,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2480299,
#     'NA',
#     0.038989868,
#     'NA',
#     0.25953627,
#     0.5569202,
#     'NA',
#     'NA',
#     0.21144553],
#    'security_concerns': [0.21325445,
#     0.23883142,
#     0.17724468,
#     0.14076656,
#     0.3256201,
#     'NA',
#     'NA',
#     'NA',
#     0.38673583,
#     'NA',
#     'NA',
#     0.3126283,
#     0.25037947],
#    'multipolarism': [0.45628697,
#     0.16506079,
#     0.1819828,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   23: {'eurasianism': [0.19711684,
#     0.26389515,
#     0.48986062,
#     'NA',
#     'NA',
#     0.3144532,
#     'NA',
#     'NA'],
#    'westphalianism': [0.26537967,
#     'NA',
#     0.13867268,
#     'NA',
#     0.299407,
#     0.45575383,
#     'NA',
#     'NA',
#     0.2801021],
#    'security_concerns': [0.12685463,
#     0.12189233,
#     0.261701,
#     0.16608903,
#     0.2898513,
#     'NA',
#     'NA',
#     'NA',
#     0.48320472,
#     'NA',
#     'NA',
#     'NA',
#     0.0787103],
#    'multipolarism': [0.46666005,
#     0.12614316,
#     0.16915433,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   24: {'eurasianism': [0.2422428,
#     0.19268651,
#     0.4235816,
#     'NA',
#     'NA',
#     0.29239845,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2861631,
#     0.24107648,
#     0.22593509,
#     'NA',
#     0.38531324,
#     0.49008584,
#     'NA',
#     'NA',
#     0.26066217],
#    'security_concerns': [0.119503975,
#     0.17688851,
#     0.200012,
#     0.14601083,
#     0.30504727,
#     'NA',
#     'NA',
#     'NA',
#     0.38148403,
#     'NA',
#     'NA',
#     0.37525517,
#     0.19063738],
#    'multipolarism': [0.40237108,
#     0.1502635,
#     0.10777766,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   25: {'eurasianism': [0.17884587,
#     0.16816206,
#     0.37077504,
#     'NA',
#     'NA',
#     0.31899953,
#     'NA',
#     'NA'],
#    'westphalianism': [0.25449497,
#     'NA',
#     0.26496175,
#     'NA',
#     0.35526127,
#     0.5136839,
#     'NA',
#     'NA',
#     0.14770992],
#    'security_concerns': [0.16272047,
#     0.1748698,
#     0.100358635,
#     0.1585993,
#     0.27932003,
#     'NA',
#     'NA',
#     'NA',
#     0.39198792,
#     'NA',
#     'NA',
#     0.41382277,
#     0.30111083],
#    'multipolarism': [0.5263902,
#     0.15968388,
#     0.1549722,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   26: {'eurasianism': [0.15944132,
#     0.0772513,
#     0.47355944,
#     'NA',
#     'NA',
#     0.25405192,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3049688,
#     0.50694895,
#     0.320518,
#     'NA',
#     0.36666298,
#     0.56714183,
#     'NA',
#     'NA',
#     0.34635502],
#    'security_concerns': [0.18151325,
#     0.29382014,
#     0.24313886,
#     0.19628966,
#     0.22798525,
#     'NA',
#     'NA',
#     'NA',
#     0.43435112,
#     'NA',
#     'NA',
#     0.44199574,
#     0.12161128],
#    'multipolarism': [0.43894553,
#     0.03019344,
#     0.16707705,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   27: {'eurasianism': [0.15771645,
#     0.20425263,
#     0.3239266,
#     'NA',
#     'NA',
#     0.23787975,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2602901,
#     'NA',
#     0.16494556,
#     0.33131266,
#     0.34648502,
#     0.44607967,
#     'NA',
#     'NA',
#     0.31639254],
#    'security_concerns': [0.18479955,
#     'NA',
#     0.14829244,
#     0.13009924,
#     0.25436494,
#     'NA',
#     'NA',
#     'NA',
#     0.3816883,
#     'NA',
#     'NA',
#     0.42937636,
#     0.17846555],
#    'multipolarism': [0.51973546,
#     0.15001962,
#     0.17763916,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   28: {'eurasianism': [0.30918807,
#     0.07449376,
#     0.41572088,
#     'NA',
#     'NA',
#     0.22693482,
#     'NA',
#     'NA'],
#    'westphalianism': [0.38334587,
#     0.4059922,
#     0.18200672,
#     'NA',
#     0.43537873,
#     0.5887869,
#     'NA',
#     'NA',
#     0.29202107],
#    'security_concerns': [0.105589174,
#     0.28351462,
#     0.11725571,
#     0.08467934,
#     0.20391323,
#     'NA',
#     'NA',
#     'NA',
#     0.38328794,
#     'NA',
#     'NA',
#     0.3550042,
#     0.15690744],
#    'multipolarism': [0.47845182,
#     0.036963068,
#     0.23157404,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   29: {'eurasianism': [0.112620994,
#     'NA',
#     0.3834137,
#     'NA',
#     'NA',
#     0.2220161,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30067468,
#     0.3717887,
#     0.21287718,
#     0.2931787,
#     0.3846999,
#     0.57345855,
#     'NA',
#     'NA',
#     0.12290483],
#    'security_concerns': [0.13488093,
#     0.20236634,
#     0.083407715,
#     0.15298,
#     0.30513504,
#     'NA',
#     'NA',
#     'NA',
#     0.34768713,
#     'NA',
#     'NA',
#     0.39447048,
#     0.17140718],
#    'multipolarism': [0.44390625,
#     0.12235445,
#     0.15323935,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   30: {'eurasianism': [0.35617363,
#     0.19313447,
#     0.39190748,
#     'NA',
#     'NA',
#     0.31042272,
#     'NA',
#     'NA'],
#    'westphalianism': [0.24384312,
#     0.34306335,
#     0.12921824,
#     0.15566878,
#     0.36280873,
#     0.38488522,
#     'NA',
#     'NA',
#     0.15899879],
#    'security_concerns': [0.2294125,
#     0.21032433,
#     0.21291694,
#     0.2034221,
#     0.25860703,
#     'NA',
#     'NA',
#     'NA',
#     0.2271335,
#     'NA',
#     'NA',
#     0.41430643,
#     0.18065698],
#    'multipolarism': [0.45191264,
#     0.08893092,
#     0.14381613,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   31: {'eurasianism': [0.35578194,
#     0.076676056,
#     0.3501235,
#     'NA',
#     'NA',
#     0.35238782,
#     'NA',
#     'NA'],
#    'westphalianism': [0.290362,
#     'NA',
#     0.19673553,
#     'NA',
#     0.26289493,
#     0.43857044,
#     'NA',
#     'NA',
#     0.2332524],
#    'security_concerns': [0.1629568,
#     'NA',
#     0.27088088,
#     0.19579996,
#     0.3085538,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.43702614,
#     'NA'],
#    'multipolarism': [0.469103, 0.1405599, 0.20987387, 'NA', 'NA', 'NA', 'NA']},
#   32: {'eurasianism': [0.17814754,
#     0.13574472,
#     0.35829738,
#     'NA',
#     'NA',
#     0.1965444,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32525125,
#     0.28985682,
#     0.14663222,
#     'NA',
#     0.29129776,
#     0.32828236,
#     'NA',
#     'NA',
#     0.24507321],
#    'security_concerns': [0.20765358,
#     -0.011848233,
#     0.05553464,
#     0.18378933,
#     0.25954255,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.32381868,
#     0.1437137],
#    'multipolarism': [0.49771056,
#     0.07902016,
#     0.13194737,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   33: {'eurasianism': [0.27137223,
#     0.058198966,
#     0.31299105,
#     'NA',
#     'NA',
#     0.2670768,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32873523,
#     0.36772263,
#     0.21614414,
#     0.20584908,
#     0.2995331,
#     0.6052435,
#     'NA',
#     'NA',
#     0.26694113],
#    'security_concerns': [0.18287167,
#     0.1866078,
#     0.050898694,
#     0.12042895,
#     0.20303613,
#     'NA',
#     'NA',
#     'NA',
#     0.40445688,
#     'NA',
#     'NA',
#     0.418838,
#     0.13303025],
#    'multipolarism': [0.44320017,
#     0.030981319,
#     0.100093745,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   34: {'eurasianism': [0.29341468,
#     0.036964227,
#     0.33769718,
#     'NA',
#     'NA',
#     0.29042953,
#     'NA',
#     'NA'],
#    'westphalianism': [0.37990773,
#     'NA',
#     0.21646173,
#     0.28140524,
#     0.28405556,
#     'NA',
#     'NA',
#     'NA',
#     0.30157217],
#    'security_concerns': [0.20808491,
#     0.16362718,
#     0.22168022,
#     0.13070409,
#     0.23001532,
#     'NA',
#     'NA',
#     'NA',
#     0.39503646,
#     'NA',
#     'NA',
#     'NA',
#     0.08080955],
#    'multipolarism': [0.4632037,
#     0.20300323,
#     0.18944097,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   35: {'eurasianism': [0.3766936,
#     0.0189805,
#     0.3921952,
#     'NA',
#     'NA',
#     0.22828306,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3719012,
#     'NA',
#     0.21879251,
#     'NA',
#     0.34046516,
#     0.5577174,
#     'NA',
#     'NA',
#     0.31458268],
#    'security_concerns': [0.08268921,
#     'NA',
#     0.13255076,
#     0.13087617,
#     0.26125827,
#     'NA',
#     'NA',
#     'NA',
#     0.436928,
#     'NA',
#     'NA',
#     'NA',
#     0.07878166],
#    'multipolarism': [0.46869418,
#     0.18523677,
#     0.29985014,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   36: {'eurasianism': [0.37606984,
#     'NA',
#     0.42210767,
#     'NA',
#     'NA',
#     0.23238951,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3465542,
#     0.36932957,
#     0.16201518,
#     'NA',
#     0.34931487,
#     0.44003007,
#     'NA',
#     'NA',
#     0.16027378],
#    'security_concerns': [0.22759001,
#     0.18458298,
#     0.22143102,
#     0.20744108,
#     0.2674161,
#     'NA',
#     'NA',
#     'NA',
#     0.46867818,
#     'NA',
#     'NA',
#     0.42138228,
#     0.27854863],
#    'multipolarism': [0.5108301,
#     0.16197813,
#     0.18796653,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   37: {'eurasianism': [0.25821626,
#     0.12959981,
#     0.41827157,
#     'NA',
#     'NA',
#     0.28009856,
#     'NA',
#     'NA'],
#    'westphalianism': [0.36771557,
#     0.5137177,
#     0.3105203,
#     0.2046133,
#     0.34753174,
#     0.5113753,
#     'NA',
#     'NA',
#     0.17539468],
#    'security_concerns': [0.14633417,
#     0.16672187,
#     0.20872088,
#     0.17735529,
#     0.23441392,
#     'NA',
#     'NA',
#     'NA',
#     0.36040995,
#     'NA',
#     'NA',
#     'NA',
#     0.13326812],
#    'multipolarism': [0.48536137,
#     0.15245222,
#     0.24247286,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   38: {'eurasianism': [0.10617963,
#     0.092643805,
#     0.38244674,
#     'NA',
#     'NA',
#     0.3295463,
#     'NA',
#     'NA'],
#    'westphalianism': [0.40078998,
#     'NA',
#     0.16010232,
#     0.15531881,
#     0.39503667,
#     0.35274875,
#     'NA',
#     'NA',
#     0.26989838],
#    'security_concerns': [0.09021272,
#     'NA',
#     0.17192696,
#     0.18144567,
#     0.3142836,
#     'NA',
#     'NA',
#     'NA',
#     0.37454167,
#     'NA',
#     'NA',
#     0.2920653,
#     0.14066306],
#    'multipolarism': [0.4638671,
#     0.09163756,
#     0.0807282,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   39: {'eurasianism': [0.30615383,
#     0.114240445,
#     0.35711685,
#     'NA',
#     'NA',
#     0.2540986,
#     'NA',
#     'NA'],
#    'westphalianism': [0.31752735,
#     'NA',
#     0.2031996,
#     'NA',
#     0.31537604,
#     0.5810079,
#     'NA',
#     'NA',
#     0.29761395],
#    'security_concerns': [0.16696571,
#     0.23030077,
#     0.28783956,
#     0.140395,
#     0.29839122,
#     'NA',
#     'NA',
#     'NA',
#     0.4702471,
#     'NA',
#     'NA',
#     'NA',
#     0.14038008],
#    'multipolarism': [0.44311482,
#     0.16768642,
#     0.22731952,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   40: {'eurasianism': [0.2783433,
#     0.20943171,
#     0.39842767,
#     'NA',
#     'NA',
#     0.2847314,
#     'NA',
#     'NA'],
#    'westphalianism': [0.28673226,
#     'NA',
#     0.13994001,
#     0.08644952,
#     0.43324748,
#     0.55020005,
#     'NA',
#     'NA',
#     0.24150594],
#    'security_concerns': [0.16104317,
#     'NA',
#     0.14835928,
#     0.17387241,
#     0.18173946,
#     'NA',
#     'NA',
#     'NA',
#     0.38567498,
#     'NA',
#     'NA',
#     'NA',
#     0.19523983],
#    'multipolarism': [0.4170966,
#     0.15968408,
#     0.2114564,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   41: {'eurasianism': [0.31558967,
#     0.17278245,
#     0.41418588,
#     'NA',
#     'NA',
#     0.15200685,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32433394,
#     0.49203393,
#     0.13524342,
#     0.16005822,
#     0.28574395,
#     0.5365788,
#     'NA',
#     'NA',
#     0.23629436],
#    'security_concerns': [0.13167907,
#     0.14585617,
#     0.18278608,
#     0.10737485,
#     0.32193077,
#     'NA',
#     'NA',
#     'NA',
#     0.4056228,
#     'NA',
#     'NA',
#     0.34085903,
#     0.06464257],
#    'multipolarism': [0.42098472,
#     0.13877763,
#     0.18428789,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   42: {'eurasianism': [0.17533083,
#     'NA',
#     0.38610595,
#     'NA',
#     'NA',
#     0.2401019,
#     'NA',
#     'NA'],
#    'westphalianism': [0.24786776,
#     'NA',
#     0.09121024,
#     0.22676983,
#     0.36645582,
#     0.44896755,
#     'NA',
#     'NA',
#     0.22719443],
#    'security_concerns': [0.1888744,
#     'NA',
#     0.15841128,
#     0.13225888,
#     0.21818979,
#     'NA',
#     'NA',
#     'NA',
#     0.36102802,
#     'NA',
#     'NA',
#     0.29523724,
#     0.0941352],
#    'multipolarism': [0.40952253,
#     0.114004575,
#     0.06906834,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   43: {'eurasianism': [0.26018402,
#     0.14087105,
#     0.32497668,
#     'NA',
#     'NA',
#     0.35802466,
#     'NA',
#     'NA'],
#    'westphalianism': [0.29992643,
#     0.34796175,
#     0.18968673,
#     'NA',
#     0.39575842,
#     0.522899,
#     'NA',
#     'NA',
#     0.21979009],
#    'security_concerns': [0.20360126,
#     'NA',
#     0.22947383,
#     0.07072077,
#     0.16075805,
#     'NA',
#     'NA',
#     'NA',
#     0.42664075,
#     'NA',
#     'NA',
#     0.38503245,
#     0.1852438],
#    'multipolarism': [0.45374924,
#     0.16490594,
#     0.116499655,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   44: {'eurasianism': [0.15503635,
#     0.15047163,
#     0.34169748,
#     'NA',
#     'NA',
#     0.22792327,
#     'NA',
#     'NA'],
#    'westphalianism': [0.28817278,
#     'NA',
#     0.0774848,
#     0.23178509,
#     0.391646,
#     0.6161916,
#     'NA',
#     'NA',
#     0.22545116],
#    'security_concerns': [0.1358373,
#     'NA',
#     0.22873706,
#     0.097985886,
#     0.22634287,
#     'NA',
#     'NA',
#     'NA',
#     0.45997304,
#     'NA',
#     'NA',
#     'NA',
#     0.14746155],
#    'multipolarism': [0.39324832,
#     0.119884856,
#     0.0944507,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   45: {'eurasianism': [0.2759781,
#     0.21566834,
#     0.3918938,
#     'NA',
#     'NA',
#     0.3292355,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3005856,
#     'NA',
#     0.20921575,
#     0.19464755,
#     0.33620697,
#     0.55292577,
#     'NA',
#     'NA',
#     0.30128962],
#    'security_concerns': [0.17499411,
#     0.051543146,
#     0.18880928,
#     0.13601246,
#     0.32777524,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.10195047],
#    'multipolarism': [0.3584502,
#     0.12463968,
#     0.13334048,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   46: {'eurasianism': [0.2528559,
#     0.12248273,
#     0.40130273,
#     'NA',
#     'NA',
#     0.23494667,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2570857,
#     0.45031866,
#     0.17111632,
#     'NA',
#     0.30801925,
#     0.41663972,
#     'NA',
#     'NA',
#     0.2781483],
#    'security_concerns': [0.22910541,
#     0.23967731,
#     0.1529902,
#     0.17313796,
#     0.22409508,
#     'NA',
#     'NA',
#     'NA',
#     0.345947,
#     'NA',
#     'NA',
#     0.3240021,
#     0.1695318],
#    'multipolarism': [0.5523663,
#     -0.012146927,
#     0.14261605,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   47: {'eurasianism': [0.29089388,
#     0.2737036,
#     0.43940032,
#     'NA',
#     'NA',
#     0.28588063,
#     'NA',
#     'NA'],
#    'westphalianism': [0.36311662,
#     0.24770045,
#     0.17679283,
#     'NA',
#     0.3303337,
#     0.5075205,
#     'NA',
#     'NA',
#     0.26106048],
#    'security_concerns': [0.19857322,
#     'NA',
#     0.11273544,
#     0.14513549,
#     0.19899331,
#     'NA',
#     'NA',
#     'NA',
#     0.44400293,
#     'NA',
#     'NA',
#     0.3858621,
#     0.20016937],
#    'multipolarism': [0.4949671,
#     0.22624256,
#     0.26959452,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   48: {'eurasianism': [0.2722162,
#     0.10340951,
#     0.38645026,
#     'NA',
#     'NA',
#     0.26646334,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3676932,
#     0.47651154,
#     0.18134016,
#     0.23494384,
#     0.3330602,
#     0.5164587,
#     'NA',
#     'NA',
#     0.31521922],
#    'security_concerns': [0.32002303,
#     0.23633842,
#     0.19022973,
#     0.25870305,
#     0.29634953,
#     'NA',
#     'NA',
#     'NA',
#     0.3656525,
#     'NA',
#     'NA',
#     0.36306196,
#     0.23004662],
#    'multipolarism': [0.5380451,
#     0.11719685,
#     0.21300359,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   49: {'eurasianism': [0.16229792,
#     0.015803603,
#     0.42896962,
#     'NA',
#     'NA',
#     0.36718714,
#     'NA',
#     'NA'],
#    'westphalianism': [0.305959,
#     'NA',
#     0.08527016,
#     0.14142132,
#     0.29331744,
#     0.53706247,
#     'NA',
#     'NA',
#     0.21606123],
#    'security_concerns': [0.10648887,
#     0.1584269,
#     0.19532931,
#     0.031938713,
#     0.24338676,
#     'NA',
#     'NA',
#     'NA',
#     0.43319267,
#     'NA',
#     'NA',
#     'NA',
#     0.11873704],
#    'multipolarism': [0.36436436,
#     0.21764764,
#     0.20954931,
#     'NA',
#     'NA',
#     'NA',
#     'NA']}},
#  1: {0: {'eurasianism': [0.29408354,
#     0.28635907,
#     0.34750503,
#     0.40125024,
#     'NA',
#     0.30926403,
#     0.25557223,
#     0.0985812],
#    'westphalianism': [0.4425498,
#     0.14526565,
#     0.17279297,
#     0.32050684,
#     0.3954289,
#     0.44519812,
#     'NA',
#     'NA',
#     0.26034343],
#    'security_concerns': [0.24727105,
#     0.3320671,
#     0.18896882,
#     0.23584557,
#     0.28728384,
#     'NA',
#     'NA',
#     'NA',
#     0.26316938,
#     'NA',
#     'NA',
#     0.38979,
#     0.11050689],
#    'multipolarism': [0.53172636,
#     0.3019555,
#     0.30738136,
#     0.722693,
#     0.348593,
#     0.5497669,
#     'NA']},
#   1: {'eurasianism': [0.19511776,
#     0.24712238,
#     0.39501914,
#     'NA',
#     'NA',
#     0.1818271,
#     0.25404716,
#     0.23843387],
#    'westphalianism': [0.39253113,
#     0.11825853,
#     0.11492979,
#     'NA',
#     0.4457949,
#     0.44433343,
#     'NA',
#     'NA',
#     0.23737793],
#    'security_concerns': [0.20417182,
#     0.3037956,
#     0.07504605,
#     0.121985935,
#     0.27441123,
#     'NA',
#     'NA',
#     'NA',
#     0.19568384,
#     'NA',
#     'NA',
#     0.4920818,
#     0.12111335],
#    'multipolarism': [0.61049795,
#     0.21729787,
#     0.26506737,
#     0.59570223,
#     0.4659446,
#     0.53481156,
#     'NA']},
#   2: {'eurasianism': [0.1849266,
#     0.21559745,
#     0.3512936,
#     0.43506536,
#     'NA',
#     0.297763,
#     0.16529706,
#     0.23906113],
#    'westphalianism': [0.3335449,
#     0.03830001,
#     0.17716518,
#     'NA',
#     0.35930333,
#     0.2565679,
#     'NA',
#     'NA',
#     0.24330376],
#    'security_concerns': [0.21021643,
#     0.24877241,
#     0.1442523,
#     0.19757041,
#     0.43452388,
#     'NA',
#     'NA',
#     'NA',
#     0.21721506,
#     'NA',
#     'NA',
#     0.48587734,
#     0.08878127],
#    'multipolarism': [0.48591366,
#     0.1590694,
#     0.29386172,
#     0.64270276,
#     0.4232325,
#     0.6251074,
#     'NA']},
#   3: {'eurasianism': [0.12583569,
#     0.21094613,
#     0.3759276,
#     'NA',
#     'NA',
#     0.23994412,
#     0.13711074,
#     0.14934126],
#    'westphalianism': [0.39430824,
#     'NA',
#     0.3056202,
#     0.36590177,
#     0.4372483,
#     0.474755,
#     'NA',
#     'NA',
#     0.32075417],
#    'security_concerns': [0.1899082,
#     0.32525408,
#     0.19419208,
#     0.15334287,
#     0.31833005,
#     'NA',
#     'NA',
#     'NA',
#     0.2446498,
#     'NA',
#     'NA',
#     0.48507938,
#     0.173975],
#    'multipolarism': [0.64892495,
#     0.26074904,
#     0.33330038,
#     0.61654305,
#     0.38565794,
#     0.5432441,
#     'NA']},
#   4: {'eurasianism': [0.1773236,
#     0.19800472,
#     0.2775501,
#     0.37775034,
#     'NA',
#     0.27615225,
#     0.24788475,
#     0.16976611],
#    'westphalianism': [0.33229095,
#     0.12650742,
#     0.09015516,
#     'NA',
#     0.3274055,
#     0.4009101,
#     'NA',
#     'NA',
#     0.23180711],
#    'security_concerns': [0.3004137,
#     0.38875264,
#     0.24201895,
#     0.2040079,
#     0.36620745,
#     'NA',
#     'NA',
#     'NA',
#     0.24562033,
#     'NA',
#     'NA',
#     0.4360511,
#     0.2931775],
#    'multipolarism': [0.39507237,
#     0.24561858,
#     0.27661708,
#     0.6116983,
#     0.48890102,
#     0.6398975,
#     'NA']},
#   5: {'eurasianism': [0.1604259,
#     0.16583878,
#     0.45678487,
#     0.42255998,
#     'NA',
#     0.18782769,
#     'NA',
#     0.12662818],
#    'westphalianism': [0.42139077,
#     0.2440658,
#     0.12903279,
#     'NA',
#     0.46515435,
#     0.4986886,
#     'NA',
#     'NA',
#     0.30497012],
#    'security_concerns': [0.15797773,
#     0.2185943,
#     0.08775217,
#     0.13526852,
#     0.24285005,
#     'NA',
#     'NA',
#     'NA',
#     0.19350465,
#     'NA',
#     'NA',
#     0.33658373,
#     0.20905083],
#    'multipolarism': [0.551329,
#     0.12100276,
#     0.28376147,
#     0.676219,
#     0.37072042,
#     0.5622425,
#     'NA']},
#   6: {'eurasianism': [0.21739121,
#     0.1614523,
#     0.3176834,
#     0.40118513,
#     'NA',
#     0.21297783,
#     0.1758234,
#     0.1801315],
#    'westphalianism': [0.3664199,
#     'NA',
#     0.12463155,
#     'NA',
#     0.40566838,
#     0.3977843,
#     'NA',
#     'NA',
#     0.3193275],
#    'security_concerns': [0.11523978,
#     0.13674766,
#     0.14826997,
#     0.092166156,
#     0.2823168,
#     'NA',
#     'NA',
#     'NA',
#     0.24579327,
#     'NA',
#     'NA',
#     0.36450833,
#     0.21463794],
#    'multipolarism': [0.39636192,
#     0.25265583,
#     0.2896178,
#     0.6268768,
#     0.30941927,
#     0.6301198,
#     'NA']},
#   7: {'eurasianism': [0.14173064,
#     0.22229221,
#     0.31138194,
#     0.31508726,
#     'NA',
#     0.21760333,
#     0.23327504,
#     0.15163876],
#    'westphalianism': [0.40317616,
#     0.25063127,
#     0.1831698,
#     'NA',
#     0.38112602,
#     0.5211297,
#     'NA',
#     'NA',
#     0.09782211],
#    'security_concerns': [0.25659135,
#     0.19005932,
#     0.15570918,
#     0.17908812,
#     0.41889474,
#     'NA',
#     'NA',
#     'NA',
#     0.20148982,
#     'NA',
#     'NA',
#     0.5637397,
#     0.123063564],
#    'multipolarism': [0.5893625,
#     0.28124887,
#     0.25893697,
#     0.5895338,
#     0.34403557,
#     0.6171633,
#     'NA']},
#   8: {'eurasianism': [0.23331252,
#     0.24384409,
#     0.36236402,
#     0.4203417,
#     'NA',
#     0.26995474,
#     0.10378386,
#     0.10440356],
#    'westphalianism': [0.39222646,
#     0.24498545,
#     0.066851355,
#     0.48677823,
#     0.3563415,
#     0.53392804,
#     'NA',
#     'NA',
#     0.29606703],
#    'security_concerns': [0.25270528,
#     0.29651237,
#     0.15174343,
#     0.12250688,
#     0.25847447,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.33054778,
#     0.35905713,
#     -0.006274922],
#    'multipolarism': [0.5845977,
#     0.34316894,
#     0.34494603,
#     0.6834133,
#     0.46127853,
#     0.560633,
#     'NA']},
#   9: {'eurasianism': [0.21389763,
#     0.20681949,
#     0.3668864,
#     0.3672286,
#     'NA',
#     0.32804796,
#     0.13823192,
#     0.22553389],
#    'westphalianism': [0.41576675,
#     0.2045708,
#     0.05525877,
#     0.3620519,
#     0.43873972,
#     0.3941142,
#     'NA',
#     'NA',
#     0.25898108],
#    'security_concerns': [0.21422616,
#     0.27554485,
#     0.19493745,
#     0.19110598,
#     0.28662363,
#     'NA',
#     'NA',
#     'NA',
#     0.2780448,
#     'NA',
#     'NA',
#     0.4541557,
#     0.103121296],
#    'multipolarism': [0.55227655,
#     0.22842266,
#     0.28008908,
#     0.59923315,
#     0.3537987,
#     0.5396458,
#     'NA']},
#   10: {'eurasianism': [0.2719399,
#     0.2614115,
#     0.35982436,
#     'NA',
#     'NA',
#     0.18652363,
#     0.27668417,
#     0.23180105],
#    'westphalianism': [0.2888487,
#     0.15738535,
#     0.13265261,
#     'NA',
#     0.35465336,
#     0.42888921,
#     'NA',
#     'NA',
#     0.09102423],
#    'security_concerns': [0.19259544,
#     0.36539173,
#     0.21389543,
#     0.18656093,
#     0.38328636,
#     'NA',
#     'NA',
#     'NA',
#     0.27814752,
#     'NA',
#     'NA',
#     0.36865804,
#     0.079864435],
#    'multipolarism': [0.5714416,
#     0.25190297,
#     0.36907932,
#     0.63712615,
#     0.52290124,
#     0.654154,
#     'NA']},
#   11: {'eurasianism': [0.2920907,
#     0.26776543,
#     0.3882641,
#     0.36725008,
#     'NA',
#     0.16189079,
#     0.12698963,
#     0.2097573],
#    'westphalianism': [0.4949682,
#     0.11164933,
#     0.027518477,
#     'NA',
#     0.27669135,
#     0.44501692,
#     'NA',
#     'NA',
#     0.17438835],
#    'security_concerns': [0.19112521,
#     0.108034536,
#     0.17344086,
#     0.10971724,
#     0.33324292,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.27756822,
#     0.5190795,
#     0.07788765],
#    'multipolarism': [0.5316509,
#     0.23140095,
#     0.28580728,
#     0.6601332,
#     0.32320797,
#     0.5974419,
#     'NA']},
#   12: {'eurasianism': [0.22689155,
#     0.24530293,
#     0.3757865,
#     0.35877797,
#     'NA',
#     0.2727428,
#     'NA',
#     0.23918936],
#    'westphalianism': [0.4183688,
#     0.16897725,
#     0.15561481,
#     'NA',
#     0.4089167,
#     'NA',
#     'NA',
#     'NA',
#     0.2921379],
#    'security_concerns': [0.19334199,
#     0.23324601,
#     0.14535421,
#     0.094253294,
#     0.25283423,
#     'NA',
#     'NA',
#     'NA',
#     0.28601012,
#     'NA',
#     'NA',
#     0.45039287,
#     0.24773595],
#    'multipolarism': [0.5891943,
#     0.315993,
#     0.37258372,
#     0.58759403,
#     0.4875444,
#     0.5513157,
#     'NA']},
#   13: {'eurasianism': [0.23865405,
#     0.29217622,
#     0.28913662,
#     0.42431992,
#     'NA',
#     0.25360587,
#     0.12968396,
#     0.23094729],
#    'westphalianism': [0.42755824,
#     0.24763429,
#     0.15335494,
#     'NA',
#     0.3548549,
#     0.32568553,
#     'NA',
#     'NA',
#     0.315066],
#    'security_concerns': [0.24570556,
#     0.3287074,
#     0.20274012,
#     0.14060868,
#     0.3666282,
#     'NA',
#     'NA',
#     'NA',
#     0.2992015,
#     'NA',
#     0.37971032,
#     0.45146188,
#     0.20191185],
#    'multipolarism': [0.5727721,
#     0.28695235,
#     0.28453892,
#     0.61443585,
#     0.40897736,
#     0.5895874,
#     'NA']},
#   14: {'eurasianism': [0.16928266,
#     0.2222195,
#     0.3157492,
#     0.363984,
#     'NA',
#     0.1870474,
#     0.1314207,
#     0.106606334],
#    'westphalianism': [0.42149964,
#     0.20358479,
#     0.18241419,
#     'NA',
#     0.4070916,
#     0.48655486,
#     'NA',
#     'NA',
#     0.3258081],
#    'security_concerns': [0.23389453,
#     0.22531614,
#     0.20025027,
#     0.11480367,
#     0.23897289,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.47700578,
#     0.080023244],
#    'multipolarism': [0.5139172,
#     0.25651792,
#     0.28392854,
#     0.6533453,
#     0.32095656,
#     0.5768821,
#     0.5418215]},
#   15: {'eurasianism': [0.23669802,
#     0.24886951,
#     0.3434409,
#     0.4380776,
#     'NA',
#     0.29665413,
#     0.12823749,
#     0.21121646],
#    'westphalianism': [0.41090417,
#     0.23541825,
#     0.1413409,
#     0.30931532,
#     0.3586285,
#     0.4097728,
#     'NA',
#     'NA',
#     0.322156],
#    'security_concerns': [0.27002606,
#     0.105164714,
#     0.18846045,
#     0.1374284,
#     0.39386532,
#     'NA',
#     'NA',
#     'NA',
#     0.31945512,
#     'NA',
#     0.30349332,
#     0.38729203,
#     0.11933502],
#    'multipolarism': [0.45333204,
#     0.16347611,
#     0.34524584,
#     0.6586385,
#     0.23877408,
#     0.58534086,
#     0.4971552]},
#   16: {'eurasianism': [0.18362552,
#     0.1847119,
#     0.2806695,
#     0.3812453,
#     'NA',
#     0.26307425,
#     0.2049844,
#     0.16561723],
#    'westphalianism': [0.35194185,
#     0.21791093,
#     0.08976116,
#     'NA',
#     0.3959893,
#     0.50635356,
#     'NA',
#     'NA',
#     0.20296663],
#    'security_concerns': [0.25069168,
#     0.23296303,
#     0.13736084,
#     0.15775058,
#     0.35461855,
#     'NA',
#     'NA',
#     'NA',
#     0.29970616,
#     'NA',
#     'NA',
#     0.5368088,
#     0.233883],
#    'multipolarism': [0.4439203,
#     0.3036127,
#     0.2994584,
#     0.7492972,
#     0.46285942,
#     0.5558975,
#     'NA']},
#   17: {'eurasianism': [0.21374051,
#     0.22515419,
#     0.37787166,
#     0.45937964,
#     'NA',
#     0.29960027,
#     0.10609741,
#     0.13426739],
#    'westphalianism': [0.3894015,
#     0.19511868,
#     0.18099684,
#     'NA',
#     0.3901266,
#     0.420976,
#     'NA',
#     'NA',
#     0.23757057],
#    'security_concerns': [0.20081103,
#     0.25961292,
#     0.14794576,
#     0.102779694,
#     0.31976688,
#     'NA',
#     'NA',
#     'NA',
#     0.36575264,
#     'NA',
#     0.37692124,
#     0.4375636,
#     0.11855082],
#    'multipolarism': [0.44947708,
#     0.23144248,
#     0.38696134,
#     0.7294394,
#     0.44862178,
#     0.6797773,
#     'NA']},
#   18: {'eurasianism': [0.2121266,
#     0.23542477,
#     0.3214101,
#     0.40386534,
#     'NA',
#     0.25187153,
#     0.19354454,
#     0.20013168],
#    'westphalianism': [0.44127184,
#     0.23952475,
#     0.18330395,
#     'NA',
#     0.4135759,
#     0.4993247,
#     'NA',
#     'NA',
#     0.26042768],
#    'security_concerns': [0.17014757,
#     0.34721208,
#     0.18311322,
#     0.17930149,
#     0.33366722,
#     'NA',
#     'NA',
#     'NA',
#     0.27839047,
#     'NA',
#     'NA',
#     0.4519233,
#     0.12315225],
#    'multipolarism': [0.6146131,
#     0.29281718,
#     0.3399916,
#     0.6663922,
#     0.5595495,
#     0.58529764,
#     'NA']},
#   19: {'eurasianism': [0.29499507,
#     0.2087324,
#     0.28232682,
#     0.34113988,
#     'NA',
#     0.27203694,
#     0.3321656,
#     0.21715826],
#    'westphalianism': [0.25593632,
#     0.25779364,
#     0.13655023,
#     0.22173096,
#     0.38997632,
#     0.30910873,
#     'NA',
#     'NA',
#     0.28160012],
#    'security_concerns': [0.19962546,
#     0.34449294,
#     0.14304982,
#     0.10528798,
#     0.30119708,
#     'NA',
#     'NA',
#     'NA',
#     0.29171064,
#     'NA',
#     'NA',
#     0.34383112,
#     0.15363999],
#    'multipolarism': [0.5227249,
#     0.22249615,
#     0.38764396,
#     0.7146981,
#     0.5113482,
#     0.41394073,
#     0.4738194]},
#   20: {'eurasianism': [0.25971547,
#     0.32082927,
#     0.28935075,
#     0.34585446,
#     'NA',
#     0.13169749,
#     0.2271595,
#     0.12415648],
#    'westphalianism': [0.41336498,
#     -0.023499224,
#     0.12391372,
#     'NA',
#     0.49232748,
#     0.50473666,
#     'NA',
#     'NA',
#     0.28159255],
#    'security_concerns': [0.18240187,
#     0.35148695,
#     0.16906482,
#     0.13700253,
#     0.3381021,
#     'NA',
#     'NA',
#     'NA',
#     0.39227274,
#     'NA',
#     'NA',
#     0.46621102,
#     0.19025716],
#    'multipolarism': [0.49483234,
#     0.24395117,
#     0.33057964,
#     0.6283447,
#     0.32111785,
#     0.5375176,
#     0.5278414]},
#   21: {'eurasianism': [0.23523451,
#     0.18557194,
#     0.39687324,
#     'NA',
#     'NA',
#     0.24580833,
#     0.19777349,
#     0.094260946],
#    'westphalianism': [0.3949967,
#     0.077566214,
#     0.09336009,
#     'NA',
#     0.40363532,
#     0.4508141,
#     'NA',
#     'NA',
#     0.15586786],
#    'security_concerns': [0.22577074,
#     0.38136244,
#     0.22154444,
#     0.13738598,
#     0.25393543,
#     'NA',
#     'NA',
#     'NA',
#     0.20445657,
#     'NA',
#     0.3549692,
#     0.5617305,
#     0.1445643],
#    'multipolarism': [0.5787679,
#     0.124430425,
#     0.24048853,
#     0.6948025,
#     0.55203897,
#     0.5596082,
#     0.52527386]},
#   22: {'eurasianism': [0.15675981,
#     0.20375599,
#     0.20778582,
#     0.36802322,
#     'NA',
#     0.3599937,
#     -0.019141763,
#     0.15391856],
#    'westphalianism': [0.33956257,
#     0.21361852,
#     -0.025716366,
#     0.29119882,
#     0.38637614,
#     0.4623512,
#     'NA',
#     'NA',
#     0.23334979],
#    'security_concerns': [0.27174425,
#     0.29615656,
#     0.22726531,
#     0.16958855,
#     0.3015106,
#     'NA',
#     'NA',
#     'NA',
#     0.27428627,
#     'NA',
#     0.3227673,
#     0.497991,
#     0.09265583],
#    'multipolarism': [0.4922039,
#     0.2942189,
#     0.23308237,
#     0.5690918,
#     0.4057291,
#     0.6138302,
#     'NA']},
#   23: {'eurasianism': [0.16492222,
#     0.23055902,
#     0.37746125,
#     0.43012592,
#     'NA',
#     0.27561587,
#     0.18358704,
#     0.07736562],
#    'westphalianism': [0.35002705,
#     'NA',
#     0.11386907,
#     'NA',
#     0.39403418,
#     0.29478395,
#     'NA',
#     'NA',
#     0.29858586],
#    'security_concerns': [0.21597184,
#     0.3502696,
#     0.18404402,
#     0.09469845,
#     0.3863039,
#     'NA',
#     'NA',
#     'NA',
#     0.28248954,
#     'NA',
#     'NA',
#     0.37734157,
#     0.111703314],
#    'multipolarism': [0.4227654,
#     0.3123368,
#     0.35842422,
#     0.58282566,
#     0.38319898,
#     0.69261146,
#     'NA']},
#   24: {'eurasianism': [0.206033,
#     0.32157972,
#     0.35601205,
#     0.3811991,
#     'NA',
#     0.3050883,
#     0.17294912,
#     0.21672478],
#    'westphalianism': [0.38823897,
#     0.10350443,
#     -0.023966048,
#     'NA',
#     0.3815857,
#     0.46494004,
#     'NA',
#     'NA',
#     0.09077876],
#    'security_concerns': [0.24348406,
#     0.3135536,
#     0.21695647,
#     0.21438392,
#     0.33227193,
#     'NA',
#     'NA',
#     'NA',
#     0.31472373,
#     'NA',
#     'NA',
#     0.3672626,
#     0.16594894],
#    'multipolarism': [0.5216727,
#     0.20711885,
#     0.27482566,
#     0.6334192,
#     0.43687963,
#     0.63084596,
#     'NA']},
#   25: {'eurasianism': [0.2929022,
#     0.1900879,
#     0.39178914,
#     0.44925535,
#     'NA',
#     0.3044021,
#     0.20774785,
#     0.1470415],
#    'westphalianism': [0.39344954,
#     0.17591348,
#     0.102671266,
#     'NA',
#     0.46416634,
#     0.45940152,
#     'NA',
#     'NA',
#     0.31747693],
#    'security_concerns': [0.21731055,
#     0.23022805,
#     0.26276696,
#     0.15762252,
#     0.24356565,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.45394292,
#     -0.023541814],
#    'multipolarism': [0.5370679,
#     0.27492565,
#     0.28151694,
#     0.6008434,
#     0.40873545,
#     0.59989053,
#     'NA']},
#   26: {'eurasianism': [0.18058178,
#     0.2316309,
#     0.4101671,
#     0.39713162,
#     'NA',
#     0.240896,
#     0.118492015,
#     0.214969],
#    'westphalianism': [0.4009204,
#     0.16465993,
#     0.057133913,
#     'NA',
#     0.32341844,
#     0.5298567,
#     'NA',
#     'NA',
#     0.27589425],
#    'security_concerns': [0.26736408,
#     0.30206043,
#     0.3160155,
#     0.18652903,
#     0.33240724,
#     'NA',
#     'NA',
#     'NA',
#     0.19384642,
#     'NA',
#     'NA',
#     0.41676712,
#     0.05795894],
#    'multipolarism': [0.53964084,
#     0.23906697,
#     0.4124788,
#     0.63499564,
#     0.35503924,
#     0.46542424,
#     'NA']},
#   27: {'eurasianism': [0.2655846,
#     0.20050038,
#     0.35560197,
#     0.39755267,
#     'NA',
#     0.26378432,
#     0.1901832,
#     0.18602556],
#    'westphalianism': [0.38717937,
#     0.052238517,
#     0.12208626,
#     0.20052704,
#     0.36615843,
#     0.38146916,
#     'NA',
#     'NA',
#     0.1739113],
#    'security_concerns': [0.1500318,
#     0.22825454,
#     0.19691837,
#     0.16768308,
#     0.31737167,
#     'NA',
#     'NA',
#     'NA',
#     0.3460653,
#     'NA',
#     0.3429432,
#     0.4903701,
#     0.11451069],
#    'multipolarism': [0.50511974,
#     0.2704683,
#     0.29807204,
#     0.7174094,
#     0.41241097,
#     0.5281495,
#     'NA']},
#   28: {'eurasianism': [0.24888895,
#     0.23483862,
#     0.3601244,
#     0.4105558,
#     'NA',
#     0.36808157,
#     0.24223544,
#     0.24498978],
#    'westphalianism': [0.44929093,
#     0.26910132,
#     0.057470415,
#     0.39801615,
#     0.4219098,
#     0.46571827,
#     'NA',
#     'NA',
#     0.2502204],
#    'security_concerns': [0.2455763,
#     0.30010796,
#     0.17253745,
#     0.17417794,
#     0.30505556,
#     'NA',
#     'NA',
#     'NA',
#     0.29420304,
#     'NA',
#     0.40637094,
#     0.40409908,
#     0.22488306],
#    'multipolarism': [0.4861547,
#     0.30040258,
#     0.30259106,
#     0.6475305,
#     0.3958163,
#     0.62772924,
#     'NA']},
#   29: {'eurasianism': [0.18112269,
#     0.30543914,
#     0.40128818,
#     0.40355802,
#     'NA',
#     0.22946206,
#     0.1753277,
#     0.1298357],
#    'westphalianism': [0.41632244,
#     0.275522,
#     0.17850843,
#     'NA',
#     0.4381726,
#     0.542104,
#     'NA',
#     'NA',
#     0.28522152],
#    'security_concerns': [0.17285882,
#     0.23885196,
#     0.15736516,
#     0.11609492,
#     0.29625103,
#     'NA',
#     'NA',
#     'NA',
#     0.31586045,
#     'NA',
#     'NA',
#     0.45424214,
#     0.0836189],
#    'multipolarism': [0.5216719,
#     0.27454454,
#     0.3804798,
#     0.6986751,
#     0.41316128,
#     0.60109204,
#     'NA']},
#   30: {'eurasianism': [0.24146266,
#     0.17282023,
#     0.3016573,
#     'NA',
#     'NA',
#     0.20015296,
#     0.044852804,
#     0.15286848],
#    'westphalianism': [0.39604545,
#     0.21053901,
#     0.14388207,
#     'NA',
#     0.33749935,
#     0.5160448,
#     'NA',
#     'NA',
#     0.11153845],
#    'security_concerns': [0.27691594,
#     0.20384187,
#     0.12915358,
#     0.19990808,
#     0.42932403,
#     'NA',
#     'NA',
#     'NA',
#     0.23220268,
#     'NA',
#     0.3328763,
#     0.40617973,
#     0.1488524],
#    'multipolarism': [0.47062752,
#     0.3237886,
#     0.37667298,
#     0.5895188,
#     0.41795805,
#     0.52610886,
#     'NA']},
#   31: {'eurasianism': [0.32348672,
#     0.19191547,
#     0.36941943,
#     'NA',
#     'NA',
#     0.23804721,
#     'NA',
#     0.2522152],
#    'westphalianism': [0.42473337,
#     'NA',
#     0.24596348,
#     'NA',
#     0.3733638,
#     0.4832674,
#     'NA',
#     'NA',
#     0.30259398],
#    'security_concerns': [0.23555256,
#     0.26996568,
#     0.26738745,
#     0.1829924,
#     0.29852232,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.36708567,
#     0.12193544],
#    'multipolarism': [0.52072865,
#     0.21912259,
#     0.36743855,
#     0.72514486,
#     0.27906972,
#     0.48926792,
#     0.473803]},
#   32: {'eurasianism': [0.07652832,
#     0.18364316,
#     0.36989385,
#     0.42129356,
#     'NA',
#     0.21549022,
#     0.17278416,
#     0.2017692],
#    'westphalianism': [0.36058608,
#     'NA',
#     0.13257818,
#     'NA',
#     0.4111673,
#     0.42985606,
#     'NA',
#     'NA',
#     0.36271766],
#    'security_concerns': [0.174033,
# ...
#     0.38246122,
#     0.1675134,
#     0.16428687,
#     0.33247042,
#     0.5206419,
#     0.6637767,
#     0.46801198,
#     0.3847946,
#     0.23172376,
#     0.5598699,
#     0.6084074,
#     0.09940845],
#    'multipolarism': [0.6881427,
#     0.2780753,
#     0.24127436,
#     0.7081463,
#     0.5637615,
#     0.49718773,
#     0.54232323]},
#   26: {'eurasianism': [0.2685311,
#     0.15683036,
#     0.35869417,
#     0.47484642,
#     0.519822,
#     0.53356695,
#     0.38083708,
#     'NA'],
#    'westphalianism': [0.3840203,
#     0.068841375,
#     0.14201263,
#     0.49794617,
#     0.6567171,
#     0.4381375,
#     0.35654655,
#     0.55162114,
#     0.43229076],
#    'security_concerns': [-0.003947683,
#     0.3639206,
#     0.17727096,
#     0.19077046,
#     0.27845287,
#     0.4702196,
#     0.67831105,
#     0.38061428,
#     0.30841297,
#     0.08576134,
#     0.5226406,
#     0.58049107,
#     0.12953636],
#    'multipolarism': [0.61167425,
#     0.30180955,
#     0.26888502,
#     0.659107,
#     0.44064164,
#     0.51103264,
#     0.4907429]},
#   27: {'eurasianism': [0.22604023,
#     0.1199497,
#     0.41495523,
#     0.50466615,
#     0.58160436,
#     0.5586886,
#     0.41246885,
#     'NA'],
#    'westphalianism': [0.43527493,
#     0.149445,
#     0.14305767,
#     0.515697,
#     0.613494,
#     0.546922,
#     0.38783064,
#     0.49103868,
#     0.53812903],
#    'security_concerns': [0.17803057,
#     0.2658571,
#     0.07247247,
#     0.24467827,
#     0.36104715,
#     0.45779884,
#     0.66786915,
#     0.4822069,
#     0.4163468,
#     0.3011898,
#     0.62058014,
#     0.53740007,
#     0.19207902],
#    'multipolarism': [0.6439493,
#     0.2635254,
#     0.23637973,
#     0.67968905,
#     0.5519259,
#     0.5507189,
#     0.4880689]},
#   28: {'eurasianism': [0.2613103,
#     0.19712114,
#     0.5662598,
#     0.55446565,
#     0.6405119,
#     0.4845031,
#     0.417388,
#     'NA'],
#    'westphalianism': [0.44062963,
#     0.03965357,
#     0.20177636,
#     0.50239617,
#     0.6283603,
#     0.47788432,
#     0.4084729,
#     0.49741435,
#     0.5054862],
#    'security_concerns': [0.19890563,
#     0.41637674,
#     0.10242209,
#     0.1776606,
#     0.2971561,
#     0.4987926,
#     0.6662738,
#     0.38905892,
#     0.3134077,
#     0.22242771,
#     0.48825464,
#     0.4529666,
#     0.13097878],
#    'multipolarism': [0.64203423,
#     0.23677425,
#     0.27695522,
#     0.651261,
#     0.55115926,
#     0.5754928,
#     0.5146314]},
#   29: {'eurasianism': [0.23623125,
#     0.075268775,
#     0.43422395,
#     0.47888726,
#     0.45906895,
#     0.5209884,
#     0.45489526,
#     'NA'],
#    'westphalianism': [0.4564199,
#     0.24046528,
#     0.16028915,
#     0.36757484,
#     0.5865417,
#     0.41231158,
#     0.47339177,
#     0.6103403,
#     0.39152893],
#    'security_concerns': [0.11301582,
#     0.22603242,
#     0.112083405,
#     0.22129251,
#     0.35925925,
#     0.46238384,
#     0.6865674,
#     0.4510341,
#     0.450837,
#     0.20105931,
#     0.51250386,
#     0.44723943,
#     0.13843481],
#    'multipolarism': [0.6094611,
#     0.40041202,
#     0.31258324,
#     0.65360606,
#     0.57102585,
#     0.5219228,
#     0.55078495]},
#   30: {'eurasianism': [0.2417375,
#     0.09897226,
#     0.40303275,
#     0.56143093,
#     0.60140896,
#     0.5142742,
#     0.45537263,
#     'NA'],
#    'westphalianism': [0.4476784,
#     0.22921585,
#     0.1684424,
#     0.4657772,
#     0.6518574,
#     0.43793646,
#     0.3712702,
#     0.49311933,
#     0.47489864],
#    'security_concerns': [0.13200098,
#     0.28424078,
#     0.06186858,
#     0.20736927,
#     0.32749537,
#     0.45550683,
#     0.69639623,
#     0.48678014,
#     0.30394736,
#     0.20612478,
#     0.5095293,
#     0.6024968,
#     0.1347101],
#    'multipolarism': [0.639351,
#     0.37904698,
#     0.2346795,
#     0.59261066,
#     0.54955137,
#     0.5532171,
#     0.582084]},
#   31: {'eurasianism': [0.27823833,
#     0.14912216,
#     0.4390112,
#     0.4982909,
#     0.4288156,
#     0.54541236,
#     0.4451223,
#     0.2628992],
#    'westphalianism': [0.49163255,
#     0.14511175,
#     0.25138208,
#     0.5352042,
#     0.65183234,
#     0.40106645,
#     0.26617676,
#     0.5594,
#     0.5432639],
#    'security_concerns': [0.12346111,
#     0.36246157,
#     0.11085957,
#     0.20611687,
#     0.32397786,
#     0.47353408,
#     0.6743416,
#     0.4268356,
#     0.24703984,
#     0.124629155,
#     0.45110694,
#     0.5139572,
#     0.15067664],
#    'multipolarism': [0.6300911,
#     0.34077746,
#     0.2526279,
#     0.6358392,
#     0.61970353,
#     0.58464897,
#     0.5705904]},
#   32: {'eurasianism': [0.30381453,
#     0.14120895,
#     0.43928942,
#     0.363991,
#     0.57039297,
#     0.53513783,
#     0.4454732,
#     'NA'],
#    'westphalianism': [0.42490926,
#     0.21102537,
#     0.21165878,
#     0.48691627,
#     0.65259165,
#     0.40958598,
#     0.4104665,
#     0.45315453,
#     0.49945024],
#    'security_concerns': [0.1945574,
#     0.46215937,
#     0.2086409,
#     0.18355095,
#     0.3229648,
#     0.44405228,
#     0.722471,
#     0.517703,
#     0.2723748,
#     0.25784352,
#     0.53978556,
#     0.6273225,
#     0.088051185],
#    'multipolarism': [0.6393373,
#     0.27030566,
#     0.25034866,
#     0.6835854,
#     0.64689195,
#     0.61126107,
#     'NA']},
#   33: {'eurasianism': [0.23253964,
#     0.12081364,
#     0.44813696,
#     0.45558617,
#     0.5430708,
#     0.4969218,
#     0.3412306,
#     0.2849636],
#    'westphalianism': [0.48266596,
#     0.12962548,
#     0.20957473,
#     0.45274898,
#     0.63506365,
#     0.5279824,
#     0.42574975,
#     0.5069419,
#     0.48413303],
#    'security_concerns': [0.1636858,
#     0.28169295,
#     0.18217343,
#     0.20945862,
#     0.35518888,
#     0.5001739,
#     0.62368196,
#     'NA',
#     0.41017023,
#     0.22884285,
#     0.48848933,
#     0.49019137,
#     0.15355428],
#    'multipolarism': [0.5850683,
#     0.32881647,
#     0.23154378,
#     0.66329616,
#     0.5903442,
#     0.5684635,
#     0.53741354]},
#   34: {'eurasianism': [0.28415066,
#     0.022833182,
#     0.4085002,
#     0.5056966,
#     0.58742505,
#     0.5022346,
#     0.527519,
#     'NA'],
#    'westphalianism': [0.46139982,
#     0.15241049,
#     0.1592375,
#     0.43122122,
#     0.66031754,
#     0.48898962,
#     0.42190242,
#     0.5140548,
#     0.53331727],
#    'security_concerns': [0.11755005,
#     0.33753914,
#     0.19502185,
#     0.21357948,
#     0.3805936,
#     0.49550056,
#     0.6822933,
#     0.4490328,
#     0.343708,
#     0.23773614,
#     0.52300787,
#     0.51706195,
#     0.20456643],
#    'multipolarism': [0.6239153,
#     0.34680867,
#     0.27230936,
#     0.6717888,
#     0.53044724,
#     0.56230617,
#     0.5331631]},
#   35: {'eurasianism': [0.29332674,
#     -0.0944224,
#     0.39175323,
#     0.4500625,
#     0.5457714,
#     0.5043204,
#     0.43587974,
#     0.39225274],
#    'westphalianism': [0.42081755,
#     0.10535117,
#     0.18257627,
#     0.39448074,
#     0.64799494,
#     0.53478265,
#     0.44500092,
#     0.53515345,
#     0.49692905],
#    'security_concerns': [0.052125808,
#     0.43731567,
#     0.18639925,
#     0.1898263,
#     0.35930613,
#     0.54147726,
#     0.70358735,
#     0.41636634,
#     0.4880954,
#     0.2003678,
#     0.59843034,
#     0.5683173,
#     0.077575974],
#    'multipolarism': [0.6278196,
#     0.2987068,
#     0.2740035,
#     0.65212077,
#     0.5161356,
#     0.59302986,
#     0.5575181]},
#   36: {'eurasianism': [0.29733065,
#     0.11116192,
#     0.4196753,
#     0.42886466,
#     0.5817323,
#     0.5014189,
#     0.46933973,
#     0.44298425],
#    'westphalianism': [0.42145056,
#     0.1265065,
#     0.06768574,
#     0.34853673,
#     0.64738363,
#     0.49272603,
#     0.41534278,
#     0.44916168,
#     0.46262828],
#    'security_concerns': [0.17483574,
#     0.3640689,
#     0.08657158,
#     0.23189984,
#     0.4475076,
#     0.5524233,
#     0.6321622,
#     0.4123205,
#     'NA',
#     0.21570912,
#     0.5020939,
#     0.5624746,
#     0.11447405],
#    'multipolarism': [0.6016057,
#     0.32845864,
#     0.2093647,
#     0.61281496,
#     0.4553709,
#     0.54862314,
#     0.5462391]},
#   37: {'eurasianism': [0.19342326,
#     0.015475301,
#     0.44323078,
#     0.48448932,
#     0.4477456,
#     0.5561654,
#     0.39170384,
#     0.27322924],
#    'westphalianism': [0.4616759,
#     0.2146738,
#     0.15862854,
#     0.4431533,
#     0.5682303,
#     0.47062242,
#     0.40570363,
#     0.55881274,
#     0.5121963],
#    'security_concerns': [0.15113674,
#     0.454296,
#     0.10134081,
#     0.18538524,
#     0.30236554,
#     0.5684874,
#     0.6850686,
#     0.3392369,
#     0.37711182,
#     0.21380883,
#     0.42679632,
#     0.47747633,
#     0.2382491],
#    'multipolarism': [0.5694786,
#     0.31104496,
#     0.27495298,
#     0.5623731,
#     0.55646545,
#     0.5842375,
#     'NA']},
#   38: {'eurasianism': [0.28045785,
#     0.096561566,
#     0.4401128,
#     0.3409533,
#     0.5394049,
#     0.5379801,
#     0.45808208,
#     'NA'],
#    'westphalianism': [0.45562872,
#     0.08961161,
#     0.09470121,
#     0.42213497,
#     0.62590414,
#     0.39923534,
#     0.38434428,
#     0.5151668,
#     0.44305867],
#    'security_concerns': [0.15083075,
#     0.38054276,
#     0.20218445,
#     0.23691733,
#     0.40387982,
#     0.50786954,
#     0.6968912,
#     'NA',
#     0.3756379,
#     0.12149581,
#     0.62110156,
#     0.5862025,
#     0.13883114],
#    'multipolarism': [0.5597248,
#     0.2935901,
#     0.18883128,
#     0.6670539,
#     0.53225315,
#     0.55926657,
#     0.5054075]},
#   39: {'eurasianism': [0.24047665,
#     0.1661308,
#     0.4633332,
#     0.44745088,
#     0.6122198,
#     0.5470789,
#     0.38532877,
#     0.17096767],
#    'westphalianism': [0.41526636,
#     0.208831,
#     0.12377026,
#     0.45333865,
#     0.5780005,
#     0.4820797,
#     0.3667242,
#     0.54085773,
#     0.494284],
#    'security_concerns': [0.17360836,
#     0.40610662,
#     0.11752892,
#     0.24116194,
#     0.38184673,
#     0.5624491,
#     0.66350687,
#     0.41935214,
#     0.4117622,
#     0.21530332,
#     0.5877463,
#     0.51803595,
#     0.18130177],
#    'multipolarism': [0.58443266,
#     0.31991994,
#     0.26622346,
#     0.7279026,
#     0.53839254,
#     0.5066221,
#     0.5593657]},
#   40: {'eurasianism': [0.2619778,
#     0.08323763,
#     0.45966655,
#     0.55253154,
#     0.5138926,
#     0.4961934,
#     0.54062474,
#     'NA'],
#    'westphalianism': [0.47154245,
#     'NA',
#     0.1325921,
#     0.51025134,
#     0.67116356,
#     0.4480211,
#     0.4509597,
#     0.45106673,
#     0.5003368],
#    'security_concerns': [0.15031527,
#     0.24902345,
#     0.13722177,
#     0.21339753,
#     0.34138352,
#     0.5792314,
#     0.6842697,
#     0.44427827,
#     0.4191696,
#     0.26018384,
#     0.53719985,
#     0.5535908,
#     0.10775542],
#    'multipolarism': [0.644975,
#     0.3083748,
#     0.28358388,
#     0.6511277,
#     0.5887085,
#     0.5868154,
#     0.53741425]},
#   41: {'eurasianism': [0.22671096,
#     0.021331165,
#     0.36179975,
#     0.5277198,
#     0.5414764,
#     0.532892,
#     0.47756425,
#     0.21948291],
#    'westphalianism': [0.41795808,
#     0.18595606,
#     0.17017092,
#     0.47489905,
#     0.6187928,
#     0.45243296,
#     0.43732113,
#     0.48868176,
#     0.45962185],
#    'security_concerns': [0.10864096,
#     0.3908681,
#     0.08059254,
#     0.1085305,
#     0.29131034,
#     0.49611768,
#     0.62037534,
#     0.52184665,
#     0.48183843,
#     0.11531127,
#     0.51954037,
#     0.5524754,
#     0.10611086],
#    'multipolarism': [0.5741654,
#     0.22095332,
#     0.16843033,
#     0.6810231,
#     0.6100208,
#     0.5302732,
#     0.5293994]},
#   42: {'eurasianism': [0.24881932,
#     0.15449205,
#     0.4083585,
#     0.44792452,
#     0.48294336,
#     0.4949638,
#     0.37247807,
#     0.25504872],
#    'westphalianism': [0.35518494,
#     0.07435941,
#     0.11380975,
#     0.3920407,
#     0.5983922,
#     0.44559747,
#     0.3957743,
#     0.46685463,
#     0.38609588],
#    'security_concerns': [0.1287777,
#     0.29210532,
#     0.20445973,
#     0.17670095,
#     0.3241297,
#     0.4763482,
#     0.58951294,
#     0.44601202,
#     0.34561697,
#     0.17733118,
#     0.5692976,
#     0.57194227,
#     0.1342821],
#    'multipolarism': [0.62984467,
#     0.30723506,
#     0.216386,
#     0.7291458,
#     0.57974905,
#     0.56400764,
#     0.5980232]},
#   43: {'eurasianism': [0.2595095,
#     0.09222342,
#     0.40245324,
#     0.53500175,
#     0.6255654,
#     0.51471406,
#     0.38366184,
#     'NA'],
#    'westphalianism': [0.42192876,
#     0.18585053,
#     0.16630568,
#     0.5158306,
#     0.62920016,
#     0.4474835,
#     0.46699286,
#     0.5111054,
#     0.49879012],
#    'security_concerns': [0.114003696,
#     0.39734674,
#     0.104272485,
#     0.18568926,
#     0.28158012,
#     0.526889,
#     0.7075328,
#     0.5153156,
#     0.39961642,
#     0.22364497,
#     0.5033146,
#     0.4762249,
#     0.08686634],
#    'multipolarism': [0.5595091,
#     0.30553213,
#     0.2014078,
#     0.6488661,
#     0.6559089,
#     0.5000426,
#     0.57624155]},
#   44: {'eurasianism': [0.24062683,
#     0.10764937,
#     0.32298064,
#     0.34812477,
#     0.5946053,
#     0.4764093,
#     0.40505952,
#     0.309666],
#    'westphalianism': [0.4099049,
#     0.10405184,
#     0.18603852,
#     0.4789757,
#     0.65390784,
#     0.55014205,
#     0.2514131,
#     0.4885254,
#     0.43037933],
#    'security_concerns': [0.06435628,
#     0.36950865,
#     0.24566095,
#     0.20331675,
#     0.27557406,
#     0.5709763,
#     0.70246553,
#     'NA',
#     0.48335755,
#     0.21762088,
#     0.50213677,
#     0.50092614,
#     0.011775602],
#    'multipolarism': [0.58665794,
#     0.2866041,
#     0.2882664,
#     0.68699306,
#     0.6363057,
#     0.5431318,
#     'NA']},
#   45: {'eurasianism': [0.26230264,
#     0.16731182,
#     0.3032251,
#     0.3783332,
#     0.42008367,
#     0.49069068,
#     0.38242343,
#     'NA'],
#    'westphalianism': [0.41695085,
#     0.24579354,
#     0.23596622,
#     0.4497903,
#     0.62775886,
#     0.48321915,
#     0.3914749,
#     0.42020643,
#     0.48183984],
#    'security_concerns': [0.15749994,
#     0.3582403,
#     0.106927246,
#     0.19344756,
#     0.32906237,
#     0.5733325,
#     0.6718684,
#     0.4534792,
#     0.28344378,
#     0.24226785,
#     0.45179862,
#     0.5457347,
#     0.1040073],
#    'multipolarism': [0.647287,
#     0.31518996,
#     0.2104665,
#     0.66645235,
#     0.57610863,
#     0.5316446,
#     'NA']},
#   46: {'eurasianism': [0.24519108,
#     0.09261264,
#     0.4084295,
#     0.52008116,
#     0.6311684,
#     0.5347931,
#     0.412361,
#     'NA'],
#    'westphalianism': [0.4320106,
#     0.15728699,
#     0.22814746,
#     0.47484022,
#     0.68439496,
#     0.54112965,
#     0.42001405,
#     0.53198695,
#     0.45653346],
#    'security_concerns': [0.1865897,
#     0.4635505,
#     0.113255665,
#     0.19222133,
#     0.30501977,
#     0.49200472,
#     0.6724197,
#     0.3693796,
#     0.3901545,
#     0.2700525,
#     0.48915902,
#     0.5787451,
#     0.18369344],
#    'multipolarism': [0.6526944,
#     0.35386407,
#     0.2491933,
#     0.6751162,
#     0.5231418,
#     0.54319274,
#     0.5460735]},
#   47: {'eurasianism': [0.2672374,
#     0.11737209,
#     0.38733777,
#     0.41366148,
#     0.61097205,
#     0.4787581,
#     0.4396639,
#     0.21798533],
#    'westphalianism': [0.4004105,
#     0.23839587,
#     0.056741826,
#     0.46544215,
#     0.6260936,
#     0.4794625,
#     0.31879538,
#     0.5503254,
#     0.46865803],
#    'security_concerns': [-0.006576566,
#     0.2698088,
#     0.085196115,
#     0.23758245,
#     0.26963446,
#     0.58594495,
#     0.6846999,
#     0.34888157,
#     0.45081937,
#     0.22387412,
#     0.4561184,
#     0.47527698,
#     0.11816692],
#    'multipolarism': [0.60238534,
#     0.36300874,
#     0.19545749,
#     0.62888336,
#     0.594386,
#     0.6004395,
#     0.45043805]},
#   48: {'eurasianism': [0.26225042,
#     0.22595705,
#     0.35959756,
#     0.404726,
#     0.66680455,
#     0.5532652,
#     0.4111912,
#     0.21370412],
#    'westphalianism': [0.45709136,
#     0.13647655,
#     0.18727782,
#     0.4104821,
#     0.6938428,
#     0.49046165,
#     0.3618033,
#     0.57447046,
#     0.4285189],
#    'security_concerns': [0.08507967,
#     0.45776352,
#     0.15180323,
#     0.23832273,
#     0.283852,
#     0.52785057,
#     0.70396245,
#     0.3890054,
#     0.3888188,
#     0.16919002,
#     0.50654334,
#     0.5067993,
#     0.12131272],
#    'multipolarism': [0.588404,
#     0.3433772,
#     0.205559,
#     0.62398034,
#     0.5666893,
#     0.5576127,
#     0.58317006]},
#   49: {'eurasianism': [0.2976434,
#     0.1974806,
#     0.42536965,
#     0.41267702,
#     0.6160187,
#     0.5797309,
#     0.40950882,
#     0.18097319],
#    'westphalianism': [0.41569957,
#     0.13040577,
#     0.1972504,
#     0.357006,
#     0.65756464,
#     0.42854992,
#     0.37102014,
#     0.54294527,
#     0.39502773],
#    'security_concerns': [0.07091254,
#     0.18593353,
#     0.16248253,
#     0.22587544,
#     0.34012228,
#     0.50874686,
#     0.6548652,
#     0.3951532,
#     0.40086165,
#     0.16385445,
#     0.5125593,
#     0.4903416,
#     0.14296925],
#    'multipolarism': [0.598343,
#     0.27614373,
#     0.22560783,
#     0.6799075,
#     0.5639075,
#     0.5256602,
#     'NA']}}}

# %%
# initialize empty dictionary to store the scores
stat_types = {}

# loop through each target word and its scores
for target_word, target_scores in scores.items():

    # initialize empty dictionary to store the scores for this target word
    target_stat_types = {}

    # loop through each era and its scores for this target word
    for era, era_scores in target_scores.items():

        # initialize empty dictionary to store the scores for this era
        era_stat_types = {}

        # loop through each statistical type and its score for this era
        for stat_type, score in era_scores.items():
            era_stat_types[stat_type] = score

        # add the scores for this era to the scores for this target word
        target_stat_types[era] = era_stat_types

    # add the scores for this target word to the overall dictionary of scores
    stat_types[target_word] = target_stat_types

# %%
stat_types
# Out:
# {0: {0: {'eurasianism': [0.26861662,
#     'NA',
#     0.4224597,
#     'NA',
#     'NA',
#     0.2951925,
#     'NA',
#     'NA'],
#    'westphalianism': [0.29417616,
#     'NA',
#     0.25111505,
#     0.10528102,
#     0.2954621,
#     0.5699735,
#     'NA',
#     'NA',
#     0.16846916],
#    'security_concerns': [0.10204306,
#     0.24536033,
#     0.19386089,
#     0.091113396,
#     0.26081195,
#     'NA',
#     'NA',
#     'NA',
#     0.48149937,
#     'NA',
#     'NA',
#     0.40881145,
#     0.046445318],
#    'multipolarism': [0.57526577,
#     0.23169893,
#     0.12056039,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   1: {'eurasianism': [0.21695624,
#     'NA',
#     0.43688533,
#     'NA',
#     'NA',
#     0.19233967,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3550019,
#     'NA',
#     0.1806682,
#     'NA',
#     0.35201317,
#     0.47790655,
#     'NA',
#     'NA',
#     0.29062065],
#    'security_concerns': [0.20916042,
#     0.1831182,
#     0.19599551,
#     0.100096494,
#     0.30253834,
#     'NA',
#     'NA',
#     'NA',
#     0.45114887,
#     'NA',
#     'NA',
#     'NA',
#     0.105179146],
#    'multipolarism': [0.43348157,
#     0.1253265,
#     0.2654461,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   2: {'eurasianism': [0.25282165,
#     0.08222587,
#     0.36149317,
#     'NA',
#     'NA',
#     0.20772223,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34803668,
#     0.46474037,
#     0.16731372,
#     'NA',
#     0.2859975,
#     'NA',
#     'NA',
#     'NA',
#     0.3004911],
#    'security_concerns': [0.17583856,
#     'NA',
#     0.15043114,
#     0.13739817,
#     0.26804477,
#     'NA',
#     'NA',
#     'NA',
#     0.37575597,
#     'NA',
#     'NA',
#     'NA',
#     -0.018795704],
#    'multipolarism': [0.38016504,
#     0.14395188,
#     0.15772629,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   3: {'eurasianism': [0.3162461,
#     0.015170151,
#     0.46097958,
#     'NA',
#     'NA',
#     0.3101261,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34937388,
#     0.40171447,
#     0.14890173,
#     0.13020103,
#     0.36965787,
#     0.47188637,
#     'NA',
#     'NA',
#     0.22727679],
#    'security_concerns': [0.1843154,
#     'NA',
#     0.114042096,
#     0.12603408,
#     0.24709393,
#     'NA',
#     'NA',
#     'NA',
#     0.41641283,
#     'NA',
#     'NA',
#     0.44330034,
#     0.24771978],
#    'multipolarism': [0.4588015,
#     0.048028123,
#     0.14778097,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   4: {'eurasianism': [0.19929491,
#     0.25271234,
#     0.43201032,
#     'NA',
#     'NA',
#     0.19304809,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3803378,
#     'NA',
#     0.1881384,
#     0.08745855,
#     0.29732528,
#     'NA',
#     'NA',
#     'NA',
#     0.28486234],
#    'security_concerns': [0.22881718,
#     0.13401555,
#     0.19261216,
#     0.087729625,
#     0.24883673,
#     'NA',
#     'NA',
#     'NA',
#     0.47696397,
#     'NA',
#     'NA',
#     'NA',
#     0.117491014],
#    'multipolarism': [0.4484873,
#     0.18722843,
#     0.19784798,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   5: {'eurasianism': [0.28447425,
#     0.07322036,
#     0.37434113,
#     'NA',
#     'NA',
#     0.14216082,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2441625,
#     0.38750297,
#     0.26327834,
#     0.2691071,
#     0.35761243,
#     0.3782691,
#     'NA',
#     'NA',
#     0.16060969],
#    'security_concerns': [0.15281534,
#     0.17980528,
#     0.13272482,
#     0.12708138,
#     0.2725994,
#     'NA',
#     'NA',
#     'NA',
#     0.4658937,
#     'NA',
#     'NA',
#     0.39683393,
#     0.1383805],
#    'multipolarism': [0.55482405,
#     0.16270395,
#     0.16827212,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   6: {'eurasianism': [0.22751963,
#     0.08876127,
#     0.41063502,
#     'NA',
#     'NA',
#     0.2726134,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30307546,
#     'NA',
#     0.11839778,
#     'NA',
#     0.34660468,
#     0.50763804,
#     'NA',
#     'NA',
#     0.29923767],
#    'security_concerns': [0.16882834,
#     0.22807789,
#     0.08303809,
#     0.11298816,
#     0.16838941,
#     'NA',
#     'NA',
#     'NA',
#     0.4332915,
#     'NA',
#     'NA',
#     'NA',
#     0.12395973],
#    'multipolarism': [0.4999324,
#     0.028371051,
#     0.20997028,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   7: {'eurasianism': [0.28725094,
#     'NA',
#     0.5118409,
#     'NA',
#     'NA',
#     0.24186808,
#     'NA',
#     'NA'],
#    'westphalianism': [0.29825684,
#     'NA',
#     0.14600042,
#     0.37441292,
#     0.35926738,
#     0.61034876,
#     'NA',
#     'NA',
#     0.27345556],
#    'security_concerns': [0.23573366,
#     'NA',
#     0.19786513,
#     0.18560009,
#     0.30058104,
#     'NA',
#     'NA',
#     'NA',
#     0.49209112,
#     'NA',
#     'NA',
#     'NA',
#     0.101475835],
#    'multipolarism': [0.39856246,
#     0.13194224,
#     0.17801489,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   8: {'eurasianism': [0.24421494,
#     0.07500764,
#     0.31099695,
#     'NA',
#     'NA',
#     0.1968447,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34827563,
#     0.47115576,
#     0.06438446,
#     'NA',
#     0.3586724,
#     0.6407889,
#     'NA',
#     'NA',
#     0.18654805],
#    'security_concerns': [0.24869655,
#     0.16108602,
#     0.1141353,
#     0.15245837,
#     0.26930904,
#     'NA',
#     'NA',
#     'NA',
#     0.43396655,
#     'NA',
#     'NA',
#     0.48294276,
#     0.21883999],
#    'multipolarism': [0.4134007,
#     0.20390211,
#     0.15061308,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   9: {'eurasianism': [0.1667035,
#     0.10164343,
#     0.4119568,
#     'NA',
#     'NA',
#     0.27888024,
#     'NA',
#     'NA'],
#    'westphalianism': [0.26120153,
#     'NA',
#     0.22594589,
#     'NA',
#     0.44212803,
#     0.5808045,
#     'NA',
#     'NA',
#     0.29419369],
#    'security_concerns': [0.2880953,
#     0.15303445,
#     0.13540658,
#     0.19073053,
#     0.27348405,
#     'NA',
#     'NA',
#     'NA',
#     0.22761537,
#     'NA',
#     'NA',
#     0.39071307,
#     0.25312522],
#    'multipolarism': [0.42203453,
#     0.07410641,
#     0.17548722,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   10: {'eurasianism': [0.279803,
#     'NA',
#     0.40516555,
#     'NA',
#     'NA',
#     0.1913603,
#     'NA',
#     'NA'],
#    'westphalianism': [0.31256753,
#     0.44722575,
#     0.19528164,
#     0.29625905,
#     0.40974125,
#     0.588949,
#     'NA',
#     'NA',
#     0.21527578],
#    'security_concerns': [0.06135087,
#     0.25792164,
#     0.2938076,
#     0.11495888,
#     0.27772027,
#     'NA',
#     'NA',
#     'NA',
#     0.49139193,
#     'NA',
#     'NA',
#     0.40406597,
#     0.13877037],
#    'multipolarism': [0.4608935,
#     0.16047798,
#     0.13596636,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   11: {'eurasianism': [0.26912564,
#     'NA',
#     0.3735627,
#     'NA',
#     'NA',
#     0.22677162,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3751029,
#     0.3552267,
#     0.17123114,
#     0.26970297,
#     0.45811078,
#     0.57969415,
#     'NA',
#     'NA',
#     0.29588875],
#    'security_concerns': [0.14560458,
#     0.1756094,
#     0.06730684,
#     0.052810047,
#     0.28996745,
#     'NA',
#     'NA',
#     'NA',
#     0.28409168,
#     'NA',
#     'NA',
#     0.4465115,
#     0.1493033],
#    'multipolarism': [0.5132751,
#     0.05679848,
#     0.096193835,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   12: {'eurasianism': [0.32554418,
#     0.24003199,
#     0.47870234,
#     'NA',
#     'NA',
#     0.25148264,
#     'NA',
#     'NA'],
#    'westphalianism': [0.27416226,
#     'NA',
#     0.16666433,
#     0.08349878,
#     0.38312224,
#     0.5164976,
#     'NA',
#     'NA',
#     0.39097786],
#    'security_concerns': [0.17485155,
#     'NA',
#     0.25297278,
#     0.17556699,
#     0.21736738,
#     'NA',
#     'NA',
#     'NA',
#     0.26022613,
#     'NA',
#     'NA',
#     0.40132844,
#     0.2536745],
#    'multipolarism': [0.38165992,
#     0.1510047,
#     0.16587391,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   13: {'eurasianism': [0.24570304,
#     0.06965464,
#     0.4076691,
#     'NA',
#     'NA',
#     0.23064518,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32997873,
#     'NA',
#     0.08774391,
#     0.18536222,
#     0.5076438,
#     0.5794456,
#     'NA',
#     'NA',
#     0.23867549],
#    'security_concerns': [0.15463158,
#     0.0983432,
#     0.073679626,
#     0.17197478,
#     0.29608995,
#     'NA',
#     'NA',
#     'NA',
#     0.4042678,
#     'NA',
#     'NA',
#     'NA',
#     0.16017096],
#    'multipolarism': [0.44413275,
#     0.15654345,
#     0.18959503,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   14: {'eurasianism': [0.30178708,
#     'NA',
#     0.39418626,
#     'NA',
#     'NA',
#     0.3432112,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32334438,
#     'NA',
#     0.19293262,
#     0.21982998,
#     0.35659367,
#     0.49706173,
#     'NA',
#     'NA',
#     0.24586363],
#    'security_concerns': [0.19167727,
#     0.23084566,
#     0.2520652,
#     0.16652493,
#     0.29357418,
#     'NA',
#     'NA',
#     'NA',
#     0.42578945,
#     'NA',
#     'NA',
#     'NA',
#     0.1086287],
#    'multipolarism': [0.43914613,
#     0.13515034,
#     0.18924251,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   15: {'eurasianism': [0.11635627,
#     0.067033045,
#     0.3072613,
#     'NA',
#     'NA',
#     0.22661924,
#     'NA',
#     'NA'],
#    'westphalianism': [0.37634823,
#     0.27286884,
#     0.1921258,
#     'NA',
#     0.293535,
#     0.46486115,
#     'NA',
#     'NA',
#     0.24689257],
#    'security_concerns': [0.16420162,
#     0.24044724,
#     0.07356139,
#     0.1627961,
#     0.29733205,
#     'NA',
#     'NA',
#     'NA',
#     0.40708798,
#     'NA',
#     'NA',
#     0.35918206,
#     0.14431319],
#    'multipolarism': [0.46622977,
#     0.12594599,
#     0.18901809,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   16: {'eurasianism': [0.3186611,
#     0.057644133,
#     0.3984292,
#     'NA',
#     'NA',
#     0.25728056,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34960535,
#     0.4327447,
#     0.19052096,
#     'NA',
#     0.32428253,
#     0.4202772,
#     'NA',
#     'NA',
#     0.30281538],
#    'security_concerns': [0.13392095,
#     0.17780983,
#     0.17782618,
#     0.21083386,
#     0.271169,
#     'NA',
#     'NA',
#     'NA',
#     0.49846414,
#     'NA',
#     'NA',
#     0.41865772,
#     0.12227538],
#    'multipolarism': [0.4437698,
#     0.14086466,
#     0.24604866,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   17: {'eurasianism': [0.1221354,
#     0.19082202,
#     0.35256976,
#     'NA',
#     'NA',
#     0.220179,
#     'NA',
#     'NA'],
#    'westphalianism': [0.33054632,
#     0.42868277,
#     0.18446286,
#     'NA',
#     0.3010165,
#     0.39187858,
#     'NA',
#     'NA',
#     0.26778612],
#    'security_concerns': [0.16962771,
#     0.14298283,
#     0.21153022,
#     0.19517687,
#     0.26515862,
#     'NA',
#     'NA',
#     'NA',
#     0.43552098,
#     'NA',
#     'NA',
#     0.34518194,
#     0.17639887],
#    'multipolarism': [0.460087,
#     0.20048758,
#     0.15231411,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   18: {'eurasianism': [0.21465006,
#     'NA',
#     0.34219053,
#     'NA',
#     'NA',
#     0.22095971,
#     'NA',
#     'NA'],
#    'westphalianism': [0.22324897,
#     0.35851565,
#     0.058601666,
#     'NA',
#     0.3724276,
#     0.5537837,
#     'NA',
#     'NA',
#     0.1538156],
#    'security_concerns': [0.053416733,
#     'NA',
#     0.25648066,
#     0.038446918,
#     0.2828356,
#     'NA',
#     'NA',
#     'NA',
#     0.37806797,
#     'NA',
#     'NA',
#     0.37659702,
#     0.0582142],
#    'multipolarism': [0.44806686,
#     0.14664319,
#     0.15896975,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   19: {'eurasianism': [0.27931225,
#     'NA',
#     0.40296823,
#     'NA',
#     'NA',
#     0.15260786,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30142277,
#     'NA',
#     0.2921376,
#     0.21013953,
#     0.37651223,
#     'NA',
#     'NA',
#     'NA',
#     0.22705652],
#    'security_concerns': [0.14767736,
#     0.16459472,
#     0.21796168,
#     0.120540865,
#     0.30913457,
#     'NA',
#     'NA',
#     'NA',
#     0.4050815,
#     'NA',
#     'NA',
#     0.2644157,
#     0.17310467],
#    'multipolarism': [0.4629557,
#     0.14197119,
#     0.2090818,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   20: {'eurasianism': [0.24261425,
#     0.23849295,
#     0.23532677,
#     'NA',
#     'NA',
#     0.11017794,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30710596,
#     0.3949141,
#     0.35777533,
#     0.12183706,
#     0.44328713,
#     0.33584854,
#     'NA',
#     'NA',
#     0.16893499],
#    'security_concerns': [0.19770858,
#     0.28366295,
#     0.12146483,
#     0.08742693,
#     0.16360322,
#     'NA',
#     'NA',
#     'NA',
#     0.23439705,
#     'NA',
#     'NA',
#     0.36425126,
#     0.14115648],
#    'multipolarism': [0.45918995,
#     0.08467303,
#     0.08570797,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   21: {'eurasianism': [0.2779709,
#     0.10924718,
#     0.31753924,
#     'NA',
#     'NA',
#     0.3686228,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30137494,
#     0.40493062,
#     0.13582699,
#     0.25549755,
#     0.3737063,
#     0.35687715,
#     'NA',
#     'NA',
#     0.26551405],
#    'security_concerns': [0.29881176,
#     0.15743418,
#     0.2186606,
#     0.28436306,
#     0.28674415,
#     'NA',
#     'NA',
#     'NA',
#     0.46429127,
#     'NA',
#     'NA',
#     0.37681416,
#     0.19704992],
#    'multipolarism': [0.45789978,
#     0.21439168,
#     0.21749206,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   22: {'eurasianism': [0.31416273,
#     'NA',
#     0.37826014,
#     'NA',
#     'NA',
#     0.266577,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2480299,
#     'NA',
#     0.038989868,
#     'NA',
#     0.25953627,
#     0.5569202,
#     'NA',
#     'NA',
#     0.21144553],
#    'security_concerns': [0.21325445,
#     0.23883142,
#     0.17724468,
#     0.14076656,
#     0.3256201,
#     'NA',
#     'NA',
#     'NA',
#     0.38673583,
#     'NA',
#     'NA',
#     0.3126283,
#     0.25037947],
#    'multipolarism': [0.45628697,
#     0.16506079,
#     0.1819828,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   23: {'eurasianism': [0.19711684,
#     0.26389515,
#     0.48986062,
#     'NA',
#     'NA',
#     0.3144532,
#     'NA',
#     'NA'],
#    'westphalianism': [0.26537967,
#     'NA',
#     0.13867268,
#     'NA',
#     0.299407,
#     0.45575383,
#     'NA',
#     'NA',
#     0.2801021],
#    'security_concerns': [0.12685463,
#     0.12189233,
#     0.261701,
#     0.16608903,
#     0.2898513,
#     'NA',
#     'NA',
#     'NA',
#     0.48320472,
#     'NA',
#     'NA',
#     'NA',
#     0.0787103],
#    'multipolarism': [0.46666005,
#     0.12614316,
#     0.16915433,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   24: {'eurasianism': [0.2422428,
#     0.19268651,
#     0.4235816,
#     'NA',
#     'NA',
#     0.29239845,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2861631,
#     0.24107648,
#     0.22593509,
#     'NA',
#     0.38531324,
#     0.49008584,
#     'NA',
#     'NA',
#     0.26066217],
#    'security_concerns': [0.119503975,
#     0.17688851,
#     0.200012,
#     0.14601083,
#     0.30504727,
#     'NA',
#     'NA',
#     'NA',
#     0.38148403,
#     'NA',
#     'NA',
#     0.37525517,
#     0.19063738],
#    'multipolarism': [0.40237108,
#     0.1502635,
#     0.10777766,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   25: {'eurasianism': [0.17884587,
#     0.16816206,
#     0.37077504,
#     'NA',
#     'NA',
#     0.31899953,
#     'NA',
#     'NA'],
#    'westphalianism': [0.25449497,
#     'NA',
#     0.26496175,
#     'NA',
#     0.35526127,
#     0.5136839,
#     'NA',
#     'NA',
#     0.14770992],
#    'security_concerns': [0.16272047,
#     0.1748698,
#     0.100358635,
#     0.1585993,
#     0.27932003,
#     'NA',
#     'NA',
#     'NA',
#     0.39198792,
#     'NA',
#     'NA',
#     0.41382277,
#     0.30111083],
#    'multipolarism': [0.5263902,
#     0.15968388,
#     0.1549722,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   26: {'eurasianism': [0.15944132,
#     0.0772513,
#     0.47355944,
#     'NA',
#     'NA',
#     0.25405192,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3049688,
#     0.50694895,
#     0.320518,
#     'NA',
#     0.36666298,
#     0.56714183,
#     'NA',
#     'NA',
#     0.34635502],
#    'security_concerns': [0.18151325,
#     0.29382014,
#     0.24313886,
#     0.19628966,
#     0.22798525,
#     'NA',
#     'NA',
#     'NA',
#     0.43435112,
#     'NA',
#     'NA',
#     0.44199574,
#     0.12161128],
#    'multipolarism': [0.43894553,
#     0.03019344,
#     0.16707705,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   27: {'eurasianism': [0.15771645,
#     0.20425263,
#     0.3239266,
#     'NA',
#     'NA',
#     0.23787975,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2602901,
#     'NA',
#     0.16494556,
#     0.33131266,
#     0.34648502,
#     0.44607967,
#     'NA',
#     'NA',
#     0.31639254],
#    'security_concerns': [0.18479955,
#     'NA',
#     0.14829244,
#     0.13009924,
#     0.25436494,
#     'NA',
#     'NA',
#     'NA',
#     0.3816883,
#     'NA',
#     'NA',
#     0.42937636,
#     0.17846555],
#    'multipolarism': [0.51973546,
#     0.15001962,
#     0.17763916,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   28: {'eurasianism': [0.30918807,
#     0.07449376,
#     0.41572088,
#     'NA',
#     'NA',
#     0.22693482,
#     'NA',
#     'NA'],
#    'westphalianism': [0.38334587,
#     0.4059922,
#     0.18200672,
#     'NA',
#     0.43537873,
#     0.5887869,
#     'NA',
#     'NA',
#     0.29202107],
#    'security_concerns': [0.105589174,
#     0.28351462,
#     0.11725571,
#     0.08467934,
#     0.20391323,
#     'NA',
#     'NA',
#     'NA',
#     0.38328794,
#     'NA',
#     'NA',
#     0.3550042,
#     0.15690744],
#    'multipolarism': [0.47845182,
#     0.036963068,
#     0.23157404,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   29: {'eurasianism': [0.112620994,
#     'NA',
#     0.3834137,
#     'NA',
#     'NA',
#     0.2220161,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30067468,
#     0.3717887,
#     0.21287718,
#     0.2931787,
#     0.3846999,
#     0.57345855,
#     'NA',
#     'NA',
#     0.12290483],
#    'security_concerns': [0.13488093,
#     0.20236634,
#     0.083407715,
#     0.15298,
#     0.30513504,
#     'NA',
#     'NA',
#     'NA',
#     0.34768713,
#     'NA',
#     'NA',
#     0.39447048,
#     0.17140718],
#    'multipolarism': [0.44390625,
#     0.12235445,
#     0.15323935,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   30: {'eurasianism': [0.35617363,
#     0.19313447,
#     0.39190748,
#     'NA',
#     'NA',
#     0.31042272,
#     'NA',
#     'NA'],
#    'westphalianism': [0.24384312,
#     0.34306335,
#     0.12921824,
#     0.15566878,
#     0.36280873,
#     0.38488522,
#     'NA',
#     'NA',
#     0.15899879],
#    'security_concerns': [0.2294125,
#     0.21032433,
#     0.21291694,
#     0.2034221,
#     0.25860703,
#     'NA',
#     'NA',
#     'NA',
#     0.2271335,
#     'NA',
#     'NA',
#     0.41430643,
#     0.18065698],
#    'multipolarism': [0.45191264,
#     0.08893092,
#     0.14381613,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   31: {'eurasianism': [0.35578194,
#     0.076676056,
#     0.3501235,
#     'NA',
#     'NA',
#     0.35238782,
#     'NA',
#     'NA'],
#    'westphalianism': [0.290362,
#     'NA',
#     0.19673553,
#     'NA',
#     0.26289493,
#     0.43857044,
#     'NA',
#     'NA',
#     0.2332524],
#    'security_concerns': [0.1629568,
#     'NA',
#     0.27088088,
#     0.19579996,
#     0.3085538,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.43702614,
#     'NA'],
#    'multipolarism': [0.469103, 0.1405599, 0.20987387, 'NA', 'NA', 'NA', 'NA']},
#   32: {'eurasianism': [0.17814754,
#     0.13574472,
#     0.35829738,
#     'NA',
#     'NA',
#     0.1965444,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32525125,
#     0.28985682,
#     0.14663222,
#     'NA',
#     0.29129776,
#     0.32828236,
#     'NA',
#     'NA',
#     0.24507321],
#    'security_concerns': [0.20765358,
#     -0.011848233,
#     0.05553464,
#     0.18378933,
#     0.25954255,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.32381868,
#     0.1437137],
#    'multipolarism': [0.49771056,
#     0.07902016,
#     0.13194737,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   33: {'eurasianism': [0.27137223,
#     0.058198966,
#     0.31299105,
#     'NA',
#     'NA',
#     0.2670768,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32873523,
#     0.36772263,
#     0.21614414,
#     0.20584908,
#     0.2995331,
#     0.6052435,
#     'NA',
#     'NA',
#     0.26694113],
#    'security_concerns': [0.18287167,
#     0.1866078,
#     0.050898694,
#     0.12042895,
#     0.20303613,
#     'NA',
#     'NA',
#     'NA',
#     0.40445688,
#     'NA',
#     'NA',
#     0.418838,
#     0.13303025],
#    'multipolarism': [0.44320017,
#     0.030981319,
#     0.100093745,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   34: {'eurasianism': [0.29341468,
#     0.036964227,
#     0.33769718,
#     'NA',
#     'NA',
#     0.29042953,
#     'NA',
#     'NA'],
#    'westphalianism': [0.37990773,
#     'NA',
#     0.21646173,
#     0.28140524,
#     0.28405556,
#     'NA',
#     'NA',
#     'NA',
#     0.30157217],
#    'security_concerns': [0.20808491,
#     0.16362718,
#     0.22168022,
#     0.13070409,
#     0.23001532,
#     'NA',
#     'NA',
#     'NA',
#     0.39503646,
#     'NA',
#     'NA',
#     'NA',
#     0.08080955],
#    'multipolarism': [0.4632037,
#     0.20300323,
#     0.18944097,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   35: {'eurasianism': [0.3766936,
#     0.0189805,
#     0.3921952,
#     'NA',
#     'NA',
#     0.22828306,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3719012,
#     'NA',
#     0.21879251,
#     'NA',
#     0.34046516,
#     0.5577174,
#     'NA',
#     'NA',
#     0.31458268],
#    'security_concerns': [0.08268921,
#     'NA',
#     0.13255076,
#     0.13087617,
#     0.26125827,
#     'NA',
#     'NA',
#     'NA',
#     0.436928,
#     'NA',
#     'NA',
#     'NA',
#     0.07878166],
#    'multipolarism': [0.46869418,
#     0.18523677,
#     0.29985014,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   36: {'eurasianism': [0.37606984,
#     'NA',
#     0.42210767,
#     'NA',
#     'NA',
#     0.23238951,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3465542,
#     0.36932957,
#     0.16201518,
#     'NA',
#     0.34931487,
#     0.44003007,
#     'NA',
#     'NA',
#     0.16027378],
#    'security_concerns': [0.22759001,
#     0.18458298,
#     0.22143102,
#     0.20744108,
#     0.2674161,
#     'NA',
#     'NA',
#     'NA',
#     0.46867818,
#     'NA',
#     'NA',
#     0.42138228,
#     0.27854863],
#    'multipolarism': [0.5108301,
#     0.16197813,
#     0.18796653,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   37: {'eurasianism': [0.25821626,
#     0.12959981,
#     0.41827157,
#     'NA',
#     'NA',
#     0.28009856,
#     'NA',
#     'NA'],
#    'westphalianism': [0.36771557,
#     0.5137177,
#     0.3105203,
#     0.2046133,
#     0.34753174,
#     0.5113753,
#     'NA',
#     'NA',
#     0.17539468],
#    'security_concerns': [0.14633417,
#     0.16672187,
#     0.20872088,
#     0.17735529,
#     0.23441392,
#     'NA',
#     'NA',
#     'NA',
#     0.36040995,
#     'NA',
#     'NA',
#     'NA',
#     0.13326812],
#    'multipolarism': [0.48536137,
#     0.15245222,
#     0.24247286,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   38: {'eurasianism': [0.10617963,
#     0.092643805,
#     0.38244674,
#     'NA',
#     'NA',
#     0.3295463,
#     'NA',
#     'NA'],
#    'westphalianism': [0.40078998,
#     'NA',
#     0.16010232,
#     0.15531881,
#     0.39503667,
#     0.35274875,
#     'NA',
#     'NA',
#     0.26989838],
#    'security_concerns': [0.09021272,
#     'NA',
#     0.17192696,
#     0.18144567,
#     0.3142836,
#     'NA',
#     'NA',
#     'NA',
#     0.37454167,
#     'NA',
#     'NA',
#     0.2920653,
#     0.14066306],
#    'multipolarism': [0.4638671,
#     0.09163756,
#     0.0807282,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   39: {'eurasianism': [0.30615383,
#     0.114240445,
#     0.35711685,
#     'NA',
#     'NA',
#     0.2540986,
#     'NA',
#     'NA'],
#    'westphalianism': [0.31752735,
#     'NA',
#     0.2031996,
#     'NA',
#     0.31537604,
#     0.5810079,
#     'NA',
#     'NA',
#     0.29761395],
#    'security_concerns': [0.16696571,
#     0.23030077,
#     0.28783956,
#     0.140395,
#     0.29839122,
#     'NA',
#     'NA',
#     'NA',
#     0.4702471,
#     'NA',
#     'NA',
#     'NA',
#     0.14038008],
#    'multipolarism': [0.44311482,
#     0.16768642,
#     0.22731952,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   40: {'eurasianism': [0.2783433,
#     0.20943171,
#     0.39842767,
#     'NA',
#     'NA',
#     0.2847314,
#     'NA',
#     'NA'],
#    'westphalianism': [0.28673226,
#     'NA',
#     0.13994001,
#     0.08644952,
#     0.43324748,
#     0.55020005,
#     'NA',
#     'NA',
#     0.24150594],
#    'security_concerns': [0.16104317,
#     'NA',
#     0.14835928,
#     0.17387241,
#     0.18173946,
#     'NA',
#     'NA',
#     'NA',
#     0.38567498,
#     'NA',
#     'NA',
#     'NA',
#     0.19523983],
#    'multipolarism': [0.4170966,
#     0.15968408,
#     0.2114564,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   41: {'eurasianism': [0.31558967,
#     0.17278245,
#     0.41418588,
#     'NA',
#     'NA',
#     0.15200685,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32433394,
#     0.49203393,
#     0.13524342,
#     0.16005822,
#     0.28574395,
#     0.5365788,
#     'NA',
#     'NA',
#     0.23629436],
#    'security_concerns': [0.13167907,
#     0.14585617,
#     0.18278608,
#     0.10737485,
#     0.32193077,
#     'NA',
#     'NA',
#     'NA',
#     0.4056228,
#     'NA',
#     'NA',
#     0.34085903,
#     0.06464257],
#    'multipolarism': [0.42098472,
#     0.13877763,
#     0.18428789,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   42: {'eurasianism': [0.17533083,
#     'NA',
#     0.38610595,
#     'NA',
#     'NA',
#     0.2401019,
#     'NA',
#     'NA'],
#    'westphalianism': [0.24786776,
#     'NA',
#     0.09121024,
#     0.22676983,
#     0.36645582,
#     0.44896755,
#     'NA',
#     'NA',
#     0.22719443],
#    'security_concerns': [0.1888744,
#     'NA',
#     0.15841128,
#     0.13225888,
#     0.21818979,
#     'NA',
#     'NA',
#     'NA',
#     0.36102802,
#     'NA',
#     'NA',
#     0.29523724,
#     0.0941352],
#    'multipolarism': [0.40952253,
#     0.114004575,
#     0.06906834,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   43: {'eurasianism': [0.26018402,
#     0.14087105,
#     0.32497668,
#     'NA',
#     'NA',
#     0.35802466,
#     'NA',
#     'NA'],
#    'westphalianism': [0.29992643,
#     0.34796175,
#     0.18968673,
#     'NA',
#     0.39575842,
#     0.522899,
#     'NA',
#     'NA',
#     0.21979009],
#    'security_concerns': [0.20360126,
#     'NA',
#     0.22947383,
#     0.07072077,
#     0.16075805,
#     'NA',
#     'NA',
#     'NA',
#     0.42664075,
#     'NA',
#     'NA',
#     0.38503245,
#     0.1852438],
#    'multipolarism': [0.45374924,
#     0.16490594,
#     0.116499655,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   44: {'eurasianism': [0.15503635,
#     0.15047163,
#     0.34169748,
#     'NA',
#     'NA',
#     0.22792327,
#     'NA',
#     'NA'],
#    'westphalianism': [0.28817278,
#     'NA',
#     0.0774848,
#     0.23178509,
#     0.391646,
#     0.6161916,
#     'NA',
#     'NA',
#     0.22545116],
#    'security_concerns': [0.1358373,
#     'NA',
#     0.22873706,
#     0.097985886,
#     0.22634287,
#     'NA',
#     'NA',
#     'NA',
#     0.45997304,
#     'NA',
#     'NA',
#     'NA',
#     0.14746155],
#    'multipolarism': [0.39324832,
#     0.119884856,
#     0.0944507,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   45: {'eurasianism': [0.2759781,
#     0.21566834,
#     0.3918938,
#     'NA',
#     'NA',
#     0.3292355,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3005856,
#     'NA',
#     0.20921575,
#     0.19464755,
#     0.33620697,
#     0.55292577,
#     'NA',
#     'NA',
#     0.30128962],
#    'security_concerns': [0.17499411,
#     0.051543146,
#     0.18880928,
#     0.13601246,
#     0.32777524,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.10195047],
#    'multipolarism': [0.3584502,
#     0.12463968,
#     0.13334048,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   46: {'eurasianism': [0.2528559,
#     0.12248273,
#     0.40130273,
#     'NA',
#     'NA',
#     0.23494667,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2570857,
#     0.45031866,
#     0.17111632,
#     'NA',
#     0.30801925,
#     0.41663972,
#     'NA',
#     'NA',
#     0.2781483],
#    'security_concerns': [0.22910541,
#     0.23967731,
#     0.1529902,
#     0.17313796,
#     0.22409508,
#     'NA',
#     'NA',
#     'NA',
#     0.345947,
#     'NA',
#     'NA',
#     0.3240021,
#     0.1695318],
#    'multipolarism': [0.5523663,
#     -0.012146927,
#     0.14261605,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   47: {'eurasianism': [0.29089388,
#     0.2737036,
#     0.43940032,
#     'NA',
#     'NA',
#     0.28588063,
#     'NA',
#     'NA'],
#    'westphalianism': [0.36311662,
#     0.24770045,
#     0.17679283,
#     'NA',
#     0.3303337,
#     0.5075205,
#     'NA',
#     'NA',
#     0.26106048],
#    'security_concerns': [0.19857322,
#     'NA',
#     0.11273544,
#     0.14513549,
#     0.19899331,
#     'NA',
#     'NA',
#     'NA',
#     0.44400293,
#     'NA',
#     'NA',
#     0.3858621,
#     0.20016937],
#    'multipolarism': [0.4949671,
#     0.22624256,
#     0.26959452,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   48: {'eurasianism': [0.2722162,
#     0.10340951,
#     0.38645026,
#     'NA',
#     'NA',
#     0.26646334,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3676932,
#     0.47651154,
#     0.18134016,
#     0.23494384,
#     0.3330602,
#     0.5164587,
#     'NA',
#     'NA',
#     0.31521922],
#    'security_concerns': [0.32002303,
#     0.23633842,
#     0.19022973,
#     0.25870305,
#     0.29634953,
#     'NA',
#     'NA',
#     'NA',
#     0.3656525,
#     'NA',
#     'NA',
#     0.36306196,
#     0.23004662],
#    'multipolarism': [0.5380451,
#     0.11719685,
#     0.21300359,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   49: {'eurasianism': [0.16229792,
#     0.015803603,
#     0.42896962,
#     'NA',
#     'NA',
#     0.36718714,
#     'NA',
#     'NA'],
#    'westphalianism': [0.305959,
#     'NA',
#     0.08527016,
#     0.14142132,
#     0.29331744,
#     0.53706247,
#     'NA',
#     'NA',
#     0.21606123],
#    'security_concerns': [0.10648887,
#     0.1584269,
#     0.19532931,
#     0.031938713,
#     0.24338676,
#     'NA',
#     'NA',
#     'NA',
#     0.43319267,
#     'NA',
#     'NA',
#     'NA',
#     0.11873704],
#    'multipolarism': [0.36436436,
#     0.21764764,
#     0.20954931,
#     'NA',
#     'NA',
#     'NA',
#     'NA']}},
#  1: {0: {'eurasianism': [0.29408354,
#     0.28635907,
#     0.34750503,
#     0.40125024,
#     'NA',
#     0.30926403,
#     0.25557223,
#     0.0985812],
#    'westphalianism': [0.4425498,
#     0.14526565,
#     0.17279297,
#     0.32050684,
#     0.3954289,
#     0.44519812,
#     'NA',
#     'NA',
#     0.26034343],
#    'security_concerns': [0.24727105,
#     0.3320671,
#     0.18896882,
#     0.23584557,
#     0.28728384,
#     'NA',
#     'NA',
#     'NA',
#     0.26316938,
#     'NA',
#     'NA',
#     0.38979,
#     0.11050689],
#    'multipolarism': [0.53172636,
#     0.3019555,
#     0.30738136,
#     0.722693,
#     0.348593,
#     0.5497669,
#     'NA']},
#   1: {'eurasianism': [0.19511776,
#     0.24712238,
#     0.39501914,
#     'NA',
#     'NA',
#     0.1818271,
#     0.25404716,
#     0.23843387],
#    'westphalianism': [0.39253113,
#     0.11825853,
#     0.11492979,
#     'NA',
#     0.4457949,
#     0.44433343,
#     'NA',
#     'NA',
#     0.23737793],
#    'security_concerns': [0.20417182,
#     0.3037956,
#     0.07504605,
#     0.121985935,
#     0.27441123,
#     'NA',
#     'NA',
#     'NA',
#     0.19568384,
#     'NA',
#     'NA',
#     0.4920818,
#     0.12111335],
#    'multipolarism': [0.61049795,
#     0.21729787,
#     0.26506737,
#     0.59570223,
#     0.4659446,
#     0.53481156,
#     'NA']},
#   2: {'eurasianism': [0.1849266,
#     0.21559745,
#     0.3512936,
#     0.43506536,
#     'NA',
#     0.297763,
#     0.16529706,
#     0.23906113],
#    'westphalianism': [0.3335449,
#     0.03830001,
#     0.17716518,
#     'NA',
#     0.35930333,
#     0.2565679,
#     'NA',
#     'NA',
#     0.24330376],
#    'security_concerns': [0.21021643,
#     0.24877241,
#     0.1442523,
#     0.19757041,
#     0.43452388,
#     'NA',
#     'NA',
#     'NA',
#     0.21721506,
#     'NA',
#     'NA',
#     0.48587734,
#     0.08878127],
#    'multipolarism': [0.48591366,
#     0.1590694,
#     0.29386172,
#     0.64270276,
#     0.4232325,
#     0.6251074,
#     'NA']},
#   3: {'eurasianism': [0.12583569,
#     0.21094613,
#     0.3759276,
#     'NA',
#     'NA',
#     0.23994412,
#     0.13711074,
#     0.14934126],
#    'westphalianism': [0.39430824,
#     'NA',
#     0.3056202,
#     0.36590177,
#     0.4372483,
#     0.474755,
#     'NA',
#     'NA',
#     0.32075417],
#    'security_concerns': [0.1899082,
#     0.32525408,
#     0.19419208,
#     0.15334287,
#     0.31833005,
#     'NA',
#     'NA',
#     'NA',
#     0.2446498,
#     'NA',
#     'NA',
#     0.48507938,
#     0.173975],
#    'multipolarism': [0.64892495,
#     0.26074904,
#     0.33330038,
#     0.61654305,
#     0.38565794,
#     0.5432441,
#     'NA']},
#   4: {'eurasianism': [0.1773236,
#     0.19800472,
#     0.2775501,
#     0.37775034,
#     'NA',
#     0.27615225,
#     0.24788475,
#     0.16976611],
#    'westphalianism': [0.33229095,
#     0.12650742,
#     0.09015516,
#     'NA',
#     0.3274055,
#     0.4009101,
#     'NA',
#     'NA',
#     0.23180711],
#    'security_concerns': [0.3004137,
#     0.38875264,
#     0.24201895,
#     0.2040079,
#     0.36620745,
#     'NA',
#     'NA',
#     'NA',
#     0.24562033,
#     'NA',
#     'NA',
#     0.4360511,
#     0.2931775],
#    'multipolarism': [0.39507237,
#     0.24561858,
#     0.27661708,
#     0.6116983,
#     0.48890102,
#     0.6398975,
#     'NA']},
#   5: {'eurasianism': [0.1604259,
#     0.16583878,
#     0.45678487,
#     0.42255998,
#     'NA',
#     0.18782769,
#     'NA',
#     0.12662818],
#    'westphalianism': [0.42139077,
#     0.2440658,
#     0.12903279,
#     'NA',
#     0.46515435,
#     0.4986886,
#     'NA',
#     'NA',
#     0.30497012],
#    'security_concerns': [0.15797773,
#     0.2185943,
#     0.08775217,
#     0.13526852,
#     0.24285005,
#     'NA',
#     'NA',
#     'NA',
#     0.19350465,
#     'NA',
#     'NA',
#     0.33658373,
#     0.20905083],
#    'multipolarism': [0.551329,
#     0.12100276,
#     0.28376147,
#     0.676219,
#     0.37072042,
#     0.5622425,
#     'NA']},
#   6: {'eurasianism': [0.21739121,
#     0.1614523,
#     0.3176834,
#     0.40118513,
#     'NA',
#     0.21297783,
#     0.1758234,
#     0.1801315],
#    'westphalianism': [0.3664199,
#     'NA',
#     0.12463155,
#     'NA',
#     0.40566838,
#     0.3977843,
#     'NA',
#     'NA',
#     0.3193275],
#    'security_concerns': [0.11523978,
#     0.13674766,
#     0.14826997,
#     0.092166156,
#     0.2823168,
#     'NA',
#     'NA',
#     'NA',
#     0.24579327,
#     'NA',
#     'NA',
#     0.36450833,
#     0.21463794],
#    'multipolarism': [0.39636192,
#     0.25265583,
#     0.2896178,
#     0.6268768,
#     0.30941927,
#     0.6301198,
#     'NA']},
#   7: {'eurasianism': [0.14173064,
#     0.22229221,
#     0.31138194,
#     0.31508726,
#     'NA',
#     0.21760333,
#     0.23327504,
#     0.15163876],
#    'westphalianism': [0.40317616,
#     0.25063127,
#     0.1831698,
#     'NA',
#     0.38112602,
#     0.5211297,
#     'NA',
#     'NA',
#     0.09782211],
#    'security_concerns': [0.25659135,
#     0.19005932,
#     0.15570918,
#     0.17908812,
#     0.41889474,
#     'NA',
#     'NA',
#     'NA',
#     0.20148982,
#     'NA',
#     'NA',
#     0.5637397,
#     0.123063564],
#    'multipolarism': [0.5893625,
#     0.28124887,
#     0.25893697,
#     0.5895338,
#     0.34403557,
#     0.6171633,
#     'NA']},
#   8: {'eurasianism': [0.23331252,
#     0.24384409,
#     0.36236402,
#     0.4203417,
#     'NA',
#     0.26995474,
#     0.10378386,
#     0.10440356],
#    'westphalianism': [0.39222646,
#     0.24498545,
#     0.066851355,
#     0.48677823,
#     0.3563415,
#     0.53392804,
#     'NA',
#     'NA',
#     0.29606703],
#    'security_concerns': [0.25270528,
#     0.29651237,
#     0.15174343,
#     0.12250688,
#     0.25847447,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.33054778,
#     0.35905713,
#     -0.006274922],
#    'multipolarism': [0.5845977,
#     0.34316894,
#     0.34494603,
#     0.6834133,
#     0.46127853,
#     0.560633,
#     'NA']},
#   9: {'eurasianism': [0.21389763,
#     0.20681949,
#     0.3668864,
#     0.3672286,
#     'NA',
#     0.32804796,
#     0.13823192,
#     0.22553389],
#    'westphalianism': [0.41576675,
#     0.2045708,
#     0.05525877,
#     0.3620519,
#     0.43873972,
#     0.3941142,
#     'NA',
#     'NA',
#     0.25898108],
#    'security_concerns': [0.21422616,
#     0.27554485,
#     0.19493745,
#     0.19110598,
#     0.28662363,
#     'NA',
#     'NA',
#     'NA',
#     0.2780448,
#     'NA',
#     'NA',
#     0.4541557,
#     0.103121296],
#    'multipolarism': [0.55227655,
#     0.22842266,
#     0.28008908,
#     0.59923315,
#     0.3537987,
#     0.5396458,
#     'NA']},
#   10: {'eurasianism': [0.2719399,
#     0.2614115,
#     0.35982436,
#     'NA',
#     'NA',
#     0.18652363,
#     0.27668417,
#     0.23180105],
#    'westphalianism': [0.2888487,
#     0.15738535,
#     0.13265261,
#     'NA',
#     0.35465336,
#     0.42888921,
#     'NA',
#     'NA',
#     0.09102423],
#    'security_concerns': [0.19259544,
#     0.36539173,
#     0.21389543,
#     0.18656093,
#     0.38328636,
#     'NA',
#     'NA',
#     'NA',
#     0.27814752,
#     'NA',
#     'NA',
#     0.36865804,
#     0.079864435],
#    'multipolarism': [0.5714416,
#     0.25190297,
#     0.36907932,
#     0.63712615,
#     0.52290124,
#     0.654154,
#     'NA']},
#   11: {'eurasianism': [0.2920907,
#     0.26776543,
#     0.3882641,
#     0.36725008,
#     'NA',
#     0.16189079,
#     0.12698963,
#     0.2097573],
#    'westphalianism': [0.4949682,
#     0.11164933,
#     0.027518477,
#     'NA',
#     0.27669135,
#     0.44501692,
#     'NA',
#     'NA',
#     0.17438835],
#    'security_concerns': [0.19112521,
#     0.108034536,
#     0.17344086,
#     0.10971724,
#     0.33324292,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.27756822,
#     0.5190795,
#     0.07788765],
#    'multipolarism': [0.5316509,
#     0.23140095,
#     0.28580728,
#     0.6601332,
#     0.32320797,
#     0.5974419,
#     'NA']},
#   12: {'eurasianism': [0.22689155,
#     0.24530293,
#     0.3757865,
#     0.35877797,
#     'NA',
#     0.2727428,
#     'NA',
#     0.23918936],
#    'westphalianism': [0.4183688,
#     0.16897725,
#     0.15561481,
#     'NA',
#     0.4089167,
#     'NA',
#     'NA',
#     'NA',
#     0.2921379],
#    'security_concerns': [0.19334199,
#     0.23324601,
#     0.14535421,
#     0.094253294,
#     0.25283423,
#     'NA',
#     'NA',
#     'NA',
#     0.28601012,
#     'NA',
#     'NA',
#     0.45039287,
#     0.24773595],
#    'multipolarism': [0.5891943,
#     0.315993,
#     0.37258372,
#     0.58759403,
#     0.4875444,
#     0.5513157,
#     'NA']},
#   13: {'eurasianism': [0.23865405,
#     0.29217622,
#     0.28913662,
#     0.42431992,
#     'NA',
#     0.25360587,
#     0.12968396,
#     0.23094729],
#    'westphalianism': [0.42755824,
#     0.24763429,
#     0.15335494,
#     'NA',
#     0.3548549,
#     0.32568553,
#     'NA',
#     'NA',
#     0.315066],
#    'security_concerns': [0.24570556,
#     0.3287074,
#     0.20274012,
#     0.14060868,
#     0.3666282,
#     'NA',
#     'NA',
#     'NA',
#     0.2992015,
#     'NA',
#     0.37971032,
#     0.45146188,
#     0.20191185],
#    'multipolarism': [0.5727721,
#     0.28695235,
#     0.28453892,
#     0.61443585,
#     0.40897736,
#     0.5895874,
#     'NA']},
#   14: {'eurasianism': [0.16928266,
#     0.2222195,
#     0.3157492,
#     0.363984,
#     'NA',
#     0.1870474,
#     0.1314207,
#     0.106606334],
#    'westphalianism': [0.42149964,
#     0.20358479,
#     0.18241419,
#     'NA',
#     0.4070916,
#     0.48655486,
#     'NA',
#     'NA',
#     0.3258081],
#    'security_concerns': [0.23389453,
#     0.22531614,
#     0.20025027,
#     0.11480367,
#     0.23897289,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.47700578,
#     0.080023244],
#    'multipolarism': [0.5139172,
#     0.25651792,
#     0.28392854,
#     0.6533453,
#     0.32095656,
#     0.5768821,
#     0.5418215]},
#   15: {'eurasianism': [0.23669802,
#     0.24886951,
#     0.3434409,
#     0.4380776,
#     'NA',
#     0.29665413,
#     0.12823749,
#     0.21121646],
#    'westphalianism': [0.41090417,
#     0.23541825,
#     0.1413409,
#     0.30931532,
#     0.3586285,
#     0.4097728,
#     'NA',
#     'NA',
#     0.322156],
#    'security_concerns': [0.27002606,
#     0.105164714,
#     0.18846045,
#     0.1374284,
#     0.39386532,
#     'NA',
#     'NA',
#     'NA',
#     0.31945512,
#     'NA',
#     0.30349332,
#     0.38729203,
#     0.11933502],
#    'multipolarism': [0.45333204,
#     0.16347611,
#     0.34524584,
#     0.6586385,
#     0.23877408,
#     0.58534086,
#     0.4971552]},
#   16: {'eurasianism': [0.18362552,
#     0.1847119,
#     0.2806695,
#     0.3812453,
#     'NA',
#     0.26307425,
#     0.2049844,
#     0.16561723],
#    'westphalianism': [0.35194185,
#     0.21791093,
#     0.08976116,
#     'NA',
#     0.3959893,
#     0.50635356,
#     'NA',
#     'NA',
#     0.20296663],
#    'security_concerns': [0.25069168,
#     0.23296303,
#     0.13736084,
#     0.15775058,
#     0.35461855,
#     'NA',
#     'NA',
#     'NA',
#     0.29970616,
#     'NA',
#     'NA',
#     0.5368088,
#     0.233883],
#    'multipolarism': [0.4439203,
#     0.3036127,
#     0.2994584,
#     0.7492972,
#     0.46285942,
#     0.5558975,
#     'NA']},
#   17: {'eurasianism': [0.21374051,
#     0.22515419,
#     0.37787166,
#     0.45937964,
#     'NA',
#     0.29960027,
#     0.10609741,
#     0.13426739],
#    'westphalianism': [0.3894015,
#     0.19511868,
#     0.18099684,
#     'NA',
#     0.3901266,
#     0.420976,
#     'NA',
#     'NA',
#     0.23757057],
#    'security_concerns': [0.20081103,
#     0.25961292,
#     0.14794576,
#     0.102779694,
#     0.31976688,
#     'NA',
#     'NA',
#     'NA',
#     0.36575264,
#     'NA',
#     0.37692124,
#     0.4375636,
#     0.11855082],
#    'multipolarism': [0.44947708,
#     0.23144248,
#     0.38696134,
#     0.7294394,
#     0.44862178,
#     0.6797773,
#     'NA']},
#   18: {'eurasianism': [0.2121266,
#     0.23542477,
#     0.3214101,
#     0.40386534,
#     'NA',
#     0.25187153,
#     0.19354454,
#     0.20013168],
#    'westphalianism': [0.44127184,
#     0.23952475,
#     0.18330395,
#     'NA',
#     0.4135759,
#     0.4993247,
#     'NA',
#     'NA',
#     0.26042768],
#    'security_concerns': [0.17014757,
#     0.34721208,
#     0.18311322,
#     0.17930149,
#     0.33366722,
#     'NA',
#     'NA',
#     'NA',
#     0.27839047,
#     'NA',
#     'NA',
#     0.4519233,
#     0.12315225],
#    'multipolarism': [0.6146131,
#     0.29281718,
#     0.3399916,
#     0.6663922,
#     0.5595495,
#     0.58529764,
#     'NA']},
#   19: {'eurasianism': [0.29499507,
#     0.2087324,
#     0.28232682,
#     0.34113988,
#     'NA',
#     0.27203694,
#     0.3321656,
#     0.21715826],
#    'westphalianism': [0.25593632,
#     0.25779364,
#     0.13655023,
#     0.22173096,
#     0.38997632,
#     0.30910873,
#     'NA',
#     'NA',
#     0.28160012],
#    'security_concerns': [0.19962546,
#     0.34449294,
#     0.14304982,
#     0.10528798,
#     0.30119708,
#     'NA',
#     'NA',
#     'NA',
#     0.29171064,
#     'NA',
#     'NA',
#     0.34383112,
#     0.15363999],
#    'multipolarism': [0.5227249,
#     0.22249615,
#     0.38764396,
#     0.7146981,
#     0.5113482,
#     0.41394073,
#     0.4738194]},
#   20: {'eurasianism': [0.25971547,
#     0.32082927,
#     0.28935075,
#     0.34585446,
#     'NA',
#     0.13169749,
#     0.2271595,
#     0.12415648],
#    'westphalianism': [0.41336498,
#     -0.023499224,
#     0.12391372,
#     'NA',
#     0.49232748,
#     0.50473666,
#     'NA',
#     'NA',
#     0.28159255],
#    'security_concerns': [0.18240187,
#     0.35148695,
#     0.16906482,
#     0.13700253,
#     0.3381021,
#     'NA',
#     'NA',
#     'NA',
#     0.39227274,
#     'NA',
#     'NA',
#     0.46621102,
#     0.19025716],
#    'multipolarism': [0.49483234,
#     0.24395117,
#     0.33057964,
#     0.6283447,
#     0.32111785,
#     0.5375176,
#     0.5278414]},
#   21: {'eurasianism': [0.23523451,
#     0.18557194,
#     0.39687324,
#     'NA',
#     'NA',
#     0.24580833,
#     0.19777349,
#     0.094260946],
#    'westphalianism': [0.3949967,
#     0.077566214,
#     0.09336009,
#     'NA',
#     0.40363532,
#     0.4508141,
#     'NA',
#     'NA',
#     0.15586786],
#    'security_concerns': [0.22577074,
#     0.38136244,
#     0.22154444,
#     0.13738598,
#     0.25393543,
#     'NA',
#     'NA',
#     'NA',
#     0.20445657,
#     'NA',
#     0.3549692,
#     0.5617305,
#     0.1445643],
#    'multipolarism': [0.5787679,
#     0.124430425,
#     0.24048853,
#     0.6948025,
#     0.55203897,
#     0.5596082,
#     0.52527386]},
#   22: {'eurasianism': [0.15675981,
#     0.20375599,
#     0.20778582,
#     0.36802322,
#     'NA',
#     0.3599937,
#     -0.019141763,
#     0.15391856],
#    'westphalianism': [0.33956257,
#     0.21361852,
#     -0.025716366,
#     0.29119882,
#     0.38637614,
#     0.4623512,
#     'NA',
#     'NA',
#     0.23334979],
#    'security_concerns': [0.27174425,
#     0.29615656,
#     0.22726531,
#     0.16958855,
#     0.3015106,
#     'NA',
#     'NA',
#     'NA',
#     0.27428627,
#     'NA',
#     0.3227673,
#     0.497991,
#     0.09265583],
#    'multipolarism': [0.4922039,
#     0.2942189,
#     0.23308237,
#     0.5690918,
#     0.4057291,
#     0.6138302,
#     'NA']},
#   23: {'eurasianism': [0.16492222,
#     0.23055902,
#     0.37746125,
#     0.43012592,
#     'NA',
#     0.27561587,
#     0.18358704,
#     0.07736562],
#    'westphalianism': [0.35002705,
#     'NA',
#     0.11386907,
#     'NA',
#     0.39403418,
#     0.29478395,
#     'NA',
#     'NA',
#     0.29858586],
#    'security_concerns': [0.21597184,
#     0.3502696,
#     0.18404402,
#     0.09469845,
#     0.3863039,
#     'NA',
#     'NA',
#     'NA',
#     0.28248954,
#     'NA',
#     'NA',
#     0.37734157,
#     0.111703314],
#    'multipolarism': [0.4227654,
#     0.3123368,
#     0.35842422,
#     0.58282566,
#     0.38319898,
#     0.69261146,
#     'NA']},
#   24: {'eurasianism': [0.206033,
#     0.32157972,
#     0.35601205,
#     0.3811991,
#     'NA',
#     0.3050883,
#     0.17294912,
#     0.21672478],
#    'westphalianism': [0.38823897,
#     0.10350443,
#     -0.023966048,
#     'NA',
#     0.3815857,
#     0.46494004,
#     'NA',
#     'NA',
#     0.09077876],
#    'security_concerns': [0.24348406,
#     0.3135536,
#     0.21695647,
#     0.21438392,
#     0.33227193,
#     'NA',
#     'NA',
#     'NA',
#     0.31472373,
#     'NA',
#     'NA',
#     0.3672626,
#     0.16594894],
#    'multipolarism': [0.5216727,
#     0.20711885,
#     0.27482566,
#     0.6334192,
#     0.43687963,
#     0.63084596,
#     'NA']},
#   25: {'eurasianism': [0.2929022,
#     0.1900879,
#     0.39178914,
#     0.44925535,
#     'NA',
#     0.3044021,
#     0.20774785,
#     0.1470415],
#    'westphalianism': [0.39344954,
#     0.17591348,
#     0.102671266,
#     'NA',
#     0.46416634,
#     0.45940152,
#     'NA',
#     'NA',
#     0.31747693],
#    'security_concerns': [0.21731055,
#     0.23022805,
#     0.26276696,
#     0.15762252,
#     0.24356565,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.45394292,
#     -0.023541814],
#    'multipolarism': [0.5370679,
#     0.27492565,
#     0.28151694,
#     0.6008434,
#     0.40873545,
#     0.59989053,
#     'NA']},
#   26: {'eurasianism': [0.18058178,
#     0.2316309,
#     0.4101671,
#     0.39713162,
#     'NA',
#     0.240896,
#     0.118492015,
#     0.214969],
#    'westphalianism': [0.4009204,
#     0.16465993,
#     0.057133913,
#     'NA',
#     0.32341844,
#     0.5298567,
#     'NA',
#     'NA',
#     0.27589425],
#    'security_concerns': [0.26736408,
#     0.30206043,
#     0.3160155,
#     0.18652903,
#     0.33240724,
#     'NA',
#     'NA',
#     'NA',
#     0.19384642,
#     'NA',
#     'NA',
#     0.41676712,
#     0.05795894],
#    'multipolarism': [0.53964084,
#     0.23906697,
#     0.4124788,
#     0.63499564,
#     0.35503924,
#     0.46542424,
#     'NA']},
#   27: {'eurasianism': [0.2655846,
#     0.20050038,
#     0.35560197,
#     0.39755267,
#     'NA',
#     0.26378432,
#     0.1901832,
#     0.18602556],
#    'westphalianism': [0.38717937,
#     0.052238517,
#     0.12208626,
#     0.20052704,
#     0.36615843,
#     0.38146916,
#     'NA',
#     'NA',
#     0.1739113],
#    'security_concerns': [0.1500318,
#     0.22825454,
#     0.19691837,
#     0.16768308,
#     0.31737167,
#     'NA',
#     'NA',
#     'NA',
#     0.3460653,
#     'NA',
#     0.3429432,
#     0.4903701,
#     0.11451069],
#    'multipolarism': [0.50511974,
#     0.2704683,
#     0.29807204,
#     0.7174094,
#     0.41241097,
#     0.5281495,
#     'NA']},
#   28: {'eurasianism': [0.24888895,
#     0.23483862,
#     0.3601244,
#     0.4105558,
#     'NA',
#     0.36808157,
#     0.24223544,
#     0.24498978],
#    'westphalianism': [0.44929093,
#     0.26910132,
#     0.057470415,
#     0.39801615,
#     0.4219098,
#     0.46571827,
#     'NA',
#     'NA',
#     0.2502204],
#    'security_concerns': [0.2455763,
#     0.30010796,
#     0.17253745,
#     0.17417794,
#     0.30505556,
#     'NA',
#     'NA',
#     'NA',
#     0.29420304,
#     'NA',
#     0.40637094,
#     0.40409908,
#     0.22488306],
#    'multipolarism': [0.4861547,
#     0.30040258,
#     0.30259106,
#     0.6475305,
#     0.3958163,
#     0.62772924,
#     'NA']},
#   29: {'eurasianism': [0.18112269,
#     0.30543914,
#     0.40128818,
#     0.40355802,
#     'NA',
#     0.22946206,
#     0.1753277,
#     0.1298357],
#    'westphalianism': [0.41632244,
#     0.275522,
#     0.17850843,
#     'NA',
#     0.4381726,
#     0.542104,
#     'NA',
#     'NA',
#     0.28522152],
#    'security_concerns': [0.17285882,
#     0.23885196,
#     0.15736516,
#     0.11609492,
#     0.29625103,
#     'NA',
#     'NA',
#     'NA',
#     0.31586045,
#     'NA',
#     'NA',
#     0.45424214,
#     0.0836189],
#    'multipolarism': [0.5216719,
#     0.27454454,
#     0.3804798,
#     0.6986751,
#     0.41316128,
#     0.60109204,
#     'NA']},
#   30: {'eurasianism': [0.24146266,
#     0.17282023,
#     0.3016573,
#     'NA',
#     'NA',
#     0.20015296,
#     0.044852804,
#     0.15286848],
#    'westphalianism': [0.39604545,
#     0.21053901,
#     0.14388207,
#     'NA',
#     0.33749935,
#     0.5160448,
#     'NA',
#     'NA',
#     0.11153845],
#    'security_concerns': [0.27691594,
#     0.20384187,
#     0.12915358,
#     0.19990808,
#     0.42932403,
#     'NA',
#     'NA',
#     'NA',
#     0.23220268,
#     'NA',
#     0.3328763,
#     0.40617973,
#     0.1488524],
#    'multipolarism': [0.47062752,
#     0.3237886,
#     0.37667298,
#     0.5895188,
#     0.41795805,
#     0.52610886,
#     'NA']},
#   31: {'eurasianism': [0.32348672,
#     0.19191547,
#     0.36941943,
#     'NA',
#     'NA',
#     0.23804721,
#     'NA',
#     0.2522152],
#    'westphalianism': [0.42473337,
#     'NA',
#     0.24596348,
#     'NA',
#     0.3733638,
#     0.4832674,
#     'NA',
#     'NA',
#     0.30259398],
#    'security_concerns': [0.23555256,
#     0.26996568,
#     0.26738745,
#     0.1829924,
#     0.29852232,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.36708567,
#     0.12193544],
#    'multipolarism': [0.52072865,
#     0.21912259,
#     0.36743855,
#     0.72514486,
#     0.27906972,
#     0.48926792,
#     0.473803]},
#   32: {'eurasianism': [0.07652832,
#     0.18364316,
#     0.36989385,
#     0.42129356,
#     'NA',
#     0.21549022,
#     0.17278416,
#     0.2017692],
#    'westphalianism': [0.36058608,
#     'NA',
#     0.13257818,
#     'NA',
#     0.4111673,
#     0.42985606,
#     'NA',
#     'NA',
#     0.36271766],
#    'security_concerns': [0.174033,
# ...
#     0.38246122,
#     0.1675134,
#     0.16428687,
#     0.33247042,
#     0.5206419,
#     0.6637767,
#     0.46801198,
#     0.3847946,
#     0.23172376,
#     0.5598699,
#     0.6084074,
#     0.09940845],
#    'multipolarism': [0.6881427,
#     0.2780753,
#     0.24127436,
#     0.7081463,
#     0.5637615,
#     0.49718773,
#     0.54232323]},
#   26: {'eurasianism': [0.2685311,
#     0.15683036,
#     0.35869417,
#     0.47484642,
#     0.519822,
#     0.53356695,
#     0.38083708,
#     'NA'],
#    'westphalianism': [0.3840203,
#     0.068841375,
#     0.14201263,
#     0.49794617,
#     0.6567171,
#     0.4381375,
#     0.35654655,
#     0.55162114,
#     0.43229076],
#    'security_concerns': [-0.003947683,
#     0.3639206,
#     0.17727096,
#     0.19077046,
#     0.27845287,
#     0.4702196,
#     0.67831105,
#     0.38061428,
#     0.30841297,
#     0.08576134,
#     0.5226406,
#     0.58049107,
#     0.12953636],
#    'multipolarism': [0.61167425,
#     0.30180955,
#     0.26888502,
#     0.659107,
#     0.44064164,
#     0.51103264,
#     0.4907429]},
#   27: {'eurasianism': [0.22604023,
#     0.1199497,
#     0.41495523,
#     0.50466615,
#     0.58160436,
#     0.5586886,
#     0.41246885,
#     'NA'],
#    'westphalianism': [0.43527493,
#     0.149445,
#     0.14305767,
#     0.515697,
#     0.613494,
#     0.546922,
#     0.38783064,
#     0.49103868,
#     0.53812903],
#    'security_concerns': [0.17803057,
#     0.2658571,
#     0.07247247,
#     0.24467827,
#     0.36104715,
#     0.45779884,
#     0.66786915,
#     0.4822069,
#     0.4163468,
#     0.3011898,
#     0.62058014,
#     0.53740007,
#     0.19207902],
#    'multipolarism': [0.6439493,
#     0.2635254,
#     0.23637973,
#     0.67968905,
#     0.5519259,
#     0.5507189,
#     0.4880689]},
#   28: {'eurasianism': [0.2613103,
#     0.19712114,
#     0.5662598,
#     0.55446565,
#     0.6405119,
#     0.4845031,
#     0.417388,
#     'NA'],
#    'westphalianism': [0.44062963,
#     0.03965357,
#     0.20177636,
#     0.50239617,
#     0.6283603,
#     0.47788432,
#     0.4084729,
#     0.49741435,
#     0.5054862],
#    'security_concerns': [0.19890563,
#     0.41637674,
#     0.10242209,
#     0.1776606,
#     0.2971561,
#     0.4987926,
#     0.6662738,
#     0.38905892,
#     0.3134077,
#     0.22242771,
#     0.48825464,
#     0.4529666,
#     0.13097878],
#    'multipolarism': [0.64203423,
#     0.23677425,
#     0.27695522,
#     0.651261,
#     0.55115926,
#     0.5754928,
#     0.5146314]},
#   29: {'eurasianism': [0.23623125,
#     0.075268775,
#     0.43422395,
#     0.47888726,
#     0.45906895,
#     0.5209884,
#     0.45489526,
#     'NA'],
#    'westphalianism': [0.4564199,
#     0.24046528,
#     0.16028915,
#     0.36757484,
#     0.5865417,
#     0.41231158,
#     0.47339177,
#     0.6103403,
#     0.39152893],
#    'security_concerns': [0.11301582,
#     0.22603242,
#     0.112083405,
#     0.22129251,
#     0.35925925,
#     0.46238384,
#     0.6865674,
#     0.4510341,
#     0.450837,
#     0.20105931,
#     0.51250386,
#     0.44723943,
#     0.13843481],
#    'multipolarism': [0.6094611,
#     0.40041202,
#     0.31258324,
#     0.65360606,
#     0.57102585,
#     0.5219228,
#     0.55078495]},
#   30: {'eurasianism': [0.2417375,
#     0.09897226,
#     0.40303275,
#     0.56143093,
#     0.60140896,
#     0.5142742,
#     0.45537263,
#     'NA'],
#    'westphalianism': [0.4476784,
#     0.22921585,
#     0.1684424,
#     0.4657772,
#     0.6518574,
#     0.43793646,
#     0.3712702,
#     0.49311933,
#     0.47489864],
#    'security_concerns': [0.13200098,
#     0.28424078,
#     0.06186858,
#     0.20736927,
#     0.32749537,
#     0.45550683,
#     0.69639623,
#     0.48678014,
#     0.30394736,
#     0.20612478,
#     0.5095293,
#     0.6024968,
#     0.1347101],
#    'multipolarism': [0.639351,
#     0.37904698,
#     0.2346795,
#     0.59261066,
#     0.54955137,
#     0.5532171,
#     0.582084]},
#   31: {'eurasianism': [0.27823833,
#     0.14912216,
#     0.4390112,
#     0.4982909,
#     0.4288156,
#     0.54541236,
#     0.4451223,
#     0.2628992],
#    'westphalianism': [0.49163255,
#     0.14511175,
#     0.25138208,
#     0.5352042,
#     0.65183234,
#     0.40106645,
#     0.26617676,
#     0.5594,
#     0.5432639],
#    'security_concerns': [0.12346111,
#     0.36246157,
#     0.11085957,
#     0.20611687,
#     0.32397786,
#     0.47353408,
#     0.6743416,
#     0.4268356,
#     0.24703984,
#     0.124629155,
#     0.45110694,
#     0.5139572,
#     0.15067664],
#    'multipolarism': [0.6300911,
#     0.34077746,
#     0.2526279,
#     0.6358392,
#     0.61970353,
#     0.58464897,
#     0.5705904]},
#   32: {'eurasianism': [0.30381453,
#     0.14120895,
#     0.43928942,
#     0.363991,
#     0.57039297,
#     0.53513783,
#     0.4454732,
#     'NA'],
#    'westphalianism': [0.42490926,
#     0.21102537,
#     0.21165878,
#     0.48691627,
#     0.65259165,
#     0.40958598,
#     0.4104665,
#     0.45315453,
#     0.49945024],
#    'security_concerns': [0.1945574,
#     0.46215937,
#     0.2086409,
#     0.18355095,
#     0.3229648,
#     0.44405228,
#     0.722471,
#     0.517703,
#     0.2723748,
#     0.25784352,
#     0.53978556,
#     0.6273225,
#     0.088051185],
#    'multipolarism': [0.6393373,
#     0.27030566,
#     0.25034866,
#     0.6835854,
#     0.64689195,
#     0.61126107,
#     'NA']},
#   33: {'eurasianism': [0.23253964,
#     0.12081364,
#     0.44813696,
#     0.45558617,
#     0.5430708,
#     0.4969218,
#     0.3412306,
#     0.2849636],
#    'westphalianism': [0.48266596,
#     0.12962548,
#     0.20957473,
#     0.45274898,
#     0.63506365,
#     0.5279824,
#     0.42574975,
#     0.5069419,
#     0.48413303],
#    'security_concerns': [0.1636858,
#     0.28169295,
#     0.18217343,
#     0.20945862,
#     0.35518888,
#     0.5001739,
#     0.62368196,
#     'NA',
#     0.41017023,
#     0.22884285,
#     0.48848933,
#     0.49019137,
#     0.15355428],
#    'multipolarism': [0.5850683,
#     0.32881647,
#     0.23154378,
#     0.66329616,
#     0.5903442,
#     0.5684635,
#     0.53741354]},
#   34: {'eurasianism': [0.28415066,
#     0.022833182,
#     0.4085002,
#     0.5056966,
#     0.58742505,
#     0.5022346,
#     0.527519,
#     'NA'],
#    'westphalianism': [0.46139982,
#     0.15241049,
#     0.1592375,
#     0.43122122,
#     0.66031754,
#     0.48898962,
#     0.42190242,
#     0.5140548,
#     0.53331727],
#    'security_concerns': [0.11755005,
#     0.33753914,
#     0.19502185,
#     0.21357948,
#     0.3805936,
#     0.49550056,
#     0.6822933,
#     0.4490328,
#     0.343708,
#     0.23773614,
#     0.52300787,
#     0.51706195,
#     0.20456643],
#    'multipolarism': [0.6239153,
#     0.34680867,
#     0.27230936,
#     0.6717888,
#     0.53044724,
#     0.56230617,
#     0.5331631]},
#   35: {'eurasianism': [0.29332674,
#     -0.0944224,
#     0.39175323,
#     0.4500625,
#     0.5457714,
#     0.5043204,
#     0.43587974,
#     0.39225274],
#    'westphalianism': [0.42081755,
#     0.10535117,
#     0.18257627,
#     0.39448074,
#     0.64799494,
#     0.53478265,
#     0.44500092,
#     0.53515345,
#     0.49692905],
#    'security_concerns': [0.052125808,
#     0.43731567,
#     0.18639925,
#     0.1898263,
#     0.35930613,
#     0.54147726,
#     0.70358735,
#     0.41636634,
#     0.4880954,
#     0.2003678,
#     0.59843034,
#     0.5683173,
#     0.077575974],
#    'multipolarism': [0.6278196,
#     0.2987068,
#     0.2740035,
#     0.65212077,
#     0.5161356,
#     0.59302986,
#     0.5575181]},
#   36: {'eurasianism': [0.29733065,
#     0.11116192,
#     0.4196753,
#     0.42886466,
#     0.5817323,
#     0.5014189,
#     0.46933973,
#     0.44298425],
#    'westphalianism': [0.42145056,
#     0.1265065,
#     0.06768574,
#     0.34853673,
#     0.64738363,
#     0.49272603,
#     0.41534278,
#     0.44916168,
#     0.46262828],
#    'security_concerns': [0.17483574,
#     0.3640689,
#     0.08657158,
#     0.23189984,
#     0.4475076,
#     0.5524233,
#     0.6321622,
#     0.4123205,
#     'NA',
#     0.21570912,
#     0.5020939,
#     0.5624746,
#     0.11447405],
#    'multipolarism': [0.6016057,
#     0.32845864,
#     0.2093647,
#     0.61281496,
#     0.4553709,
#     0.54862314,
#     0.5462391]},
#   37: {'eurasianism': [0.19342326,
#     0.015475301,
#     0.44323078,
#     0.48448932,
#     0.4477456,
#     0.5561654,
#     0.39170384,
#     0.27322924],
#    'westphalianism': [0.4616759,
#     0.2146738,
#     0.15862854,
#     0.4431533,
#     0.5682303,
#     0.47062242,
#     0.40570363,
#     0.55881274,
#     0.5121963],
#    'security_concerns': [0.15113674,
#     0.454296,
#     0.10134081,
#     0.18538524,
#     0.30236554,
#     0.5684874,
#     0.6850686,
#     0.3392369,
#     0.37711182,
#     0.21380883,
#     0.42679632,
#     0.47747633,
#     0.2382491],
#    'multipolarism': [0.5694786,
#     0.31104496,
#     0.27495298,
#     0.5623731,
#     0.55646545,
#     0.5842375,
#     'NA']},
#   38: {'eurasianism': [0.28045785,
#     0.096561566,
#     0.4401128,
#     0.3409533,
#     0.5394049,
#     0.5379801,
#     0.45808208,
#     'NA'],
#    'westphalianism': [0.45562872,
#     0.08961161,
#     0.09470121,
#     0.42213497,
#     0.62590414,
#     0.39923534,
#     0.38434428,
#     0.5151668,
#     0.44305867],
#    'security_concerns': [0.15083075,
#     0.38054276,
#     0.20218445,
#     0.23691733,
#     0.40387982,
#     0.50786954,
#     0.6968912,
#     'NA',
#     0.3756379,
#     0.12149581,
#     0.62110156,
#     0.5862025,
#     0.13883114],
#    'multipolarism': [0.5597248,
#     0.2935901,
#     0.18883128,
#     0.6670539,
#     0.53225315,
#     0.55926657,
#     0.5054075]},
#   39: {'eurasianism': [0.24047665,
#     0.1661308,
#     0.4633332,
#     0.44745088,
#     0.6122198,
#     0.5470789,
#     0.38532877,
#     0.17096767],
#    'westphalianism': [0.41526636,
#     0.208831,
#     0.12377026,
#     0.45333865,
#     0.5780005,
#     0.4820797,
#     0.3667242,
#     0.54085773,
#     0.494284],
#    'security_concerns': [0.17360836,
#     0.40610662,
#     0.11752892,
#     0.24116194,
#     0.38184673,
#     0.5624491,
#     0.66350687,
#     0.41935214,
#     0.4117622,
#     0.21530332,
#     0.5877463,
#     0.51803595,
#     0.18130177],
#    'multipolarism': [0.58443266,
#     0.31991994,
#     0.26622346,
#     0.7279026,
#     0.53839254,
#     0.5066221,
#     0.5593657]},
#   40: {'eurasianism': [0.2619778,
#     0.08323763,
#     0.45966655,
#     0.55253154,
#     0.5138926,
#     0.4961934,
#     0.54062474,
#     'NA'],
#    'westphalianism': [0.47154245,
#     'NA',
#     0.1325921,
#     0.51025134,
#     0.67116356,
#     0.4480211,
#     0.4509597,
#     0.45106673,
#     0.5003368],
#    'security_concerns': [0.15031527,
#     0.24902345,
#     0.13722177,
#     0.21339753,
#     0.34138352,
#     0.5792314,
#     0.6842697,
#     0.44427827,
#     0.4191696,
#     0.26018384,
#     0.53719985,
#     0.5535908,
#     0.10775542],
#    'multipolarism': [0.644975,
#     0.3083748,
#     0.28358388,
#     0.6511277,
#     0.5887085,
#     0.5868154,
#     0.53741425]},
#   41: {'eurasianism': [0.22671096,
#     0.021331165,
#     0.36179975,
#     0.5277198,
#     0.5414764,
#     0.532892,
#     0.47756425,
#     0.21948291],
#    'westphalianism': [0.41795808,
#     0.18595606,
#     0.17017092,
#     0.47489905,
#     0.6187928,
#     0.45243296,
#     0.43732113,
#     0.48868176,
#     0.45962185],
#    'security_concerns': [0.10864096,
#     0.3908681,
#     0.08059254,
#     0.1085305,
#     0.29131034,
#     0.49611768,
#     0.62037534,
#     0.52184665,
#     0.48183843,
#     0.11531127,
#     0.51954037,
#     0.5524754,
#     0.10611086],
#    'multipolarism': [0.5741654,
#     0.22095332,
#     0.16843033,
#     0.6810231,
#     0.6100208,
#     0.5302732,
#     0.5293994]},
#   42: {'eurasianism': [0.24881932,
#     0.15449205,
#     0.4083585,
#     0.44792452,
#     0.48294336,
#     0.4949638,
#     0.37247807,
#     0.25504872],
#    'westphalianism': [0.35518494,
#     0.07435941,
#     0.11380975,
#     0.3920407,
#     0.5983922,
#     0.44559747,
#     0.3957743,
#     0.46685463,
#     0.38609588],
#    'security_concerns': [0.1287777,
#     0.29210532,
#     0.20445973,
#     0.17670095,
#     0.3241297,
#     0.4763482,
#     0.58951294,
#     0.44601202,
#     0.34561697,
#     0.17733118,
#     0.5692976,
#     0.57194227,
#     0.1342821],
#    'multipolarism': [0.62984467,
#     0.30723506,
#     0.216386,
#     0.7291458,
#     0.57974905,
#     0.56400764,
#     0.5980232]},
#   43: {'eurasianism': [0.2595095,
#     0.09222342,
#     0.40245324,
#     0.53500175,
#     0.6255654,
#     0.51471406,
#     0.38366184,
#     'NA'],
#    'westphalianism': [0.42192876,
#     0.18585053,
#     0.16630568,
#     0.5158306,
#     0.62920016,
#     0.4474835,
#     0.46699286,
#     0.5111054,
#     0.49879012],
#    'security_concerns': [0.114003696,
#     0.39734674,
#     0.104272485,
#     0.18568926,
#     0.28158012,
#     0.526889,
#     0.7075328,
#     0.5153156,
#     0.39961642,
#     0.22364497,
#     0.5033146,
#     0.4762249,
#     0.08686634],
#    'multipolarism': [0.5595091,
#     0.30553213,
#     0.2014078,
#     0.6488661,
#     0.6559089,
#     0.5000426,
#     0.57624155]},
#   44: {'eurasianism': [0.24062683,
#     0.10764937,
#     0.32298064,
#     0.34812477,
#     0.5946053,
#     0.4764093,
#     0.40505952,
#     0.309666],
#    'westphalianism': [0.4099049,
#     0.10405184,
#     0.18603852,
#     0.4789757,
#     0.65390784,
#     0.55014205,
#     0.2514131,
#     0.4885254,
#     0.43037933],
#    'security_concerns': [0.06435628,
#     0.36950865,
#     0.24566095,
#     0.20331675,
#     0.27557406,
#     0.5709763,
#     0.70246553,
#     'NA',
#     0.48335755,
#     0.21762088,
#     0.50213677,
#     0.50092614,
#     0.011775602],
#    'multipolarism': [0.58665794,
#     0.2866041,
#     0.2882664,
#     0.68699306,
#     0.6363057,
#     0.5431318,
#     'NA']},
#   45: {'eurasianism': [0.26230264,
#     0.16731182,
#     0.3032251,
#     0.3783332,
#     0.42008367,
#     0.49069068,
#     0.38242343,
#     'NA'],
#    'westphalianism': [0.41695085,
#     0.24579354,
#     0.23596622,
#     0.4497903,
#     0.62775886,
#     0.48321915,
#     0.3914749,
#     0.42020643,
#     0.48183984],
#    'security_concerns': [0.15749994,
#     0.3582403,
#     0.106927246,
#     0.19344756,
#     0.32906237,
#     0.5733325,
#     0.6718684,
#     0.4534792,
#     0.28344378,
#     0.24226785,
#     0.45179862,
#     0.5457347,
#     0.1040073],
#    'multipolarism': [0.647287,
#     0.31518996,
#     0.2104665,
#     0.66645235,
#     0.57610863,
#     0.5316446,
#     'NA']},
#   46: {'eurasianism': [0.24519108,
#     0.09261264,
#     0.4084295,
#     0.52008116,
#     0.6311684,
#     0.5347931,
#     0.412361,
#     'NA'],
#    'westphalianism': [0.4320106,
#     0.15728699,
#     0.22814746,
#     0.47484022,
#     0.68439496,
#     0.54112965,
#     0.42001405,
#     0.53198695,
#     0.45653346],
#    'security_concerns': [0.1865897,
#     0.4635505,
#     0.113255665,
#     0.19222133,
#     0.30501977,
#     0.49200472,
#     0.6724197,
#     0.3693796,
#     0.3901545,
#     0.2700525,
#     0.48915902,
#     0.5787451,
#     0.18369344],
#    'multipolarism': [0.6526944,
#     0.35386407,
#     0.2491933,
#     0.6751162,
#     0.5231418,
#     0.54319274,
#     0.5460735]},
#   47: {'eurasianism': [0.2672374,
#     0.11737209,
#     0.38733777,
#     0.41366148,
#     0.61097205,
#     0.4787581,
#     0.4396639,
#     0.21798533],
#    'westphalianism': [0.4004105,
#     0.23839587,
#     0.056741826,
#     0.46544215,
#     0.6260936,
#     0.4794625,
#     0.31879538,
#     0.5503254,
#     0.46865803],
#    'security_concerns': [-0.006576566,
#     0.2698088,
#     0.085196115,
#     0.23758245,
#     0.26963446,
#     0.58594495,
#     0.6846999,
#     0.34888157,
#     0.45081937,
#     0.22387412,
#     0.4561184,
#     0.47527698,
#     0.11816692],
#    'multipolarism': [0.60238534,
#     0.36300874,
#     0.19545749,
#     0.62888336,
#     0.594386,
#     0.6004395,
#     0.45043805]},
#   48: {'eurasianism': [0.26225042,
#     0.22595705,
#     0.35959756,
#     0.404726,
#     0.66680455,
#     0.5532652,
#     0.4111912,
#     0.21370412],
#    'westphalianism': [0.45709136,
#     0.13647655,
#     0.18727782,
#     0.4104821,
#     0.6938428,
#     0.49046165,
#     0.3618033,
#     0.57447046,
#     0.4285189],
#    'security_concerns': [0.08507967,
#     0.45776352,
#     0.15180323,
#     0.23832273,
#     0.283852,
#     0.52785057,
#     0.70396245,
#     0.3890054,
#     0.3888188,
#     0.16919002,
#     0.50654334,
#     0.5067993,
#     0.12131272],
#    'multipolarism': [0.588404,
#     0.3433772,
#     0.205559,
#     0.62398034,
#     0.5666893,
#     0.5576127,
#     0.58317006]},
#   49: {'eurasianism': [0.2976434,
#     0.1974806,
#     0.42536965,
#     0.41267702,
#     0.6160187,
#     0.5797309,
#     0.40950882,
#     0.18097319],
#    'westphalianism': [0.41569957,
#     0.13040577,
#     0.1972504,
#     0.357006,
#     0.65756464,
#     0.42854992,
#     0.37102014,
#     0.54294527,
#     0.39502773],
#    'security_concerns': [0.07091254,
#     0.18593353,
#     0.16248253,
#     0.22587544,
#     0.34012228,
#     0.50874686,
#     0.6548652,
#     0.3951532,
#     0.40086165,
#     0.16385445,
#     0.5125593,
#     0.4903416,
#     0.14296925],
#    'multipolarism': [0.598343,
#     0.27614373,
#     0.22560783,
#     0.6799075,
#     0.5639075,
#     0.5256602,
#     'NA']}}}

# %%
### Saving the model
with open('models/naive_model_entire_corpus_50_bootstrap.pkl', 'wb') as f:
    pickle.dump(stat_types, f)

# %%
### Loading the model
with open('models/naive_model_entire_corpus_50_bootstrap.pkl', 'rb') as f:
    stat_types = pickle.load(f)

# %%
### for all words of concepts for era and bootstrap
concept_lists = [eurasianism, westphalianism, security_concerns, multipolarism]
topic_names = ['eurasianism', 'westphalianism', 'security_concerns', 'multipolarism']

for era in stat_types:
    for bootstrap in stat_types[era]:
        print(f"bootstrap: {bootstrap}, Era: {era}")
        for topic_idx, topic in enumerate(stat_types[era][bootstrap]):
            scores = stat_types[era][bootstrap][topic]
            concept_list = concept_lists[topic_idx]  # Get the corresponding concept list
            topic_name = topic_names[topic_idx]  # Get the corresponding topic name
            for i, score in enumerate(scores):
                if score != 'NA':
                    word = concept_list[i]  # Get the corresponding word from the concept list
                    print(f"Topic: {topic_name}, Word: {word}, Score: {score}")
                else:
                    word = concept_list[i]  # Get the corresponding word from the concept list
                    print(f"Topic: {topic_name}, Word: {word}, Score: NA")
        print()
# Out:
# bootstrap: 0, Era: 0
# Topic: eurasianism, Word: евразия, Score: 0.26861661672592163
# Topic: eurasianism, Word: русский_мир, Score: NA
# Topic: eurasianism, Word: цивилизация, Score: 0.4224596917629242
# Topic: eurasianism, Word: доминирование_запад, Score: NA
# Topic: eurasianism, Word: правило_запад, Score: NA
# Topic: eurasianism, Word: запад, Score: 0.29519250988960266
# Topic: eurasianism, Word: гегемония, Score: NA
# Topic: eurasianism, Word: исторический_ревизионизм, Score: NA
# Topic: westphalianism, Word: оон, Score: 0.2941761612892151
# Topic: westphalianism, Word: великодержавность, Score: NA
# Topic: westphalianism, Word: статус, Score: 0.2511150538921356
# Topic: westphalianism, Word: принцип_суверенный, Score: 0.10528101772069931
# Topic: westphalianism, Word: международное_право, Score: 0.29546210169792175
# Topic: westphalianism, Word: демократический_справедливый, Score: 0.5699735283851624
# Topic: westphalianism, Word: международное_право_норма, Score: NA
# Topic: westphalianism, Word: ооноцентричной, Score: NA
# Topic: westphalianism, Word: суверенность, Score: 0.1684691607952118
# Topic: security_concerns, Word: национальная_безопасность, Score: 0.10204306244850159
# Topic: security_concerns, Word: противовес, Score: 0.2453603297472
# Topic: security_concerns, Word: дестабилизация, Score: 0.19386088848114014
# Topic: security_concerns, Word: нато, Score: 0.09111339598894119
# Topic: security_concerns, Word: угроза, Score: 0.2608119547367096
# Topic: security_concerns, Word: подменить_международное_право, Score: NA
# Topic: security_concerns, Word: порядок_основать, Score: NA
# Topic: security_concerns, Word: однополярная, Score: NA
# Topic: security_concerns, Word: новый_мироустройство, Score: 0.4814993739128113
# Topic: security_concerns, Word: расширяться_восток, Score: NA
# Topic: security_concerns, Word: однополярный_модель, Score: NA
# Topic: security_concerns, Word: однополярный, Score: 0.40881145000457764
# Topic: security_concerns, Word: военный_инфраструктура, Score: 0.046445317566394806
# Topic: multipolarism, Word: многополярный, Score: 0.5752657651901245
# Topic: multipolarism, Word: партнёрство, Score: 0.2316989302635193
# Topic: multipolarism, Word: сотрудничество, Score: 0.12056039273738861
# Topic: multipolarism, Word: полицентричный, Score: NA
# Topic: multipolarism, Word: формирование_многополярный, Score: NA
# Topic: multipolarism, Word: формирование_полицентричного, Score: NA
# Topic: multipolarism, Word: демократический_полицентричного, Score: NA
#
# bootstrap: 1, Era: 0
# Topic: eurasianism, Word: евразия, Score: 0.2169562429189682
# Topic: eurasianism, Word: русский_мир, Score: NA
# Topic: eurasianism, Word: цивилизация, Score: 0.4368853271007538
# Topic: eurasianism, Word: доминирование_запад, Score: NA
# Topic: eurasianism, Word: правило_запад, Score: NA
# Topic: eurasianism, Word: запад, Score: 0.1923396736383438
# Topic: eurasianism, Word: гегемония, Score: NA
# Topic: eurasianism, Word: исторический_ревизионизм, Score: NA
# Topic: westphalianism, Word: оон, Score: 0.35500189661979675
# Topic: westphalianism, Word: великодержавность, Score: NA
# Topic: westphalianism, Word: статус, Score: 0.1806682050228119
# Topic: westphalianism, Word: принцип_суверенный, Score: NA
# Topic: westphalianism, Word: международное_право, Score: 0.35201317071914673
# Topic: westphalianism, Word: демократический_справедливый, Score: 0.47790655493736267
# Topic: westphalianism, Word: международное_право_норма, Score: NA
# Topic: westphalianism, Word: ооноцентричной, Score: NA
# Topic: westphalianism, Word: суверенность, Score: 0.2906206548213959
# Topic: security_concerns, Word: национальная_безопасность, Score: 0.20916041731834412
# Topic: security_concerns, Word: противовес, Score: 0.18311819434165955
# Topic: security_concerns, Word: дестабилизация, Score: 0.1959955096244812
# Topic: security_concerns, Word: нато, Score: 0.10009649395942688
# Topic: security_concerns, Word: угроза, Score: 0.30253833532333374
# Topic: security_concerns, Word: подменить_международное_право, Score: NA
# Topic: security_concerns, Word: порядок_основать, Score: NA
# Topic: security_concerns, Word: однополярная, Score: NA
# Topic: security_concerns, Word: новый_мироустройство, Score: 0.
# Topic: security_concerns, Word: новый_мироустройство, Score: 0.4008616507053375
# Topic: security_concerns, Word: расширяться_восток, Score: 0.1638544499874115
# Topic: security_concerns, Word: однополярный_модель, Score: 0.5125592947006226
# Topic: security_concerns, Word: однополярный, Score: 0.4903416037559509
# Topic: security_concerns, Word: военный_инфраструктура, Score: 0.1429692506790161
# Topic: multipolarism, Word: многополярный, Score: 0.598343014717102
# Topic: multipolarism, Word: партнёрство, Score: 0.27614372968673706
# Topic: multipolarism, Word: сотрудничество, Score: 0.22560782730579376
# Topic: multipolarism, Word: полицентричный, Score: 0.679907500743866
# Topic: multipolarism, Word: формирование_многополярный, Score: 0.5639075040817261
# Topic: multipolarism, Word: формирование_полицентричного, Score: 0.5256602168083191
# Topic: multipolarism, Word: демократический_полицентричного, Score: NA

# %%
#### no NA
concept_lists = [eurasianism, westphalianism, security_concerns, multipolarism]
topic_names = ['eurasianism', 'westphalianism', 'security_concerns', 'multipolarism']

for era in stat_types:
    for bootstrap in stat_types[era]:
        print(f"bootstrap: {bootstrap}, Era: {era}")
        for topic_idx, topic in enumerate(stat_types[era][bootstrap]):
            scores = stat_types[era][bootstrap][topic]
            concept_list = concept_lists[topic_idx]  # Get the corresponding concept list
            topic_name = topic_names[topic_idx]  # Get the corresponding topic name
            for i, score in enumerate(scores):
                if score != 'NA':
                    word = concept_list[i]  # Get the corresponding word from the concept list
                    print(f"Topic: {topic_name}, Word: {word}, Score: {score}")
        print()
# Out:
# bootstrap: 0, Era: 0
# Topic: eurasianism, Word: евразия, Score: 0.26861661672592163
# Topic: eurasianism, Word: цивилизация, Score: 0.4224596917629242
# Topic: eurasianism, Word: запад, Score: 0.29519250988960266
# Topic: westphalianism, Word: оон, Score: 0.2941761612892151
# Topic: westphalianism, Word: статус, Score: 0.2511150538921356
# Topic: westphalianism, Word: принцип_суверенный, Score: 0.10528101772069931
# Topic: westphalianism, Word: международное_право, Score: 0.29546210169792175
# Topic: westphalianism, Word: демократический_справедливый, Score: 0.5699735283851624
# Topic: westphalianism, Word: суверенность, Score: 0.1684691607952118
# Topic: security_concerns, Word: национальная_безопасность, Score: 0.10204306244850159
# Topic: security_concerns, Word: противовес, Score: 0.2453603297472
# Topic: security_concerns, Word: дестабилизация, Score: 0.19386088848114014
# Topic: security_concerns, Word: нато, Score: 0.09111339598894119
# Topic: security_concerns, Word: угроза, Score: 0.2608119547367096
# Topic: security_concerns, Word: новый_мироустройство, Score: 0.4814993739128113
# Topic: security_concerns, Word: однополярный, Score: 0.40881145000457764
# Topic: security_concerns, Word: военный_инфраструктура, Score: 0.046445317566394806
# Topic: multipolarism, Word: многополярный, Score: 0.5752657651901245
# Topic: multipolarism, Word: партнёрство, Score: 0.2316989302635193
# Topic: multipolarism, Word: сотрудничество, Score: 0.12056039273738861
#
# bootstrap: 1, Era: 0
# Topic: eurasianism, Word: евразия, Score: 0.2169562429189682
# Topic: eurasianism, Word: цивилизация, Score: 0.4368853271007538
# Topic: eurasianism, Word: запад, Score: 0.1923396736383438
# Topic: westphalianism, Word: оон, Score: 0.35500189661979675
# Topic: westphalianism, Word: статус, Score: 0.1806682050228119
# Topic: westphalianism, Word: международное_право, Score: 0.35201317071914673
# Topic: westphalianism, Word: демократический_справедливый, Score: 0.47790655493736267
# Topic: westphalianism, Word: суверенность, Score: 0.2906206548213959
# Topic: security_concerns, Word: национальная_безопасность, Score: 0.20916041731834412
# Topic: security_concerns, Word: противовес, Score: 0.18311819434165955
# Topic: security_concerns, Word: дестабилизация, Score: 0.1959955096244812
# Topic: security_concerns, Word: нато, Score: 0.10009649395942688
# Topic: security_concerns, Word: угроза, Score: 0.30253833532333374
# Topic: security_concerns, Word: новый_мироустройство, Score: 0.4511488676071167
# Topic: security_concerns, Word: военный_инфраструктура, Score: 0.10517914593219757
# Topic: multipolarism, Word: многополярный, Score: 0.4334815740585327
# Topic: multipolarism, Word: партнёрство, Score: 0.1253264993429184
# Topic: multipolarism, Word: сотрудничество, Score: 0.26544609665870667
#
# bootstrap: 2, Era: 0
# Topic: eurasianism, Word: евразия, Score: 0
# Topic: security_concerns, Word: военный_инфраструктура, Score: 0.12131272256374359
# Topic: multipolarism, Word: многополярный, Score: 0.5884039998054504
# Topic: multipolarism, Word: партнёрство, Score: 0.3433772027492523
# Topic: multipolarism, Word: сотрудничество, Score: 0.20555900037288666
# Topic: multipolarism, Word: полицентричный, Score: 0.6239803433418274
# Topic: multipolarism, Word: формирование_многополярный, Score: 0.5666893124580383
# Topic: multipolarism, Word: формирование_полицентричного, Score: 0.5576127171516418
# Topic: multipolarism, Word: демократический_полицентричного, Score: 0.5831700563430786
#
# bootstrap: 49, Era: 3
# Topic: eurasianism, Word: евразия, Score: 0.29764339327812195
# Topic: eurasianism, Word: русский_мир, Score: 0.19748060405254364
# Topic: eurasianism, Word: цивилизация, Score: 0.42536965012550354
# Topic: eurasianism, Word: доминирование_запад, Score: 0.41267701983451843
# Topic: eurasianism, Word: правило_запад, Score: 0.6160187125205994
# Topic: eurasianism, Word: запад, Score: 0.5797309279441833
# Topic: eurasianism, Word: гегемония, Score: 0.4095088243484497
# Topic: eurasianism, Word: исторический_ревизионизм, Score: 0.18097318708896637
# Topic: westphalianism, Word: оон, Score: 0.4156995713710785
# Topic: westphalianism, Word: великодержавность, Score: 0.13040576875209808
# Topic: westphalianism, Word: статус, Score: 0.1972503960132599
# Topic: westphalianism, Word: принцип_суверенный, Score: 0.3570060133934021
# Topic: westphalianism, Word: международное_право, Score: 0.657564640045166
# Topic: westphalianism, Word: демократический_справедливый, Score: 0.4285499155521393
# Topic: westphalianism, Word: международное_право_норма, Score: 0.3710201382637024
# Topic: westphalianism, Word: ооноцентричной, Score: 0.5429452657699585
# Topic: westphalianism, Word: суверенность, Score: 0.3950277268886566
# Topic: security_concerns, Word: национальная_безопасность, Score: 0.07091253995895386
# Topic: security_concerns, Word: противовес, Score: 0.18593353033065796
# Topic: security_concerns, Word: дестабилизация, Score: 0.16248252987861633
# Topic: security_concerns, Word: нато, Score: 0.22587543725967407
# Topic: security_concerns, Word: угроза, Score: 0.3401222825050354
# Topic: security_concerns, Word: подменить_международное_право, Score: 0.508746862411499
# Topic: security_concerns, Word: порядок_основать, Score: 0.6548652052879333
# Topic: security_concerns, Word: однополярная, Score: 0.3951531946659088
# Topic: security_concerns, Word: новый_мироустройство, Score: 0.4008616507053375
# Topic: security_concerns, Word: расширяться_восток, Score: 0.1638544499874115
# Topic: security_concerns, Word: однополярный_модель, Score: 0.5125592947006226
# Topic: security_concerns, Word: однополярный, Score: 0.4903416037559509
# Topic: security_concerns, Word: военный_инфраструктура, Score: 0.1429692506790161
# Topic: multipolarism, Word: многополярный, Score: 0.598343014717102
# Topic: multipolarism, Word: партнёрство, Score: 0.27614372968673706
# Topic: multipolarism, Word: сотрудничество, Score: 0.22560782730579376
# Topic: multipolarism, Word: полицентричный, Score: 0.679907500743866
# Topic: multipolarism, Word: формирование_многополярный, Score: 0.5639075040817261
# Topic: multipolarism, Word: формирование_полицентричного, Score: 0.5256602168083191

# %% [markdown]
# ##### means_wCI

# %%
means_wCI = []

# %%
#The mean_wCI list stores the calculated means and 
# confidence intervals for each concept (topic) within each bootstrap and era
## calculate means for nonNA vectors and CI
for era in stat_types:
    stats = []
    for boostrap in stat_types[era]:
        for topic in stat_types[era][boostrap]:
            scores = stat_types[era][boostrap][topic]
            non_na_scores = [score for score in scores if score != 'NA' and score is not None] # filter out None values
            test = np.asarray(non_na_scores)
            if len(test) > 0: # check if there are any non-NA values
                test_mean = test.mean()
                test_error = 1.95 * (test.std() / math.sqrt(len(non_na_scores)))
                test_ci = (test_mean - test_error, test_mean + test_error)
                test_stats = test_mean, test_ci
                stats.append(test_stats)
    means_wCI.append(stats)

# %%
means_wCI
# Out:
# [[(0.32875624, (0.2531669854379823, 0.4043455005430053)),
#   (0.2807462, (0.16432471119993866, 0.3971676722801334)),
#   (0.22874323, (0.1291156524060124, 0.32837079826613724)),
#   (0.30917504, (0.09127248862258622, 0.5270775999737578)),
#   (0.2820604, (0.1582885380027517, 0.40583229110262553)),
#   (0.3312421, (0.2468460559869616, 0.4156381726240308)),
#   (0.22103386, (0.13753230924573168, 0.3045354032996632)),
#   (0.2747514, (0.1329237600270222, 0.4165790299471904)),
#   (0.22606574, (0.12846480812877417, 0.32366667184978726)),
#   (0.31331587, (0.22934142646375427, 0.3972903102916168)),
#   (0.18144548, (0.08487834308577298, 0.2780126157002378)),
#   (0.22728108, (0.1054080185370302, 0.34915413885547164)),
#   (0.27563047, (0.1176372654736042, 0.43362368270754814)),
#   (0.29985887, (0.209965434489313, 0.3897523017548886)),
#   (0.2541312, (0.16467593214003998, 0.3435864637187247)),
#   (0.21820353, (0.021256334208030164, 0.41515072522304586)),
#   (0.26926643, (0.17490670178085566, 0.3636261513456702)),
#   (0.24762449, (0.15984297013871418, 0.3354060032308842)),
#   (0.21235232, (0.12308882766988577, 0.30161581343385874)),
#   (0.27785456, (0.14192887631710555, 0.41378024729434465)),
#   (0.21854915, (0.10362636651843786, 0.3334719279780984)),
#   (0.29436317, (0.2374568628347234, 0.35126947888967236)),
#   (0.2332668, (0.1480816560224983, 0.3184519452615288)),
#   (0.29526672, (0.08862137427870034, 0.5019120610659957)),
#   (0.24988234, (0.13784404527395966, 0.3619206355884671)),
#   (0.3149907, (0.20666378740999714, 0.42331761117246136)),
#   (0.1883676, (0.10798139733844068, 0.2687538130802605)),
#   (0.24609125, (0.027453305352737406, 0.4647291878571015)),
#   (0.34698662, (0.2141014581303882, 0.4798717851061536)),
#   (0.34362364, (0.2318068072541437, 0.45544046905200863)),
#   (0.25222448, (0.15458092846615512, 0.3498680218245248)),
#   (0.2361732, (0.10517480520438505, 0.3671715900497501)),
#   (0.20676605, (0.12271617352962494, 0.29081593453884125)),
#   (0.34497085, (0.19694197013207138, 0.4929997341411525)),
#   (0.26017934, (0.17417259464291357, 0.3461860870358584)),
#   (0.25597197, (0.12827455694604545, 0.383669379401916)),
#   (0.23979598, (0.1248497674241662, 0.3547421982511878)),
#   (0.36085472, (0.2454528538488122, 0.4762565763689307)),
#   (0.23902558, (0.18595907639867132, 0.29209207940691645)),
#   (0.22387606, (0.059387257940436394, 0.3883648601702203)),
#   (0.29210964, (0.1933534285070721, 0.3908658483979877)),
#   (0.35218573, (0.25711867430583835, 0.4472527780257046)),
#   (0.25499845, (0.1603576940186381, 0.34963919700309043)),
#   (0.36662352, (0.2648439290458532, 0.4684031126564173)),
#   (0.40048057, (0.29443306997418406, 0.5065280668437481)),
#   (0.3230329, (0.21826773421458806, 0.42779803736515437)),
#   (0.49071407, (0.3794750898491109, 0.6019530565131939)),
#   (0.387187, (0.28402761639664004, 0.4903463917820709)),
#   (0.4156028, (0.3087721146643162, 0.5224334917962551)),
#   (0.34848493, (0.2499033424390661, 0.4470665243135584)),
#   (0.49554178, (0.38802712293512664, 0.6030564394389883)),
#   (0.3899253, (0.28693876155927645, 0.49291184059068693)),
#   (0.38838547, (0.290735874325037, 0.4860350750386715)),
#   (0.3272829, (0.23298928545354503, 0.42157652570368154)),
#   (0.47826168, (0.344517963535146, 0.6120053952867228))]]

# %%
#know the corresponding era and topic

#The mean_wCI list stores the calculated means and 
# confidence intervals for each concept (topic) within each bootstrap and era
## calculate means for nonNA vectors and CI

means_wCI = []  # List to store the mean and confidence interval for each concept, bootstrap, and era

for era in stat_types:
    for bootstrap in stat_types[era]:
        for topic in stat_types[era][bootstrap]:
            scores = stat_types[era][bootstrap][topic]
            non_na_scores = [score for score in scores if score != 'NA' and score is not None]  # filter out None values
            test = np.asarray(non_na_scores)
            if len(test) > 0:  # check if there are any non-NA values
                test_mean = test.mean()
                test_error = 1.95 * (test.std() / math.sqrt(len(non_na_scores)))
                test_ci = (test_mean - test_error, test_mean + test_error)
                test_stats = (test_mean, test_ci, topic, bootstrap, era)  # include topic, bootstrap, and era in the output
                means_wCI.append(test_stats)

# %%
means_wCI 
#The output of the code would be a list of statistics: mean and CI
# Out:
# [(0.32875624, (0.2531669854379823, 0.4043455005430053), 'eurasianism', 0, 0),
#  (0.2807462,
#   (0.16432471119993866, 0.3971676722801334),
#   'westphalianism',
#   0,
#   0),
#  (0.22874323,
#   (0.1291156524060124, 0.32837079826613724),
#   'security_concerns',
#   0,
#   0),
#  (0.30917504,
#   (0.09127248862258622, 0.5270775999737578),
#   'multipolarism',
#   0,
#   0),
#  (0.2820604, (0.1582885380027517, 0.40583229110262553), 'eurasianism', 1, 0),
#  (0.3312421, (0.2468460559869616, 0.4156381726240308), 'westphalianism', 1, 0),
#  (0.22103386,
#   (0.13753230924573168, 0.3045354032996632),
#   'security_concerns',
#   1,
#   0),
#  (0.2747514, (0.1329237600270222, 0.4165790299471904), 'multipolarism', 1, 0),
#  (0.22606574, (0.12846480812877417, 0.32366667184978726), 'eurasianism', 2, 0),
#  (0.31331587,
#   (0.22934142646375427, 0.3972903102916168),
#   'westphalianism',
#   2,
#   0),
#  (0.18144548,
#   (0.08487834308577298, 0.2780126157002378),
#   'security_concerns',
#   2,
#   0),
#  (0.22728108,
#   (0.1054080185370302, 0.34915413885547164),
#   'multipolarism',
#   2,
#   0),
#  (0.27563047, (0.1176372654736042, 0.43362368270754814), 'eurasianism', 3, 0),
#  (0.29985887, (0.209965434489313, 0.3897523017548886), 'westphalianism', 3, 0),
#  (0.2541312,
#   (0.16467593214003998, 0.3435864637187247),
#   'security_concerns',
#   3,
#   0),
#  (0.21820353,
#   (0.021256334208030164, 0.41515072522304586),
#   'multipolarism',
#   3,
#   0),
#  (0.26926643, (0.17490670178085566, 0.3636261513456702), 'eurasianism', 4, 0),
#  (0.24762449,
#   (0.15984297013871418, 0.3354060032308842),
#   'westphalianism',
#   4,
#   0),
#  (0.21235232,
#   (0.12308882766988577, 0.30161581343385874),
#   'security_concerns',
#   4,
#   0),
#  (0.27785456,
#   (0.14192887631710555, 0.41378024729434465),
#   'multipolarism',
#   4,
#   0),
#  (0.21854915, (0.10362636651843786, 0.3334719279780984), 'eurasianism', 5, 0),
#  (0.29436317,
#   (0.2374568628347234, 0.35126947888967236),
#   'westphalianism',
#   5,
#   0),
#  (0.2332668,
#   (0.1480816560224983, 0.3184519452615288),
#   'security_concerns',
#   5,
#   0),
#  (0.29526672,
#   (0.08862137427870034, 0.5019120610659957),
#   'multipolarism',
#   5,
#   0),
#  (0.24988234, (0.13784404527395966, 0.3619206355884671), 'eurasianism', 6, 0),
#  (0.3149907,
#   (0.20666378740999714, 0.42331761117246136),
#   'westphalianism',
#   6,
#   0),
#  (0.1883676,
#   (0.10798139733844068, 0.2687538130802605),
#   'security_concerns',
#   6,
#   0),
#  (0.24609125,
#   (0.027453305352737406, 0.4647291878571015),
#   'multipolarism',
#   6,
#   0),
#  (0.34698662, (0.2141014581303882, 0.4798717851061536), 'eurasianism', 7, 0),
#  (0.34362364,
#   (0.2318068072541437, 0.45544046905200863),
#   'westphalianism',
#   7,
#   0),
#  (0.25222448,
#   (0.15458092846615512, 0.3498680218245248),
#   'security_concerns',
#   7,
#   0),
#  (0.2361732, (0.10517480520438505, 0.3671715900497501), 'multipolarism', 7, 0),
#  (0.20676605, (0.12271617352962494, 0.29081593453884125), 'eurasianism', 8, 0),
#  (0.34497085,
#   (0.19694197013207138, 0.4929997341411525),
#   'westphalianism',
#   8,
#   0),
#  (0.26017934,
#   (0.17417259464291357, 0.3461860870358584),
#   'security_concerns',
#   8,
#   0),
#  (0.25597197, (0.12827455694604545, 0.383669379401916), 'multipolarism', 8, 0),
#  (0.23979598, (0.1248497674241662, 0.3547421982511878), 'eurasianism', 9, 0),
#  (0.36085472,
#   (0.2454528538488122, 0.4762565763689307),
#   'westphalianism',
#   9,
#   0),
#  (0.23902558,
#   (0.18595907639867132, 0.29209207940691645),
#   'security_concerns',
#   9,
#   0),
#  (0.22387606,
#   (0.059387257940436394, 0.3883648601702203),
#   'multipolarism',
#   9,
#   0),
#  (0.29210964, (0.1933534285070721, 0.3908658483979877), 'eurasianism', 10, 0),
#  (0.35218573,
#   (0.25711867430583835, 0.4472527780257046),
#   'westphalianism',
#   10,
#   0),
#  (0.25499845,
#   (0.1603576940186381, 0.34963919700309043),
#   'security_concerns',
#   10,
#   0),
#  (0.25244597,
#   (0.08612218201446448, 0.41876974999618616),
#   'multipolarism',
#   10,
#   0),
#  (0.28982, (0.2203697045566701, 0.359270266699586), 'eurasianism', 11, 0),
#  (0.35785106,
#   (0.2671516490390473, 0.4485504674503631),
#   'westphalianism',
#   11,
#   0),
#  (0.20140061,
#   (0.11650207784317036, 0.2862991378054808),
#   'security_concerns',
#   11,
#   0),
#  (0.22208913,
#   (-0.010425499274692052, 0.45460375268693876),
#   'multipolarism',
#   11,
#   0),
#  (0.32394028, (0.23112998008728028, 0.4167505741119385), 'eurasianism', 12, 0),
#  (0.30248716,
#   (0.18651217978738638, 0.41846214968420176),
#   'westphalianism',
#   12,
#   0),
#  (0.24799825,
#   (0.19569531795611045, 0.3003011870659385),
#   'security_concerns',
#   12,
#   0),
#  (0.23284619,
#   (0.11418096503051424, 0.3515114060994754),
#   'multipolarism',
#   12,
#   0),
#  (0.23841798,
#   (0.12178367860615254, 0.35505228750407697),
#   'eurasianism',
#   13,
#   0),
#  (0.32147497,
#   (0.18309493078553962, 0.45985500798856926),
#   'westphalianism',
#   13,
#   0),
#  (0.1941654,
#   (0.11466688853119221, 0.2736638988890806),
#   'security_concerns',
#   13,
#   0),
#  (0.26342374, (0.118764313624526, 0.4080831681030741), 'multipolarism', 13, 0),
#  (0.34639487, (0.30385085247523597, 0.3889388809346456), 'eurasianism', 14, 0),
#  (0.30593768,
#   (0.2242397674264807, 0.3876355878172022),
#   'westphalianism',
#   14,
#   0),
#  (0.23844364,
#   (0.16874931134410923, 0.3081379743652719),
#   'security_concerns',
#   14,
#   0),
#  (0.254513,
#   (0.10544165741190481, 0.40358433355107737),
#   'multipolarism',
#   14,
#   0),
#  (0.17931746, (0.0878816582262516, 0.27075326070189476), 'eurasianism', 15, 0),
#  (0.30777195,
#   (0.23665635640029206, 0.37888754552002657),
#   'westphalianism',
#   15,
#   0),
#  (0.2311152,
#   (0.15664488756121467, 0.30558552659093074),
#   'security_concerns',
#   15,
#   0),
#  (0.26039794,
#   (0.09399393300215567, 0.4268019487460438),
#   'multipolarism',
#   15,
#   0),
#  (0.25800374, (0.13511592149734497, 0.3808915615081787), 'eurasianism', 16, 0),
#  (0.33670768,
#   (0.27248669458127206, 0.40092866825365836),
#   'westphalianism',
#   16,
#   0),
#  (0.25136966,
#   (0.16269175995179447, 0.34004755031279293),
#   'security_concerns',
#   16,
#   0),
#  (0.27689436,
#   (0.13552428042804793, 0.41826444113338396),
#   'multipolarism',
#   16,
#   0),
#  (0.22142655, (0.13985879570245743, 0.3029942974448204), 'eurasianism', 17, 0),
#  (0.31739554,
#   (0.2536209816029744, 0.3811700945803447),
#   'westphalianism',
#   17,
#   0),
#  (0.24269727,
#   (0.17770427382649648, 0.3076902636223866),
#   'security_concerns',
#   17,
#   0),
#  (0.2709629,
#   (0.11878481815463743, 0.4231409697710828),
#   'multipolarism',
#   17,
#   0),
#  (0.25926676, (0.19318880072770744, 0.3253447271233973), 'eurasianism', 18, 0),
#  (0.28673223,
#   (0.1577299121803636, 0.41573454104000385),
#   'westphalianism',
#   18,
#   0),
#  (0.20629416,
#   (0.10192892401566847, 0.3106594041074242),
#   'security_concerns',
#   18,
#   0),
#  (0.2512266,
#   (0.09442280443027826, 0.40803040353938724),
#   'multipolarism',
#   18,
#   0),
#  (0.2782961, (0.16322279009478569, 0.3933694359336567), 'eurasianism', 19, 0),
#  (0.2814537,
#   (0.2297234679381851, 0.3331839298088547),
#   'westphalianism',
#   19,
#   0),
#  (0.22531389,
#   (0.16348457363596666, 0.28714320036420116),
#   'security_concerns',
#   19,
#   0),
#  (0.27133623,
#   (0.11570369340942746, 0.4269687619013941),
#   'multipolarism',
#   19,
#   0),
#  (0.20665298,
#   (0.15228719115257264, 0.26101877689361574),
#   'eurasianism',
#   20,
#   0),
#  (0.3042433,
#   (0.2239840090879563, 0.3845025836816665),
#   'westphalianism',
#   20,
#   0),
#  (0.19920892,
#   (0.14010815288555994, 0.2583096775816642),
#   'security_concerns',
#   20,
#   0),
#  (0.20985699,
#   (0.011366396085108088, 0.40834757791391535),
#   'multipolarism',
#   20,
#   0),
#  (0.26834503, (0.1734633404761553, 0.3632267158478498), 'eurasianism', 21, 0),
#  (0.29910398,
#   (0.23694017482134644, 0.3612677757706946),
#   'westphalianism',
#   21,
#   0),
#  (0.28552115,
#   (0.22141146285668734, 0.34963083641394255),
#   'security_concerns',
#   21,
#   0),
#  (0.2965945,
#   (0.16817401748218166, 0.4250149836011924),
#   'multipolarism',
#   21,
#   0),
#  (0.31966662, (0.2681482299980436, 0.3711850181403841), 'eurasianism', 22, 0),
#  (0.26298434,
#   (0.11733952467212735, 0.40862914617290436),
#   'westphalianism',
#   22,
#   0),
#  (0.2556826,
#   (0.20296297417563575, 0.30840220107155664),
#   'security_concerns',
#   22,
#   0),
#  (0.26777688,
#   (0.1175055524222646, 0.4180482009537425),
#   'multipolarism',
#   22,
#   0),
#  (0.31633148,
#   (0.21055679377168418, 0.42210615817457436),
#   'eurasianism',
#   23,
#   0),
#  (0.28786308,
#   (0.19966435451833756, 0.3760617969480321),
#   'westphalianism',
#   23,
#   0),
#  (0.21832906,
#   (0.12302436344445049, 0.3136337507504195),
#   'security_concerns',
#   23,
#   0),
#  (0.25398585,
#   (0.08352906182914502, 0.4244426421770501),
#   'multipolarism',
#   23,
#   0),
#  (0.28772736, (0.2038833025842905, 0.371571409329772), 'eurasianism', 24, 0),
#  (0.31487265,
#   (0.24020725822677097, 0.3895380463577322),
#   'westphalianism',
#   24,
#   0),
#  (0.23685491,
#   (0.17062137970636265, 0.30308844199468715),
#   'security_concerns',
#   24,
#   0),
#  (0.22013742,
#   (0.07375576017165816, 0.36651907446121534),
#   'multipolarism',
#   24,
#   0),
#  (0.25919563,
#   (0.17368186935782431, 0.34470938220620156),
#   'eurasianism',
#   25,
#   0),
#  (0.3072224,
#   (0.200456043219893, 0.41398874905076744),
#   'westphalianism',
#   25,
#   0),
#  (0.24784872,
#   (0.17294076264200836, 0.32275667607488007),
#   'security_concerns',
#   25,
#   0),
#  (0.28034875,
#   (0.0844670940351937, 0.4762304019021537),
#   'multipolarism',
#   25,
#   0),
#  (0.241076, (0.0966906350106001, 0.38546135015785693), 'eurasianism', 26, 0),
#  (0.40209925,
#   (0.3233677157222135, 0.4808307877720492),
#   'westphalianism',
#   26,
#   0),
#  (0.26758814,
#   (0.19250530984789427, 0.34267096731275026),
#   'security_concerns',
#   26,
#   0),
#  (0.21207201,
#   (0.020817359614179604, 0.40332667000312994),
#   'multipolarism',
#   26,
#   0),
#  (0.23094386,
#   (0.17169992858543992, 0.29018778866156936),
#   'eurasianism',
#   27,
#   0),
#  (0.3109176, (0.2428607395974381, 0.378974432578923), 'westphalianism', 27, 0),
#  (0.24386947,
#   (0.16343872620070243, 0.3243002109388087),
#   'security_concerns',
#   27,
#   0),
#  (0.28246474,
#   (0.09315117992960531, 0.4717783053914396),
#   'multipolarism',
#   27,
#   0),
#  (0.25658438,
#   (0.13507294785231352, 0.37809580434113743),
#   'eurasianism',
#   28,
#   0),
#  (0.38125524,
#   (0.2814650344347102, 0.4810454440618413),
#   'westphalianism',
#   28,
#   0),
#  (0.21126895,
#   (0.13633387345162928, 0.2862040196052402),
#   'security_concerns',
#   28,
#   0),
#  (0.24899632,
#   (0.04560608061582755, 0.45238655415742685),
#   'multipolarism',
#   28,
#   0),
#  (0.23935026,
#   (0.11412601511357898, 0.36457450349451426),
#   'eurasianism',
#   29,
#   0),
#  (0.3227975,
#   (0.22530974437656257, 0.4202852697187438),
#   'westphalianism',
#   29,
#   0),
#  (0.22404185,
#   (0.15217575346806278, 0.29590794528147946),
#   'security_concerns',
#   29,
#   0),
#  (0.23983335,
#   (0.07675514868932959, 0.40291156121057276),
#   'multipolarism',
#   29,
#   0),
#  (0.3129096, (0.2398419737815857, 0.3859772324562073), 'eurasianism', 30, 0),
#  (0.25406948,
#   (0.17970058852653487, 0.32843836611289995),
#   'westphalianism',
#   30,
#   0),
#  (0.24209748,
#   (0.1949300808282543, 0.28926488334220163),
#   'security_concerns',
#   30,
#   0),
#  (0.22821988,
#   (0.04836374483710057, 0.4080760184704708),
#   'multipolarism',
#   30,
#   0),
#  (0.2837423, (0.16716474574059248, 0.4003198714926839), 'eurasianism', 31, 0),
#  (0.28436306,
#   (0.2118527715060573, 0.3568733508732457),
#   'westphalianism',
#   31,
#   0),
#  (0.27504355,
#   (0.19119661675041139, 0.3588904775565344),
#   'security_concerns',
#   31,
#   0),
#  (0.2731789, (0.11398650757852291, 0.432371302918761), 'multipolarism', 31, 0),
#  (0.2171835, (0.13489098884165288, 0.2994760122150183), 'eurasianism', 32, 0),
#  (0.27106562,
#   (0.22163616492036076, 0.32049508021590023),
#   'westphalianism',
#   32,
#   0),
#  (0.16602919,
#   (0.08721872414578809, 0.24483964596758473),
#   'security_concerns',
#   32,
#   0),
#  (0.23622604,
#   (0.02664576127506474, 0.44580631301425716),
#   'multipolarism',
#   32,
#   0),
#  (0.22740977, (0.1305669154971838, 0.32425261475145817), 'eurasianism', 33, 0),
#  (0.32716697,
#   (0.23460381581114692, 0.41973013327790337),
#   'westphalianism',
#   33,
#   0),
#  (0.21252106,
#   (0.12739397106794403, 0.29764815153451873),
#   'security_concerns',
#   33,
#   0),
#  (0.19142509,
#   (-0.011510616815123192, 0.39436078695062127),
#   'multipolarism',
#   33,
#   0),
#  (0.23962641,
#   (0.12409407813102007, 0.35515873711556195),
#   'eurasianism',
#   34,
#   0),
#  (0.2926805,
#   (0.24703471746232397, 0.33832628641340845),
#   'westphalianism',
#   34,
#   0),
#  (0.20427969,
#   (0.13622690875971888, 0.27233247320210363),
#   'security_concerns',
#   34,
#   0),
#  (0.28521597, (0.1433857050275379, 0.427046242680592), 'multipolarism', 34, 0),
#  (0.2540381, (0.107749792188406, 0.40032639876008036), 'eurasianism', 35, 0),
#  (0.36069182,
#   (0.26388433585855586, 0.45749929537084477),
#   'westphalianism',
#   35,
#   0),
#  (0.18718068,
#   (0.08612466990312817, 0.2882366961304259),
#   'security_concerns',
#   35,
#   0),
#  (0.31792703, (0.186852132337949, 0.4490019330802944), 'multipolarism', 35, 0),
#  (0.3435223, (0.25255597840730226, 0.43448864210661375), 'eurasianism', 36, 0),
#  (0.3045863,
#   (0.2201792944121823, 0.38899328821416046),
#   'westphalianism',
#   36,
#   0),
#  (0.2846338,
#   (0.2173820065017889, 0.3518855644706537),
#   'security_concerns',
#   36,
#   0),
#  (0.28692493,
#   (0.10827778663601806, 0.46557207021746705),
#   'multipolarism',
#   36,
#   0),
#  (0.27154654, (0.17172450982034207, 0.3713685754686594), 'eurasianism', 37, 0),
#  (0.34726697,
#   (0.2564441072998497, 0.43808983683009417),
#   'westphalianism',
#   37,
#   0),
#  (0.20388916,
#   (0.15115210604309456, 0.2566262166535912),
#   'security_concerns',
#   37,
#   0),
#  (0.2934288,
#   (0.13513143886081216, 0.45172617804058557),
#   'multipolarism',
#   37,
#   0),
#  (0.22770411, (0.10121068805456163, 0.3541975274682045), 'eurasianism', 38, 0),
#  (0.28898248,
#   (0.20763191279843046, 0.3703330487303476),
#   'westphalianism',
#   38,
#   0),
#  (0.22359128,
#   (0.1526719013105975, 0.294510664616908),
#   'security_concerns',
#   38,
#   0),
#  (0.21207762,
#   (0.011569300497166451, 0.4125859347933609),
#   'multipolarism',
#   38,
#   0),
#  (0.25790244,
#   (0.16957888584583997, 0.34622600097209216),
#   'eurasianism',
#   39,
#   0),
#  (0.34294498,
#   (0.2328684019404396, 0.4530215573948876),
#   'westphalianism',
#   39,
#   0),
#  (0.2477885,
#   (0.167262267571765, 0.32831473996035476),
#   'security_concerns',
#   39,
#   0),
#  (0.2793736,
#   (0.14617141086039723, 0.41257576149525466),
#   'multipolarism',
#   39,
#   0),
#  (0.29273352, (0.2266389515250921, 0.35882808901369573), 'eurasianism', 40, 0),
#  (0.28967923,
#   (0.16191808455423573, 0.4174403739647462),
#   'westphalianism',
#   40,
#   0),
#  (0.20765485,
#   (0.14318777859917503, 0.27212191879042763),
#   'security_concerns',
#   40,
#   0),
#  (0.2627457, (0.1375865389916715, 0.3879048774626437), 'multipolarism', 40, 0),
#  (0.2636412, (0.15899335239082574, 0.3682890644297004), 'eurasianism', 41, 0),
#  (0.31004095,
#   (0.20443223725238263, 0.41564966429791034),
#   'westphalianism',
#   41,
#   0),
#  (0.21259393,
#   (0.13156146466511004, 0.29362639129382856),
#   'security_concerns',
#   41,
#   0),
#  (0.24801676,
#   (0.10873999089067699, 0.3872935286157775),
#   'multipolarism',
#   41,
#   0),
#  (0.26717958,
#   (0.16793398111355867, 0.36642517597186003),
#   'eurasianism',
#   42,
#   0),
#  (0.2680776,
#   (0.17762029073466434, 0.3585349331117712),
#   'westphalianism',
#   42,
#   0),
#  (0.2068764,
#   (0.14295676229170118, 0.2707960319740459),
#   'security_concerns',
#   42,
#   0),
#  (0.19753182,
#   (0.027510254629033448, 0.36755338405810034),
#   'multipolarism',
#   42,
#   0),
#  (0.2710141, (0.19011655654758214, 0.3519116321578622), 'eurasianism', 43, 0),
#  (0.32933706,
#   (0.2405741959053927, 0.41809992499762244),
#   'westphalianism',
#   43,
#   0),
#  (0.23735298,
#   (0.15140623309698065, 0.3232997312298779),
#   'security_concerns',
#   43,
#   0),
#  (0.24505162,
#   (0.07742768139780554, 0.4126755633836886),
#   'multipolarism',
#   43,
#   0),
#  (0.21878219,
#   (0.14338247198611498, 0.29418190103024244),
#   'eurasianism',
#   44,
#   0),
#  (0.3051219,
#   (0.171878866625555, 0.43836493067669113),
#   'westphalianism',
#   44,
#   0),
#  (0.21605629,
#   (0.12139090025165113, 0.31072167432568043),
#   'security_concerns',
#   44,
#   0),
#  (0.20252796, (0.050249121392617, 0.3548067889562752), 'multipolarism', 44, 0),
#  (0.30319393,
#   (0.23973036985844376, 0.36665748376399276),
#   'eurasianism',
#   45,
#   0),
#  (0.31581187,
#   (0.2221096793681533, 0.4095140655964463),
#   'westphalianism',
#   45,
#   0),
#  (0.16351412,
#   (0.09469597710786205, 0.23233226762594839),
#   'security_concerns',
#   45,
#   0),
#  (0.2054768,
#   (0.08363145133482955, 0.32732215980065327),
#   'multipolarism',
#   45,
#   0),
#  (0.25289702,
#   (0.15618710424751042, 0.34960694406181575),
#   'eurasianism',
#   46,
#   0),
#  (0.31355467,
#   (0.23796677504284142, 0.3891425737311149),
#   'westphalianism',
#   46,
#   0),
#  (0.23231086,
#   (0.18658781849774803, 0.27803390420046364),
#   'security_concerns',
#   46,
#   0),
#  (0.2276118,
#   (-0.04052721665113662, 0.49575080678671096),
#   'multipolarism',
#   46,
#   0),
#  (0.3224696, (0.25636579040437935, 0.38857339378446343), 'eurasianism', 47, 0),
#  (0.3144208,
#   (0.23083044807003275, 0.398011130890386),
#   'westphalianism',
#   47,
#   0),
#  (0.24078168,
#   (0.15579756774759068, 0.325765791751387),
#   'security_concerns',
#   47,
#   0),
#  (0.33026806,
#   (0.1976483669962996, 0.46288774340485395),
#   'multipolarism',
#   47,
#   0),
#  (0.25713482, (0.15882355198264123, 0.3554460979998112), 'eurasianism', 48, 0),
#  (0.346461,
#   (0.2642376954628932, 0.42868430065374497),
#   'westphalianism',
#   48,
#   0),
#  (0.2825506,
#   (0.24106532759703897, 0.32403587870560385),
#   'security_concerns',
#   48,
#   0),
#  (0.28941518,
#   (0.08664568080567814, 0.49218468056059383),
#   'multipolarism',
#   48,
#   0),
#  (0.24356458,
#   (0.08325422480702402, 0.40387492701411243),
#   'eurasianism',
#   49,
#   0),
#  (0.26318195,
#   (0.14761386797855947, 0.3787500412659779),
#   'westphalianism',
#   49,
#   0),
#  (0.1839286,
#   (0.09592650370478653, 0.2719306842815874),
#   'security_concerns',
#   49,
#   0),
#  (0.26385376,
#   (0.18375234389179307, 0.34395517325527114),
#   'multipolarism',
#   49,
#   0),
#  (0.28465933, (0.22009847683167472, 0.3492201753213404), 'eurasianism', 0, 1),
#  (0.3117265,
#   (0.2273858039579251, 0.39606721709157444),
#   'westphalianism',
#   0,
#   1),
#  (0.25686282,
#   (0.2018952137560338, 0.3118304246335536),
#   'security_concerns',
#   0,
#   1),
#  (0.46035266,
#   (0.33749935980493456, 0.5832059586459931),
#   'multipolarism',
#   0,
#   1),
#  (0.25192788, (0.19674838684379056, 0.30710737802208465), 'eurasianism', 1, 1),
#  (0.2922043,
#   (0.1789250529161447, 0.40548352834072177),
#   'westphalianism',
#   1,
#   1),
#  (0.2235362,
#   (0.13730602356937677, 0.3097663631722614),
#   'security_concerns',
#   1,
#   1),
#  (0.44822025, (0.3254204300740149, 0.5710200759074304), 'multipolarism', 1, 1),
#  (0.26985773, (0.20349987701204403, 0.3362155918714704), 'eurasianism', 2, 1),
#  (0.2346975,
#   (0.15011520374584164, 0.31927980791759525),
#   'westphalianism',
#   2,
#   1),
#  (0.25340113,
#   (0.16478312856326371, 0.3420191323124382),
#   'security_concerns',
#   2,
#   1),
#  (0.4383146, (0.30119550478178997, 0.5754336689738557), 'multipolarism', 2, 1),
#  (0.20651758, (0.13801060513987642, 0.27502454920277497), 'eurasianism', 3, 1),
#  (0.38309798,
#   (0.3352840803969451, 0.4309118724953584),
#   'westphalianism',
#   3,
#   1),
#  (0.26059145,
#   (0.1888719154001356, 0.3323109793065905),
#   'security_concerns',
#   3,
#   1),
#  (0.46473658,
#   (0.34833674951433613, 0.5811364121830516),
#   'multipolarism',
#   3,
#   1),
#  (0.2463474, (0.19643953491063865, 0.2962552602210447), 'eurasianism', 4, 1),
#  (0.2515127, (0.1615309380688959, 0.3414944744906134), 'westphalianism', 4, 1),
#  (0.30953118,
#   (0.25746686609117614, 0.3615954980102338),
#   'security_concerns',
#   4,
#   1),
#  (0.44296744, (0.3221153266408498, 0.563819562675709), 'multipolarism', 4, 1),
#  (0.25334424, (0.14720177642433077, 0.35948669918449494), 'eurasianism', 5, 1),
#  (0.34388375,
#   (0.23992577340868187, 0.4478417322370701),
#   'westphalianism',
#   5,
#   1),
#  (0.19769774,
#   (0.1492691466753829, 0.24612634087153787),
#   'security_concerns',
#   5,
#   1),
#  (0.42754588,
#   (0.27749034294724495, 0.5776014076745507),
#   'multipolarism',
#   5,
#   1),
#  (0.23809211, (0.17763258008194427, 0.2985516390399887), 'eurasianism', 6, 1),
#  (0.32276633,
#   (0.23241141082263547, 0.41312125681423584),
#   'westphalianism',
#   6,
#   1),
#  (0.19996, (0.1394433861371565, 0.260476600587697), 'security_concerns', 6, 1),
#  (0.4175086, (0.2938797273402943, 0.5411374769443736), 'multipolarism', 6, 1),
#  (0.22757272, (0.18097762418604219, 0.2741678242602316), 'eurasianism', 7, 1),
#  (0.30617583,
#   (0.19225939186429886, 0.42009226409578415),
#   'westphalianism',
#   7,
#   1),
#  (0.2610795,
#   (0.1629727038334647, 0.35918627653610313),
#   'security_concerns',
#   7,
#   1),
#  (0.44671354,
#   (0.32382190956614565, 0.5696051643893902),
#   'multipolarism',
#   7,
#   1),
#  (0.24828637, (0.16711089306551818, 0.32946183985989685), 'eurasianism', 8, 1),
#  (0.33959684,
#   (0.23253203834270847, 0.4466616371753274),
#   'westphalianism',
#   8,
#   1),
#  (0.22065906,
#   (0.1415538330107423, 0.29976429152195727),
#   'security_concerns',
#   8,
#   1),
#  (0.49633956, (0.3964157939702978, 0.5962633251398096), 'multipolarism', 8, 1),
#  (0.26380655, (0.20250770342809168, 0.32510539996164833), 'eurasianism', 9, 1),
#  (0.30421188,
#   (0.20936580306268993, 0.3990579664113396),
#   'westphalianism',
#   9,
#   1),
#  (0.24971998,
#   (0.18349674007559613, 0.3159432146820943),
#   'security_concerns',
#   9,
#   1),
#  (0.42557764, (0.3109444555629136, 0.5402108255039809), 'multipolarism', 9, 1),
#  (0.26469743, (0.2230145144274993, 0.30638035060851143), 'eurasianism', 10, 1),
#  (0.24224223,
#   (0.1438133766587208, 0.3406710872714092),
#   'westphalianism',
#   10,
#   1),
#  (0.25855,
#   (0.18835288662241362, 0.3287470899171982),
#   'security_concerns',
#   10,
#   1),
#  (0.5011009,
#   (0.38533495519869987, 0.6168668403793031),
#   'multipolarism',
#   10,
#   1),
#  (0.259144, (0.19154765786830538, 0.3267403584509695), 'eurasianism', 11, 1),
#  (0.25503877,
#   (0.11987736728480805, 0.3902001688213016),
#   'westphalianism',
#   11,
#   1),
#  (0.223762,
#   (0.12830365394650672, 0.3192203571885946),
#   'security_concerns',
#   11,
#   1),
#  (0.4382737,
#   (0.30723865966238906, 0.5693087365206249),
#   'multipolarism',
#   11,
#   1),
#  (0.2864485, (0.23949293524959586, 0.33340408175250985), 'eurasianism', 12, 1),
#  (0.28880307,
#   (0.190663207819063, 0.38694293374816724),
#   'westphalianism',
#   12,
#   1),
#  (0.23789608,
#   (0.16938812846420276, 0.3064040411067201),
#   'security_concerns',
#   12,
#   1),
#  (0.48403752,
#   (0.3999249923173762, 0.5681500446851873),
#   'multipolarism',
#   12,
#   1),
#  (0.2655034, (0.20511304005477457, 0.32589377299454186), 'eurasianism', 13, 1),
#  (0.30402565,
#   (0.23560824639183442, 0.3724430536569937),
#   'westphalianism',
#   13,
#   1),
#  (0.29074174,
#   (0.2289931420236826, 0.35249034129083157),
#   'security_concerns',
#   13,
#   1),
#  (0.45954397, (0.348521852029152, 0.5705660943857955), 'multipolarism', 13, 1),
#  (0.21375854,
#   (0.14902794661311938, 0.27848913965435196),
#   'eurasianism',
#   14,
#   1),
#  (0.33782554,
#   (0.24808948403654663, 0.4275615894192639),
#   'westphalianism',
#   14,
#   1),
#  (0.22432378,
#   (0.1373165985307689, 0.3113309601583485),
#   'security_concerns',
#   14,
#   1),
#  (0.44962412, (0.3411488027430839, 0.558099439635151), 'multipolarism', 14, 1),
#  (0.27188486, (0.20397005096169551, 0.3397996662547962), 'eurasianism', 15, 1),
#  (0.31250516,
#   (0.2462229301406082, 0.37878738146293794),
#   'westphalianism',
#   15,
#   1),
#  (0.24716894,
#   (0.17794712521135808, 0.3163907613605261),
#   'security_concerns',
#   15,
#   1),
#  (0.4202804,
#   (0.29708224797147886, 0.5434785459051691),
#   'multipolarism',
#   15,
#   1),
#  (0.23770402, (0.1855185097772117, 0.28988953766045616), 'eurasianism', 16, 1),
#  (0.29415393,
#   (0.18411222596522397, 0.40419563154820376),
#   'westphalianism',
#   16,
#   1),
#  (0.27547282,
#   (0.19381397318923071, 0.3571316664210598),
#   'security_concerns',
#   16,
#   1),
#  (0.46917427,
#   (0.34632533186986536, 0.5920231998531571),
#   'multipolarism',
#   16,
#   1),
#  (0.25944445,
#   (0.17221072069582827, 0.34667817004742735),
#   'eurasianism',
#   17,
#   1),
#  (0.30236503,
#   (0.22290513054331196, 0.3818249390939866),
#   'westphalianism',
#   17,
#   1),
#  (0.25885606,
#   (0.18357286565005781, 0.33413925059139726),
#   'security_concerns',
#   17,
#   1),
#  (0.4876199, (0.35199872421605227, 0.623241089111737), 'multipolarism', 17, 1),
#  (0.2597678, (0.20733233881632326, 0.3122032623227453), 'eurasianism', 18, 1),
#  (0.33957148,
#   (0.24648671821621349, 0.43265623374911855),
#   'westphalianism',
#   18,
#   1),
#  (0.25836346,
#   (0.18547905014723687, 0.3312478609207258),
#   'security_concerns',
#   18,
#   1),
#  (0.5097769, (0.3973822094556487, 0.6221715711000764), 'multipolarism', 18, 1),
#  (0.278365, (0.24339072687574953, 0.3133392454867688), 'eurasianism', 19, 1),
#  (0.2646709,
#   (0.21156295930198613, 0.31777885760017455),
#   'westphalianism',
#   19,
#   1),
#  (0.23535436,
#   (0.17341072419829665, 0.29729800363831227),
#   'security_concerns',
#   19,
#   1),
#  (0.4638102, (0.3613442107485886, 0.5662762001706009), 'multipolarism', 19, 1),
#  (0.2426805, (0.1830463902380162, 0.30231461959818073), 'eurasianism', 20, 1),
#  (0.29873934,
#   (0.143640436274009, 0.4538382514892051),
#   'westphalianism',
#   20,
#   1),
#  (0.27834988,
#   (0.1989613456472607, 0.3577384071603565),
#   'security_concerns',
#   20,
#   1),
#  (0.4405978,
#   (0.34399955455270786, 0.5371960502484701),
#   'multipolarism',
#   20,
#   1),
#  (0.2259204, (0.15364049928716259, 0.2982002888388292), 'eurasianism', 21, 1),
#  (0.2627067,
#   (0.1380507720022463, 0.3873626219720579),
#   'westphalianism',
#   21,
#   1),
#  (0.2761911,
#   (0.19324371516704558, 0.35913845598697663),
#   'security_concerns',
#   21,
#   1),
#  (0.46791577,
#   (0.3280059853552968, 0.6078255614281505),
#   'multipolarism',
#   21,
#   1),
#  (0.20444219,
#   (0.11383891524620961, 0.29504546104125073),
#   'eurasianism',
#   22,
#   1),
#  (0.27153438,
#   (0.16444386259960864, 0.37862490399432447),
#   'westphalianism',
#   22,
#   1),
#  (0.27266285,
#   (0.20422957167029382, 0.34109612479805945),
#   'security_concerns',
#   22,
#   1),
#  (0.4346927, (0.3246335817187583, 0.5447518395573343), 'multipolarism', 22, 1),
#  (0.24851955, (0.16441033969684138, 0.3326287697716187), 'eurasianism', 23, 1),
#  (0.29026002,
#   (0.20702929360706374, 0.373490740229301),
#   'westphalianism',
#   23,
#   1),
#  (0.2503528,
#   (0.1753602117773442, 0.3253453880075069),
#   'security_concerns',
#   23,
#   1),
#  (0.45869374,
#   (0.3515960828270256, 0.5657914026771248),
#   'multipolarism',
#   23,
#   1),
#  (0.27994087, (0.22470772260832758, 0.3351740241606238), 'eurasianism', 24, 1),
#  (0.23418029,
#   (0.08775266281669125, 0.38060791023666873),
#   'westphalianism',
#   24,
#   1),
#  (0.27107316,
#   (0.22569230259169823, 0.3164540225196909),
#   'security_concerns',
#   24,
#   1),
#  (0.4507937, (0.3202543171564678, 0.5813331095059773), 'multipolarism', 24, 1),
#  (0.283318, (0.2081493592547421, 0.35848666665086704), 'eurasianism', 25, 1),
#  (0.3188465,
#   (0.20930527335432308, 0.4283877145645307),
#   'westphalianism',
#   25,
#   1),
#  (0.22027068,
#   (0.12359855051143294, 0.31694280629055377),
#   'security_concerns',
#   25,
#   1),
#  (0.45049664,
#   (0.34098535246208206, 0.5600079351012419),
#   'multipolarism',
#   25,
#   1),
#  (0.25626692,
#   (0.18215068799131012, 0.33038315552599334),
#   'eurasianism',
#   26,
#   1),
#  (0.2919806,
#   (0.1699157175300742, 0.4140454712631082),
#   'westphalianism',
#   26,
#   1),
#  (0.2591186,
#   (0.18790000633991322, 0.3303371672173683),
#   'security_concerns',
#   26,
#   1),
#  (0.44110763,
#   (0.3399180331196791, 0.5422972283396715),
#   'multipolarism',
#   26,
#   1),
#  (0.26560467,
#   (0.20866907615818905, 0.32254027347407416),
#   'eurasianism',
#   27,
#   1),
#  (0.24051, (0.14700237122356638, 0.3340176323336388), 'westphalianism', 27, 1),
#  (0.2615721,
#   (0.18733534924685954, 0.33580883629620073),
#   'security_concerns',
#   27,
#   1),
#  (0.45527163, (0.3348841469360307, 0.575659116022496), 'multipolarism', 27, 1),
#  (0.3013878, (0.2502637699844724, 0.35251180374599633), 'eurasianism', 28, 1),
#  (0.33024675,
#   (0.22977982912154848, 0.4307136639585907),
#   'westphalianism',
#   28,
#   1),
#  (0.28077903,
#   (0.22789818830788136, 0.33365987949073317),
#   'security_concerns',
#   28,
#   1),
#  (0.46003738,
#   (0.34822920924028783, 0.5718455516735611),
#   'multipolarism',
#   28,
#   1),
#  (0.26086193, (0.18513501131883592, 0.3365888551438716), 'eurasianism', 29, 1),
#  (0.35597515,
#   (0.25955613684106305, 0.4523941652829604),
#   'westphalianism',
#   29,
#   1),
#  (0.22939292,
#   (0.15038486179953484, 0.30840097012871837),
#   'security_concerns',
#   29,
#   1),
#  (0.48160413, (0.368652334117705, 0.5945559240343031), 'multipolarism', 29, 1),
#  (0.18563573,
#   (0.12240994294763308, 0.24886151830076475),
#   'eurasianism',
#   30,
#   1),
#  (0.28592482,
#   (0.17147522238619456, 0.400374421797918),
#   'westphalianism',
#   30,
#   1),
#  (0.26213938,
#   (0.19620465040206908, 0.3280741095542908),
#   'security_concerns',
#   30,
#   1),
#  (0.4507791, (0.3795657205363347, 0.5219924998501705), 'multipolarism', 30, 1),
#  (0.27501684,
#   (0.21978854538995055, 0.33024514315527653),
#   'eurasianism',
#   31,
#   1),
#  (0.3659844,
#   (0.29231201456522937, 0.4396568055298329),
#   'westphalianism',
#   31,
#   1),
#  (0.24906309,
#   (0.19486139283514942, 0.30326478614472424),
#   'security_concerns',
#   31,
#   1),
#  (0.43922502, (0.3239149445705232, 0.554535091478366), 'multipolarism', 31, 1),
#  (0.23448609, (0.15278990708356338, 0.3161822692298369), 'eurasianism', 32, 1),
#  (0.33938104,
#   (0.24618762869732433, 0.43257444958789293),
#   'westphalianism',
#   32,
#   1),
#  (0.21520539,
#   (0.12821507476171148, 0.3021956978003155),
#   'security_concerns',
#   32,
#   1),
#  (0.40808204,
#   (0.3061573874600323, 0.5100066888682453),
#   'multipolarism',
#   32,
#   1),
#  (0.23262827,
#   (0.12155400421101589, 0.34370253775637605),
#   'eurasianism',
#   33,
#   1),
#  (0.29573223,
#   (0.18574961465999995, 0.4057148452360877),
#   'westphalianism',
#   33,
#   1),
#  (0.27085286,
#   (0.19726993776857854, 0.34443578980863093),
#   'security_concerns',
#   33,
#   1),
#  (0.47333026,
#   (0.37944392340311267, 0.5672165952431275),
#   'multipolarism',
#   33,
#   1),
#  (0.25466585, (0.2104580367825923, 0.2988736664034428), 'eurasianism', 34, 1),
#  (0.30357972,
#   (0.20996237778430127, 0.3971970579647527),
#   'westphalianism',
#   34,
#   1),
#  (0.2367326,
#   (0.15603150391352427, 0.31743370032536733),
#   'security_concerns',
#   34,
#   1),
#  (0.45346808,
#   (0.3432864149802637, 0.5636497536903906),
#   'multipolarism',
#   34,
#   1),
#  (0.2582389, (0.20056466081927132, 0.31591316243817497), 'eurasianism', 35, 1),
#  (0.22539906,
#   (0.12226273225962955, 0.32853539181530633),
#   'westphalianism',
#   35,
#   1),
#  (0.2894079,
#   (0.2296289511024952, 0.3491868667304516),
#   'security_concerns',
#   35,
#   1),
#  (0.44223675,
#   (0.3237234948628721, 0.5607500077730837),
#   'multipolarism',
#   35,
#   1),
#  (0.19011362, (0.1222658622875949, 0.2579613756522397), 'eurasianism', 36, 1),
#  (0.31465635,
#   (0.21623410511752425, 0.4130785889551991),
#   'westphalianism',
#   36,
#   1),
#  (0.3032357,
#   (0.21993678087852475, 0.38653463845588687),
#   'security_concerns',
#   36,
#   1),
#  (0.49232814, (0.402079355572263, 0.582576918746432), 'multipolarism', 36, 1),
#  (0.26836938,
#   (0.17822156922173638, 0.35851718409705025),
#   'eurasianism',
#   37,
#   1),
#  (0.2828636,
#   (0.19413108486456082, 0.37159608941751315),
#   'westphalianism',
#   37,
#   1),
#  (0.29422575,
#   (0.23419776355306127, 0.35425374115427516),
#   'security_concerns',
#   37,
#   1),
#  (0.46969834,
#   (0.3580922295612759, 0.5813044498401218),
#   'multipolarism',
#   37,
#   1),
#  (0.23455471,
#   (0.18020561070284094, 0.28890380530515464),
#   'eurasianism',
#   38,
#   1),
#  (0.30031607,
#   (0.1947697699142344, 0.40586236118546654),
#   'westphalianism',
#   38,
#   1),
#  (0.28207996,
#   (0.20515553721598895, 0.3590043925363609),
#   'security_concerns',
#   38,
#   1),
#  (0.4518613, (0.3495442157414574, 0.5541783685061318), 'multipolarism', 38, 1),
#  (0.20159827,
#   (0.16467628088721462, 0.23852026256790929),
#   'eurasianism',
#   39,
#   1),
#  (0.29092693,
#   (0.1932269029419213, 0.38862696363522714),
#   'westphalianism',
#   39,
#   1),
#  (0.23582466,
#   (0.17002302275263165, 0.3016262961808553),
#   'security_concerns',
#   39,
#   1),
#  (0.4353334, (0.3158552067877254, 0.5548115951417485), 'multipolarism', 39, 1),
#  (0.27686977, (0.22398975607734448, 0.3297497916521477), 'eurasianism', 40, 1),
#  (0.2366428,
#   (0.06401527287973852, 0.40927031276212245),
#   'westphalianism',
#   40,
#   1),
#  (0.26736334,
#   (0.1805946437726177, 0.35413203555248607),
#   'security_concerns',
#   40,
#   1),
#  (0.4128594,
#   (0.27208572849623736, 0.5536330915988249),
#   'multipolarism',
#   40,
#   1),
#  (0.2237326, (0.1507311279451572, 0.2967340832078732), 'eurasianism', 41, 1),
#  (0.31534067,
#   (0.14607355925056414, 0.48460777667549176),
#   'westphalianism',
#   41,
#   1),
#  (0.265935,
#   (0.17043673011468774, 0.3614332774002659),
#   'security_concerns',
#   41,
#   1),
#  (0.46854517, (0.366435034937606, 0.5706553023388528), 'multipolarism', 41, 1),
#  (0.25760975,
#   (0.19604987647153915, 0.31916963313005386),
#   'eurasianism',
#   42,
#   1),
#  (0.30272475,
#   (0.1836253623916974, 0.42182413530804014),
#   'westphalianism',
#   42,
#   1),
#  (0.29066554,
#   (0.20812970474362374, 0.37320136949419974),
#   'security_concerns',
#   42,
#   1),
#  (0.4610803, (0.321269018445119, 0.6008916070126447), 'multipolarism', 42, 1),
#  (0.28258863, (0.2079283349435812, 0.357248926885795), 'eurasianism', 43, 1),
#  (0.30788592,
#   (0.21831606300550982, 0.3974557670764299),
#   'westphalianism',
#   43,
#   1),
#  (0.2563277,
#   (0.18821189483699186, 0.32444348255100863),
#   'security_concerns',
#   43,
#   1),
#  (0.48655212,
#   (0.37232066050501017, 0.6007835780051216),
#   'multipolarism',
#   43,
#   1),
#  (0.28854135, (0.23044341969415275, 0.34663927388266), 'eurasianism', 44, 1),
#  (0.3302227,
#   (0.22810082242238633, 0.4323445697094191),
#   'westphalianism',
#   44,
#   1),
#  (0.2621371,
#   (0.19376520379807297, 0.3305089666006392),
#   'security_concerns',
#   44,
#   1),
#  (0.42927012,
#   (0.29822517763970946, 0.5603150593102112),
#   'multipolarism',
#   44,
#   1),
#  (0.27739444, (0.22350903684843185, 0.3312798506523311), 'eurasianism', 45, 1),
#  (0.28214177,
#   (0.14245439289388015, 0.42182915689173384),
#   'westphalianism',
#   45,
#   1),
#  (0.25819787,
#   (0.20508917570114135, 0.3113065719604492),
#   'security_concerns',
#   45,
#   1),
#  (0.48373747,
#   (0.3912043144864562, 0.5762706229525086),
#   'multipolarism',
#   45,
#   1),
#  (0.34205407, (0.2742363913832725, 0.40987174670113913), 'eurasianism', 46, 1),
#  (0.26470667,
#   (0.15661884188654734, 0.37279450058934377),
#   'westphalianism',
#   46,
#   1),
#  (0.24431849,
#   (0.20425304318946697, 0.28438392733055257),
#   'security_concerns',
#   46,
#   1),
#  (0.40997592,
#   (0.29831456346140706, 0.521637268833057),
#   'multipolarism',
#   46,
#   1),
#  (0.25778833,
#   (0.18936838834012892, 0.32620827229295823),
#   'eurasianism',
#   47,
#   1),
#  (0.30223092,
#   (0.1905136747103495, 0.4139481740254598),
#   'westphalianism',
#   47,
#   1),
#  (0.27616084,
#   (0.20297911142199693, 0.34934256101757827),
#   'security_concerns',
#   47,
#   1),
#  (0.4727384,
#   (0.35843558490342114, 0.5870411854975799),
#   'multipolarism',
#   47,
#   1),
#  (0.24467207, (0.18986459925830723, 0.2994795505696499), 'eurasianism', 48, 1),
#  (0.3115763,
#   (0.1954661118073978, 0.42768650183243373),
#   'westphalianism',
#   48,
#   1),
#  (0.22914179,
#   (0.17977061997882068, 0.27851295341023263),
#   'security_concerns',
#   48,
#   1),
#  (0.42243174, (0.3331904731124621, 0.511673001256587), 'multipolarism', 48, 1),
#  (0.250793, (0.14487804629344714, 0.35670797369938123), 'eurasianism', 49, 1),
#  (0.2909288, (0.1764401464069133, 0.405417475262856), 'westphalianism', 49, 1),
#  (0.23235586,
#   (0.11770342830428746, 0.347008297407535),
#   'security_concerns',
#   49,
#   1),
#  (0.44244796,
#   (0.2708831164940849, 0.6140128042593941),
#   'multipolarism',
#   49,
#   1),
#  (0.32781336, (0.2404472340788157, 0.415179480150768), 'eurasianism', 0, 2),
#  (0.333157, (0.23142497628167605, 0.4348890295700696), 'westphalianism', 0, 2),
#  (0.33071098,
#   (0.23412015525673496, 0.42730179937507046),
#   'security_concerns',
#   0,
#   2),
#  (0.5705128, (0.423546939880728, 0.7174786033321626), 'multipolarism', 0, 2),
#  (0.38711062, (0.2700872092393676, 0.504134032234784), 'eurasianism', 1, 2),
#  (0.3799922, (0.2863177415501741, 0.4736666324961516), 'westphalianism', 1, 2),
#  (0.32349557,
#   (0.21960413709802395, 0.4273869965918564),
#   'security_concerns',
#   1,
#   2),
#  (0.54534304, (0.4271493070438729, 0.6635367757960929), 'multipolarism', 1, 2),
#  (0.35790023, (0.2736749417961303, 0.4421255223571595), 'eurasianism', 2, 2),
#  (0.33133236,
#   (0.22736989435432783, 0.43529481712104445),
#   'westphalianism',
#   2,
#   2),
#  (0.3296235,
#   (0.22593081270422913, 0.4333161684397223),
#   'security_concerns',
#   2,
#   2),
#  (0.5425623, (0.36908997245389935, 0.7160346394006538), 'multipolarism', 2, 2),
#  (0.3397229, (0.2769231693415244, 0.4025226338239114), 'eurasianism', 3, 2),
#  (0.3624458,
#   (0.23804003456674358, 0.48685156842626787),
#   'westphalianism',
#   3,
#   2),
#  (0.31256312,
#   (0.22645346820354462, 0.39867277443408966),
#   'security_concerns',
#   3,
#   2),
#  (0.5855198, (0.45979315848416624, 0.7112464228146619), 'multipolarism', 3, 2),
#  (0.35929683, (0.2775126061919415, 0.44108105082481264), 'eurasianism', 4, 2),
#  (0.39675346,
#   (0.30754849912602694, 0.48595842121165006),
#   'westphalianism',
#   4,
#   2),
#  (0.3199523,
#   (0.226547035574913, 0.4133575826883316),
#   'security_concerns',
#   4,
#   2),
#  (0.53867334, (0.42074305783316, 0.6566036247153629), 'multipolarism', 4, 2),
#  (0.36454833, (0.2755703449942287, 0.4535263060830418), 'eurasianism', 5, 2),
#  (0.30987173,
#   (0.21322920975067958, 0.4065142566265787),
#   'westphalianism',
#   5,
#   2),
#  (0.3048534,
#   (0.19110499024391175, 0.41860182881355285),
#   'security_concerns',
#   5,
#   2),
#  (0.56468207,
#   (0.42346382080260525, 0.7059003120785593),
#   'multipolarism',
#   5,
#   2),
#  (0.34525183, (0.27473908903003785, 0.4157645678341284), 'eurasianism', 6, 2),
#  (0.36890817,
#   (0.2816169592100002, 0.45619937456075177),
#   'westphalianism',
#   6,
#   2),
#  (0.289132,
#   (0.2000197909772396, 0.3782442070543766),
#   'security_concerns',
#   6,
#   2),
#  (0.5610232, (0.43575072953653166, 0.6862956218962686), 'multipolarism', 6, 2),
#  (0.33207536, (0.24796104097572846, 0.4161896738985391), 'eurasianism', 7, 2),
#  (0.3857964,
#   (0.28186246707979834, 0.4897303287690481),
#   'westphalianism',
#   7,
#   2),
#  (0.28519428,
#   (0.19032457619905474, 0.38006397932767866),
#   'security_concerns',
#   7,
#   2),
#  (0.56847966, (0.4595693503503146, 0.6773899639959988), 'multipolarism', 7, 2),
#  (0.29251465, (0.19327283415959276, 0.39175646986796464), 'eurasianism', 8, 2),
#  (0.36655483,
#   (0.21780123394808423, 0.515308419047979),
#   'westphalianism',
#   8,
#   2),
#  (0.32759434,
#   (0.23682688352707149, 0.4183617961680579),
#   'security_concerns',
#   8,
#   2),
#  (0.53976834,
#   (0.40556513815817924, 0.6739715382486811),
#   'multipolarism',
#   8,
#   2),
#  (0.305386, (0.21684489539696336, 0.3939271182672822), 'eurasianism', 9, 2),
#  (0.32609773,
#   (0.1971567582216159, 0.4550386954221829),
#   'westphalianism',
#   9,
#   2),
#  (0.32110816,
#   (0.22097576195592578, 0.4212405628502876),
#   'security_concerns',
#   9,
#   2),
#  (0.54731387, (0.4093894127247774, 0.6852383252741849), 'multipolarism', 9, 2),
#  (0.32996702, (0.2357766352475044, 0.424157408636773), 'eurasianism', 10, 2),
#  (0.31537932,
#   (0.19320624583117949, 0.4375523973191501),
#   'westphalianism',
#   10,
#   2),
#  (0.29690254,
#   (0.2012588235826803, 0.39254625110909214),
#   'security_concerns',
#   10,
#   2),
#  (0.52320653,
#   (0.3888856203036922, 0.6575274436992985),
#   'multipolarism',
#   10,
#   2),
#  (0.35840124, (0.2619545511380871, 0.4548479266985218), 'eurasianism', 11, 2),
#  (0.33925304,
#   (0.21473902931799255, 0.46376704701791444),
#   'westphalianism',
#   11,
#   2),
#  (0.33505583,
#   (0.238095895402571, 0.4320157607863938),
#   'security_concerns',
#   11,
#   2),
#  (0.5571087,
#   (0.43710826006662307, 0.6771091404842192),
#   'multipolarism',
#   11,
#   2),
#  (0.34590283, (0.2587285133579076, 0.4330771473667323), 'eurasianism', 12, 2),
#  (0.3426814,
#   (0.23399905623348183, 0.45136375962345177),
#   'westphalianism',
#   12,
#   2),
#  (0.32859117,
#   (0.23448092185230676, 0.4227014140012699),
#   'security_concerns',
#   12,
#   2),
#  (0.57475334,
#   (0.4501059952973262, 0.6994006928206548),
#   'multipolarism',
#   12,
#   2),
#  (0.35965994, (0.2586905711639723, 0.4606293088447252), 'eurasianism', 13, 2),
#  (0.34073913,
#   (0.2378248435370951, 0.44365341841053674),
#   'westphalianism',
#   13,
#   2),
#  (0.33719996,
#   (0.2315969467163086, 0.44280296564102173),
#   'security_concerns',
#   13,
#   2),
#  (0.5496052, (0.40953262317898753, 0.689677758328886), 'multipolarism', 13, 2),
#  (0.33797193, (0.2494350810083329, 0.4265087704626144), 'eurasianism', 14, 2),
#  (0.3511286,
#   (0.2555797928002984, 0.4466774231764167),
#   'westphalianism',
#   14,
#   2),
#  (0.32632542,
#   (0.2168334022164345, 0.4358174309134483),
#   'security_concerns',
#   14,
#   2),
#  (0.5445007, (0.419349554384734, 0.6696518627753002), 'multipolarism', 14, 2),
#  (0.3690231, (0.2618252275921351, 0.4762210012935155), 'eurasianism', 15, 2),
#  (0.3243293,
#   (0.1745579343803288, 0.47410063924714313),
#   'westphalianism',
#   15,
#   2),
#  (0.3313496,
#   (0.23133418316165083, 0.43136503940304644),
#   'security_concerns',
#   15,
#   2),
#  (0.58120304, (0.463919504169352, 0.6984865827523399), 'multipolarism', 15, 2),
#  (0.35434556, (0.27564394784633217, 0.4330471723013729), 'eurasianism', 16, 2),
#  (0.36669898,
#   (0.250408752544259, 0.4829892081185828),
#   'westphalianism',
#   16,
#   2),
#  (0.3369784,
#   (0.22830221973627712, 0.44565459169179295),
#   'security_concerns',
#   16,
#   2),
#  (0.56935894,
#   (0.45009014443681167, 0.688627745348955),
#   'multipolarism',
#   16,
#   2),
#  (0.3087429, (0.2276353950282215, 0.38985042621887933), 'eurasianism', 17, 2),
#  (0.3674043,
#   (0.2617803545049315, 0.4730282692858095),
#   'westphalianism',
#   17,
#   2),
#  (0.3333523,
#   (0.2332808032631874, 0.43342379182577134),
#   'security_concerns',
#   17,
#   2),
#  (0.5538194, (0.4211642612254488, 0.6864745746815336), 'multipolarism', 17, 2),
#  (0.307981, (0.23125416381016586, 0.38470786469325213), 'eurasianism', 18, 2),
#  (0.3235282,
#   (0.20505463999996026, 0.44200176077594916),
#   'westphalianism',
#   18,
#   2),
#  (0.3372998,
#   (0.23033998620623472, 0.44425960171109313),
#   'security_concerns',
#   18,
#   2),
#  (0.5592134,
#   (0.44113426908387865, 0.6772925306902913),
#   'multipolarism',
#   18,
#   2),
#  (0.3477554, (0.23909393426726733, 0.4564168703859004), 'eurasianism', 19, 2),
#  (0.36200783,
#   (0.27591853964965524, 0.4480971134837371),
#   'westphalianism',
#   19,
#   2),
#  (0.3304848,
#   (0.22702715396881104, 0.43394246101379397),
#   'security_concerns',
#   19,
#   2),
#  (0.5518054, (0.4261267168974826, 0.6774840371155789), 'multipolarism', 19, 2),
#  (0.36446497, (0.27442369753836504, 0.4545062393474687), 'eurasianism', 20, 2),
#  (0.37289104,
#   (0.2644444967939541, 0.4813375805185154),
#   'westphalianism',
#   20,
#   2),
#  (0.27346385,
#   (0.15613607175453018, 0.3907916187514513),
#   'security_concerns',
#   20,
#   2),
#  (0.56826776,
#   (0.4347503609392942, 0.7017851643826662),
#   'multipolarism',
#   20,
#   2),
#  (0.3511226, (0.24036792686428826, 0.4618772489741822), 'eurasianism', 21, 2),
#  (0.2921339,
#   (0.2051483529564171, 0.3791194421294899),
#   'westphalianism',
#   21,
#   2),
#  (0.30895132,
#   (0.22802659162088101, 0.3898760449071341),
#   'security_concerns',
#   21,
#   2),
#  (0.5413994,
#   (0.41891434947660805, 0.6638844891388095),
#   'multipolarism',
#   21,
#   2),
#  (0.35434213,
#   (0.25090092289923327, 0.45778334271432264),
#   'eurasianism',
#   22,
#   2),
#  (0.3346516,
#   (0.24498764287725938, 0.42431553590997206),
#   'westphalianism',
#   22,
#   2),
#  (0.29665738,
#   (0.2005880943997666, 0.3927266724840835),
#   'security_concerns',
#   22,
#   2),
#  (0.5751373,
#   (0.45784612300746125, 0.6924285113538059),
#   'multipolarism',
#   22,
#   2),
#  (0.35939863, (0.266393064117894, 0.4524042023654129), 'eurasianism', 23, 2),
#  (0.39359453,
#   (0.27921683971519673, 0.507972226694868),
#   'westphalianism',
#   23,
#   2),
#  (0.34619707,
#   (0.2272006168961525, 0.4651935204863548),
#   'security_concerns',
#   23,
#   2),
#  (0.5744932, (0.47490336152744445, 0.674083097250937), 'multipolarism', 23, 2),
#  (0.35778, (0.2415618057009521, 0.4739982133153138), 'eurasianism', 24, 2),
#  (0.39593863,
#   (0.28841711493216615, 0.5034601548127069),
#   'westphalianism',
#   24,
#   2),
#  (0.30991533,
#   (0.23226990308488976, 0.38756076488767494),
#   'security_concerns',
#   24,
#   2),
#  (0.5596056,
#   (0.45199966369615635, 0.6672115332032578),
#   'multipolarism',
#   24,
#   2),
#  (0.36076188, (0.2677319104269256, 0.45379185132234195), 'eurasianism', 25, 2),
#  (0.36800036,
#   (0.24539120694358418, 0.4906095097426646),
#   'westphalianism',
#   25,
#   2),
#  (0.29447222,
#   (0.1947005748748779, 0.394243860244751),
#   'security_concerns',
#   25,
#   2),
#  (0.56375086,
#   (0.43439024880936183, 0.6931114773411509),
#   'multipolarism',
#   25,
#   2),
#  (0.3317544, (0.27616316949770775, 0.38734560335232887), 'eurasianism', 26, 2),
#  (0.31582016,
#   (0.2053496669229185, 0.42629064813292866),
#   'westphalianism',
#   26,
#   2),
#  (0.32438004,
#   (0.24280884116888046, 0.40595123916864395),
#   'security_concerns',
#   26,
#   2),
#  (0.5765953,
#   (0.44866940585807213, 0.7045212069348966),
#   'multipolarism',
#   26,
#   2),
#  (0.34639025,
#   (0.27124948948544925, 0.42153100520449216),
#   'eurasianism',
#   27,
#   2),
#  (0.3958209,
#   (0.2808643270365808, 0.5107774447567847),
#   'westphalianism',
#   27,
#   2),
#  (0.3100504,
#   (0.22109363675117494, 0.39900715947151183),
#   'security_concerns',
#   27,
#   2),
#  (0.55854553,
#   (0.42166944080408103, 0.6954216188806723),
#   'multipolarism',
#   27,
#   2),
#  (0.3153164, (0.24737874640715485, 0.3832540713380539), 'eurasianism', 28, 2),
#  (0.3742337,
#   (0.2734108399417998, 0.47505654582709056),
#   'westphalianism',
#   28,
#   2),
#  (0.30333585,
#   (0.21615837368216784, 0.3905133172586891),
#   'security_concerns',
#   28,
#   2),
#  (0.54728186,
#   (0.4384600304175468, 0.6561036921929269),
#   'multipolarism',
#   28,
#   2),
#  (0.32382512, (0.232715357345739, 0.41493488450606764), 'eurasianism', 29, 2),
#  (0.38328284,
#   (0.25945772682256146, 0.5071079536812837),
#   'westphalianism',
#   29,
#   2),
#  (0.3296024,
#   (0.22504903599619866, 0.4341557450592518),
#   'security_concerns',
#   29,
#   2),
#  (0.56771785,
#   (0.4325488610883782, 0.7028868393281867),
#   'multipolarism',
#   29,
#   2),
#  (0.360958, (0.2598792325565009, 0.4620367873600335), 'eurasianism', 30, 2),
#  (0.34395555,
#   (0.2523737997266274, 0.4355372935083885),
#   'westphalianism',
#   30,
#   2),
#  (0.28335142,
#   (0.185307569205914, 0.38139527350648833),
#   'security_concerns',
#   30,
#   2),
#  (0.561445, (0.4382439384280268, 0.6846460571469244), 'multipolarism', 30, 2),
#  (0.34850198, (0.2687248517100785, 0.42827910889935755), 'eurasianism', 31, 2),
#  (0.38947722,
#   (0.29550025061070073, 0.48345419570506465),
#   'westphalianism',
#   31,
#   2),
#  (0.28962147,
#   (0.19076011912326107, 0.38848282559414615),
#   'security_concerns',
#   31,
#   2),
#  (0.5746437,
#   (0.45308454583401986, 0.6962027971911876),
#   'multipolarism',
#   31,
#   2),
#  (0.3477325, (0.25980931745937685, 0.43565571082660337), 'eurasianism', 32, 2),
#  (0.35546783,
#   (0.2452407588477329, 0.4656948934082791),
#   'westphalianism',
#   32,
#   2),
#  (0.2964434,
#   (0.21514582568480067, 0.3777409798495621),
#   'security_concerns',
#   32,
#   2),
#  (0.5579646,
#   (0.43342063158931005, 0.6825086143594815),
#   'multipolarism',
#   32,
#   2),
#  (0.3359523, (0.25318687989502886, 0.4187177436134245), 'eurasianism', 33, 2),
#  (0.3853135,
#   (0.2945848165499563, 0.4760422052395945),
#   'westphalianism',
#   33,
#   2),
#  (0.32215565,
#   (0.22201381251215935, 0.42229749634861946),
#   'security_concerns',
#   33,
#   2),
#  (0.5398436, (0.4111197216272787, 0.6685675161122843), 'multipolarism', 33, 2),
#  (0.34308484,
#   (0.24418266143798673, 0.44198702249527133),
#   'eurasianism',
#   34,
#   2),
#  (0.38190225,
#   (0.25834141661547705, 0.5054630787191482),
#   'westphalianism',
#   34,
#   2),
#  (0.35283387,
#   (0.2501060448586941, 0.4555616892874241),
#   'security_concerns',
#   34,
#   2),
#  (0.5631111,
#   (0.44879706619623805, 0.6774251866495261),
#   'multipolarism',
#   34,
#   2),
#  (0.29953504,
#   (0.24539753280873383, 0.35367253936533843),
#   'eurasianism',
#   35,
#   2),
#  (0.32523584,
#   (0.21309210382155727, 0.43737958349533723),
#   'westphalianism',
#   35,
#   2),
#  (0.30106142,
#   (0.2259391725063324, 0.37618367075920106),
#   'security_concerns',
#   35,
#   2),
#  (0.5117076, (0.3819759969781642, 0.6414392108846898), 'multipolarism', 35, 2),
#  (0.35816106,
#   (0.27240422978139106, 0.44391789422297295),
#   'eurasianism',
#   36,
#   2),
#  (0.36821157,
#   (0.27438944970644746, 0.4620336850973245),
#   'westphalianism',
#   36,
#   2),
#  (0.31471035,
#   (0.23496043495833874, 0.39446026273071766),
#   'security_concerns',
#   36,
#   2),
# ...
#  (0.41763073,
#   (0.32385550141334535, 0.5114059627056122),
#   'westphalianism',
#   4,
#   3),
#  (0.34995767,
#   (0.2573622867316717, 0.44255306275181827),
#   'security_concerns',
#   4,
#   3),
#  (0.48531356, (0.3731438706000955, 0.5974832584778158), 'multipolarism', 4, 3),
#  (0.3559808, (0.24379139529187988, 0.4681702317146509), 'eurasianism', 5, 3),
#  (0.38068283,
#   (0.2660501167178154, 0.49531553536653516),
#   'westphalianism',
#   5,
#   3),
#  (0.33811995,
#   (0.24894436905637513, 0.4272955386851715),
#   'security_concerns',
#   5,
#   3),
#  (0.4767104, (0.35386995667798277, 0.5995508611740374), 'multipolarism', 5, 3),
#  (0.34907594, (0.2270742858716573, 0.471077600591508), 'eurasianism', 6, 3),
#  (0.41961825,
#   (0.31051128208637235, 0.528725215792656),
#   'westphalianism',
#   6,
#   3),
#  (0.35075423,
#   (0.25254653115227516, 0.4489619312767715),
#   'security_concerns',
#   6,
#   3),
#  (0.49476576, (0.3743837932917967, 0.6151477237370119), 'multipolarism', 6, 3),
#  (0.3788069, (0.2590458039291341, 0.4985679741851847), 'eurasianism', 7, 3),
#  (0.40256426,
#   (0.30217754989862444, 0.5029509648680687),
#   'westphalianism',
#   7,
#   3),
#  (0.34738243,
#   (0.2514642738979402, 0.44330057862586353),
#   'security_concerns',
#   7,
#   3),
#  (0.44591117, (0.3355332807862994, 0.5562890573179486), 'multipolarism', 7, 3),
#  (0.37885904, (0.2694069544560178, 0.48831113178665797), 'eurasianism', 8, 3),
#  (0.37532726,
#   (0.23800653144717215, 0.5126479871571064),
#   'westphalianism',
#   8,
#   3),
#  (0.3627047,
#   (0.2714379429667262, 0.4539714455754491),
#   'security_concerns',
#   8,
#   3),
#  (0.49640483,
#   (0.37735581024835074, 0.6154538430338148),
#   'multipolarism',
#   8,
#   3),
#  (0.34369615, (0.2050147999980955, 0.4823774944087954), 'eurasianism', 9, 3),
#  (0.39868236,
#   (0.2988236382603645, 0.4985410735011101),
#   'westphalianism',
#   9,
#   3),
#  (0.35596362,
#   (0.24694034457997827, 0.4649868905465171),
#   'security_concerns',
#   9,
#   3),
#  (0.47972408,
#   (0.39521390558453734, 0.5642342531564599),
#   'multipolarism',
#   9,
#   3),
#  (0.37074444, (0.27572230400897985, 0.4657665699496078), 'eurasianism', 10, 3),
#  (0.38269296,
#   (0.2760943740606308, 0.4892915517091751),
#   'westphalianism',
#   10,
#   3),
#  (0.33953613,
#   (0.23560415413907654, 0.4434681067175519),
#   'security_concerns',
#   10,
#   3),
#  (0.48892826,
#   (0.38344998539798625, 0.5944065314400875),
#   'multipolarism',
#   10,
#   3),
#  (0.36137542,
#   (0.24904056404649139, 0.47371027852476716),
#   'eurasianism',
#   11,
#   3),
#  (0.40925837,
#   (0.2993933916091919, 0.5191233396530152),
#   'westphalianism',
#   11,
#   3),
#  (0.33668345,
#   (0.24029187980676803, 0.43307502445196),
#   'security_concerns',
#   11,
#   3),
#  (0.47727516,
#   (0.37140728169678805, 0.5831430441737259),
#   'multipolarism',
#   11,
#   3),
#  (0.38704345, (0.2821798320874965, 0.4919070605173314), 'eurasianism', 12, 3),
#  (0.38018432,
#   (0.26549454480409623, 0.4948741003870964),
#   'westphalianism',
#   12,
#   3),
#  (0.36078936,
#   (0.2797623125576896, 0.4418164046740609),
#   'security_concerns',
#   12,
#   3),
#  (0.4952177, (0.3944439171257143, 0.5959915043411131), 'multipolarism', 12, 3),
#  (0.3784575, (0.2581393448304045, 0.49877562842856765), 'eurasianism', 13, 3),
#  (0.40018192,
#   (0.29761298224329946, 0.5027508564293385),
#   'westphalianism',
#   13,
#   3),
#  (0.3211503,
#   (0.22032447214683126, 0.4219761336270945),
#   'security_concerns',
#   13,
#   3),
#  (0.48826605, (0.3564983222141656, 0.620033779416999), 'multipolarism', 13, 3),
#  (0.31916228,
#   (0.18104860358658753, 0.45727595514830627),
#   'eurasianism',
#   14,
#   3),
#  (0.3988571,
#   (0.2987824060022831, 0.4989317677915096),
#   'westphalianism',
#   14,
#   3),
#  (0.32560366,
#   (0.2485209030639512, 0.4026864247787612),
#   'security_concerns',
#   14,
#   3),
#  (0.4295416,
#   (0.33013301995983374, 0.5289501556993459),
#   'multipolarism',
#   14,
#   3),
#  (0.4039201, (0.30107015617534016, 0.5067700719054093), 'eurasianism', 15, 3),
#  (0.43059203,
#   (0.32706876546144487, 0.5341152951121331),
#   'westphalianism',
#   15,
#   3),
#  (0.3524494,
#   (0.25379190444103716, 0.4511068701828337),
#   'security_concerns',
#   15,
#   3),
#  (0.5052591, (0.4141487839116228, 0.5963694093333113), 'multipolarism', 15, 3),
#  (0.40937933, (0.3211949755139887, 0.49756369100136166), 'eurasianism', 16, 3),
#  (0.40551713,
#   (0.3113597877323627, 0.49967447444796564),
#   'westphalianism',
#   16,
#   3),
#  (0.35037145,
#   (0.2557884757974869, 0.4449544245740646),
#   'security_concerns',
#   16,
#   3),
#  (0.496654, (0.38645183416332174, 0.6068561735538108), 'multipolarism', 16, 3),
#  (0.4013557, (0.2978722346580116, 0.5048391925537499), 'eurasianism', 17, 3),
#  (0.40187103,
#   (0.2859939098358154, 0.5177481412887573),
#   'westphalianism',
#   17,
#   3),
#  (0.3482301,
#   (0.25190566121649927, 0.4445545262186509),
#   'security_concerns',
#   17,
#   3),
#  (0.4903667,
#   (0.38372260887422205, 0.5970107857485807),
#   'multipolarism',
#   17,
#   3),
#  (0.40648732, (0.3107369917108028, 0.5022376400755436), 'eurasianism', 18, 3),
#  (0.4388688,
#   (0.3310986615717411, 0.5466389201581479),
#   'westphalianism',
#   18,
#   3),
#  (0.3308032,
#   (0.23661995506850822, 0.4249864163342323),
#   'security_concerns',
#   18,
#   3),
#  (0.48035404,
#   (0.3551032633778918, 0.6056048183443677),
#   'multipolarism',
#   18,
#   3),
#  (0.33350056,
#   (0.25300902568671557, 0.41399210251000074),
#   'eurasianism',
#   19,
#   3),
#  (0.42271116,
#   (0.31865841039205495, 0.5267639171264081),
#   'westphalianism',
#   19,
#   3),
#  (0.3248987,
#   (0.23933200556642614, 0.4104653744041244),
#   'security_concerns',
#   19,
#   3),
#  (0.4427238, (0.3287021954810254, 0.5567454258644946), 'multipolarism', 19, 3),
#  (0.3432137, (0.24964349462478927, 0.43678391979247755), 'eurasianism', 20, 3),
#  (0.34971797,
#   (0.22462028190493585, 0.47481566742062564),
#   'westphalianism',
#   20,
#   3),
#  (0.3544887,
#   (0.25542313719742454, 0.45355426405913674),
#   'security_concerns',
#   20,
#   3),
#  (0.46722746,
#   (0.3630643978417203, 0.5713905200659946),
#   'multipolarism',
#   20,
#   3),
#  (0.36812758, (0.2540319354673932, 0.4822232334474017), 'eurasianism', 21, 3),
#  (0.39810073,
#   (0.2799267865717411, 0.516274680942297),
#   'westphalianism',
#   21,
#   3),
#  (0.34647518,
#   (0.25202846634867987, 0.4409219015788714),
#   'security_concerns',
#   21,
#   3),
#  (0.4989483, (0.3851082332563146, 0.6127883784342066), 'multipolarism', 21, 3),
#  (0.3766726, (0.27323340967213955, 0.4801117818065897), 'eurasianism', 22, 3),
#  (0.40539467,
#   (0.29852121248841285, 0.5122681342065334),
#   'westphalianism',
#   22,
#   3),
#  (0.30749515,
#   (0.20399634176571024, 0.41099395221393453),
#   'security_concerns',
#   22,
#   3),
#  (0.4879829, (0.38332372023434, 0.5926420776668135), 'multipolarism', 22, 3),
#  (0.35322222, (0.2568052067818613, 0.449639235490325), 'eurasianism', 23, 3),
#  (0.3888551,
#   (0.29706746339797974, 0.48064273595809937),
#   'westphalianism',
#   23,
#   3),
#  (0.31475866,
#   (0.22488847341743023, 0.40462884340080707),
#   'security_concerns',
#   23,
#   3),
#  (0.46941406,
#   (0.3833499625459974, 0.5554781481488879),
#   'multipolarism',
#   23,
#   3),
#  (0.3878091, (0.2683646194236778, 0.5072535761100747), 'eurasianism', 24, 3),
#  (0.44420487,
#   (0.3350940547883511, 0.5533156789839268),
#   'westphalianism',
#   24,
#   3),
#  (0.36401388,
#   (0.26069447176910265, 0.4673332892134108),
#   'security_concerns',
#   24,
#   3),
#  (0.47664553,
#   (0.38266349373812114, 0.5706275648022231),
#   'multipolarism',
#   24,
#   3),
#  (0.40452966, (0.31621661991294636, 0.4928427019673942), 'eurasianism', 25, 3),
#  (0.40999037,
#   (0.30628583654761316, 0.5136949039995671),
#   'westphalianism',
#   25,
#   3),
#  (0.36905032,
#   (0.2726329949643505, 0.46546765296198006),
#   'security_concerns',
#   25,
#   3),
#  (0.5027016,
#   (0.37789484109162064, 0.6275083199572685),
#   'multipolarism',
#   25,
#   3),
#  (0.38473257, (0.2904055089036004, 0.4790596395453437), 'eurasianism', 26, 3),
#  (0.39201483,
#   (0.27761638164520264, 0.5064132809638977),
#   'westphalianism',
#   26,
#   3),
#  (0.3201888,
#   (0.2140705269891378, 0.42630705413039954),
#   'security_concerns',
#   26,
#   3),
#  (0.46912757,
#   (0.36964250484215705, 0.5686126264025024),
#   'multipolarism',
#   26,
#   3),
#  (0.40262476, (0.28504969431093247, 0.5201998178846546), 'eurasianism', 27, 3),
#  (0.4245432,
#   (0.32002821266651155, 0.5290581911802292),
#   'westphalianism',
#   27,
#   3),
#  (0.3690428,
#   (0.2753232467829364, 0.46276238077291076),
#   'security_concerns',
#   27,
#   3),
#  (0.48775098, (0.3686519240974675, 0.606850030458044), 'multipolarism', 27, 3),
#  (0.44593713, (0.33367106050173384, 0.5582031932481135), 'eurasianism', 28, 3),
#  (0.41134152,
#   (0.30107046887278555, 0.5216125674545765),
#   'westphalianism',
#   28,
#   3),
#  (0.3349755,
#   (0.2478871919382183, 0.4220638297330769),
#   'security_concerns',
#   28,
#   3),
#  (0.49261543,
#   (0.3776767132068606, 0.6075541498874693),
#   'multipolarism',
#   28,
#   3),
#  (0.3799377, (0.2692118217705201, 0.49066359498515616), 'eurasianism', 29, 3),
#  (0.4109848,
#   (0.3214640513062477, 0.5005055770277977),
#   'westphalianism',
#   29,
#   3),
#  (0.33705717,
#   (0.24317858537628353, 0.43093576112792786),
#   'security_concerns',
#   29,
#   3),
#  (0.5171137,
#   (0.43510119428051364, 0.5991261769353067),
#   'multipolarism',
#   29,
#   3),
#  (0.41088986, (0.2870605551801396, 0.5347191727556514), 'eurasianism', 30, 3),
#  (0.4155773,
#   (0.32698741778731344, 0.5041671670973301),
#   'westphalianism',
#   30,
#   3),
#  (0.33911282,
#   (0.2371147605487346, 0.4411108759335042),
#   'security_concerns',
#   30,
#   3),
#  (0.50436294,
#   (0.40590775263309886, 0.6028181289434392),
#   'multipolarism',
#   30,
#   3),
#  (0.38086402, (0.2933761668497582, 0.46835188147482676), 'eurasianism', 31, 3),
#  (0.42723, (0.32234879285097123, 0.5321112081408501), 'westphalianism', 31, 3),
#  (0.32223064,
#   (0.22920559772450388, 0.4152556764225298),
#   'security_concerns',
#   31,
#   3),
#  (0.5191827, (0.4128054820932392, 0.6255598819814678), 'multipolarism', 31, 3),
#  (0.39990112,
#   (0.30006969140692974, 0.49973255230263447),
#   'eurasianism',
#   32,
#   3),
#  (0.41775095,
#   (0.3329341560602188, 0.5025677531957626),
#   'westphalianism',
#   32,
#   3),
#  (0.37242138,
#   (0.27175449340807933, 0.47308827430737477),
#   'security_concerns',
#   32,
#   3),
#  (0.516955, (0.37145254496718816, 0.662457491119848), 'multipolarism', 32, 3),
#  (0.36540788, (0.2715174940461787, 0.4592982741957036), 'eurasianism', 33, 3),
#  (0.42827624,
#   (0.33075295239686964, 0.5257995292544365),
#   'westphalianism',
#   33,
#   3),
#  (0.34060863,
#   (0.2547073709101433, 0.4265098822980171),
#   'security_concerns',
#   33,
#   3),
#  (0.50070655,
#   (0.3929889255253167, 0.6084241813930182),
#   'multipolarism',
#   33,
#   3),
#  (0.40547988, (0.27230325598285143, 0.5386565003915077), 'eurasianism', 34, 3),
#  (0.42476118,
#   (0.32188674062490463, 0.5276356115937233),
#   'westphalianism',
#   34,
#   3),
#  (0.36132243,
#   (0.27526918409267237, 0.44737568142017553),
#   'security_concerns',
#   34,
#   3),
#  (0.50581986,
#   (0.4069961583486488, 0.6046435558923791),
#   'multipolarism',
#   34,
#   3),
#  (0.36486804, (0.2354250089356661, 0.4943110807707548), 'eurasianism', 35, 3),
#  (0.41812074,
#   (0.3117653913795948, 0.5244760923087597),
#   'westphalianism',
#   35,
#   3),
#  (0.370707,
#   (0.2610495680679862, 0.4803644424567636),
#   'security_concerns',
#   35,
#   3),
#  (0.502762, (0.3973302579817872, 0.6081937812867064), 'multipolarism', 35, 3),
#  (0.40656346, (0.31380636921552185, 0.4993205524382257), 'eurasianism', 36, 3),
#  (0.3812691,
#   (0.27046072110533714, 0.4920774735510349),
#   'westphalianism',
#   36,
#   3),
#  (0.3580451,
#   (0.2566663571135812, 0.45942384521796176),
#   'security_concerns',
#   36,
#   3),
#  (0.47178245,
#   (0.36834776271194325, 0.5752171291032423),
#   'multipolarism',
#   36,
#   3),
#  (0.35068285, (0.23560547985356756, 0.465760229451242), 'eurasianism', 37, 3),
#  (0.42152187,
#   (0.3334489747881889, 0.5095947697758675),
#   'westphalianism',
#   37,
#   3),
#  (0.34775072,
#   (0.2583024449764774, 0.43719900174746057),
#   'security_concerns',
#   37,
#   3),
#  (0.47642544,
#   (0.37261981080065937, 0.5802310674380186),
#   'multipolarism',
#   37,
#   3),
#  (0.38479322, (0.2762976735302484, 0.4932887703708136), 'eurasianism', 38, 3),
#  (0.38108733,
#   (0.27139547243714335, 0.4907791934907436),
#   'westphalianism',
#   38,
#   3),
#  (0.36853206,
#   (0.26000592669062106, 0.47705819646306546),
#   'security_concerns',
#   38,
#   3),
#  (0.4723039,
#   (0.35740624279435196, 0.5872015514904686),
#   'multipolarism',
#   38,
#   3),
#  (0.37912333, (0.2695011156969377, 0.48874554453560626), 'eurasianism', 39, 3),
#  (0.4070169,
#   (0.31414236053824424, 0.4998914457857609),
#   'westphalianism',
#   39,
#   3),
#  (0.37536234,
#   (0.2833584415075804, 0.4673662317635988),
#   'security_concerns',
#   39,
#   3),
#  (0.5004085, (0.3920912029769129, 0.6087257382843786), 'multipolarism', 39, 3),
#  (0.41544634, (0.2951291622527621, 0.5357635198227384), 'eurasianism', 40, 3),
#  (0.45449173,
#   (0.35817692915570265, 0.5508065398536968),
#   'westphalianism',
#   40,
#   3),
#  (0.35977077,
#   (0.26094858141078603, 0.45859296827183116),
#   'security_concerns',
#   40,
#   3),
#  (0.5144285, (0.4091734010306699, 0.6196835916908877), 'multipolarism', 40, 3),
#  (0.3636222, (0.24008097532071576, 0.4871634018155147), 'eurasianism', 41, 3),
#  (0.4117594,
#   (0.3232820123434067, 0.5002368003129959),
#   'westphalianism',
#   41,
#   3),
#  (0.33796602,
#   (0.23000343500150003, 0.44592861474978174),
#   'security_concerns',
#   41,
#   3),
#  (0.4734665,
#   (0.33841462619288143, 0.6085183452846271),
#   'multipolarism',
#   41,
#   3),
#  (0.35812855, (0.27760368269002567, 0.4386534126468884), 'eurasianism', 42, 3),
#  (0.35867882,
#   (0.25687528774142265, 0.4604823477566242),
#   'westphalianism',
#   42,
#   3),
#  (0.3412705,
#   (0.25133920166800877, 0.4312018110959683),
#   'security_concerns',
#   42,
#   3),
#  (0.5177702, (0.3916977074806051, 0.6438426348503274), 'multipolarism', 42, 3),
#  (0.4018756, (0.27823980116408065, 0.5255113694711427), 'eurasianism', 43, 3),
#  (0.42705417,
#   (0.3328197054564953, 0.5212886281311512),
#   'westphalianism',
#   43,
#   3),
#  (0.34786904,
#   (0.24574869309067, 0.4499893840730263),
#   'security_concerns',
#   43,
#   3),
#  (0.49250117,
#   (0.37352662615321214, 0.6114757127330489),
#   'multipolarism',
#   43,
#   3),
#  (0.3506402, (0.2556414625495149, 0.44563895250862107), 'eurasianism', 44, 3),
#  (0.39481542,
#   (0.2849101580679417, 0.5047206722199917),
#   'westphalianism',
#   44,
#   3),
#  (0.3456396,
#   (0.23207806092692435, 0.4592011119704145),
#   'security_concerns',
#   44,
#   3),
#  (0.50465983,
#   (0.3774713290699654, 0.6318483339778251),
#   'multipolarism',
#   44,
#   3),
#  (0.3434815, (0.27003373388696006, 0.41692928786825845), 'eurasianism', 45, 3),
#  (0.41700003,
#   (0.34294236190617083, 0.4910576891154051),
#   'westphalianism',
#   45,
#   3),
#  (0.34393153,
#   (0.24787472594163057, 0.43998832594969634),
#   'security_concerns',
#   45,
#   3),
#  (0.4911915, (0.3557352612292506, 0.6266477515423559), 'multipolarism', 45, 3),
#  (0.4063767, (0.280426813920599, 0.5323265654243412), 'eurasianism', 46, 3),
#  (0.43626046,
#   (0.33814838603138925, 0.5343725375831128),
#   'westphalianism',
#   46,
#   3),
#  (0.3620189,
#   (0.272957460271486, 0.4510803657897628),
#   'security_concerns',
#   46,
#   3),
#  (0.50618225,
#   (0.40102482641337367, 0.6113396803081229),
#   'multipolarism',
#   46,
#   3),
#  (0.36662352, (0.2648439290458532, 0.4684031126564173), 'eurasianism', 47, 3),
#  (0.40048057,
#   (0.29443306997418406, 0.5065280668437481),
#   'westphalianism',
#   47,
#   3),
#  (0.3230329,
#   (0.21826773421458806, 0.42779803736515437),
#   'security_concerns',
#   47,
#   3),
#  (0.49071407,
#   (0.3794750898491109, 0.6019530565131939),
#   'multipolarism',
#   47,
#   3),
#  (0.387187, (0.28402761639664004, 0.4903463917820709), 'eurasianism', 48, 3),
#  (0.4156028,
#   (0.3087721146643162, 0.5224334917962551),
#   'westphalianism',
#   48,
#   3),
#  (0.34848493,
#   (0.2499033424390661, 0.4470665243135584),
#   'security_concerns',
#   48,
#   3),
#  (0.49554178,
#   (0.38802712293512664, 0.6030564394389883),
#   'multipolarism',
#   48,
#   3),
#  (0.3899253, (0.28693876155927645, 0.49291184059068693), 'eurasianism', 49, 3),
#  (0.38838547,
#   (0.290735874325037, 0.4860350750386715),
#   'westphalianism',
#   49,
#   3),
#  (0.3272829,
#   (0.23298928545354503, 0.42157652570368154),
#   'security_concerns',
#   49,
#   3),
#  (0.47826168, (0.344517963535146, 0.6120053952867228), 'multipolarism', 49, 3)]

# %%
### extract the average of mean_wCI for each concept
concept_averages = {}

for concept_stats in means_wCI:
    concept_mean = concept_stats[0]
    concept = concept_stats[2]
    era = concept_stats[4]
    print("Era", era, concept, ":", era_mean)
# Out:
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 0 eurasianism : 0.4273262470960617
# Era 0 westphalianism : 0.4273262470960617
# Era 0 security_concerns : 0.4273262470960617
# Era 0 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 1 eurasianism : 0.4273262470960617
# Era 1 westphalianism : 0.4273262470960617
# Era 1 security_concerns : 0.4273262470960617
# Era 1 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 2 eurasianism : 0.4273262470960617
# Era 2 westphalianism : 0.4273262470960617
# Era 2 security_concerns : 0.4273262470960617
# Era 2 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617
# Era 3 eurasianism : 0.4273262470960617
# Era 3 westphalianism : 0.4273262470960617
# Era 3 security_concerns : 0.4273262470960617
# Era 3 multipolarism : 0.4273262470960617

# %%
# define the file path
file_path = "models/means_wCI_entire_corpus_50_bootstrap.pkl"

# save the object to file
with open(file_path, 'wb') as f:
    pickle.dump(means_wCI, f)

# %% [markdown]
# ##### plot each concept cos sim evolution over time

# %%
# load the object from file
with open("models/means_wCI_entire_corpus_50_bootstrap.pkl", 'rb') as f:
    means_wCI = pickle.load(f)

# %% [markdown]
# ##### eurasianism

# %%
eurasianism_means = [era[0][0] for era in means_wCI]

# %%
eurasianism_means
# Out:
# [0.32875624, 0.28465933, 0.32781336, 0.38009515]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(eurasianism_means, marker="o", markersize=10, linewidth=2)
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'eurasianism' - 'word order' Cosine similarity")
plt.ylim(0.0, 1.0)
plt.savefig("figures/similarity_scores_eurasianism_50.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### westphalianism

# %%
westphalianism_means = [era[1][0] for era in means_wCI]

# %%
westphalianism_means
# Out:
# [0.2807462, 0.3117265, 0.333157, 0.4234438]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(westphalianism_means, marker="o", markersize=10, linewidth=2,color='purple')
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'westphalianism' - 'word order' Cosine similarity")
plt.ylim(0.0, 1.0)
plt.savefig("figures/similarity_scores_westphalianism_50.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### security_concerns

# %%
sec_con_means = [era[2][0] for era in means_wCI]

# %%
sec_con_means
# Out:
# [0.22874323, 0.25686282, 0.33071098, 0.3629411]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(sec_con_means, marker="o", markersize=10, linewidth=2,color='green')
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'security concerns' - 'word order' Cosine similarity")
plt.ylim(0.0, 1.0)
plt.savefig("figures/similarity_scores_security_concerns_50.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### multipolarty

# %%
multipolarity_means = [era[3][0] for era in means_wCI]

# %%
multipolarity_means
# Out:
# [0.30917504, 0.46035266, 0.5705128, 0.46524104]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(multipolarity_means, marker="o", markersize=10, linewidth=2,color='red')
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'multipolarity' - 'word order' Cosine similarity")
plt.ylim(0.0, 1.0)
plt.savefig("figures/similarity_scores_multipolarity_50.png", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]

# Define data for different categories
eurasianism_means = [0.32875624, 0.28465933, 0.32781336, 0.38009515]
westphalianism_means = [0.2807462, 0.3117265, 0.333157, 0.4234438]
sec_con_means = [0.22874323, 0.25686282, 0.33071098, 0.3629411]
multipolarity_means = [0.30917504, 0.46035266, 0.5705128, 0.46524104]

# Plot cosine similarity over time
plt.plot(sec_con_means, marker="o", markersize=10, linewidth=2, color='green', label='security concerns')
plt.plot(westphalianism_means, marker="o", markersize=10, linewidth=2, color='blue', label='westphalianism')
plt.plot(eurasianism_means, marker="o", markersize=10, linewidth=2, color='red', label='eurasianism')
plt.plot(multipolarity_means, marker="o", markersize=10, linewidth=2, color='purple', label='multipolarity')

plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("Cosine Similarity Comparison")
plt.legend()  # Add legend based on labels provided in each plot

plt.ylim(0.0, 1.0)
plt.savefig("figures/similarity_scores_comparison.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Filter according to Speaker AND Time

# %%
# read each era from MAc
t1 = pd.read_pickle('/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/corpus_president_of_russia/t1.pkl')
t2 = pd.read_pickle('/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/corpus_president_of_russia/t2.pkl')
t3 = pd.read_pickle('/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/corpus_president_of_russia/t3.pkl')
t4 = pd.read_pickle('/Users/adrianacuppuleri/Desktop/GITHUB ADRIANA/russia_lio_contestation/corpus_president_of_russia/t4.pkl')

# %%
# read each era from office
#t1 = pd.read_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t1.pkl')
#t2 = pd.read_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t2.pkl')
#t3 = pd.read_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t3.pkl')
#t4 = pd.read_pickle('/Users/adrianacupp/Desktop/GitHub/russia_lio_contestation/corpus_president_of_russia/t4.pkl')

# %%
dfs = [t1, t2, t3, t4]  # Create a list of the DataFrames

# Define the speakers for filtering
president_speakers = ['В.Путин', 'Д.Медведев']
lavrov_speaker = 'С.Лавров'

filtered_dfs = []  # Create an empty list to store the filtered DataFrames

# Iterate over the list of DataFrames
for df in dfs:
    df_president = df[df['speaker'].isin(president_speakers)]
    df_lavrov = df[df['speaker'] == lavrov_speaker]
    
    filtered_dfs.extend([df_president, df_lavrov])  # Add the filtered DataFrames to the list

# Access the filtered DataFrames
df_president_1, df_lavrov_1, df_president_2, df_lavrov_2, df_president_3, df_lavrov_3, df_president_4, df_lavrov_4 = filtered_dfs

# %%
##### president of russia ###
dfs = [t1, t2, t3, t4]  # Create a list of the DataFrames

# Define the speakers for filtering
president_speakers = ['В.Путин', 'Д.Медведев']

filtered_dfs = []  # Create an empty list to store the filtered DataFrames

# Iterate over the list of DataFrames
for df in dfs:
    df_president = df[df['speaker'].isin(president_speakers)]
    filtered_dfs.append(df_president)  # Add the filtered DataFrame to the list

# Concatenate the filtered DataFrames into a single DataFrame
df_president = pd.concat(filtered_dfs, ignore_index=True)

# %%
df_president.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1442 entries, 0 to 1441
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1442 non-null   object
#  1   url            1442 non-null   object
#  2   title          1442 non-null   object
#  3   speaker        1442 non-null   object
#  4   text           1442 non-null   object
#  5   text_clean     1442 non-null   object
#  6   word_count     1442 non-null   int64
#  7   lemma          1442 non-null   object
#  8   phrased_lemma  1442 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 101.5+ KB

# %%
#### load the concepts 

eurasianism = ['евразия',
               'русский_мир', 
               'цивилизация', 
               'доминирование_запад', 
               'правило_запад',
               'запад', 
               'гегемония',
               'исторический_ревизионизм']

westphalianism = ['оон',
                  'великодержавность',
                  'статус',
                  'принцип_суверенный',
                  'международное_право',
                  'демократический_справедливый',
                  'международное_право_норма',
                  'суверенность']

# %%
security_concerns = ['национальная_безопасность',
                     'противовес',
                     'дестабилизация',
                     'нато',
                     'угроза',
                     'подменить_международное_право',
                     'порядок_основать', 
                     'однополярная',
                     'новый_мироустройство', 
                     'расширяться_восток',
                     'однополярный_модель', 
                     'однополярный', 
                     'военный_инфраструктура']

multipolarity = ['многополярный', 
                 'партнёрство', 
                 'сотрудничество', 
                 'полицентричный',
                 'формирование_многополярный', 
                 'формирование_полицентричного', 
                 'демократический_полицентричного',
                 'ооноцентричной']

# %%
concept_lists = [eurasianism, westphalianism, security_concerns, multipolarity]

# %% [markdown]
# ### president across time

# %%
#### slicing the data according to time era make data quite uneven
#transform each timeframe df in a list
era1 = pd.concat([df_president_1['phrased_lemma'], df_president_2['phrased_lemma']], ignore_index=True).tolist()
era2 = pd.concat([df_president_3['phrased_lemma'], df_president_4['phrased_lemma']], ignore_index=True).tolist()
print(len(era1))
print(len(era2))

# %%
##### slicing in 4 equal parts according to date column
# Sort the df_president DataFrame by the date column
df_president_sorted = df_president.sort_values('date')

# %%
# Calculate the number of rows in the DataFrame
num_rows = len(df_president_sorted)
num_rows
# Out:
# 1442

# %%
# Determine the approximate chunk size for each split
chunk_size = num_rows // 4
chunk_size
# Out:
# 360

# %%
# Perform the split using indexing and retrieve the individual pieces
df_president_1 = df_president_sorted.iloc[:chunk_size]
df_president_2 = df_president_sorted.iloc[chunk_size:2*chunk_size]
df_president_3 = df_president_sorted.iloc[2*chunk_size:3*chunk_size]
df_president_4 = df_president_sorted.iloc[3*chunk_size:]

# %%
# Print the sizes of the individual pieces (optional)
print("Size of df_president_1:", len(df_president_1))
print("Size of df_president_2:", len(df_president_2))
print("Size of df_president_3:", len(df_president_3))
print("Size of df_president_4:", len(df_president_4))
# Out:
# Size of df_president_1: 360
# Size of df_president_2: 360
# Size of df_president_3: 360
# Size of df_president_4: 362

# %%
## count target_word
word_count = 0
for doc in df_president_4['phrased_lemma']:
    if 'миропорядок' in doc:
        word_count += doc.count('миропорядок')

print(f"'миропорядок' appears {word_count} times in the 'phrased_lemma' column of the DataFrame.")
# Out:
# 'миропорядок' appears 35 times in the 'phrased_lemma' column of the DataFrame.

# %%
#transform each in list
#transform each timeframe df in a list
era1 = df_president_1['phrased_lemma'].tolist()
era2 = df_president_2['phrased_lemma'].tolist()
era3 = df_president_3['phrased_lemma'].tolist()
era4 = df_president_4['phrased_lemma'].tolist()

# %%
#create a list of eras

list_of_lists = []
list_of_lists.append(era1)
list_of_lists.append(era2)
list_of_lists.append(era3)
list_of_lists.append(era4)

# %% [markdown]
# #### 50 bootstraps

# %%
n_bootstraps = 50
target_word = 'миропорядок'
vector_size=100 
min_count=2 
sg=1 
hs=0 
negative=5 
window=30 
workers=4 
epochs=100

# %%
#print the progress for each run
def word_embedding(list_of_lists, target_word, eurasianism, westphalianism, security_concerns, multipolarism, 
                   n_bootstraps=n_bootstraps, vector_size=vector_size, min_count=min_count, sg=sg, 
                   hs=hs, negative=negative, window=window, workers=workers, epochs=epochs):
    
    scores = {}
    
    for j in range(len(list_of_lists)):
        era_scores = {}
        start_time = time.time()
        for k in range(n_bootstraps):
            sentence_samples = resample(list_of_lists[j])
            model = Word2Vec(
                sentence_samples,
                vector_size=vector_size, 
                min_count=min_count, 
                sg=sg, 
                hs=hs, 
                negative=negative, 
                window=window, 
                workers=workers,
                epochs=epochs
            )

            eurasianism_scores = []
            westphalianism_scores = []
            security_concerns_scores = []
            multipolarism_scores = []

            for word in eurasianism:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    eurasianism_scores.append(similarity_score)
                else:
                    eurasianism_scores.append('NA')

            for word in westphalianism:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    westphalianism_scores.append(similarity_score)
                else:
                    westphalianism_scores.append('NA')

            for word in security_concerns:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    security_concerns_scores.append(similarity_score)
                else:
                    security_concerns_scores.append('NA')

            for word in multipolarism:
                if word in model.wv:
                    similarity_score = model.wv.similarity(target_word, word)
                    multipolarism_scores.append(similarity_score)
                else:
                    multipolarism_scores.append('NA')

            era_scores[k] = {
                'eurasianism': eurasianism_scores,
                'westphalianism': westphalianism_scores,
                'security_concerns': security_concerns_scores,
                'multipolarism': multipolarism_scores
            }
            
            # Print progress for each run
            print("Finished with run %d out of %d for era %d" % (k+1, n_bootstraps, j+1))
            
        scores[j] = era_scores
        
        end_time = time.time()
        era = j+1
        print("Finished with era %d in %.2f seconds." % (era, end_time-start_time))
        
    print("*******Finished with all eras.*******")
    
    return scores

# %% [raw]
# #print the progress for each run
# def word_embedding(list_of_lists, target_word, eurasianism, westphalianism, security_concerns, multipolarity,
#                    n_bootstraps=n_bootstraps, vector_size=vector_size, min_count=min_count, sg=sg,
#                    hs=hs, negative=negative, window=window, workers=workers, epochs=epochs):
#
#     scores = {}
#
#     for j in range(len(list_of_lists)):
#         era_scores = {}
#         start_time = time.time()
#         for k in range(n_bootstraps):
#             sentence_samples = resample(list_of_lists[j])
#             model = Word2Vec(
#                 sentence_samples,
#                 vector_size=vector_size,
#                 min_count=min_count,
#                 sg=sg,
#                 hs=hs,
#                 negative=negative,
#                 window=window,
#                 workers=workers,
#                 epochs=epochs
#             )
#
#             eurasianism_scores = []
#             westphalianism_scores = []
#             security_concerns_scores = []
#             multipolarity_scores = []
#
#             for word in eurasianism:
#                 if 'миропорядок' in model.wv and word in model.wv: #If both words are in the vocabulary, it calculates the similarity score
#                     similarity_score = model.wv.similarity(target_word, word)
#                     eurasianism_scores.append(similarity_score)
#                 else:
#                     eurasianism_scores.append('NA')
#
#             for word in westphalianism:
#                 if 'миропорядок' in model.wv and word in model.wv:
#                     similarity_score = model.wv.similarity(target_word, word)
#                     westphalianism_scores.append(similarity_score)
#                 else:
#                     westphalianism_scores.append('NA')
#
#             for word in security_concerns:
#                 if 'миропорядок' in model.wv and word in model.wv:
#                     similarity_score = model.wv.similarity(target_word, word)
#                     security_concerns_scores.append(similarity_score)
#                 else:
#                     security_concerns_scores.append('NA')
#
#             for word in multipolarism:
#                 if 'миропорядок' in model.wv and word in model.wv:
#                     similarity_score = model.wv.similarity(target_word, word)
#                     multipolarity_scores.append(similarity_score)
#                 else:
#                     multipolarity_scores.append('NA')
#
#             era_scores[k] = {
#                 'eurasianism': eurasianism_scores,
#                 'westphalianism': westphalianism_scores,
#                 'security_concerns': security_concerns_scores,
#                 'multipolarism': multipolarity_scores
#             }
#
#             # Print progress for each run
#             print("Finished with run %d out of %d for era %d" % (k+1, n_bootstraps, j+1))
#
#         scores[j] = era_scores
#
#         end_time = time.time()
#         era = j+1
#         print("Finished with era %d in %.2f seconds." % (era, end_time-start_time))
#
#     print("*******Finished with all eras.*******")
#
#     return scores

# %%
scores = word_embedding(list_of_lists, target_word, eurasianism, westphalianism, security_concerns, multipolarity, 
               n_bootstraps = n_bootstraps, vector_size=vector_size, min_count=min_count, sg=sg, hs=hs, negative=negative, 
               window=window, workers=workers, epochs=epochs)

# %%
scores
# Out:
# {0: {0: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   1: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   2: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   3: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   4: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   5: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   6: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   7: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   8: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   9: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   10: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   11: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   12: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   13: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   14: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   15: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   16: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   17: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   18: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   19: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   20: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   21: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   22: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   23: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   24: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   25: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   26: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   27: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   28: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   29: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   30: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   31: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   32: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   33: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   34: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   35: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   36: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   37: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   38: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   39: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   40: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   41: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   42: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   43: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   44: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   45: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   46: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   47: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   48: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   49: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']}},
#  1: {0: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   1: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   2: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   3: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   4: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   5: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   6: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   7: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   8: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   9: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   10: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   11: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   12: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   13: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   14: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   15: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   16: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   17: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   18: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   19: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   20: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   21: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   22: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   23: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   24: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   25: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   26: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   27: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   28: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   29: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   30: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   31: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   32: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   33: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   34: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   35: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   36: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   37: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   38: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   39: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   40: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   41: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   42: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   43: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   44: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   45: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   46: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   47: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   48: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   49: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']}},
#  2: {0: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   1: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   2: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   3: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   4: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   5: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   6: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   7: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   8: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   9: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   10: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   11: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   12: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   13: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   14: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   15: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   16: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   17: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   18: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   19: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   20: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   21: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   22: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   23: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   24: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   25: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   26: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   27: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   28: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   29: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   30: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   31: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
# ...
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   7: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   8: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   9: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   10: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   11: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   12: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   13: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   14: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   15: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   16: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   17: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   18: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   19: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   20: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   21: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   22: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   23: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   24: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   25: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   26: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   27: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   28: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   29: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   30: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   31: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   32: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   33: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   34: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   35: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   36: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   37: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   38: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   39: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   40: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   41: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   42: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   43: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   44: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   45: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   46: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   47: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   48: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   49: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']}}}

# %%
# initialize empty dictionary to store the scores
stat_types = {}

# loop through each target word and its scores
for target_word, target_scores in scores.items():

    # initialize empty dictionary to store the scores for this target word
    target_stat_types = {}

    # loop through each era and its scores for this target word
    for era, era_scores in target_scores.items():

        # initialize empty dictionary to store the scores for this era
        era_stat_types = {}

        # loop through each statistical type and its score for this era
        for stat_type, score in era_scores.items():
            era_stat_types[stat_type] = score

        # add the scores for this era to the scores for this target word
        target_stat_types[era] = era_stat_types

    # add the scores for this target word to the overall dictionary of scores
    stat_types[target_word] = target_stat_types

# %%
stat_types
# Out:
# {0: {0: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   1: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': [0.44482204,
#     'NA',
#     0.31657496,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'security_concerns': [0.19294322,
#     'NA',
#     'NA',
#     0.4504428,
#     0.2261714,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.5471958, 'NA', 'NA', 'NA', 'NA']},
#   2: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.31882414, 'NA', 'NA'],
#    'westphalianism': [0.37194616,
#     'NA',
#     0.20502758,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.503491],
#    'security_concerns': [0.2953891,
#     'NA',
#     0.3526421,
#     0.42694965,
#     0.30283052,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.31043983, 0.552419, 'NA', 'NA', 'NA', 'NA']},
#   3: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   4: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.3019583, 'NA', 'NA'],
#    'westphalianism': [0.36560205,
#     'NA',
#     0.2919832,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.4395999],
#    'security_concerns': [0.24113417,
#     'NA',
#     0.3573594,
#     0.41639203,
#     0.26522323,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.42391652, 0.4966776, 'NA', 'NA', 'NA', 'NA']},
#   5: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   6: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.32179368, 'NA', 'NA'],
#    'westphalianism': [0.37534317,
#     'NA',
#     0.28599092,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.5397695],
#    'security_concerns': [0.32083848,
#     'NA',
#     0.40425208,
#     0.39983425,
#     0.27760035,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.32959884, 0.50747424, 'NA', 'NA', 'NA', 'NA']},
#   7: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   8: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA',
#     'NA',
#     0.17687689,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'security_concerns': [0.29315725,
#     'NA',
#     0.32945198,
#     0.468425,
#     0.38872045,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.3192914, 0.5883634, 'NA', 'NA', 'NA', 'NA']},
#   9: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.23494825, 'NA', 'NA'],
#    'westphalianism': [0.40412235,
#     'NA',
#     0.49591538,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.48089772],
#    'security_concerns': [0.24441752,
#     'NA',
#     'NA',
#     0.34590527,
#     0.2742184,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.31034628, 0.46007383, 'NA', 'NA', 'NA', 'NA']},
#   10: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   11: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   12: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   13: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.33633125, 'NA', 'NA'],
#    'westphalianism': [0.33151722,
#     'NA',
#     0.30341503,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.46923107],
#    'security_concerns': [0.171991,
#     'NA',
#     0.34111586,
#     0.40876836,
#     0.24490984,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.44150075, 'NA', 'NA', 'NA', 'NA']},
#   14: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.2997802, 'NA', 'NA'],
#    'westphalianism': [0.42454374,
#     'NA',
#     0.33185625,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.53324914],
#    'security_concerns': [0.29282537,
#     'NA',
#     'NA',
#     0.4082354,
#     0.28845617,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.47662666, 'NA', 'NA', 'NA', 'NA']},
#   15: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': [0.45367163,
#     'NA',
#     0.23253317,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'security_concerns': [0.26490667,
#     'NA',
#     0.2561268,
#     0.38290748,
#     0.23467892,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.3415219, 0.51997966, 'NA', 'NA', 'NA', 'NA']},
#   16: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': [0.45957175,
#     'NA',
#     0.51157445,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'security_concerns': [0.28916267,
#     'NA',
#     'NA',
#     0.4688362,
#     0.33665088,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.51297843, 'NA', 'NA', 'NA', 'NA']},
#   17: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.32030293, 'NA', 'NA'],
#    'westphalianism': [0.42768994,
#     'NA',
#     0.15602575,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.50983626],
#    'security_concerns': [0.25616014,
#     'NA',
#     0.33635393,
#     0.3840499,
#     0.30884692,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.32233912, 0.5688743, 'NA', 'NA', 'NA', 'NA']},
#   18: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   19: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.26900804, 'NA', 'NA'],
#    'westphalianism': [0.373537,
#     'NA',
#     0.4883416,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.48818764],
#    'security_concerns': [0.29082292,
#     'NA',
#     'NA',
#     0.42116946,
#     0.24857709,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.37431577, 0.44569674, 'NA', 'NA', 'NA', 'NA']},
#   20: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.31407228, 'NA', 'NA'],
#    'westphalianism': [0.4643088,
#     'NA',
#     0.29179075,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.50681096],
#    'security_concerns': [0.26791045,
#     'NA',
#     'NA',
#     0.3787406,
#     0.2811083,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.5219677, 'NA', 'NA', 'NA', 'NA']},
#   21: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   22: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.31754008, 'NA', 'NA'],
#    'westphalianism': [0.34780023,
#     'NA',
#     0.48842168,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.5028013],
#    'security_concerns': [0.23100598,
#     'NA',
#     'NA',
#     0.4314889,
#     0.21021245,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.46274653, 'NA', 'NA', 'NA', 'NA']},
#   23: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.32655776, 'NA', 'NA'],
#    'westphalianism': [0.36505914,
#     'NA',
#     0.23048688,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.50241387],
#    'security_concerns': [0.25532413,
#     'NA',
#     'NA',
#     0.41995642,
#     0.2571995,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.3702569, 0.4964619, 'NA', 'NA', 'NA', 'NA']},
#   24: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.28209358, 'NA', 'NA'],
#    'westphalianism': [0.37806115,
#     'NA',
#     0.21373203,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.50384253],
#    'security_concerns': [0.23926449,
#     'NA',
#     0.3716789,
#     0.4150088,
#     0.3270658,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.48662364, 'NA', 'NA', 'NA', 'NA']},
#   25: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   26: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.2475934, 'NA', 'NA'],
#    'westphalianism': [0.38408458,
#     'NA',
#     0.27268973,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.46417287],
#    'security_concerns': [0.3113655,
#     'NA',
#     0.30196032,
#     0.392565,
#     0.2598972,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.5153864, 'NA', 'NA', 'NA', 'NA']},
#   27: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.3209637, 'NA', 'NA'],
#    'westphalianism': [0.3986945,
#     'NA',
#     0.30414706,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.49054688],
#    'security_concerns': [0.2761903,
#     'NA',
#     'NA',
#     0.3636299,
#     0.22138427,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.43259197, 'NA', 'NA', 'NA', 'NA']},
#   28: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.29571015, 'NA', 'NA'],
#    'westphalianism': [0.37201494,
#     'NA',
#     0.31170923,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.52424026],
#    'security_concerns': [0.21001603,
#     'NA',
#     0.33422458,
#     0.39865208,
#     0.24225971,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.36359137, 0.51315856, 'NA', 'NA', 'NA', 'NA']},
#   29: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.30907694, 'NA', 'NA'],
#    'westphalianism': [0.40827504,
#     'NA',
#     0.23950022,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.5385416],
#    'security_concerns': [0.20062461,
#     'NA',
#     0.3849073,
#     0.40249094,
#     0.26327345,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.37910515, 0.5007835, 'NA', 'NA', 'NA', 'NA']},
#   30: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.2803981, 'NA', 'NA'],
#    'westphalianism': [0.3923033,
#     'NA',
#     0.41384196,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.47989783],
#    'security_concerns': [0.19806968,
#     'NA',
#     0.25007078,
#     0.41207448,
#     0.28708526,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.47136262, 'NA', 'NA', 'NA', 'NA']},
#   31: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   32: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.2683604, 'NA', 'NA'],
#    'westphalianism': [0.3975862,
#     'NA',
#     0.47241953,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.5394593],
#    'security_concerns': [0.27988774,
#     'NA',
#     0.2727449,
#     0.41115135,
#     0.31861573,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.34391624, 0.47581658, 'NA', 'NA', 'NA', 'NA']},
#   33: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.2887706, 'NA', 'NA'],
#    'westphalianism': [0.36183918,
#     'NA',
#     0.2521817,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.5250817],
#    'security_concerns': [0.2642004,
#     'NA',
#     'NA',
#     0.40778086,
#     0.25902244,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.5560569, 'NA', 'NA', 'NA', 'NA']},
#   34: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   35: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   36: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.29311174, 'NA', 'NA'],
#    'westphalianism': [0.37276068,
#     'NA',
#     0.28703704,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.5006049],
#    'security_concerns': [0.36992222,
#     'NA',
#     0.37088776,
#     0.49971792,
#     0.24972916,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.52110404, 'NA', 'NA', 'NA', 'NA']},
#   37: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   38: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.44729054, 'NA', 'NA'],
#    'westphalianism': [0.41164774,
#     'NA',
#     0.38253668,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'security_concerns': [0.27129638,
#     'NA',
#     0.35452834,
#     0.41201746,
#     0.28844106,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.4289406, 0.47509414, 'NA', 'NA', 'NA', 'NA']},
#   39: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   40: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   41: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.32744005, 'NA', 'NA'],
#    'westphalianism': [0.39382803,
#     'NA',
#     0.13228029,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.51838946],
#    'security_concerns': [0.25065988,
#     'NA',
#     0.2602668,
#     0.4014647,
#     0.34475282,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.5094519, 'NA', 'NA', 'NA', 'NA']},
#   42: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.32044235, 'NA', 'NA'],
#    'westphalianism': [0.4001528,
#     'NA',
#     0.13912743,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.44777095],
#    'security_concerns': [0.27405748,
#     'NA',
#     0.26368397,
#     0.32656118,
#     0.3105513,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.37490654, 0.5222657, 'NA', 'NA', 'NA', 'NA']},
#   43: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.2891348, 'NA', 'NA'],
#    'westphalianism': [0.39739648,
#     'NA',
#     0.33075264,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.5012542],
#    'security_concerns': [0.24357928,
#     'NA',
#     0.345845,
#     0.39717013,
#     0.28399256,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.35655937, 0.5160842, 'NA', 'NA', 'NA', 'NA']},
#   44: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   45: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   46: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA',
#     'NA',
#     0.21949309,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'security_concerns': [0.2762673,
#     'NA',
#     'NA',
#     0.49511862,
#     0.23106068,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 0.33155048, 0.64761853, 'NA', 'NA', 'NA', 'NA']},
#   47: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 0.31137198, 'NA', 'NA'],
#    'westphalianism': [0.39877093,
#     'NA',
#     0.35572633,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.5133989],
#    'security_concerns': [0.29197174,
#     'NA',
#     0.40426707,
#     0.4217652,
#     0.28500953,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 0.51206905, 'NA', 'NA', 'NA', 'NA']},
#   48: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']},
#   49: {'eurasianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'westphalianism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'],
#    'security_concerns': ['NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']}},
#  1: {0: {'eurasianism': [0.17594033,
#     'NA',
#     0.2248715,
#     'NA',
#     'NA',
#     0.11478457,
#     'NA',
#     'NA'],
#    'westphalianism': [0.37632716,
#     'NA',
#     0.05848167,
#     'NA',
#     0.3361973,
#     'NA',
#     'NA',
#     'NA',
#     0.33242428],
#    'security_concerns': [0.06840236,
#     0.3128404,
#     0.24151629,
#     0.39599276,
#     0.17438015,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.21656439,
#     0.3552477,
#     0.2985954,
#     0.34722248,
#     'NA',
#     'NA',
#     'NA']},
#   1: {'eurasianism': [0.2625988,
#     0.27252483,
#     0.31537032,
#     'NA',
#     'NA',
#     0.14208435,
#     'NA',
#     'NA'],
#    'westphalianism': [0.22211067,
#     'NA',
#     0.0037376897,
#     'NA',
#     0.31449407,
#     'NA',
#     'NA',
#     'NA',
#     0.20682538],
#    'security_concerns': [0.18885972,
#     0.15450682,
#     0.29671282,
#     0.23804389,
#     0.25693086,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.17453979,
#     0.28821316],
#    'multipolarism': [0.113698065,
#     0.26586246,
#     0.3161247,
#     0.2945827,
#     'NA',
#     'NA',
#     'NA']},
#   2: {'eurasianism': [0.28148365,
#     0.1076657,
#     0.19313756,
#     'NA',
#     'NA',
#     0.2027926,
#     'NA',
#     'NA'],
#    'westphalianism': [0.23307078,
#     'NA',
#     0.11013593,
#     'NA',
#     0.3604866,
#     'NA',
#     'NA',
#     'NA',
#     0.12821816],
#    'security_concerns': [0.23009779,
#     0.20839463,
#     'NA',
#     0.17458157,
#     0.26599637,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.16144155,
#     0.17315678,
#     0.06868067,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   3: {'eurasianism': [0.296302,
#     'NA',
#     0.33242112,
#     'NA',
#     'NA',
#     0.30336893,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34317884,
#     'NA',
#     0.08529121,
#     'NA',
#     0.26148742,
#     'NA',
#     'NA',
#     'NA',
#     0.25280118],
#    'security_concerns': [0.17455618,
#     0.20085888,
#     0.16141036,
#     0.2593251,
#     0.176453,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.31343913,
#     0.16957942,
#     0.17507109,
#     0.16746344,
#     'NA',
#     'NA',
#     'NA']},
#   4: {'eurasianism': [0.26003376,
#     'NA',
#     0.24063747,
#     'NA',
#     'NA',
#     0.18851636,
#     'NA',
#     'NA'],
#    'westphalianism': [0.36189708,
#     'NA',
#     0.057901647,
#     'NA',
#     0.3655678,
#     'NA',
#     'NA',
#     'NA',
#     0.34963468],
#    'security_concerns': [0.22792667,
#     0.19377613,
#     0.25398156,
#     0.32179868,
#     0.18714696,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.24118297,
#     0.29339814,
#     0.13284253,
#     0.24236773,
#     'NA',
#     'NA',
#     'NA']},
#   5: {'eurasianism': [0.13591605,
#     0.19606954,
#     0.24975656,
#     'NA',
#     'NA',
#     0.2770791,
#     'NA',
#     'NA'],
#    'westphalianism': [0.29465044,
#     'NA',
#     0.11922371,
#     'NA',
#     0.25692347,
#     'NA',
#     'NA',
#     'NA',
#     0.21792847],
#    'security_concerns': [0.24203901,
#     0.33930343,
#     0.13020243,
#     0.33664852,
#     0.25771272,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.34106544,
#     0.26127335],
#    'multipolarism': [0.19485755,
#     0.2541175,
#     0.27795434,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   6: {'eurasianism': [0.24298753,
#     0.17873827,
#     0.16632344,
#     'NA',
#     'NA',
#     0.10370666,
#     'NA',
#     'NA'],
#    'westphalianism': [0.23774771,
#     'NA',
#     0.3004004,
#     'NA',
#     0.3578941,
#     'NA',
#     'NA',
#     'NA',
#     0.10460423],
#    'security_concerns': [0.07289038,
#     0.25606743,
#     0.15666774,
#     0.22554007,
#     0.15325432,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.27900988,
#     0.35778123,
#     0.25695345,
#     0.3228178,
#     'NA',
#     'NA',
#     'NA']},
#   7: {'eurasianism': [0.27055565,
#     0.20488083,
#     0.20205463,
#     'NA',
#     'NA',
#     0.24149653,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2651537,
#     'NA',
#     0.23133786,
#     'NA',
#     0.38815853,
#     'NA',
#     'NA',
#     'NA',
#     0.16853185],
#    'security_concerns': [0.05230221,
#     0.2793494,
#     0.16986252,
#     0.25738862,
#     0.2863636,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.3412523,
#     0.35232368],
#    'multipolarism': [0.29488844,
#     0.33754036,
#     0.23498237,
#     0.25005823,
#     'NA',
#     'NA',
#     'NA']},
#   8: {'eurasianism': [0.24728881,
#     0.26766905,
#     0.36270007,
#     'NA',
#     'NA',
#     0.15748066,
#     'NA',
#     'NA'],
#    'westphalianism': [0.23018393,
#     'NA',
#     0.15791011,
#     'NA',
#     0.32251367,
#     'NA',
#     'NA',
#     'NA',
#     0.17689902],
#    'security_concerns': [0.17979944,
#     0.3207066,
#     0.16929892,
#     0.16473603,
#     0.15984017,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.34284583,
#     0.3079232],
#    'multipolarism': [0.27097744,
#     0.25188264,
#     0.27091974,
#     0.3011946,
#     'NA',
#     'NA',
#     'NA']},
#   9: {'eurasianism': [0.20920384,
#     'NA',
#     0.18777153,
#     'NA',
#     'NA',
#     0.20804025,
#     'NA',
#     'NA'],
#    'westphalianism': [0.22157457,
#     'NA',
#     0.17388144,
#     'NA',
#     0.2597799,
#     'NA',
#     'NA',
#     'NA',
#     0.23008117],
#    'security_concerns': [0.19306815,
#     0.36531213,
#     0.15053898,
#     0.28394577,
#     0.15412724,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.31011584,
#     0.30719388,
#     0.15927626,
#     0.22668439,
#     'NA',
#     'NA',
#     'NA']},
#   10: {'eurasianism': [0.22476868,
#     'NA',
#     0.20428061,
#     'NA',
#     'NA',
#     0.35105056,
#     'NA',
#     'NA'],
#    'westphalianism': [0.34272936,
#     'NA',
#     0.17857507,
#     'NA',
#     0.293462,
#     'NA',
#     'NA',
#     'NA',
#     0.2064742],
#    'security_concerns': [0.17322452,
#     0.20143208,
#     0.124760546,
#     0.24697694,
#     0.077641614,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.24334837,
#     0.35000157],
#    'multipolarism': [0.18733059,
#     0.23575403,
#     0.2374317,
#     0.16473985,
#     'NA',
#     'NA',
#     'NA']},
#   11: {'eurasianism': [0.25118572,
#     0.2683878,
#     0.32663697,
#     'NA',
#     'NA',
#     0.27664694,
#     'NA',
#     'NA'],
#    'westphalianism': [0.33310285,
#     'NA',
#     0.095982164,
#     'NA',
#     0.34817457,
#     'NA',
#     'NA',
#     'NA',
#     0.19650699],
#    'security_concerns': [0.2981583,
#     0.10863573,
#     0.18373209,
#     0.18985015,
#     0.28752944,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.2934296,
#     0.26939926],
#    'multipolarism': [0.27925667,
#     0.1754339,
#     0.2536977,
#     0.21808206,
#     'NA',
#     'NA',
#     'NA']},
#   12: {'eurasianism': [0.3004964,
#     'NA',
#     0.23376994,
#     'NA',
#     'NA',
#     0.1312528,
#     'NA',
#     'NA'],
#    'westphalianism': [0.28404126,
#     'NA',
#     0.11201519,
#     'NA',
#     0.32548934,
#     'NA',
#     'NA',
#     'NA',
#     0.21368438],
#    'security_concerns': [0.35807884,
#     0.17927964,
#     0.20445839,
#     0.26210424,
#     0.13477995,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.30110794,
#     0.36725774],
#    'multipolarism': [0.18858069,
#     0.25154796,
#     0.17713842,
#     0.24050346,
#     'NA',
#     'NA',
#     'NA']},
#   13: {'eurasianism': [0.28768137,
#     'NA',
#     0.22635652,
#     'NA',
#     'NA',
#     0.24904686,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2394076,
#     'NA',
#     0.16772926,
#     'NA',
#     0.32042542,
#     'NA',
#     'NA',
#     'NA',
#     0.18841366],
#    'security_concerns': [0.10548863,
#     0.2842161,
#     0.19450982,
#     0.17407496,
#     0.2105877,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.31457648,
#     0.15323691,
#     0.20769617,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   14: {'eurasianism': [0.263458,
#     0.10417972,
#     0.24452336,
#     'NA',
#     'NA',
#     0.2231083,
#     'NA',
#     'NA'],
#    'westphalianism': [0.25122958,
#     'NA',
#     0.2076315,
#     'NA',
#     0.3771712,
#     'NA',
#     'NA',
#     'NA',
#     0.26068062],
#    'security_concerns': [0.27398184,
#     0.26484942,
#     0.23236701,
#     0.33590406,
#     0.17590697,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.3572959,
#     0.24123447],
#    'multipolarism': [0.34698987,
#     0.2769755,
#     0.23041256,
#     0.25425932,
#     'NA',
#     'NA',
#     'NA']},
#   15: {'eurasianism': [0.37446213,
#     0.3072181,
#     0.3277394,
#     'NA',
#     'NA',
#     0.20694986,
#     'NA',
#     'NA'],
#    'westphalianism': [0.38584673,
#     'NA',
#     0.2827826,
#     'NA',
#     0.41030747,
#     'NA',
#     'NA',
#     'NA',
#     0.27394387],
#    'security_concerns': [0.27999067,
#     0.1586649,
#     0.14603059,
#     0.29126278,
#     0.22909145,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.33324522,
#     0.35742137],
#    'multipolarism': [0.24124138,
#     0.27295756,
#     0.1887883,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   16: {'eurasianism': [0.2618182,
#     'NA',
#     0.3185105,
#     'NA',
#     'NA',
#     0.32102433,
#     'NA',
#     'NA'],
#    'westphalianism': [0.25260037,
#     'NA',
#     0.20219485,
#     'NA',
#     0.23416807,
#     'NA',
#     'NA',
#     'NA',
#     0.19862115],
#    'security_concerns': [0.13903646,
#     0.2637981,
#     0.18159088,
#     0.28927258,
#     0.14341179,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.3503007,
#     0.36054486],
#    'multipolarism': [0.27499938,
#     0.08560228,
#     0.19011116,
#     0.19702163,
#     'NA',
#     'NA',
#     'NA']},
#   17: {'eurasianism': [0.19722456,
#     0.3337778,
#     0.19977567,
#     'NA',
#     'NA',
#     0.14529333,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2873637,
#     'NA',
#     0.091251925,
#     'NA',
#     0.21329002,
#     'NA',
#     'NA',
#     'NA',
#     0.29175887],
#    'security_concerns': [0.32063076,
#     0.2545192,
#     0.18838182,
#     0.31163102,
#     0.12582304,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.3296854,
#     0.25627548],
#    'multipolarism': [0.3323335,
#     0.11025063,
#     0.093986414,
#     0.07599204,
#     'NA',
#     'NA',
#     'NA']},
#   18: {'eurasianism': [0.19865671,
#     'NA',
#     0.3002632,
#     'NA',
#     'NA',
#     0.27347204,
#     'NA',
#     'NA'],
#    'westphalianism': [0.2421909,
#     'NA',
#     0.17205448,
#     'NA',
#     0.20628686,
#     'NA',
#     'NA',
#     'NA',
#     0.1928698],
#    'security_concerns': [0.27108148,
#     0.29111043,
#     0.047879633,
#     0.28669983,
#     0.1821303,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.24974743,
#     0.22374502],
#    'multipolarism': [0.16506296,
#     0.082941115,
#     0.22215499,
#     0.20800003,
#     'NA',
#     'NA',
#     'NA']},
#   19: {'eurasianism': [0.29334417,
#     0.2209738,
#     0.098272026,
#     'NA',
#     'NA',
#     0.11761733,
#     'NA',
#     'NA'],
#    'westphalianism': [0.36817947,
#     'NA',
#     0.1453402,
#     'NA',
#     0.2944956,
#     'NA',
#     'NA',
#     'NA',
#     0.1612584],
#    'security_concerns': [0.17737474,
#     0.15819374,
#     0.14045821,
#     0.28696176,
#     0.15045103,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.34518975,
#     0.26372528,
#     0.13900247,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   20: {'eurasianism': [0.28563064,
#     0.19700047,
#     0.30157998,
#     'NA',
#     'NA',
#     0.2713586,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3632552,
#     'NA',
#     0.24723849,
#     'NA',
#     0.18191545,
#     'NA',
#     'NA',
#     'NA',
#     0.24311809],
#    'security_concerns': [0.22945397,
#     0.4141106,
#     0.17463098,
#     0.33648747,
#     0.113912135,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.29673928,
#     0.15325333,
#     0.056571107,
#     0.20410761,
#     'NA',
#     'NA',
#     'NA']},
#   21: {'eurasianism': [0.23495986,
#     'NA',
#     0.3221692,
#     'NA',
#     'NA',
#     0.1363852,
#     'NA',
#     'NA'],
#    'westphalianism': [0.30810142,
#     'NA',
#     0.1642385,
#     'NA',
#     0.36854234,
#     'NA',
#     'NA',
#     'NA',
#     0.22922872],
#    'security_concerns': [0.26034266,
#     0.20317423,
#     0.26258588,
#     0.25792173,
#     0.2508654,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.31320286,
#     0.33216798],
#    'multipolarism': [0.22869486,
#     0.31176254,
#     0.188426,
#     0.17639156,
#     'NA',
#     'NA',
#     'NA']},
#   22: {'eurasianism': [0.18611571,
#     0.2760242,
#     0.18538688,
#     'NA',
#     'NA',
#     0.11908185,
#     'NA',
#     'NA'],
#    'westphalianism': [0.17883508,
#     'NA',
#     0.12402485,
#     'NA',
#     0.26683736,
#     'NA',
#     'NA',
#     'NA',
#     0.23028578],
#    'security_concerns': [0.23808028,
#     0.20883839,
#     0.20072587,
#     0.25187346,
#     0.23944573,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.37158263,
#     0.38038146],
#    'multipolarism': [0.29280233,
#     0.18245456,
#     0.10732691,
#     0.22645646,
#     'NA',
#     'NA',
#     'NA']},
#   23: {'eurasianism': [0.29916278,
#     'NA',
#     0.1723691,
#     'NA',
#     'NA',
#     0.034520306,
#     'NA',
#     'NA'],
#    'westphalianism': [0.21917993,
#     'NA',
#     0.095373936,
#     'NA',
#     0.16699205,
#     'NA',
#     'NA',
#     'NA',
#     0.24031866],
#    'security_concerns': [0.2807129,
#     0.30025673,
#     0.1996437,
#     0.20484546,
#     0.20732464,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.13162784,
#     0.27426076],
#    'multipolarism': [0.09274915,
#     0.05877844,
#     0.2674449,
#     0.26044264,
#     'NA',
#     'NA',
#     'NA']},
#   24: {'eurasianism': [0.25191125,
#     0.30649966,
#     0.19386388,
#     'NA',
#     'NA',
#     0.18528123,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3145001,
#     'NA',
#     0.100542046,
#     'NA',
#     0.2346551,
#     'NA',
#     'NA',
#     'NA',
#     0.14050674],
#    'security_concerns': [0.3170429,
#     0.2216256,
#     0.09658556,
#     0.2190814,
#     0.18026674,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.14911518,
#     0.1769241,
#     0.13186133,
#     0.25533444,
#     'NA',
#     'NA',
#     'NA']},
#   25: {'eurasianism': [0.26742426,
#     0.2666135,
#     0.22511174,
#     'NA',
#     'NA',
#     0.26235047,
#     'NA',
#     'NA'],
#    'westphalianism': [0.23395544,
#     'NA',
#     0.21040602,
#     'NA',
#     0.19512843,
#     'NA',
#     'NA',
#     'NA',
#     0.26243952],
#    'security_concerns': [0.28367922,
#     0.18142086,
#     0.12614039,
#     0.2642932,
#     0.14101033,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.27872062,
#     0.2571409],
#    'multipolarism': [0.23994753,
#     0.2539136,
#     0.17881896,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   26: {'eurasianism': [0.25426987,
#     0.27950218,
#     0.20252137,
#     'NA',
#     'NA',
#     0.12613162,
#     'NA',
#     'NA'],
#    'westphalianism': [0.14104456,
#     'NA',
#     0.1650752,
#     'NA',
#     0.3193352,
#     'NA',
#     'NA',
#     'NA',
#     0.25575584],
#    'security_concerns': [0.27207002,
#     0.19058108,
#     0.1566825,
#     0.26515478,
#     0.22529602,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.41044113,
#     0.24579613],
#    'multipolarism': [0.35700956,
#     0.19403943,
#     0.28048906,
#     0.28321487,
#     'NA',
#     'NA',
#     'NA']},
#   27: {'eurasianism': [0.2905856,
#     'NA',
#     0.18098734,
#     'NA',
#     'NA',
#     0.23940012,
#     'NA',
#     'NA'],
#    'westphalianism': [0.18002768,
#     'NA',
#     0.21097593,
#     'NA',
#     0.35685235,
#     'NA',
#     'NA',
#     'NA',
#     0.34967583],
#    'security_concerns': [0.29249018,
#     0.16795194,
#     0.12513149,
#     0.37371287,
#     0.20588772,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.2902354,
#     0.33770794],
#    'multipolarism': [0.29078785,
#     0.3662687,
#     0.24244416,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   28: {'eurasianism': [0.19809683,
#     'NA',
#     0.17115076,
#     'NA',
#     'NA',
#     0.28210452,
#     'NA',
#     'NA'],
#    'westphalianism': [0.26128927,
#     'NA',
#     0.23112272,
#     'NA',
#     0.28284627,
#     'NA',
#     'NA',
#     'NA',
#     0.13951994],
#    'security_concerns': [0.18084623,
#     0.25532493,
#     0.24896972,
#     0.2808305,
#     0.1891454,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.34288093,
#     0.2546839],
#    'multipolarism': [0.3259011,
#     0.2605559,
#     0.14874037,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   29: {'eurasianism': [0.4250474,
#     0.1162435,
#     0.24768665,
#     'NA',
#     'NA',
#     0.08289057,
#     'NA',
#     'NA'],
#    'westphalianism': [0.28146866,
#     'NA',
#     0.17759551,
#     'NA',
#     0.29655543,
#     'NA',
#     'NA',
#     'NA',
#     0.24708734],
#    'security_concerns': [0.3479664,
#     0.15479083,
#     0.12581609,
#     0.2760924,
#     0.23340744,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.24941033,
#     0.3161917],
#    'multipolarism': [0.20478833,
#     0.36228317,
#     0.20991382,
#     0.17607546,
#     'NA',
#     'NA',
#     'NA']},
#   30: {'eurasianism': [0.3158565,
#     0.24472511,
#     0.17312707,
#     'NA',
#     'NA',
#     0.18893999,
#     'NA',
#     'NA'],
#    'westphalianism': [0.39038658,
#     'NA',
#     0.09947033,
#     'NA',
#     0.19671503,
#     'NA',
#     'NA',
#     'NA',
#     0.08742179],
#    'security_concerns': [0.25638998,
#     0.3331624,
#     0.14089668,
#     0.281338,
#     0.14797981,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.36124966,
#     0.20825735],
#    'multipolarism': [0.2883749,
#     0.16097398,
#     0.1459527,
#     0.14519802,
#     'NA',
#     'NA',
#     'NA']},
#   31: {'eurasianism': [0.37381634,
#     'NA',
#     0.18223946,
#     'NA',
#     'NA',
#     0.16072455,
#     'NA',
#     'NA'],
#    'westphalianism': [0.28003383,
#     'NA',
#     0.15261468,
#     'NA',
#     0.38657248,
#     'NA',
#     'NA',
#     'NA',
#     0.22704284],
#    'security_concerns': [0.20882456,
#     0.07313184,
#     0.27597803,
#     0.28708506,
#     0.2781768,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.33656,
#     0.32473472],
#    'multipolarism': [0.26473424,
#     0.2769683,
#     0.12640412,
#     0.18931745,
#     'NA',
#     'NA',
#     'NA']},
#   32: {'eurasianism': [0.12755613,
#     0.25680497,
#     0.18063407,
#     'NA',
#     'NA',
#     0.21520758,
#     'NA',
#     'NA'],
#    'westphalianism': [0.24548054,
#     'NA',
#     -0.032108344,
#     'NA',
#     0.22550736,
#     'NA',
#     'NA',
#     'NA',
#     0.3212125],
#    'security_concerns': [0.24360247,
#     0.23495159,
#     0.16956492,
#     0.20325205,
#     0.263071,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.21505362,
#     0.33712795],
#    'multipolarism': [0.13301644,
#     0.14864674,
#     0.09747557,
#     0.14415757,
#     'NA',
#     'NA',
#     'NA']},
#   33: {'eurasianism': [0.20470946,
#     0.20442493,
#     0.13544643,
#     'NA',
#     'NA',
#     0.1367846,
#     'NA',
#     'NA'],
#    'westphalianism': [0.38326615,
#     'NA',
#     0.20804429,
#     'NA',
#     0.41320205,
#     'NA',
#     'NA',
#     'NA',
#     0.13953523],
#    'security_concerns': [0.22993438,
#     'NA',
#     0.08099408,
#     0.32619718,
#     0.098162346,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.38101584,
#     0.2974323,
#     0.1813207,
#     0.34511235,
#     'NA',
#     'NA',
#     'NA']},
#   34: {'eurasianism': [0.22092025,
#     0.20695303,
#     0.13733827,
#     'NA',
#     'NA',
#     0.13990709,
#     'NA',
#     'NA'],
#    'westphalianism': [0.22675344,
#     'NA',
#     0.16129643,
#     'NA',
#     0.25523132,
#     'NA',
#     'NA',
#     'NA',
#     0.09992528],
#    'security_concerns': [0.17765878,
#     0.2724651,
#     0.18462402,
#     0.2246653,
#     0.17841038,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.3705401,
#     0.3834053],
#    'multipolarism': [0.3489531,
#     0.11113379,
#     0.18153791,
#     0.15571615,
#     'NA',
#     'NA',
#     'NA']},
#   35: {'eurasianism': [0.23441143,
#     0.18526419,
#     0.3025101,
#     'NA',
#     'NA',
#     0.28169376,
#     'NA',
#     'NA'],
#    'westphalianism': [0.23100592,
#     'NA',
#     0.1765247,
#     'NA',
#     0.2689996,
#     'NA',
#     'NA',
#     'NA',
#     0.23771594],
#    'security_concerns': [0.20150644,
#     0.20036532,
#     0.1707155,
#     0.25660363,
#     0.25542077,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.33843932,
#     0.31460392],
#    'multipolarism': [0.25495863,
#     0.17089432,
#     0.1338302,
#     0.16120695,
#     'NA',
#     'NA',
#     'NA']},
#   36: {'eurasianism': [0.17690676,
#     0.21459922,
#     0.13641888,
#     'NA',
#     'NA',
#     0.05618951,
#     'NA',
#     'NA'],
#    'westphalianism': [0.13142131,
#     'NA',
#     0.16157617,
#     'NA',
#     0.18223731,
#     'NA',
#     'NA',
#     'NA',
#     0.24153873],
#    'security_concerns': [0.30435735,
#     0.19140786,
#     0.2460337,
#     0.25909963,
#     0.21177928,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.39579046,
#     0.21113059],
#    'multipolarism': [0.22101696,
#     0.032372497,
#     0.08729268,
#     0.19578083,
#     'NA',
#     'NA',
#     'NA']},
#   37: {'eurasianism': [0.241863,
#     0.17464134,
#     0.23367468,
#     'NA',
#     'NA',
#     0.17703013,
#     'NA',
#     'NA'],
#    'westphalianism': [0.19236533,
#     'NA',
#     0.081672534,
#     'NA',
#     0.338258,
#     'NA',
#     'NA',
#     'NA',
#     0.15774927],
#    'security_concerns': [0.13765097,
#     0.2466553,
#     0.097718835,
#     0.23511726,
#     0.22640063,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.23226714,
#     0.33399323,
#     0.33659816,
#     0.38259646,
#     'NA',
#     'NA',
#     'NA']},
#   38: {'eurasianism': [0.32291391,
#     'NA',
#     0.18447912,
#     'NA',
#     'NA',
#     0.13368335,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32874948,
#     'NA',
#     -0.023951393,
#     'NA',
#     0.3669899,
#     'NA',
#     'NA',
#     'NA',
#     0.13564597],
#    'security_concerns': [0.24160214,
#     'NA',
#     0.18814313,
#     0.3032375,
#     0.30525792,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.1834388,
#     0.37752753,
#     0.15046863,
#     0.26180086,
#     'NA',
#     'NA',
#     'NA']},
#   39: {'eurasianism': [0.2292228,
#     'NA',
#     0.434361,
#     'NA',
#     'NA',
#     0.11583477,
#     'NA',
#     'NA'],
#    'westphalianism': [0.36350033,
#     'NA',
#     0.123777114,
#     'NA',
#     0.3649377,
#     'NA',
#     'NA',
#     'NA',
#     0.20819375],
#    'security_concerns': [0.3134441,
#     0.24572808,
#     0.18915144,
#     0.28318566,
#     0.1648264,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.2064953,
#     0.2706727],
#    'multipolarism': [0.18388426,
#     0.37470397,
#     0.29162857,
#     0.3091432,
#     'NA',
#     'NA',
#     'NA']},
#   40: {'eurasianism': [0.29298154,
#     0.09108311,
#     0.280631,
#     'NA',
#     'NA',
#     0.21312615,
#     'NA',
#     'NA'],
#    'westphalianism': [0.28041863,
#     'NA',
#     0.29851404,
#     'NA',
#     0.46167836,
#     'NA',
#     'NA',
#     'NA',
#     0.18748863],
#    'security_concerns': [0.19654986,
#     0.12962575,
#     0.20717591,
#     0.27611977,
#     0.16791476,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.23692726,
#     0.35518467],
#    'multipolarism': [0.3410063,
#     0.32508308,
#     0.18781026,
#     0.16090904,
#     'NA',
#     'NA',
#     'NA']},
#   41: {'eurasianism': [0.2205426,
#     0.23803318,
#     0.29786998,
#     'NA',
#     'NA',
#     0.16280659,
#     'NA',
#     'NA'],
#    'westphalianism': [0.17570694,
#     'NA',
#     0.16876681,
#     'NA',
#     0.1894311,
#     'NA',
#     'NA',
#     'NA',
#     0.19778115],
#    'security_concerns': [0.18326002,
#     0.19699098,
#     0.23416284,
#     0.19665603,
#     0.26237816,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.28754288,
#     0.32643872],
#    'multipolarism': [0.19149199,
#     0.11806505,
#     0.18119884,
#     0.15275556,
#     'NA',
#     'NA',
#     'NA']},
#   42: {'eurasianism': [0.23803358,
#     'NA',
#     0.22572036,
#     'NA',
#     'NA',
#     0.22569048,
#     'NA',
#     'NA'],
#    'westphalianism': [0.1950561,
#     'NA',
#     -0.015146768,
#     'NA',
#     0.22933327,
#     'NA',
#     'NA',
#     'NA',
#     0.15901048],
#    'security_concerns': [0.20044611,
#     0.21694507,
#     0.1117935,
#     0.2477888,
#     0.274864,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.32527953,
#     0.25660285],
#    'multipolarism': [0.2983933,
#     0.026419062,
#     0.09969651,
#     0.17118683,
#     'NA',
#     'NA',
#     'NA']},
#   43: {'eurasianism': [0.2813996,
#     'NA',
#     0.26980367,
#     'NA',
#     'NA',
#     0.18240014,
#     'NA',
#     'NA'],
#    'westphalianism': [0.17877471,
#     'NA',
#     0.14511137,
#     'NA',
#     0.13886376,
#     'NA',
#     'NA',
#     'NA',
#     0.19984664],
#    'security_concerns': [0.15052584,
#     0.18830183,
#     0.22724514,
#     0.2094649,
#     0.15154456,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.36668828,
#     0.27448604],
#    'multipolarism': [0.28933063,
#     0.19758052,
#     0.12050775,
#     0.23733117,
#     'NA',
#     'NA',
#     'NA']},
#   44: {'eurasianism': [0.19132483,
#     'NA',
#     0.3148818,
#     'NA',
#     'NA',
#     0.12840495,
#     'NA',
#     'NA'],
#    'westphalianism': [0.3520895,
#     'NA',
#     0.1169219,
#     'NA',
#     0.39188918,
#     'NA',
#     'NA',
#     'NA',
#     0.2825582],
#    'security_concerns': [0.32438502,
#     0.18776177,
#     0.2323486,
#     0.29963621,
#     0.25412825,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.29562166,
#     0.40167466],
#    'multipolarism': [0.24219345,
#     0.29434806,
#     0.17898765,
#     0.2511408,
#     'NA',
#     'NA',
#     'NA']},
#   45: {'eurasianism': [0.19378248,
#     'NA',
#     0.24690795,
#     'NA',
#     'NA',
#     0.19270074,
#     'NA',
#     'NA'],
#    'westphalianism': [0.32025266,
#     'NA',
#     0.1398117,
#     'NA',
#     0.20831409,
#     'NA',
#     'NA',
#     'NA',
#     0.25992534],
#    'security_concerns': [0.16827926,
#     0.35367575,
#     0.29730448,
#     0.22538684,
#     0.21918276,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.46835092,
#     0.1617905],
#    'multipolarism': [0.36490008,
#     0.19854937,
#     0.11644056,
#     0.28713608,
#     'NA',
#     'NA',
#     'NA']},
#   46: {'eurasianism': [0.25888807,
#     0.21296585,
#     0.30383718,
#     'NA',
#     'NA',
#     0.058098234,
#     'NA',
#     'NA'],
#    'westphalianism': [0.23211497,
#     'NA',
#     0.19204825,
#     'NA',
#     0.2514521,
#     'NA',
#     'NA',
#     'NA',
#     0.20579126],
#    'security_concerns': [0.03778382,
#     0.07811734,
#     0.13943672,
#     0.22786193,
#     0.17514353,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.26792467,
#     0.16264814,
#     0.22849281,
#     0.1502198,
#     'NA',
#     'NA',
#     'NA']},
#   47: {'eurasianism': [0.17698742,
#     0.29177248,
#     0.18364127,
#     'NA',
#     'NA',
#     0.21459247,
#     'NA',
#     'NA'],
#    'westphalianism': [0.26482093,
#     'NA',
#     0.15110786,
#     'NA',
#     0.31490538,
#     'NA',
#     'NA',
#     'NA',
#     0.05862462],
#    'security_concerns': [0.25862786,
#     0.22849815,
#     0.19641767,
#     0.2431346,
#     0.24870537,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.2052059,
#     0.23492324,
#     0.12003944,
#     0.05357029,
#     'NA',
#     'NA',
#     'NA']},
#   48: {'eurasianism': [0.29191625,
#     'NA',
#     0.16979757,
#     'NA',
#     'NA',
#     0.11482864,
#     'NA',
#     'NA'],
#    'westphalianism': [0.35776228,
#     'NA',
#     0.2699456,
#     'NA',
#     0.38284823,
#     'NA',
#     'NA',
#     'NA',
#     0.09384439],
#    'security_concerns': [0.18117252,
#     0.2939981,
#     0.15875573,
#     0.197013,
#     0.12137897,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA'],
#    'multipolarism': [0.3899312,
#     0.16267453,
#     0.22957854,
#     0.27705425,
#     'NA',
#     'NA',
#     'NA']},
#   49: {'eurasianism': [0.28462598,
#     'NA',
#     0.36544138,
#     'NA',
#     'NA',
#     0.1436412,
#     'NA',
#     'NA'],
#    'westphalianism': [0.23972854,
#     'NA',
# ...
#     0.45824268,
#     'NA',
#     0.31526104,
#     0.3955537,
#     0.47437176],
#    'westphalianism': [0.28568113,
#     'NA',
#     0.28764877,
#     0.4398287,
#     0.48837447,
#     0.48466286,
#     0.33433154,
#     'NA',
#     0.29695863],
#    'security_concerns': [0.30376878,
#     0.2024089,
#     0.27271697,
#     0.22879751,
#     0.38607872,
#     'NA',
#     0.35266927,
#     'NA',
#     'NA',
#     'NA',
#     0.39181298,
#     0.3197362,
#     0.34342146],
#    'multipolarism': [0.4857211,
#     0.11839125,
#     0.20202203,
#     'NA',
#     0.46465883,
#     'NA',
#     'NA']},
#   24: {'eurasianism': [0.06938882,
#     0.29936802,
#     0.27234268,
#     0.24921183,
#     'NA',
#     0.2600755,
#     0.22666809,
#     'NA'],
#    'westphalianism': [0.3125831,
#     'NA',
#     0.108434394,
#     0.44449094,
#     0.4557021,
#     0.4879797,
#     0.41948467,
#     'NA',
#     0.27367914],
#    'security_concerns': [0.19879876,
#     'NA',
#     0.08516558,
#     0.18291372,
#     0.31909248,
#     'NA',
#     0.3496601,
#     'NA',
#     'NA',
#     'NA',
#     0.35259867,
#     'NA',
#     0.23423988],
#    'multipolarism': [0.5143426,
#     0.12974232,
#     0.18909608,
#     'NA',
#     0.47663462,
#     'NA',
#     'NA']},
#   25: {'eurasianism': [0.14343323,
#     0.17753457,
#     0.14061323,
#     0.40735593,
#     'NA',
#     0.35838777,
#     0.3709703,
#     0.30895397],
#    'westphalianism': [0.40486234,
#     'NA',
#     0.07811483,
#     0.40419477,
#     0.44311324,
#     0.39355668,
#     0.33019525,
#     'NA',
#     0.39387378],
#    'security_concerns': [0.19870031,
#     0.114803,
#     0.13589767,
#     0.22429782,
#     0.40849227,
#     'NA',
#     0.30668405,
#     'NA',
#     'NA',
#     'NA',
#     0.35490307,
#     0.38779086,
#     0.25634757],
#    'multipolarism': [0.44800678,
#     0.25172353,
#     0.24641414,
#     'NA',
#     0.41998634,
#     'NA',
#     'NA']},
#   26: {'eurasianism': [0.16634066,
#     0.14879704,
#     0.14897244,
#     0.32623476,
#     'NA',
#     0.341061,
#     0.30756816,
#     0.4486183],
#    'westphalianism': [0.28137714,
#     'NA',
#     0.15571868,
#     0.41369006,
#     0.42376897,
#     0.4549452,
#     0.35179403,
#     'NA',
#     0.40271658],
#    'security_concerns': [0.20647708,
#     0.11317106,
#     0.13875563,
#     0.31290352,
#     0.3131133,
#     'NA',
#     0.34966406,
#     'NA',
#     'NA',
#     'NA',
#     0.41056877,
#     0.31012052,
#     0.22575092],
#    'multipolarism': [0.45370516,
#     0.211369,
#     0.22986262,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   27: {'eurasianism': [0.24756499,
#     0.26967692,
#     0.20912425,
#     0.42953014,
#     'NA',
#     0.3346969,
#     0.30335534,
#     'NA'],
#    'westphalianism': [0.28724724,
#     'NA',
#     0.0898127,
#     0.40150112,
#     0.41857532,
#     0.42676935,
#     'NA',
#     'NA',
#     0.31715068],
#    'security_concerns': [0.18172115,
#     0.051625762,
#     0.089786395,
#     0.27902618,
#     0.27395535,
#     'NA',
#     0.41555744,
#     'NA',
#     'NA',
#     'NA',
#     0.4077483,
#     0.4409889,
#     0.24943039],
#    'multipolarism': [0.4222592,
#     0.21387246,
#     0.17210001,
#     'NA',
#     0.4980044,
#     'NA',
#     'NA']},
#   28: {'eurasianism': [0.2061991,
#     0.23775524,
#     0.19425821,
#     0.41842645,
#     'NA',
#     0.43514282,
#     0.38956925,
#     0.48576558],
#    'westphalianism': [0.2629402,
#     'NA',
#     0.17099935,
#     'NA',
#     0.4519771,
#     'NA',
#     'NA',
#     'NA',
#     0.37838897],
#    'security_concerns': [0.11811651,
#     0.020659877,
#     0.14492165,
#     0.2751087,
#     0.2244217,
#     'NA',
#     0.43591446,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.5220362,
#     0.31054303],
#    'multipolarism': [0.37341297,
#     0.20825984,
#     0.09125358,
#     'NA',
#     0.40504548,
#     'NA',
#     'NA']},
#   29: {'eurasianism': [0.19095688,
#     0.17800033,
#     0.2967324,
#     0.3655547,
#     'NA',
#     0.4273154,
#     0.27272338,
#     0.41218245],
#    'westphalianism': [0.37695974,
#     'NA',
#     0.09257496,
#     0.3407904,
#     0.44918457,
#     0.4098797,
#     0.26343864,
#     'NA',
#     0.24040277],
#    'security_concerns': [0.22063339,
#     0.095761485,
#     0.11742456,
#     0.23237945,
#     0.3244411,
#     'NA',
#     0.5093242,
#     'NA',
#     'NA',
#     'NA',
#     0.41628343,
#     0.538875,
#     0.16158329],
#    'multipolarism': [0.49050328,
#     0.021736704,
#     0.17097881,
#     'NA',
#     0.51688325,
#     'NA',
#     'NA']},
#   30: {'eurasianism': [0.26815405,
#     0.25618815,
#     0.18020815,
#     0.44484183,
#     'NA',
#     0.38849586,
#     0.24709192,
#     0.49932703],
#    'westphalianism': [0.32214236,
#     'NA',
#     0.21289465,
#     'NA',
#     0.38142172,
#     'NA',
#     'NA',
#     'NA',
#     0.29775694],
#    'security_concerns': [0.30177355,
#     0.20584512,
#     0.16011448,
#     0.2538231,
#     0.36864725,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.332113],
#    'multipolarism': [0.41250774,
#     0.09695217,
#     0.10288681,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   31: {'eurasianism': [0.16226405,
#     0.2474832,
#     0.12101272,
#     0.3982273,
#     'NA',
#     0.32601842,
#     0.3734897,
#     0.42085487],
#    'westphalianism': [0.3541147,
#     'NA',
#     0.02601919,
#     0.41163307,
#     0.47201008,
#     0.5460269,
#     'NA',
#     'NA',
#     0.25670168],
#    'security_concerns': [0.25567088,
#     'NA',
#     0.20098643,
#     0.28271323,
#     0.37522528,
#     'NA',
#     0.281531,
#     'NA',
#     'NA',
#     'NA',
#     0.21627058,
#     0.43374735,
#     0.21236293],
#    'multipolarism': [0.566299,
#     0.142523,
#     0.14397657,
#     'NA',
#     0.44807723,
#     'NA',
#     'NA']},
#   32: {'eurasianism': [0.098434344,
#     0.13019705,
#     0.21307586,
#     0.33350727,
#     'NA',
#     0.32667112,
#     0.25230333,
#     0.46023163],
#    'westphalianism': [0.3476646,
#     'NA',
#     0.063379176,
#     'NA',
#     0.34033722,
#     'NA',
#     'NA',
#     'NA',
#     0.24164867],
#    'security_concerns': [0.20380455,
#     0.1928276,
#     0.2956065,
#     0.2949422,
#     0.31728652,
#     'NA',
#     0.3810066,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.54165643,
#     0.28858116],
#    'multipolarism': [0.34562442,
#     0.044561245,
#     0.15909094,
#     'NA',
#     0.48844558,
#     'NA',
#     'NA']},
#   33: {'eurasianism': [0.21881203,
#     0.14202386,
#     0.23093207,
#     0.2805729,
#     'NA',
#     0.33774042,
#     0.36395654,
#     0.42363602],
#    'westphalianism': [0.40075776,
#     'NA',
#     0.07087654,
#     0.30604592,
#     0.43949798,
#     0.47130278,
#     0.27776995,
#     'NA',
#     0.2988842],
#    'security_concerns': [0.30771565,
#     0.26734722,
#     0.21382032,
#     0.31470078,
#     0.38517222,
#     'NA',
#     0.32194895,
#     'NA',
#     'NA',
#     'NA',
#     0.3195361,
#     0.3107304,
#     0.2561406],
#    'multipolarism': [0.49083707,
#     0.17028888,
#     0.2676481,
#     'NA',
#     0.44476798,
#     'NA',
#     'NA']},
#   34: {'eurasianism': [0.16628218,
#     0.26257983,
#     0.21227314,
#     0.3856407,
#     'NA',
#     0.43573427,
#     0.29587477,
#     0.42780152],
#    'westphalianism': [0.36647835,
#     'NA',
#     0.023851179,
#     0.38146147,
#     0.3536318,
#     0.46066624,
#     'NA',
#     'NA',
#     0.23763894],
#    'security_concerns': [0.24483804,
#     0.16103354,
#     0.20528677,
#     0.29879993,
#     0.32078415,
#     'NA',
#     0.4047941,
#     'NA',
#     'NA',
#     'NA',
#     0.3542123,
#     0.53948915,
#     0.30669272],
#    'multipolarism': [0.5048222,
#     0.14852187,
#     0.17440084,
#     'NA',
#     0.4685973,
#     'NA',
#     'NA']},
#   35: {'eurasianism': [0.22280249,
#     0.08892713,
#     0.29780263,
#     0.33563533,
#     'NA',
#     0.30543843,
#     0.36479726,
#     'NA'],
#    'westphalianism': [0.30317703,
#     'NA',
#     0.022972936,
#     0.44564453,
#     0.50325215,
#     0.47189993,
#     0.28724468,
#     'NA',
#     0.32542163],
#    'security_concerns': [0.21620373,
#     0.113857396,
#     0.12572978,
#     0.18393661,
#     0.28437233,
#     'NA',
#     0.30714616,
#     'NA',
#     'NA',
#     'NA',
#     0.22291182,
#     0.48951223,
#     0.32187724],
#    'multipolarism': [0.4864877,
#     0.21490864,
#     0.19091855,
#     'NA',
#     0.44169554,
#     'NA',
#     'NA']},
#   36: {'eurasianism': [0.21863475,
#     0.11137176,
#     0.28957805,
#     0.38534135,
#     'NA',
#     0.46220928,
#     0.33342436,
#     0.39826012],
#    'westphalianism': [0.3834932,
#     'NA',
#     -0.023125006,
#     0.50476766,
#     0.36235285,
#     0.4371459,
#     0.21616541,
#     'NA',
#     0.24614465],
#    'security_concerns': [0.051502164,
#     0.08620569,
#     0.17554592,
#     0.17306262,
#     0.35813996,
#     'NA',
#     0.38599864,
#     'NA',
#     'NA',
#     'NA',
#     0.33974704,
#     0.4772335,
#     0.17556216],
#    'multipolarism': [0.4257123,
#     0.083195314,
#     0.16050436,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   37: {'eurasianism': [0.2405102,
#     0.16733393,
#     0.24510542,
#     0.37054446,
#     'NA',
#     0.36778867,
#     0.29404446,
#     0.501269],
#    'westphalianism': [0.27471384,
#     'NA',
#     0.035324275,
#     0.3448121,
#     0.45945477,
#     0.43241197,
#     'NA',
#     'NA',
#     0.36796924],
#    'security_concerns': [0.26231727,
#     'NA',
#     -0.06394002,
#     0.38746423,
#     0.2936759,
#     'NA',
#     0.3432383,
#     'NA',
#     'NA',
#     'NA',
#     0.319059,
#     0.4201103,
#     0.1966573],
#    'multipolarism': [0.3902714,
#     0.20494013,
#     0.16100992,
#     'NA',
#     0.47281253,
#     'NA',
#     'NA']},
#   38: {'eurasianism': [0.29897553,
#     0.09446156,
#     0.2517325,
#     0.38227725,
#     'NA',
#     0.39942756,
#     0.25660962,
#     'NA'],
#    'westphalianism': [0.34099355,
#     'NA',
#     0.10038627,
#     0.30728868,
#     0.46079117,
#     0.41082737,
#     0.23890397,
#     'NA',
#     0.3895142],
#    'security_concerns': [0.28067023,
#     'NA',
#     0.046829093,
#     0.38917115,
#     0.31428057,
#     'NA',
#     0.3801854,
#     'NA',
#     'NA',
#     'NA',
#     0.27672577,
#     0.5200431,
#     0.2498799],
#    'multipolarism': [0.46998936,
#     0.12745908,
#     0.21910256,
#     'NA',
#     0.5166077,
#     'NA',
#     'NA']},
#   39: {'eurasianism': [0.18228447,
#     0.11655327,
#     0.3498257,
#     0.30682826,
#     'NA',
#     0.24298614,
#     0.29052874,
#     0.36689338],
#    'westphalianism': [0.34131533,
#     'NA',
#     0.11328438,
#     0.3847231,
#     0.47236496,
#     0.5222451,
#     'NA',
#     'NA',
#     0.3226096],
#    'security_concerns': [0.12955569,
#     0.22292683,
#     0.25015026,
#     0.20213003,
#     0.38197693,
#     'NA',
#     0.21830443,
#     'NA',
#     'NA',
#     'NA',
#     0.3402941,
#     0.31667274,
#     0.32184845],
#    'multipolarism': [0.5086378,
#     0.09469142,
#     0.16124736,
#     'NA',
#     0.48404416,
#     'NA',
#     'NA']},
#   40: {'eurasianism': [0.2209335,
#     0.09413725,
#     0.22059585,
#     0.41012618,
#     'NA',
#     0.37280074,
#     0.4125311,
#     'NA'],
#    'westphalianism': [0.37729323,
#     'NA',
#     0.00486794,
#     0.406155,
#     0.42491588,
#     0.49743205,
#     0.35401872,
#     'NA',
#     0.28324765],
#    'security_concerns': [0.20892599,
#     0.1259457,
#     0.1878416,
#     0.31466633,
#     0.35775122,
#     'NA',
#     0.4339249,
#     'NA',
#     'NA',
#     'NA',
#     0.37459877,
#     0.46210787,
#     0.25444865],
#    'multipolarism': [0.42061764,
#     0.15925415,
#     0.18556604,
#     'NA',
#     0.50622153,
#     'NA',
#     'NA']},
#   41: {'eurasianism': [0.25650853,
#     0.1170514,
#     0.39283392,
#     0.36790076,
#     'NA',
#     0.39205766,
#     0.43129236,
#     'NA'],
#    'westphalianism': [0.34541473,
#     'NA',
#     0.10303361,
#     0.42739865,
#     0.40808722,
#     0.4374965,
#     0.25034374,
#     'NA',
#     0.39734778],
#    'security_concerns': [0.19147463,
#     0.0687221,
#     0.08876524,
#     0.32100195,
#     0.3641488,
#     'NA',
#     0.35066414,
#     'NA',
#     'NA',
#     'NA',
#     0.32791242,
#     0.45707402,
#     0.35393983],
#    'multipolarism': [0.45720622,
#     0.22470449,
#     0.15048845,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   42: {'eurasianism': [0.23311287,
#     0.12632868,
#     0.1813498,
#     0.42149833,
#     'NA',
#     0.40262362,
#     0.22854826,
#     0.33759204],
#    'westphalianism': [0.36895356,
#     'NA',
#     0.098268904,
#     0.4328676,
#     0.4104884,
#     0.48699543,
#     0.4400218,
#     'NA',
#     0.37987354],
#    'security_concerns': [0.17396258,
#     'NA',
#     0.092846155,
#     0.19529977,
#     0.42170477,
#     'NA',
#     0.33536848,
#     'NA',
#     'NA',
#     'NA',
#     0.3110026,
#     0.5761133,
#     0.20157252],
#    'multipolarism': [0.48904157,
#     0.14530121,
#     0.20067845,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   43: {'eurasianism': [0.20740259,
#     0.15779637,
#     0.21108417,
#     0.38280883,
#     'NA',
#     0.34413755,
#     0.27162454,
#     0.39631906],
#    'westphalianism': [0.2696358,
#     'NA',
#     0.019890685,
#     'NA',
#     0.4219168,
#     'NA',
#     0.35524544,
#     'NA',
#     0.25274733],
#    'security_concerns': [0.38669705,
#     'NA',
#     0.078862764,
#     0.28650272,
#     0.37871253,
#     'NA',
#     0.27915514,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.4856424,
#     0.23453724],
#    'multipolarism': [0.33188796,
#     0.24699047,
#     0.19823967,
#     'NA',
#     0.48929915,
#     'NA',
#     'NA']},
#   44: {'eurasianism': [0.20531848,
#     0.13362688,
#     0.23422578,
#     0.35472488,
#     'NA',
#     0.36081937,
#     0.25926706,
#     0.3424296],
#    'westphalianism': [0.40267143,
#     'NA',
#     0.020705257,
#     0.43229482,
#     0.36412045,
#     0.39603156,
#     0.34276018,
#     'NA',
#     0.2904465],
#    'security_concerns': [0.25596786,
#     0.11503354,
#     0.14365155,
#     0.23815678,
#     0.3057702,
#     'NA',
#     0.3435518,
#     'NA',
#     'NA',
#     'NA',
#     0.30103338,
#     0.5165152,
#     0.3370106],
#    'multipolarism': [0.39412132,
#     0.062006906,
#     0.1230822,
#     'NA',
#     0.4578143,
#     'NA',
#     'NA']},
#   45: {'eurasianism': [0.098779954,
#     0.16605239,
#     0.24225135,
#     0.3726623,
#     'NA',
#     0.2965378,
#     0.34720567,
#     0.48349077],
#    'westphalianism': [0.30137715,
#     'NA',
#     0.1680533,
#     0.38668588,
#     0.4717928,
#     0.4460742,
#     'NA',
#     'NA',
#     0.39340073],
#    'security_concerns': [0.29972637,
#     0.16716811,
#     0.19590023,
#     0.25687364,
#     0.33317092,
#     'NA',
#     0.2860993,
#     'NA',
#     'NA',
#     'NA',
#     0.29960188,
#     0.44278687,
#     0.3251322],
#    'multipolarism': [0.4552499,
#     0.20054069,
#     0.1741599,
#     'NA',
#     0.5121012,
#     'NA',
#     'NA']},
#   46: {'eurasianism': [0.14473815,
#     0.18907356,
#     0.3302017,
#     0.24697213,
#     'NA',
#     0.37129357,
#     0.34738857,
#     0.4338123],
#    'westphalianism': [0.25378248,
#     'NA',
#     0.04334937,
#     0.3363063,
#     0.34953597,
#     0.4441103,
#     0.33171126,
#     'NA',
#     0.25146428],
#    'security_concerns': [0.28030103,
#     0.15087773,
#     0.19989847,
#     0.28689647,
#     0.31869155,
#     'NA',
#     0.3302997,
#     'NA',
#     'NA',
#     'NA',
#     0.34544516,
#     'NA',
#     0.22494027],
#    'multipolarism': [0.44643, 0.35104474, 0.18120071, 'NA', 'NA', 'NA', 'NA']},
#   47: {'eurasianism': [0.2639166,
#     0.15269428,
#     0.20072968,
#     0.3535685,
#     'NA',
#     0.34464756,
#     0.2438284,
#     'NA'],
#    'westphalianism': [0.32762426,
#     'NA',
#     0.049693342,
#     'NA',
#     0.3225439,
#     'NA',
#     'NA',
#     'NA',
#     0.2921092],
#    'security_concerns': [0.26619402,
#     0.11666837,
#     0.098294035,
#     0.27759603,
#     0.29036576,
#     'NA',
#     0.41414997,
#     'NA',
#     'NA',
#     'NA',
#     'NA',
#     0.50640315,
#     0.27301806],
#    'multipolarism': [0.47489324,
#     0.15497725,
#     0.18524532,
#     'NA',
#     0.43666267,
#     'NA',
#     'NA']},
#   48: {'eurasianism': [0.17796701,
#     0.11071602,
#     0.30701086,
#     0.31744015,
#     'NA',
#     0.34457678,
#     0.28004643,
#     'NA'],
#    'westphalianism': [0.36761522,
#     'NA',
#     0.13667956,
#     0.3821565,
#     0.45467713,
#     0.45598507,
#     0.24905483,
#     'NA',
#     0.3276975],
#    'security_concerns': [0.15982525,
#     0.11998378,
#     0.21121822,
#     0.24763557,
#     0.3071834,
#     'NA',
#     0.25383446,
#     'NA',
#     'NA',
#     'NA',
#     0.27062407,
#     0.504053,
#     0.25109777],
#    'multipolarism': [0.43637776,
#     0.14666112,
#     0.029175175,
#     'NA',
#     'NA',
#     'NA',
#     'NA']},
#   49: {'eurasianism': [0.055087186,
#     0.12839752,
#     0.19401973,
#     0.33547285,
#     'NA',
#     0.23597603,
#     0.2973368,
#     0.422321],
#    'westphalianism': [0.35322312,
#     'NA',
#     0.075065345,
#     0.37766632,
#     0.47195294,
#     0.43387067,
#     'NA',
#     'NA',
#     0.31065527],
#    'security_concerns': [0.25031322,
#     'NA',
#     0.22867338,
#     0.26187277,
#     0.34514508,
#     'NA',
#     0.2990274,
#     'NA',
#     'NA',
#     'NA',
#     0.34619674,
#     0.30644915,
#     0.31593445],
#    'multipolarism': [0.48715368,
#     0.14869973,
#     0.08398423,
#     'NA',
#     0.48136783,
#     'NA',
#     'NA']}}}

# %%
### Saving the model
with open('models/naive_model_por_50_bootstrap.pkl', 'wb') as f:
    pickle.dump(stat_types, f)

# %%
### Loading the model
with open('models/naive_model_por_50_bootstrap.pkl', 'rb') as f:
    stat_types = pickle.load(f)

# %%
means_wCI = []

# %%
## calculate means for nonNA vectors and CI
for era in stat_types:
    stats = []
    for boostrap in stat_types[era]:
        for topic in stat_types[era][boostrap]:
            scores = stat_types[era][boostrap][topic]
            non_na_scores = [score for score in scores if score != 'NA' and score is not None] # filter out None values
            test = np.asarray(non_na_scores)
            if len(test) > 0: # check if there are any non-NA values
                test_mean = test.mean()
                test_error = 1.95 * (test.std() / math.sqrt(len(non_na_scores)))
                test_ci = (test_mean - test_error, test_mean + test_error)
                test_stats = test_mean, test_ci
                stats.append(test_stats)
    means_wCI.append(stats)

# %%
means_wCI 
#The output of the code would be a list of statistics: mean and CI
# Out:
# [[(0.3806985, (0.292281230086971, 0.46911577404053145)),
#   (0.28985247, (0.16110006121144893, 0.41860487910761235)),
#   (0.5471958, (0.5471957921981812, 0.5471957921981812)),
#   (0.31882414, (0.3188241422176361, 0.3188241422176361)),
#   (0.3601549, (0.2226545368180111, 0.49765525713111614)),
#   (0.34445286, (0.2932944822125137, 0.3956112337298691)),
#   (0.43142942, (0.2646019236164938, 0.598256908265983)),
#   (0.2598975, (0.20246846834110527, 0.31732653221202584)),
#   (0.24799268, (0.13558405674993992, 0.36040130220353606)),
#   (0.28033617, (0.19268759865967883, 0.36798474411757337)),
#   (0.31294462, (0.1726713601499796, 0.4532178815454244)),
#   (0.25629288, (0.18968996409173572, 0.3228957950711671)),
#   (0.3391237, (0.26087568776812914, 0.41737170440945265)),
#   (0.25838393, (0.19189626462757586, 0.3248715948313475)),
#   (0.20407134, (0.01141362541885571, 0.39672906047134204)),
#   (0.23837301, (0.15278163769501385, 0.3239643850062496)),
#   (0.33707228, (0.2349080085207161, 0.4392365575383964)),
#   (0.29420152, (0.26618656791469664, 0.3222164782164374)),
#   (0.30030137, (0.11954795792698861, 0.4810547880828381))]]

# %%
# define the file path
file_path = "models/means_wCI_por_50_bootstrap.pkl"

# save the object to file
with open(file_path, 'wb') as f:
    pickle.dump(means_wCI, f)

# %% [markdown]
# ##### plot each concept cos sim evolution over time

# %%
# load the object from file
with open("models/means_wCI_por_50_bootstrap.pkl", 'rb') as f:
    means_wCI = pickle.load(f)

# %% [markdown]
# ##### eurasianism

# %%
eurasianism_means = [era[0][0] for era in means_wCI]

# %%
eurasianism_means
# Out:
# [0.3806985, 0.17186546, 0.27527285, 0.3196349]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(eurasianism_means, marker="o", markersize=10, linewidth=2)
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'eurasianism' - 'word order' Cosine similarity President of Russia")
plt.ylim(0.0, 1.0)
#plt.savefig("figures/sc_por_eurasianism_50.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### westphalianism

# %%
westphalianism_means = [era[1][0] for era in means_wCI]

# %%
westphalianism_means
# Out:
# [0.28985247, 0.2758576, 0.3168518, 0.28630668]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(westphalianism_means, marker="o", markersize=10, linewidth=2,color='purple')
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'westphalianism' - 'word order' Cosine similarity President of Russia")
plt.ylim(0.0, 1.0)
#plt.savefig("figures/sc_por_westphalianism_50.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### security_concerns

# %%
sec_con_means = [era[2][0] for era in means_wCI]

# %%
sec_con_means
# Out:
# [0.5471958, 0.2386264, 0.31323734, 0.28014842]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(sec_con_means, marker="o", markersize=10, linewidth=2,color='green')
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'security concerns' - 'word order' Cosine similarity President of Russia")
plt.ylim(0.0, 1.0)
#plt.savefig("figures/sc_por_security_concerns_50.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### multipolarty

# %%
multipolarity_means = [era[3][0] for era in means_wCI]

# %%
multipolarity_means
# Out:
# [0.31882414, 0.30440748, 0.38391948, 0.35611513]

# %%
# Define x-axis labels
x_labels = ["2004-2008", "2008-2012", "2012-2018", "2018-2023"]
y_limits = [0.2, 0.5]
# Plot cosine similarity over time
plt.plot(multipolarity_means, marker="o", markersize=10, linewidth=2,color='red')
plt.xticks(range(len(x_labels)), x_labels)
plt.xlabel("Era")
plt.ylabel("Cosine similarity")
plt.title("'multipolarity' - 'word order' Cosine similarity President of Russia")
plt.ylim(0.0, 1.0)
#plt.savefig("figures/sc_por_multipolarity_50.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### lavrov MID across time

# %%
print(len(df_lavrov_1))
print(len(df_lavrov_2))
print(len(df_lavrov_3))
print(len(df_lavrov_4))
# Out:
# 992
# 899
# 1822
# 1494
